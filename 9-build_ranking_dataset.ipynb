# %%
#!/usr/bin/env python

import os
import pandas as pd
import numpy as np
from datetime import datetime

#contains price OHLC + volume + slope_adj (slope × r2) for all tickers and dates.  Organzed by date and ranked by slope_adj.
# # ============================================================
# CONFIG
# ============================================================

ADJ_PRICE_DIR      = "./3-adjusted_All_Prices_OHLC"
REGRESSION_DIR     = "./7-90Day_exp_regression_adjusted_all_prices"

OUTPUT_DIR         = "./9-ranking_dataset"
VER_DIR            = "./system_verification/9-ranking_dataset"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(VER_DIR, exist_ok=True)

print("=== BUILDING RANKING DATASET (OHLC + slope × r2) ===")

# ============================================================
# VALIDATION LOGGING
# ============================================================

validation_rows = []

def log_issue(ticker, issue, detail=""):
    validation_rows.append({
        "timestamp": datetime.now().isoformat(timespec="seconds"),
        "ticker": ticker,
        "issue": issue,
        "detail": detail,
    })
    print(f"⚠ {ticker} | {issue} | {detail}")

# ============================================================
# DISCOVER TICKERS
# ============================================================

tickers = sorted([
    f.replace(".parquet", "")
    for f in os.listdir(ADJ_PRICE_DIR)
    if f.endswith(".parquet")
])

print(f"Found {len(tickers)} tickers with adjusted OHLC data.")

# ============================================================
# MAIN LOOP — MERGE OHLC + REGRESSION
# ============================================================

rows = []

for ticker in tickers:
    print(f"\nProcessing: {ticker}")

    # --------------------------------------------------------
    # Load adjusted OHLC
    # --------------------------------------------------------
    f_px = os.path.join(ADJ_PRICE_DIR, f"{ticker}.parquet")

    try:
        px = pd.read_parquet(f_px)
    except:
        log_issue(ticker, "cannot_read_adjusted_price_file", f_px)
        continue

    # Ensure date is datetime
    px["date"] = pd.to_datetime(px["date"])

    # Keep only adjusted OHLC + volume + date
    if not {"open_adj", "high_adj", "low_adj", "close_adj"}.issubset(px.columns):
        log_issue(ticker, "missing_adjusted_ohlc_columns", f_px)
        continue

    df = px[[
        "date",
        "open_adj", "high_adj", "low_adj", "close_adj",
        "volume"
    ]].copy()

    # --------------------------------------------------------
    # Load regression file (slope + r2)
    # --------------------------------------------------------
    f_reg = os.path.join(REGRESSION_DIR, f"{ticker}.parquet")

    if not os.path.exists(f_reg):
        log_issue(ticker, "missing_regression_file", f_reg)

        df["slope_annual"] = np.nan
        df["r2"] = np.nan
        df["slope_adj"] = np.nan

    else:
        rg = pd.read_parquet(f_reg)[["date", "slope_annual", "r2"]]
        rg["date"] = pd.to_datetime(rg["date"])

        df = df.merge(rg, on="date", how="left")

        df["slope_adj"] = df["slope_annual"] * df["r2"]

    # --------------------------------------------------------
    # Add ticker
    # --------------------------------------------------------
    df["ticker"] = ticker

    rows.append(df)

# ============================================================
# CONCAT FINAL DATA
# ============================================================

ranking_df = pd.concat(rows, ignore_index=True)

ranking_df = ranking_df.sort_values(
    ["date", "slope_adj"], ascending=[True, False]
)

# ============================================================
# SAVE OUTPUTS
# ============================================================

ranking_path = os.path.join(OUTPUT_DIR, "ranking_dataset.parquet")
ranking_df.to_parquet(ranking_path, index=False)

val_df = pd.DataFrame(validation_rows)
val_path = os.path.join(VER_DIR, f"ranking_validation-{datetime.now().strftime('%Y%m%d-%H%M%S')}.csv")
val_df.to_csv(val_path, index=False)

print("\n=== COMPLETED ===")
print(f"Saved ranking dataset → {ranking_path}")
print(f"Saved validation log → {val_path}")
print(f"Rows: {len(ranking_df):,}")
# Out:
# === BUILDING RANKING DATASET (OHLC + slope × r2) ===
# Found 1167 tickers with adjusted OHLC data.
#
# Processing: A
#
# Processing: AAL
#
# Processing: AAMRQ
#
# Processing: AAP
#
# Processing: AAPL
#
# Processing: ABBV
#
# Processing: ABI1
#
# Processing: ABKFQ
#
# Processing: ABMD
#
# Processing: ABNB
#
# Processing: ABS
#
# Processing: ABT
#
# Processing: ACAS
#
# Processing: ACGL
#
# Processing: ACKHQ
#
# Processing: ACN
#
# Processing: ACS
#
# Processing: ACV1
#
# Processing: ADBE
#
# Processing: ADCT1
#
# Processing: ADI
#
# Processing: ADM
#
# Processing: ADP
#
# Processing: ADSK
#
# Processing: ADT1
#
# Processing: AEE
#
# Processing: AEP
#
# Processing: AES
#
# Processing: AET
#
# Processing: AFL
#
# Processing: AFS.A
#
# Processing: AGC1
#
# Processing: AGN
#
# Processing: AGN1
#
# Processing: AHM1
#
# Processing: AIG
#
# Processing: AIT
#
# Processing: AIV
#
# Processing: AIZ
#
# Processing: AJG
#
# Processing: AKAM
#
# Processing: AKS
#
# Processing: AL1
#
# Processing: ALB
#
# Processing: ALGN
#
# Processing: ALK
#
# Processing: ALL
#
# Processing: ALLE
#
# Processing: ALTR1
#
# Processing: ALXN
#
# Processing: AM1
#
# Processing: AMAT
#
# Processing: AMCC
#
# Processing: AMCR
#
# Processing: AMD
#
# Processing: AME
#
# Processing: AMG
#
# Processing: AMGN
#
# Processing: AMP
#
# Processing: AMP1
#
# Processing: AMT
#
# Processing: AMTM
#
# Processing: AMZN
#
# Processing: AN
#
# Processing: AN1
#
# Processing: ANDV
#
# Processing: ANDW
#
# Processing: ANET
#
# Processing: ANF
#
# Processing: ANRZQ
#
# Processing: ANSS
#
# Processing: ANV1
#
# Processing: AON
#
# Processing: AOS
#
# Processing: APA
#
# Processing: APC
#
# Processing: APCC
#
# Processing: APD
#
# Processing: APH
#
# Processing: APO
#
# Processing: APOL
#
# Processing: APP
#
# Processing: APTV
#
# Processing: AR1
#
# Processing: ARC1
#
# Processing: ARE
#
# Processing: ARES
#
# Processing: ARG
#
# Processing: AS1
#
# Processing: ASC1
#
# Processing: ASH
#
# Processing: ASN
#
# Processing: ASND1
#
# Processing: ASO1
#
# Processing: AT1
#
# Processing: ATGE
#
# Processing: ATI
#
# Processing: ATI1
#
# Processing: ATO
#
# Processing: ATVI
#
# Processing: AV1
#
# Processing: AVB
#
# Processing: AVGO
#
# Processing: AVP
#
# Processing: AVY
#
# Processing: AW
#
# Processing: AWE
#
# Processing: AWK
#
# Processing: AXON
#
# Processing: AXP
#
# Processing: AYE
#
# Processing: AYI
#
# Processing: AZA.A
#
# Processing: AZO
#
# Processing: B
#
# Processing: BA
#
# Processing: BAC
#
# Processing: BAC1
#
# Processing: BALL
#
# Processing: BAX
#
# Processing: BAY1
#
# Processing: BBBYQ
#
# Processing: BBI1
# ⚠ BBI1 | missing_regression_file | ./7-90Day_exp_regression_adjusted_all_prices\BBI1.parquet
#
# Processing: BBWI
#
# Processing: BBY
#
# Processing: BC
#
# Processing: BCR
#
# Processing: BDK
#
# Processing: BDX
#
# Processing: BEAM2
#
# Processing: BEN
#
# Processing: BF.B
#
# Processing: BFH
#
# Processing: BFI1
#
# Processing: BFO1
#
# Processing: BG
#
# Processing: BGEN
#
# Processing: BGGSQ
#
# Processing: BHF
#
# Processing: BHI
#
# Processing: BHMSQ
#
# Processing: BIGGQ
#
# Processing: BIIB
#
# Processing: BIO
#
# Processing: BJS
#
# Processing: BK
#
# Processing: BKB
#
# Processing: BKNG
#
# Processing: BKR
#
# Processing: BLDR
#
# Processing: BLK
#
# Processing: BLS
#
# Processing: BMC
#
# Processing: BMET
#
# Processing: BMGCA
#
# Processing: BMS
#
# Processing: BMY
#
# Processing: BNI
#
# Processing: BNL1
#
# Processing: BOL
#
# Processing: BR
#
# Processing: BR1
#
# Processing: BRCM
#
# Processing: BRK.B
#
# Processing: BRL
#
# Processing: BRO
#
# Processing: BSC1
#
# Processing: BSX
#
# Processing: BT1
#
# Processing: BTUUQ
#
# Processing: BUD1
#
# Processing: BVSN
#
# Processing: BWA
#
# Processing: BX
#
# Processing: BXLT
#
# Processing: BXP
#
# Processing: C
#
# Processing: C1
#
# Processing: CA1
#
# Processing: CAG
#
# Processing: CAH
#
# Processing: CAL
#
# Processing: CAM2
#
# Processing: CAR
#
# Processing: CARR
#
# Processing: CAT
#
# Processing: CB
#
# Processing: CB1
#
# Processing: CBE
#
# Processing: CBH1
#
# Processing: CBOE
#
# Processing: CBRE
#
# Processing: CBS1
#
# Processing: CBSS
#
# Processing: CCE1
#
# Processing: CCI
#
# Processing: CCI1
#
# Processing: CCK
#
# Processing: CCL
#
# Processing: CCTYQ
#
# Processing: CCU1
#
# Processing: CDNS
#
# Processing: CDW
#
# Processing: CE
#
# Processing: CE1
#
# Processing: CEG
#
# Processing: CEG1
#
# Processing: CELG
#
# Processing: CEM1
#
# Processing: CEN1
#
# Processing: CEPH
#
# Processing: CERN
#
# Processing: CF
#
# Processing: CF1
#
# Processing: CFC
#
# Processing: CFG
#
# Processing: CFL1
# ⚠ CFL1 | missing_regression_file | ./7-90Day_exp_regression_adjusted_all_prices\CFL1.parquet
#
# Processing: CFN
#
# Processing: CG1
#
# Processing: CGP
#
# Processing: CHA1
#
# Processing: CHD
#
# Processing: CHIR1
#
# Processing: CHKAQ
#
# Processing: CHRS1
#
# Processing: CHRW
#
# Processing: CHTR
#
# Processing: CI
#
# Processing: CIEN
#
# Processing: CIN
#
# Processing: CINF
#
# Processing: CIT.A
#
# Processing: CITGQ
#
# Processing: CL
#
# Processing: CLF
#
# Processing: CLX
#
# Processing: CMA
#
# Processing: CMCSA
#
# Processing: CMCSK
#
# Processing: CME
#
# Processing: CMG
#
# Processing: CMI
#
# Processing: CMS
#
# Processing: CMVT
#
# Processing: CMX
#
# Processing: CNC
#
# Processing: CNCEQ
#
# Processing: CNG
#
# Processing: CNP
#
# Processing: CNW
#
# Processing: CNX
#
# Processing: CNXT1
#
# Processing: COC
#
# Processing: COF
#
# Processing: COIN
#
# Processing: COL
#
# Processing: COMS1
#
# Processing: COO
#
# Processing: COP
#
# Processing: COR
#
# Processing: COST
#
# Processing: COT1
#
# Processing: COTY
#
# Processing: COV
#
# Processing: CPAY
#
# Processing: CPB
#
# Processing: CPGX
#
# Processing: CPNLQ
#
# Processing: CPPRQ
#
# Processing: CPQ
#
# Processing: CPRI
#
# Processing: CPRT
#
# Processing: CPT
#
# Processing: CPWR
#
# Processing: CRH
#
# Processing: CRL
#
# Processing: CRM
#
# Processing: CRWD
#
# Processing: CSC
#
# Processing: CSCO
#
# Processing: CSE1
#
# Processing: CSGP
#
# Processing: CSR1
#
# Processing: CSRA
#
# Processing: CSX
#
# Processing: CTAS
#
# Processing: CTB
#
# Processing: CTLT
#
# Processing: CTRA
#
# Processing: CTSH
#
# Processing: CTVA
#
# Processing: CTX1
#
# Processing: CTXS
#
# Processing: CVC
#
# Processing: CVG
#
# Processing: CVGYQ
#
# Processing: CVH
#
# Processing: CVNA
#
# Processing: CVS
#
# Processing: CVX
#
# Processing: CXO
#
# Processing: CXT
#
# Processing: CYM
#
# Processing: CZR
#
# Processing: D
#
# Processing: DAL
#
# Processing: DALRQ
#
# Processing: DASH
#
# Processing: DAY
#
# Processing: DCNAQ
#
# Processing: DD
#
# Processing: DD1
#
# Processing: DDOG
#
# Processing: DDS
#
# Processing: DE
#
# Processing: DEC1
#
# Processing: DECK
#
# Processing: DELL
#
# Processing: DELL1
#
# Processing: DFODQ
#
# Processing: DFS
#
# Processing: DG
#
# Processing: DG1
#
# Processing: DGN
#
# Processing: DGX
#
# Processing: DHI
#
# Processing: DHR
#
# Processing: DI1
#
# Processing: DIGI2
#
# Processing: DINO
#
# Processing: DIS
#
# Processing: DISCK
#
# Processing: DISH
#
# Processing: DJ
#
# Processing: DLR
#
# Processing: DLTR
#
# Processing: DLX
#
# Processing: DNB1
#
# Processing: DNB2
#
# Processing: DNB3
#
# Processing: DNRCQ
#
# Processing: DOC
#
# Processing: DOFSQ
#
# Processing: DOV
#
# Processing: DOW
#
# Processing: DPHIQ
#
# Processing: DPZ
#
# Processing: DRE
#
# Processing: DRI
#
# Processing: DTE
#
# Processing: DTV1
#
# Processing: DUK
#
# Processing: DVA
#
# Processing: DVN
#
# Processing: DXC
#
# Processing: DXCM
#
# Processing: DYNIQ
#
# Processing: EA
#
# Processing: EBAY
#
# Processing: EC1
#
# Processing: ECH1
#
# Processing: ECL
#
# Processing: ECO1
#
# Processing: ED
#
# Processing: EDS
#
# Processing: EFU1
#
# Processing: EFX
#
# Processing: EG
#
# Processing: EHC
#
# Processing: EIX
#
# Processing: EKDKQ
#
# Processing: EL
#
# Processing: ELV
#
# Processing: EMC1
#
# Processing: EME
#
# Processing: EMN
#
# Processing: EMR
#
# Processing: ENDPQ
#
# Processing: ENPH
#
# Processing: ENRNQ
#
# Processing: EOG
#
# Processing: EOP
#
# Processing: EP1
#
# Processing: EPAM
#
# Processing: EQ1
#
# Processing: EQIX
#
# Processing: EQR
#
# Processing: EQT
#
# Processing: ERIE
#
# Processing: ES
#
# Processing: ESRX
#
# Processing: ESS
#
# Processing: ETFC
#
# Processing: ETN
#
# Processing: ETR
#
# Processing: ETS1
#
# Processing: ETSY
#
# Processing: EVHC
#
# Processing: EVRG
#
# Processing: EW
#
# Processing: EXC
#
# Processing: EXE
#
# Processing: EXPD
#
# Processing: EXPE
#
# Processing: EXR
#
# Processing: F
#
# Processing: FANG
#
# Processing: FAST
#
# Processing: FBF
#
# Processing: FBIN
#
# Processing: FCN1
#
# Processing: FCX
#
# Processing: FDC1
#
# Processing: FDO
#
# Processing: FDS
#
# Processing: FDX
#
# Processing: FE
#
# Processing: FFIV
#
# Processing: FG1
# ⚠ FG1 | missing_regression_file | ./7-90Day_exp_regression_adjusted_all_prices\FG1.parquet
#
# Processing: FHI
#
# Processing: FHN
#
# Processing: FICO
#
# Processing: FIS
#
# Processing: FISV
#
# Processing: FITB
#
# Processing: FIX
#
# Processing: FJ
#
# Processing: FL
#
# Processing: FLIR
#
# Processing: FLMIQ
#
# Processing: FLR
#
# Processing: FLS
#
# Processing: FLTWQ
#
# Processing: FMC
#
# Processing: FMCC
#
# Processing: FMY1
#
# Processing: FNMA
#
# Processing: FOSL
#
# Processing: FOX
#
# Processing: FOXA
#
# Processing: FPC
#
# Processing: FRCB
#
# Processing: FRO1
#
# Processing: FRT
#
# Processing: FRX1
#
# Processing: FSH
#
# Processing: FSL.B
#
# Processing: FSLR
#
# Processing: FTI
#
# Processing: FTI1
#
# Processing: FTL.A
#
# Processing: FTNT
#
# Processing: FTRCQ
#
# Processing: FTV
#
# Processing: FWLT
#
# Processing: G1
#
# Processing: GAP
#
# Processing: GAPTQ
#
# Processing: GAS
#
# Processing: GAS1
#
# Processing: GD
#
# Processing: GDDY
#
# Processing: GDT
#
# Processing: GDW
#
# Processing: GE
#
# Processing: GEHC
#
# Processing: GEN
#
# Processing: GEN1
#
# Processing: GENZ
#
# Processing: GEV
#
# Processing: GFS.A
#
# Processing: GGP
#
# Processing: GHC
#
# Processing: GIC1
#
# Processing: GILD
#
# Processing: GIS
#
# Processing: GL
#
# Processing: GLK1
#
# Processing: GLW
#
# Processing: GM
#
# Processing: GMCR
#
# Processing: GME
#
# Processing: GNRC
#
# Processing: GNT1
#
# Processing: GNW
#
# Processing: GOOG
#
# Processing: GOOGL
#
# Processing: GOSHA
#
# Processing: GP1
#
# Processing: GPC
#
# Processing: GPN
#
# Processing: GPU
#
# Processing: GR
#
# Processing: GRA
#
# Processing: GRMN
#
# Processing: GRN1
#
# Processing: GS
#
# Processing: GSX1
#
# Processing: GT
#
# Processing: GTE1
#
# Processing: GTW
#
# Processing: GWOW
#
# Processing: GWW
#
# Processing: GX
#
# Processing: H1
#
# Processing: H2
#
# Processing: HAL
#
# Processing: HAR
#
# Processing: HAS
#
# Processing: HBAN
#
# Processing: HBI
#
# Processing: HBOC
#
# Processing: HCA
#
# Processing: HCA1
#
# Processing: HCBK
#
# Processing: HCR1
#
# Processing: HD
#
# Processing: HES
#
# Processing: HET
#
# Processing: HI1
#
# Processing: HIG
#
# Processing: HII
#
# Processing: HLT
#
# Processing: HLT1
#
# Processing: HM
#
# Processing: HMA1
#
# Processing: HNZ
#
# Processing: HOG
#
# Processing: HOLX
#
# Processing: HON
#
# Processing: HON1
#
# Processing: HOOD
#
# Processing: HOT
#
# Processing: HP
#
# Processing: HPC
#
# Processing: HPE
#
# Processing: HPQ
#
# Processing: HRB
#
# Processing: HRL
#
# Processing: HRZIQ
#
# Processing: HSH
#
# Processing: HSIC
#
# Processing: HSP
#
# Processing: HST
#
# Processing: HSY
#
# Processing: HUBB
#
# Processing: HUM
#
# Processing: HWM
#
# Processing: IBKR
#
# Processing: IBM
#
# Processing: ICE
#
# Processing: IDXX
#
# Processing: IEX
#
# Processing: IFF
#
# Processing: IGT1
#
# Processing: IKN
#
# Processing: ILMN
#
# Processing: IMNX
#
# Processing: INCLF
#
# Processing: INCY
#
# Processing: INFO1
#
# Processing: INTC
#
# Processing: INTU
#
# Processing: INVH
#
# Processing: IP
#
# Processing: IPG
#
# Processing: IPGP
#
# Processing: IQV
#
# Processing: IR
#
# Processing: IRM
#
# Processing: ISRG
#
# Processing: IT
#
# Processing: ITT
#
# Processing: ITT1
# ⚠ ITT1 | missing_regression_file | ./7-90Day_exp_regression_adjusted_all_prices\ITT1.parquet
#
# Processing: ITW
#
# Processing: IVZ
#
# Processing: J
#
# Processing: JAVA1
#
# Processing: JBHT
#
# Processing: JBL
#
# Processing: JCI
#
# Processing: JEF
#
# Processing: JH
#
# Processing: JHF
#
# Processing: JKHY
#
# Processing: JM
#
# Processing: JNJ
#
# Processing: JNPR
#
# Processing: JNS
#
# Processing: JNY
#
# Processing: JOS
#
# Processing: JOY
#
# Processing: JP1
#
# Processing: JPM
#
# Processing: JPM1
#
# Processing: JWN
#
# Processing: K
#
# Processing: KATE
#
# Processing: KBH
#
# Processing: KDP
#
# Processing: KEY
#
# Processing: KEYS
#
# Processing: KG1
#
# Processing: KHC
#
# Processing: KIM
#
# Processing: KKR
#
# Processing: KLAC
#
# Processing: KM
#
# Processing: KMB
#
# Processing: KMG1
#
# Processing: KMI
#
# Processing: KMI1
#
# Processing: KMX
#
# Processing: KO
#
# Processing: KR
#
# Processing: KRB
#
# Processing: KRFT
#
# Processing: KRI
#
# Processing: KSE
#
# Processing: KSS
#
# Processing: KSU
#
# Processing: KVUE
#
# Processing: KWP
#
# Processing: L
#
# Processing: LDG
#
# Processing: LDOS
#
# Processing: LDWIF
#
# Processing: LEG
#
# Processing: LEHMQ
#
# Processing: LEN
#
# Processing: LH
#
# Processing: LHX
#
# Processing: LIFE2
#
# Processing: LII
#
# Processing: LIN
#
# Processing: LKQ
#
# Processing: LLL1
#
# Processing: LLTC
#
# Processing: LLY
#
# Processing: LM
#
# Processing: LMT
#
# Processing: LNC
#
# Processing: LNT
#
# Processing: LO
#
# Processing: LOW
#
# Processing: LPX
#
# Processing: LRCX
#
# Processing: LSI1
#
# Processing: LU1
#
# Processing: LULU
#
# Processing: LUMN
#
# Processing: LUV
#
# Processing: LVLT
#
# Processing: LVS
#
# Processing: LW
#
# Processing: LXK
#
# Processing: LYB
#
# Processing: LYV
#
# Processing: M
#
# Processing: MA
#
# Processing: MAA
#
# Processing: MAC
#
# Processing: MAR
#
# Processing: MAS
#
# Processing: MAT
#
# Processing: MAY1
#
# Processing: MBI
#
# Processing: MCD
#
# Processing: MCHP
#
# Processing: MCIC
#
# Processing: MCK
#
# Processing: MCO
#
# Processing: MDLZ
#
# Processing: MDP
#
# Processing: MDRIQ
#
# Processing: MDT
#
# Processing: MEA1
#
# Processing: MEDI1
#
# Processing: MEE
#
# Processing: MEL
#
# Processing: MER
#
# Processing: MERQ
#
# Processing: MET
#
# Processing: META
#
# Processing: MFE
#
# Processing: MGM
#
# Processing: MHK
#
# Processing: MHS
#
# Processing: MI2
#
# Processing: MII1
#
# Processing: MIL1
#
# Processing: MIR1
#
# Processing: MJN
#
# Processing: MKC
#
# Processing: MKG
#
# Processing: MKTX
#
# Processing: MLM
#
# Processing: MMC
#
# Processing: MMI1
#
# Processing: MMM
#
# Processing: MNKKQ
#
# Processing: MNR1
#
# Processing: MNST
#
# Processing: MO
#
# Processing: MOB1
#
# Processing: MOH
#
# Processing: MOLX
#
# Processing: MON2
#
# Processing: MOS
#
# Processing: MPC
#
# Processing: MPWR
#
# Processing: MRK
#
# Processing: MRNA
#
# Processing: MRO
#
# Processing: MS
#
# Processing: MSCI
#
# Processing: MSFT
#
# Processing: MSI
#
# Processing: MST1
#
# Processing: MTB
#
# Processing: MTCH
#
# Processing: MTD
#
# Processing: MTG
#
# Processing: MTL1
#
# Processing: MTLQQ
#
# Processing: MTW
#
# Processing: MU
#
# Processing: MUR
#
# Processing: MWI
#
# Processing: MWV
#
# Processing: MWW
#
# Processing: MXIM
#
# Processing: MYG1
#
# Processing: MZIAQ
#
# Processing: NAV
#
# Processing: NAVI
#
# Processing: NBL
#
# Processing: NBR
#
# Processing: NC
#
# Processing: NCC
#
# Processing: NCE
#
# Processing: NCLH
#
# Processing: NDAQ
#
# Processing: NDSN
#
# Processing: NEBLQ
#
# Processing: NEE
#
# Processing: NEM
#
# Processing: NFB
#
# Processing: NFLX
#
# Processing: NFX
#
# Processing: NGH
#
# Processing: NI
#
# Processing: NKE
#
# Processing: NKTR
#
# Processing: NLC1
#
# Processing: NLSN
#
# Processing: NMK1
#
# Processing: NOC
#
# Processing: NOV
#
# Processing: NOVL
#
# Processing: NOW
#
# Processing: NRG
#
# Processing: NRTLQ
#
# Processing: NSC
#
# Processing: NSI1
#
# Processing: NSM1
#
# Processing: NTAP
#
# Processing: NTRS
#
# Processing: NUE
#
# Processing: NVDA
#
# Processing: NVLS1
#
# Processing: NVR
#
# Processing: NWL
#
# Processing: NWS
#
# Processing: NWSA
#
# Processing: NXPI
#
# Processing: NXTL
#
# Processing: NYT
#
# Processing: NYX1
#
# Processing: O
#
# Processing: OAT
#
# Processing: ODFL
#
# Processing: ODP
#
# Processing: OGN
#
# Processing: OI
#
# Processing: OK
#
# Processing: OKE
#
# Processing: OMC
#
# Processing: OMX
#
# Processing: ON
#
# Processing: ONE1
#
# Processing: ORCL
#
# Processing: ORLY
#
# Processing: ORX
#
# Processing: OTIS
#
# Processing: OWENQ
#
# Processing: OXY
#
# Processing: PALM
#
# Processing: PANW
#
# Processing: PAS
#
# Processing: PAYC
#
# Processing: PAYX
#
# Processing: PBCT
#
# Processing: PBG
#
# Processing: PBI
#
# Processing: PBY1
#
# Processing: PCAR
#
# Processing: PCG
#
# Processing: PCH
#
# Processing: PCL1
#
# Processing: PCP
#
# Processing: PCS1
#
# Processing: PD1
#
# Processing: PDCO
#
# Processing: PDG
#
# Processing: PEG
#
# Processing: PENN
#
# Processing: PEP
#
# Processing: PET1
#
# Processing: PETM
#
# Processing: PFE
#
# Processing: PFG
#
# Processing: PG
#
# Processing: PGL
#
# Processing: PGN1
#
# Processing: PGR
#
# Processing: PH
#
# Processing: PHA
#
# Processing: PHB1
#
# Processing: PHM
#
# Processing: PKG
#
# Processing: PLD
#
# Processing: PLL1
#
# Processing: PLTR
#
# Processing: PM
#
# Processing: PMCS
#
# Processing: PMI1
#
# Processing: PNC
#
# Processing: PNR
#
# Processing: PNU1
#
# Processing: PNW
#
# Processing: PODD
#
# Processing: POM1
#
# Processing: POOL
#
# Processing: PPG
#
# Processing: PPL
#
# Processing: PPW
#
# Processing: PRDCQ
#
# Processing: PRGO
#
# Processing: PRU
#
# Processing: PSA
#
# Processing: PSFT
#
# Processing: PSKY
#
# Processing: PSX
#
# Processing: PTC
#
# Processing: PTV
#
# Processing: PVH
#
# Processing: PVN
#
# Processing: PVT1
#
# Processing: PWER1
#
# Processing: PWJ1
#
# Processing: PWR
#
# Processing: PX1
#
# Processing: PXD
#
# Processing: PYPL
#
# Processing: PZE1
#
# Processing: Q
# ⚠ Q | missing_regression_file | ./7-90Day_exp_regression_adjusted_all_prices\Q.parquet
#
# Processing: Q1
#
# Processing: QCOM
#
# Processing: QEP
#
# Processing: QLGC
#
# Processing: QRVO
#
# Processing: QTRN
#
# Processing: R
#
# Processing: RADCQ
#
# Processing: RAI
#
# Processing: RAL1
#
# Processing: RATL
#
# Processing: RBD
#
# Processing: RBK
#
# Processing: RCL
#
# Processing: RDC
#
# Processing: REG
#
# Processing: REGN
#
# Processing: RF
#
# Processing: RHI
#
# Processing: RHT
#
# Processing: RIG
#
# Processing: RJF
#
# Processing: RL
#
# Processing: RLM1
#
# Processing: RMD
#
# Processing: RML
#
# Processing: RNB
#
# Processing: ROH
#
# Processing: ROK
#
# Processing: ROL
#
# Processing: ROP
#
# Processing: ROST
#
# Processing: RRC
#
# Processing: RRD
#
# Processing: RSG
#
# Processing: RSHCQ
#
# Processing: RTN
#
# Processing: RTX
#
# Processing: RVTY
#
# Processing: RX
#
# Processing: RYAN1
#
# Processing: RYC
#
# Processing: RYI1
#
# Processing: S1
#
# Processing: S2
#
# Processing: SAF2
#
# Processing: SAI1
#
# Processing: SANM
#
# Processing: SAPE
#
# Processing: SBAC
#
# Processing: SBL
#
# Processing: SBNY
#
# Processing: SBUX
#
# Processing: SCG
#
# Processing: SCHW
#
# Processing: SCI
#
# Processing: SDS1
#
# Processing: SE1
#
# Processing: SEBL
#
# Processing: SEDG
#
# Processing: SEE
#
# Processing: SEG1
#
# Processing: SFA
#
# Processing: SGID
#
# Processing: SGP
#
# Processing: SHEL
#
# Processing: SHLDQ
#
# Processing: SHW
#
# Processing: SIAL
#
# Processing: SIG
#
# Processing: SII1
#
# Processing: SITC
#
# Processing: SIVBQ
#
# Processing: SJM
#
# Processing: SK1
#
# Processing: SLB
#
# Processing: SLG
#
# Processing: SLM
#
# Processing: SLR
#
# Processing: SMCI
#
# Processing: SMI1
#
# Processing: SMS1
#
# Processing: SNA
#
# Processing: SNDK
#
# Processing: SNDK1
#
# Processing: SNI
#
# Processing: SNPS
#
# Processing: SNV
#
# Processing: SO
#
# Processing: SOLS
# ⚠ SOLS | missing_regression_file | ./7-90Day_exp_regression_adjusted_all_prices\SOLS.parquet
#
# Processing: SOLV
#
# Processing: SOTR
#
# Processing: SOV
#
# Processing: SPG
#
# Processing: SPGI
#
# Processing: SPLS
#
# Processing: SRCL
#
# Processing: SRE
#
# Processing: SSP
#
# Processing: STE
#
# Processing: STI1
#
# Processing: STJ
#
# Processing: STLD
#
# Processing: STO1
#
# Processing: STR1
#
# Processing: STT
#
# Processing: STX
#
# Processing: STZ
#
# Processing: SUB1
#
# Processing: SUN1
#
# Processing: SUNEQ
#
# Processing: SVU
#
# Processing: SW
#
# Processing: SWK
#
# Processing: SWKS
#
# Processing: SWN
#
# Processing: SWY
#
# Processing: SXCL
#
# Processing: SYF
#
# Processing: SYK
#
# Processing: SYY
#
# Processing: T
#
# Processing: T1
#
# Processing: TA2
#
# Processing: TAP
#
# Processing: TAP.B
#
# Processing: TCOMA
#
# Processing: TDC
#
# Processing: TDG
#
# Processing: TDY
#
# Processing: TE1
#
# Processing: TECH
#
# Processing: TEG
#
# Processing: TEK1
#
# Processing: TEL
#
# Processing: TEN1
#
# Processing: TER
#
# Processing: TEX
#
# Processing: TFC
#
# Processing: TFCF
#
# Processing: TFCFA
#
# Processing: TFX
#
# Processing: TGNA
#
# Processing: TGT
#
# Processing: THC
#
# Processing: TIE
#
# Processing: TIF
#
# Processing: TIN
#
# Processing: TJX
#
# Processing: TKO
#
# Processing: TKR
#
# Processing: TLAB
#
# Processing: TMC.A
#
# Processing: TMO
#
# Processing: TMUS
#
# Processing: TNB
#
# Processing: TNL
#
# Processing: TOS
#
# Processing: TOY
#
# Processing: TPL
#
# Processing: TPR
#
# Processing: TRB
#
# Processing: TRGP
#
# Processing: TRIP
#
# Processing: TRMB
#
# Processing: TROW
#
# Processing: TRV
#
# Processing: TRW1
#
# Processing: TSCO
#
# Processing: TSG1
#
# Processing: TSLA
#
# Processing: TSN
#
# Processing: TSS
#
# Processing: TT
#
# Processing: TT2
#
# Processing: TTD
#
# Processing: TTWO
#
# Processing: TUPBQ
#
# Processing: TWC
#
# Processing: TWTR
#
# Processing: TWX
#
# Processing: TWX1
#
# Processing: TX1
#
# Processing: TXN
#
# Processing: TXT
#
# Processing: TXU
#
# Processing: TYC
#
# Processing: TYL
#
# Processing: UA
#
# Processing: UAA
#
# Processing: UAL
#
# Processing: UAWGQ
#
# Processing: UBER
#
# Processing: UCC1
#
# Processing: UCL1
#
# Processing: UCM
#
# Processing: UDR
#
# Processing: UHS
#
# Processing: UIS
#
# Processing: UK1
#
# Processing: UL
#
# Processing: ULTA
#
# Processing: UNH
#
# Processing: UNM
#
# Processing: UNP
#
# Processing: UPC1
#
# Processing: UPR
#
# Processing: UPS
#
# Processing: URBN
#
# Processing: URI
#
# Processing: USB
#
# Processing: USB1
#
# Processing: USG1
#
# Processing: USS1
#
# Processing: UST1
#
# Processing: USW
#
# Processing: UVN
#
# Processing: V
#
# Processing: VALPQ
#
# Processing: VAR
#
# Processing: VFC
#
# Processing: VIAB
#
# Processing: VIAV
#
# Processing: VICI
#
# Processing: VLO
#
# Processing: VLTO
#
# Processing: VMC
#
# Processing: VNO
#
# Processing: VNT
#
# Processing: VO1
#
# Processing: VRSK
#
# Processing: VRSN
#
# Processing: VRTS1
#
# Processing: VRTX
#
# Processing: VST
#
# Processing: VSTNQ
#
# Processing: VTR
#
# Processing: VTRS
#
# Processing: VTSS
#
# Processing: VYX
#
# Processing: VZ
#
# Processing: WAB
#
# Processing: WAI1
#
# Processing: WAMUQ
#
# Processing: WAT
#
# Processing: WB1
#
# Processing: WB2
#
# Processing: WBA
#
# Processing: WBD
#
# Processing: WCG
#
# Processing: WCOEQ
#
# Processing: WDAY
#
# Processing: WDC
#
# Processing: WEC
#
# Processing: WELL
#
# Processing: WEN
#
# Processing: WFC
#
# Processing: WFC1
#
# Processing: WFM
#
# Processing: WFTIQ
#
# Processing: WGL
#
# Processing: WHR
#
# Processing: WINMQ
#
# Processing: WLA
#
# Processing: WLL1
#
# Processing: WLP1
#
# Processing: WM
#
# Processing: WMB
#
# Processing: WMT
#
# Processing: WNDXQ
#
# Processing: WOR
#
# Processing: WPX
#
# Processing: WRB
#
# Processing: WRK
#
# Processing: WSM
#
# Processing: WST
#
# Processing: WTW
#
# Processing: WU
#
# Processing: WWY
#
# Processing: WY
#
# Processing: WYE
#
# Processing: WYNN
#
# Processing: X
#
# Processing: XEC
#
# Processing: XEL
#
# Processing: XL1
#
# Processing: XLNX
#
# Processing: XOM
#
# Processing: XRAY
#
# Processing: XRX
#
# Processing: XTO
#
# Processing: XYL
#
# Processing: XYZ
#
# Processing: YHOO
#
# Processing: YNR
#
# Processing: YUM
#
# Processing: ZBH
#
# Processing: ZBRA
#
# Processing: ZION
#
# Processing: ZTS
#
# === COMPLETED ===
# Saved ranking dataset → ./9-ranking_dataset\ranking_dataset.parquet
# Saved validation log → ./system_verification/9-ranking_dataset\ranking_validation-20251231-084610.csv
# Rows: 5,366,253

# %%
df_join_date = pd.read_parquet("1-sp500_membership_daily_matrix/sp500_membership_join_exit_date.parquet")

print("Join Exit File Info:")
print("="*60)
print(f"Shape: {df_join_date.shape}")
print(f"\nColumns: {df_join_date.columns.tolist()}")
print(f"\nData types:\n{df_join_date.dtypes}")
print(f"\nFirst few rows:")
print(df_join_date.head(93))
print(f"\nLast few rows:")
print(df_join_date.tail(10))
print(f"\nSummary statistics:")
print(df_join_date.describe())
print(f"\nNull values:")
print(df_join_date.isnull().sum())
# Out:
# Join Exit File Info:
# ============================================================
# Shape: (1192, 2)
#
# Columns: ['first_join_date', 'last_exit_date']
#
# Data types:
# first_join_date    datetime64[ns]
# last_exit_date     datetime64[ns]
# dtype: object
#
# First few rows:
#        first_join_date last_exit_date
# ticker
# A           2000-06-05            NaT
# AAL         2015-03-17     2024-09-20
# AAMRQ       1957-03-04     2003-03-13
# AAP         2015-07-07     2023-08-24
# AAPL        1982-11-30            NaT
# ...                ...            ...
# ARG         2009-09-09     2016-05-19
# AS1         1957-03-04     1998-11-20
# ASC1        1957-03-04     1999-06-23
# ASH         1989-08-03     2008-11-13
# ASN         2004-12-20     2007-10-04
#
# [93 rows x 2 columns]
#
# Last few rows:
#        first_join_date last_exit_date
# ticker
# XTO         2004-12-28     2010-06-24
# XYL         2011-11-01            NaT
# XYZ         2025-07-23            NaT
# YHOO        1999-12-08     2017-06-16
# YNR         2000-01-05     2000-10-02
# YUM         1997-10-06            NaT
# ZBH         2001-08-07            NaT
# ZBRA        2019-12-23            NaT
# ZION        2001-06-22     2024-03-15
# ZTS         2013-06-14            NaT
#
# Summary statistics:
#                      first_join_date                 last_exit_date
# count                           1191                            684
# mean   1995-11-08 13:08:18.740554112  2009-05-10 08:44:12.631579136
# min              1957-03-04 00:00:00            1963-06-26 00:00:00
# 25%              1983-11-30 00:00:00            2001-04-22 06:00:00
# 50%              1999-08-06 00:00:00            2008-09-26 00:00:00
# 75%              2009-12-21 00:00:00            2017-02-24 06:00:00
# max              2025-12-22 00:00:00            2025-12-19 00:00:00
#
# Null values:
# first_join_date      1
# last_exit_date     508
# dtype: int64

# %%
import pandas as pd

# Load and inspect the ABBV regression file

df_abbv_reg = pd.read_parquet("7-90Day_exp_regression_adjusted_all_prices/ABBV.parquet")

print("ABBV Regression File Info:")
print("="*60)
print(f"Shape: {df_abbv_reg.shape}")
print(f"\nColumns: {df_abbv_reg.columns.tolist()}")
print(f"\nData types:\n{df_abbv_reg.dtypes}")
print(f"\nFirst few rows:")
print(df_abbv_reg.head(93))
print(f"\nLast few rows:")
print(df_abbv_reg.tail(10))
print(f"\nSummary statistics:")
print(df_abbv_reg.describe())
print(f"\nNull values:")
print(df_abbv_reg.isnull().sum())
# Out:
# ABBV Regression File Info:
# ============================================================
# Shape: (3269, 18)
#
# Columns: ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'closeadj', 'closeunadj', 'lastupdated', 'adj_factor', 'open_adj', 'high_adj', 'low_adj', 'close_adj', 'slope_daily', 'slope_annual', 'r2']
#
# Data types:
# ticker                  object
# date            datetime64[ns]
# open                   float64
# high                   float64
# low                    float64
# close                  float64
# volume                 float64
# closeadj               float64
# closeunadj             float64
# lastupdated     datetime64[ms]
# adj_factor             float64
# open_adj               float64
# high_adj               float64
# low_adj                float64
# close_adj              float64
# slope_daily            float64
# slope_annual           float64
# r2                     float64
# dtype: object
#
# First few rows:
#    ticker       date   open   high    low   close      volume  closeadj  \
# 0    ABBV 2013-01-02  34.92  35.40  34.10  35.120  13768000.0    20.865
# 1    ABBV 2013-01-03  35.00  35.00  34.16  34.830  16739000.0    20.692
# 2    ABBV 2013-01-04  34.62  34.89  34.25  34.391  21372000.0    20.431
# 3    ABBV 2013-01-07  34.15  35.45  34.15  34.460  17897000.0    20.473
# 4    ABBV 2013-01-08  34.29  34.64  33.36  33.710  17863000.0    20.027
# ..    ...        ...    ...    ...    ...     ...         ...       ...
# 88   ABBV 2013-05-09  43.34  44.45  43.25  44.240   5047000.0    26.840
# 89   ABBV 2013-05-10  44.21  45.01  44.20  45.010   4456000.0    27.307
# 90   ABBV 2013-05-13  44.79  44.79  44.17  44.540   3738000.0    27.022
# 91   ABBV 2013-05-14  44.09  45.52  44.09  45.350   5760000.0    27.513
# 92   ABBV 2013-05-15  45.72  46.93  45.48  46.030   6702000.0    27.926
#
#     closeunadj lastupdated  adj_factor   open_adj   high_adj    low_adj  \
# 0       35.120  2025-10-21    0.594106  20.746179  21.031350  20.259012
# 1       34.830  2025-10-21    0.594086  20.792995  20.792995  20.293963
# 2       34.391  2025-10-21    0.594080  20.567044  20.727446  20.347235
# 3       34.460  2025-10-21    0.594109  20.288826  21.061168  20.288826
# 4       33.710  2025-10-21    0.594097  20.371576  20.579510  19.819066
# ..         ...         ...         ...        ...        ...        ...
# 88      44.240  2025-10-21    0.606691  26.293978  26.967405  26.239376
# 89      45.010  2025-10-21    0.606687  26.821650  27.307000  26.815583
# 90      44.540  2025-10-21    0.606691  27.173673  27.173673  26.797524
# 91      45.350  2025-10-21    0.606681  26.748581  27.616136  26.748581
# 92      46.030  2025-10-21    0.606691  27.737926  28.472022  27.592320
#
#     close_adj  slope_daily  slope_annual        r2
# 0      20.865          NaN           NaN       NaN
# 1      20.692          NaN           NaN       NaN
# 2      20.431          NaN           NaN       NaN
# 3      20.473          NaN           NaN       NaN
# 4      20.027          NaN           NaN       NaN
# ..        ...          ...           ...       ...
# 88     26.840          NaN           NaN       NaN
# 89     27.307     0.003268      1.278319  0.881727
# 90     27.022     0.003282      1.286801  0.883521
# 91     27.513     0.003300      1.296876  0.884922
# 92     27.926     0.003314      1.305087  0.885457
#
# [93 rows x 18 columns]
#
# Last few rows:
#      ticker       date    open     high      low   close      volume  \
# 3259   ABBV 2025-12-16  226.41  226.840  221.910  223.67   6406000.0
# 3260   ABBV 2025-12-17  223.88  226.410  222.860  224.31   5243000.0
# 3261   ABBV 2025-12-18  224.00  226.260  222.805  222.82   3460000.0
# 3262   ABBV 2025-12-19  222.95  229.470  222.350  226.82  18962000.0
# 3263   ABBV 2025-12-22  226.11  228.650  224.250  227.91   4816000.0
# 3264   ABBV 2025-12-23  228.22  230.790  227.910  228.79   2117000.0
# 3265   ABBV 2025-12-24  229.46  230.800  228.980  229.89   1745000.0
# 3266   ABBV 2025-12-26  229.82  230.610  228.680  229.98   1594000.0
# 3267   ABBV 2025-12-29  230.15  232.020  229.740  230.84   3803000.0
# 3268   ABBV 2025-12-30  230.77  231.205  228.620  229.74   1790000.0
#
#       closeadj  closeunadj lastupdated  adj_factor  open_adj  high_adj  \
# 3259    223.67      223.67  2025-12-16         1.0    226.41   226.840
# 3260    224.31      224.31  2025-12-17         1.0    223.88   226.410
# 3261    222.82      222.82  2025-12-18         1.0    224.00   226.260
# 3262    226.82      226.82  2025-12-20         1.0    222.95   229.470
# 3263    227.91      227.91  2025-12-22         1.0    226.11   228.650
# 3264    228.79      228.79  2025-12-23         1.0    228.22   230.790
# 3265    229.89      229.89  2025-12-24         1.0    229.46   230.800
# 3266    229.98      229.98  2025-12-27         1.0    229.82   230.610
# 3267    230.84      230.84  2025-12-29         1.0    230.15   232.020
# 3268    229.74      229.74  2025-12-30         1.0    230.77   231.205
#
#       low_adj  close_adj  slope_daily  slope_annual        r2
# 3259  221.910     223.67     0.001286      0.382722  0.529992
# 3260  222.860     224.31     0.001212      0.357304  0.505148
# 3261  222.805     222.82     0.001132      0.330005  0.475980
# 3262  222.350     226.82     0.001073      0.310375  0.455554
# 3263  224.250     227.91     0.001027      0.295364  0.437749
# 3264  227.910     228.79     0.000989      0.283190  0.422268
# 3265  228.980     229.89     0.000953      0.271544  0.408112
# 3266  228.680     229.98     0.000914      0.259060  0.393161
# 3267  229.740     230.84     0.000886      0.250316  0.381410
# 3268  228.620     229.74     0.000855      0.240384  0.367126
#
# Summary statistics:
#                                 date         open         high          low  \
# count                           3269  3269.000000  3269.000000  3269.000000
# mean   2019-06-30 03:41:34.340777216   103.939846   105.021351   102.857377
# min              2013-01-02 00:00:00    33.590000    33.900000    33.330000
# 25%              2016-04-01 00:00:00    62.900000    63.580000    62.255000
# 50%              2019-07-01 00:00:00    91.010000    92.060000    89.600000
# 75%              2022-09-27 00:00:00   145.280000   146.660000   143.610000
# max              2025-12-30 00:00:00   240.890000   244.810000   234.520000
# std                              NaN    49.301788    49.764581    48.837309
#
#              close        volume     closeadj   closeunadj  \
# count  3269.000000  3.269000e+03  3269.000000  3269.000000
# mean    103.991114  7.277567e+06    86.848822   103.991114
# min      33.710000  1.379000e+06    20.027000    33.710000
# 25%      62.830000  4.713000e+06    42.165000    62.830000
# 50%      90.710000  6.162000e+06    68.414000    90.710000
# 75%     145.260000  8.476000e+06   130.872000   145.260000
# max     244.380000  1.227410e+08   242.621000   244.380000
# std      49.336659  4.883115e+06    53.997010    49.336659
#
#                       lastupdated   adj_factor     open_adj     high_adj  \
# count                        3269  3269.000000  3269.000000  3269.000000
# mean   2025-10-21 12:13:26.118000     0.779801    86.805179    87.701591
# min           2025-10-15 00:00:00     0.594080    19.967711    20.169705
# 25%           2025-10-21 00:00:00     0.666380    42.156211    42.535134
# 50%           2025-10-21 00:00:00     0.757019    68.443239    69.246262
# 75%           2025-10-21 00:00:00     0.886503   130.438527   131.816348
# max           2025-12-30 00:00:00     1.000000   239.155828   243.047905
# std                           NaN     0.122936    53.961057    54.478857
#
#            low_adj    close_adj  slope_daily  slope_annual            r2
# count  3269.000000  3269.000000  3180.000000   3180.000000  3.180000e+03
# mean     85.907304    86.848822     0.000713      0.300634  4.391351e-01
# min      19.800961    20.027000    -0.003676     -0.603958  1.362268e-07
# 25%      41.768099    42.165000    -0.000603     -0.140966  1.558443e-01
# 50%      67.557248    68.414000     0.000701      0.193154  4.244567e-01
# 75%     129.272255   130.872000     0.001839      0.589446  7.154060e-01
# max     232.831686   242.621000     0.004351      1.993777  9.613561e-01
# std      53.439902    53.997010     0.001616      0.542953  3.000819e-01
#
# Null values:
# ticker           0
# date             0
# open             0
# high             0
# low              0
# close            0
# volume           0
# closeadj         0
# closeunadj       0
# lastupdated      0
# adj_factor       0
# open_adj         0
# high_adj         0
# low_adj          0
# close_adj        0
# slope_daily     89
# slope_annual    89
# r2              89
# dtype: int64

# %%
# Load and inspect the final ranking dataset
df_ranking = pd.read_parquet("9-ranking_dataset/ranking_dataset.parquet")

print("Ranking Dataset Info:")
print("="*60)
print(f"Shape: {df_ranking.shape}")
print(f"\nColumns: {df_ranking.columns.tolist()}")
print(f"\nData types:\n{df_ranking.dtypes}")
print(f"\nFirst few rows:")
print(df_ranking.head(93))
print(f"\nLast few rows:")
print(df_ranking.tail(10))
print(f"\nSummary statistics:")
print(df_ranking.describe())
print(f"\nNull values:")
print(df_ranking.isnull().sum())
# Out:
# Ranking Dataset Info:
# ============================================================
# Shape: (5366253, 10)
#
# Columns: ['date', 'open_adj', 'high_adj', 'low_adj', 'close_adj', 'volume', 'slope_annual', 'r2', 'slope_adj', 'ticker']
#
# Data types:
# date            datetime64[ns]
# open_adj               float64
# high_adj               float64
# low_adj                float64
# close_adj              float64
# volume                 float64
# slope_annual           float64
# r2                     float64
# slope_adj              float64
# ticker                  object
# dtype: object
#
# First few rows:
#          date   open_adj   high_adj    low_adj  close_adj       volume  \
# 0  1997-12-31  31.776559  32.770191  31.666043     32.423    3793386.6
# 1  1997-12-31   0.098000   0.102188   0.097162      0.098  406358000.0
# 2  1997-12-31  16.272963  16.637861  15.908998     16.580    2817385.2
# 3  1997-12-31  30.000000  30.750000  29.917000     30.667     256200.0
# 4  1997-12-31   8.000000   8.250000   7.750000      8.190     121400.0
# ..        ...        ...        ...        ...        ...          ...
# 88 1997-12-31  30.444800  30.953259  30.407136     30.721    3524300.0
# 89 1997-12-31  15.083226  15.159256  14.837971     14.914    2239000.0
# 90 1997-12-31  72.167003  72.601493  71.175017     72.415     935100.0
# 91 1997-12-31   1.668014   1.668014   1.655986      1.662     971000.0
# 92 1997-12-31   7.735165   7.929282   7.707212      7.833    1446000.0
#
#     slope_annual  r2  slope_adj ticker
# 0            NaN NaN        NaN  AAMRQ
# 1            NaN NaN        NaN   AAPL
# 2            NaN NaN        NaN   ABI1
# 3            NaN NaN        NaN  ABKFQ
# 4            NaN NaN        NaN   ABMD
# ..           ...  ..        ...    ...
# 88           NaN NaN        NaN     BA
# 89           NaN NaN        NaN    BAC
# 90           NaN NaN        NaN   BAC1
# 91           NaN NaN        NaN   BALL
# 92           NaN NaN        NaN    BAX
#
# [93 rows x 10 columns]
#
# Last few rows:
#               date  open_adj  high_adj  low_adj  close_adj     volume  \
# 5366243 2025-12-30   228.330   232.595  227.400     231.07   789000.0
# 5366244 2025-12-30     6.470     6.495    6.420       6.43   939000.0
# 5366245 2025-12-30   160.250   161.950  159.300     160.52   513000.0
# 5366246 2025-12-30     2.460     2.486    2.425       2.48  3450000.0
# 5366247 2025-12-30    13.910    14.070   13.830      13.94  1827000.0
# 5366248 2025-12-30    67.179    68.590   67.050      67.54  4994000.0
# 5366249 2025-12-30    49.180    49.600   48.920      49.47  1678000.0
# 5366250 2025-12-30    13.830    14.160   13.800      13.98  3136000.0
# 5366251 2025-12-30    84.110    85.000   83.480      84.01  1115000.0
# 5366252 2025-12-30    49.110    49.535   48.840      48.86   947000.0
#
#          slope_annual        r2  slope_adj ticker
# 5366243     -0.685711  0.901891  -0.618436   POOL
# 5366244     -0.759082  0.815598  -0.619106   SITC
# 5366245     -0.704177  0.908465  -0.639720   PAYC
# 5366246     -0.768505  0.866762  -0.666111    XRX
# 5366247     -0.876914  0.800521  -0.701988   PRGO
# 5366248     -0.948021  0.766516  -0.726673   FISV
# 5366249     -0.880482  0.853463  -0.751460    ARE
# 5366250     -0.983254  0.839586  -0.825525    FMC
# 5366251           NaN       NaN        NaN      Q
# 5366252           NaN       NaN        NaN   SOLS
#
# Summary statistics:
#                                 date      open_adj      high_adj  \
# count                        5366253  5.366253e+06  5.366253e+06
# mean   2011-04-15 00:58:09.680563712  6.164247e+01  6.246309e+01
# min              1997-12-31 00:00:00  4.000000e-03  5.000000e-03
# 25%              2004-04-26 00:00:00  1.384000e+01  1.405976e+01
# 50%              2010-12-17 00:00:00  2.750898e+01  2.788290e+01
# 75%              2018-01-26 00:00:00  5.535000e+01  5.600000e+01
# max              2025-12-30 00:00:00  2.043675e+04  2.096175e+04
# std                              NaN  2.080208e+02  2.115924e+02
#
#             low_adj     close_adj        volume  slope_annual            r2  \
# count  5.366253e+06  5.366253e+06  5.366253e+06  5.262640e+06  5.262640e+06
# mean   6.078099e+01  6.163145e+01  5.784313e+06  2.198557e+00  4.426700e-01
# min    1.000000e-03  1.000000e-03  0.000000e+00 -1.000000e+00  7.527312e-14
# 25%    1.361100e+01  1.384000e+01  6.970000e+05 -2.134021e-01  1.567267e-01
# 50%    2.712166e+01  2.750900e+01  1.692600e+06  1.366845e-01  4.544436e-01
# 75%    5.467000e+01  5.534100e+01  4.026060e+06  5.713576e-01  7.117486e-01
# max    1.942050e+04  2.039475e+04  9.230856e+09  5.139988e+05  9.896028e-01
# std    2.039807e+02  2.077206e+02  3.572453e+07  6.615729e+02  2.976921e-01
#
#           slope_adj
# count  5.262640e+06
# mean   1.780293e+00
# min   -9.678651e-01
# 25%   -5.091673e-02
# 50%    1.507545e-02
# 75%    3.413751e-01
# max    4.380858e+05
# std    5.542299e+02
#
# Null values:
# date                 0
# open_adj             0
# high_adj             0
# low_adj              0
# close_adj            0
# volume               0
# slope_annual    103613
# r2              103613
# slope_adj       103613
# ticker               0
# dtype: int64

# %%
# GitHub Copilot

# Filter df_ranking for January 15, 2001 and export to CSV
target_date = pd.Timestamp("2001-01-17")
subset = df_ranking[df_ranking["date"] == target_date]

out_path = os.path.join(VER_DIR, f"ranking_{target_date.date()}.csv")
subset.to_csv(out_path, index=False)

print(f"Saved {len(subset):,} rows for {target_date.date()} → {out_path}")
# Out:
# Saved 835 rows for 2001-01-17 → ./system_verification/9-ranking_dataset\ranking_2001-01-17.csv
