# %%
# run_pipeline.py
import papermill as pm
import sys
import os
import shutil

# Remove and recreate output folder
if os.path.exists("output"):
    shutil.rmtree("output")
os.makedirs("output", exist_ok=True)

notebooks =[
 '1-SP500MEMBERSHIPBUILDER.ipynb', 
 '1a-SP500_Join_Exit_Date.ipynb', 
 '2a-Incremental_price_fetch.ipynb', 
 '3-adjusted_All_Prices_OHLC.ipynb', 
 '4-ATR20_adjusted_All_Prices.ipynb', 
 '4a-Multiple-ATRs.ipynb', 
 '5-100D_MA_adjusted_all_prices.ipynb', 
 '6-90Day_jump_filter_adjusted_all_prices.ipynb', 
 '7-90Day_exp_regression_adjusted_all_prices.ipynb', 
 '7a-multiple-regressions.ipynb', 
 '8-SPY_200DMA_market_regime.ipynb', 
 '9-build_ranking_dataset.ipynb', 
 '9a-multiple-ranking_datasets.ipynb', 
 '10-build_100MA_filtered_universe.ipynb', 
 '10a-multiple_100MA_filtered.ipynb', 
 '11-build_90D_jump_filtered_univers.ipynb', 
 '11a-mulitple_jump_filtered_universe.ipynb', 
 '12-trim_to_sp500.ipynb', 
 '12a-multiple-trim_sp500.ipynb', 
 '13-match_trade_generator.ipynb', 
 '13-regime_pct_cap_trading_engine.ipynb', 
 '13a-strategy_vs_spy.ipynb', 
 '13a-sweep-trading_engine.ipynb', 
 '13b-wfo.ipynb', 
 '13c-wfo_vs_spy.ipynb', 
 '13d-wfo_monte_carlo.ipynb', 
 '13e-rankings_vs_trades.ipynb', 
 '14-math_verification.ipynb', 
 '15a-weekly_report_with_rankings.ipynb', 
 '15b-cash-monitoring.ipynb', 
 '15c-cashwithraw.ipynb', 
 '15d-position_too_big.ipynb', 
 '16-Monte-Carlo.ipynb', 
 '17-robustness_suite.ipynb',
 '17c-industry_standard_cost_slippage.ipynb', 
 '18_risk_adjusted_full_report.ipynb', 
 '23-robustness_test.ipynb', 
 '24-crash_test.ipynb', 
 '25-return_analysis.ipynb', 
 '25a-cashflow.ipynb', 
 '25b-monthly_profit.ipynb', '25c-convexity_test.ipynb', 
 '25d-Monthly-components.ipynb', '25d-min_cash.ipynb', 
]
failed = []

for nb in notebooks:
    try:
        print(f"\n{'='*50}")
        print(f"Running: {nb}")
        print('='*50)
        
        pm.execute_notebook(nb, f"output/{nb}", kernel_name="python3")
        
        print(f"✓ Completed: {nb}")
        
    except Exception as e:
        print(f"✗ Failed: {nb}")
        print(f"  Error: {e}")
        failed.append(nb)
        
        # Option: stop on first failure
        # sys.exit(1)

print(f"\n{'='*50}")
print(f"Summary: {len(notebooks) - len(failed)}/{len(notebooks)} succeeded")
if failed:
    print(f"Failed: {failed}")
# Out:
# ==================================================
# Running: 1-SP500MEMBERSHIPBUILDER.ipynb
# ==================================================
# Executing:   0%|          | 0/11 [00:00<?, ?cell/s]
# ✗ Failed: 1-SP500MEMBERSHIPBUILDER.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [6]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_2005 = pd.read_parquet("./sp500_membership_daily_matrix/sp500_membership_2005.parquet")
#       2 df_2005
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)    270         **kwargs,
#     271     )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './sp500_membership_daily_matrix/sp500_membership_2005.parquet'
#
#
# ==================================================
# Running: 1a-SP500_Join_Exit_Date.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 1a-SP500_Join_Exit_Date.ipynb
#
# ==================================================
# Running: 2a-Incremental_price_fetch.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 2a-Incremental_price_fetch.ipynb
#
# ==================================================
# Running: 3-adjusted_All_Prices_OHLC.ipynb
# ==================================================
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# ✓ Completed: 3-adjusted_All_Prices_OHLC.ipynb
#
# ==================================================
# Running: 4-ATR20_adjusted_All_Prices.ipynb
# ==================================================
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# ✓ Completed: 4-ATR20_adjusted_All_Prices.ipynb
#
# ==================================================
# Running: 4a-Multiple-ATRs.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 4a-Multiple-ATRs.ipynb
#
# ==================================================
# Running: 5-100D_MA_adjusted_all_prices.ipynb
# ==================================================
# Executing:   0%|          | 0/2 [00:00<?, ?cell/s]
# ✗ Failed: 5-100D_MA_adjusted_all_prices.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [2]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Read the AAPL parquet file
# ----> 4 aapl_df = pd.read_parquet(r"C:\TWS API\source\pythonclient\TradingIdeas\Momentum System\5-100D_MA_adjusted_all_prices\AAPL.parquet")
#       6 # Display the dataframe
#       7 print(aapl_df)
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)    270         **kwargs,
#     271     )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\TWS API\\source\\pythonclient\\TradingIdeas\\Momentum System\\5-100D_MA_adjusted_all_prices\\AAPL.parquet'
#
#
# ==================================================
# Running: 6-90Day_jump_filter_adjusted_all_prices.ipynb
# ==================================================
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# ✗ Failed: 6-90Day_jump_filter_adjusted_all_prices.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [3]":
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 19
#      16 # Plot adjusted close over time with jump filter indicator
#      17 fig, ax = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
# ---> 19 ax[0].plot(df_aapl["date"], df_aapl["close_adj"], label="close_adj", color="tabblue")
#      20 ax[0].set_title("AAPL Adjusted Close")
#      21 ax[0].set_ylabel("Price")
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\axes\_base.py:546, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     544     return list(result)
#     545 else:
# --> 546     return [l[0] for l in result]
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\axes\_base.py:546, in <listcomp>(.0)
#     544     return list(result)
#     545 else:
# --> 546     return [l[0] for l in result]
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\axes\_base.py:539, in <genexpr>(.0)
#     534 else:
#     535     raise ValueError(
#     536         f"label must be scalar or have the same length as the input "
#     537         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 539 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     540                       {**kwargs, 'label': label})
#     541           for j, label in enumerate(labels))
#     543 if return_kwargs:
#     544     return list(result)
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\axes\_base.py:338, in _process_plot_var_args._make_line(self, axes, x, y, kw, kwargs)
#     336 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     337 self._setdefaults(self._getdefaults(kw), kw)
# --> 338 seg = mlines.Line2D(x, y, **kw)
#     339 return seg, kw
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\lines.py:390, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     387 self.set_drawstyle(drawstyle)
#     389 self._color = None
# --> 390 self.set_color(color)
#     391 if marker is None:
#     392     marker = 'none'  # Default.
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\lines.py:1081, in Line2D.set_color(self, color)
#    1073 def set_color(self, color):
#    1074     """
#    1075     Set the color of the line.
#    1076
#    (...)   1079     color : :mpltype:`color`
#    1080     """
# -> 1081     mcolors._check_color_like(color=color)
#    1082     self._color = color
#    1083     self.stale = True
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\matplotlib\colors.py:249, in _check_color_like(**kwargs)
#     247 for k, v in kwargs.items():
#     248     if not is_color_like(v):
# --> 249         raise ValueError(
#     250             f"{v!r} is not a valid value for {k}: supported inputs are "
#     251             f"(r, g, b) and (r, g, b, a) 0-1 float tuples; "
#     252             f"'#rrggbb', '#rrggbbaa', '#rgb', '#rgba' strings; "
#     253             f"named color strings; "
#     254             f"string reprs of 0-1 floats for grayscale values; "
#     255             f"'C0', 'C1', ... strings for colors of the color cycle; "
#     256             f"and pairs combining one of the above with an alpha value")
#
# ValueError: 'tabblue' is not a valid value for color: supported inputs are (r, g, b) and (r, g, b, a) 0-1 float tuples; '#rrggbb', '#rrggbbaa', '#rgb', '#rgba' strings; named color strings; string reprs of 0-1 floats for grayscale values; 'C0', 'C1', ... strings for colors of the color cycle; and pairs combining one of the above with an alpha value
#
#
# ==================================================
# Running: 7-90Day_exp_regression_adjusted_all_prices.ipynb
# ==================================================
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# ✓ Completed: 7-90Day_exp_regression_adjusted_all_prices.ipynb
#
# ==================================================
# Running: 7a-multiple-regressions.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 7a-multiple-regressions.ipynb
#
# ==================================================
# Running: 7b-explicitregressioncalc.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✗ Failed: 7b-explicitregressioncalc.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [1]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#       9 TRADING_DAYS = 250             # Annualization standard
#      11 # ============================================================
#      12 # LOAD PRICE DATA
#      13 # ============================================================
# ---> 14 df = pd.read_csv(FILE)
#      15 df["date"] = pd.to_datetime(df["date"])
#      16 df = df.sort_values("date").reset_index(drop=True)
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AAPL_raw_prices.csv'
#
#
# ==================================================
# Running: 8-SPY_200DMA_market_regime.ipynb
# ==================================================
# Executing:   0%|          | 0/2 [00:00<?, ?cell/s]
# ✓ Completed: 8-SPY_200DMA_market_regime.ipynb
#
# ==================================================
# Running: 9-build_ranking_dataset.ipynb
# ==================================================
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# ✓ Completed: 9-build_ranking_dataset.ipynb
#
# ==================================================
# Running: 9a-multiple-ranking_datasets.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 9a-multiple-ranking_datasets.ipynb
#
# ==================================================
# Running: 10-build_100MA_filtered_universe.ipynb
# ==================================================
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# ✓ Completed: 10-build_100MA_filtered_universe.ipynb
#
# ==================================================
# Running: 10a-multiple_100MA_filtered.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 10a-multiple_100MA_filtered.ipynb
#
# ==================================================
# Running: 11-build_90D_jump_filtered_univers.ipynb
# ==================================================
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# ✓ Completed: 11-build_90D_jump_filtered_univers.ipynb
#
# ==================================================
# Running: 11a-mulitple_jump_filtered_universe.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 11a-mulitple_jump_filtered_universe.ipynb
#
# ==================================================
# Running: 12 - trim_to_sp500.ipynb
# ==================================================
# Executing:   0%|          | 0/6 [00:00<?, ?cell/s]
# ✗ Failed: 12 - trim_to_sp500.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [2]":
#   Cell In[2], line 1
#     df[(df['ticker']=='TWX') & (df['date'].dt.date == datetime(1999,1,06).date())][['ticker','date','slope_adj','atr20','close_adj']]
#                                                                       ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#
#
#
# ==================================================
# Running: 12a-multiple-trim_sp500.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 12a-multiple-trim_sp500.ipynb
#
# ==================================================
# Running: 13-match_trade_generator.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 13-match_trade_generator.ipynb
#
# ==================================================
# Running: 13-regime_pct_cap_trading_engine.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 13-regime_pct_cap_trading_engine.ipynb
#
# ==================================================
# Running: 13a-strategy_vs_spy.ipynb
# ==================================================
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# ✓ Completed: 13a-strategy_vs_spy.ipynb
#
# ==================================================
# Running: 13a-sweep-trading_engine.ipynb
# ==================================================
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# ✓ Completed: 13a-sweep-trading_engine.ipynb
#
# ==================================================
# Running: 13b-wfo.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 13b-wfo.ipynb
#
# ==================================================
# Running: 13c-wfo_vs_spy.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 13c-wfo_vs_spy.ipynb
#
# ==================================================
# Running: 13d-wfo_monte_carlo.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 13d-wfo_monte_carlo.ipynb
#
# ==================================================
# Running: 13e-rankings_vs_trades.ipynb
# ==================================================
# Executing:   0%|          | 0/2 [00:00<?, ?cell/s]
# ✓ Completed: 13e-rankings_vs_trades.ipynb
#
# ==================================================
# Running: 14-math_verification.ipynb
# ==================================================
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# ✗ Failed: 14-math_verification.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [2]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 26
#      21     return date.day_name() == REBALANCE_DAY
#      23 # -----------------------
#      24 # Load trades/equity
#      25 # -----------------------
# ---> 26 trades = pd.read_parquet(TRADES_FILE).copy()
#      27 trades["signal_date"] = pd.to_datetime(trades["signal_date"])
#      28 trades["exec_date"]   = pd.to_datetime(trades["exec_date"])
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)    270         **kwargs,
#     271     )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './13-trading_output_regression_insp500_spyfilter/13-trades_regression_insp500_spyfilter.parquet'
#
#
# ==================================================
# Running: 15a-weekly_report_with_rankings.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 15a-weekly_report_with_rankings.ipynb
#
# ==================================================
# Running: 15b-cash-monitoring.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 15b-cash-monitoring.ipynb
#
# ==================================================
# Running: 15c-cashwithraw.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 15c-cashwithraw.ipynb
#
# ==================================================
# Running: 15d-position_too_big.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 15d-position_too_big.ipynb
#
# ==================================================
# Running: 16-Monte-Carlo.ipynb
# ==================================================
# Executing:   0%|          | 0/2 [00:00<?, ?cell/s]
# ✓ Completed: 16-Monte-Carlo.ipynb
#
# ==================================================
# Running: 17-robustness_suite.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 17-robustness_suite.ipynb
#
# ==================================================
# Running: 17c-industry_standard_cost_slippage.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 17c-industry_standard_cost_slippage.ipynb
#
# ==================================================
# Running: 18-parameter_grid.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✗ Failed: 18-parameter_grid.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [1]":
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[1], line 137
#     133     return res_df
#     136 if __name__ == "__main__":
# --> 137     run_param_grid()
#
# Cell In[1], line 108, in run_param_grid()
#     105 print(f"\n[{i}/{len(param_grid)}] Params: {params}")
#     107 # ---- run your engine here ----
# --> 108 eq = run_backtest(params)  # you must implement this
#     110 eq = eq.sort_values("date")
#     111 eq["ret"] = eq["portfolio_value"].pct_change()
#
# Cell In[1], line 64, in run_backtest(params)
#      53 def run_backtest(params: dict) -> pd.DataFrame:
#      54     """
#      55     Placeholder hook.
#      56     You should modify your trading-engine script to accept these params,
#    (...)     62       DataFrame with columns: ['date', 'portfolio_value']
#      63     """
# ---> 64     raise NotImplementedError(
#      65         "Implement run_backtest(params) to connect to your engine."
#      66     )
#
# NotImplementedError: Implement run_backtest(params) to connect to your engine.
#
#
# ==================================================
# Running: 18_risk_adjusted_full_report.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✗ Failed: 18_risk_adjusted_full_report.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [1]":
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 691
#     687     print("\n=== LOOKAHEAD AUDIT COMPLETE ===\n")
#     690 if __name__ == "__main__":
# --> 691     main()
#
# Cell In[1], line 649, in main()
#     647 # 1) Deterministic lag scenarios: 0, 1, 3, 5 days
#     648 for lag in LAG_SCENARIOS:
# --> 649     eq_df, trades, rebal_df, st = run_strategy_with_lag(
#     650         signal_lag_days=lag,
#     651         random_lag=False,
#     652         label=f"lag_{lag}d"
#     653     )
#     654     all_stats.append(st)
#     656 # 2) Random lag scenario: 0–RAND_LAG_MAX days
#
# Cell In[1], line 339, in run_strategy_with_lag(signal_lag_days, random_lag, max_random_lag, label)
#     337 # SPY regime at signal date
#     338 if "market_regime" in univ:
# --> 339     spy_regime_signal = int(univ["market_regime"].iloc[0])
#     340 else:
#     341     spy_regime_signal = None
#
# ValueError: cannot convert float NaN to integer
#
#
# ==================================================
# Running: 22-bias_framework.ipynb
# ==================================================
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# ✗ Failed: 22-bias_framework.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [1]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 759
#     756 if __name__ == "__main__":
#     757     # 1) Load universes
#     758     print("Loading tradable universe...")
# --> 759     df_tradable = load_universe(TRADABLE_FILE)
#     761     print("Loading full universe...")
#     762     df_full = load_universe(FULL_UNIVERSE_FILE)
#
# Cell In[1], line 120, in load_universe(path)
#     107 def load_universe(path: str) -> pd.DataFrame:
#     108     """
#     109     Load a universe parquet with at least:
#     110       - date
#    (...)    118     Returns a clean DataFrame sorted by date, ticker.
#     119     """
# --> 120     df = pd.read_parquet(path)
#     121     df["date"] = pd.to_datetime(df["date"])
#     122     df = df.sort_values(["date", "ticker"]).reset_index(drop=True)
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)    270         **kwargs,
#     271     )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\TWS API\\source\\pythonclient\\TradingIdeas\\Momentum System\\12-tradable_sp500_universe\\12-tradable_sp500_universe.parquet'
#
#
# ==================================================
# Running: 23-robustness_test.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✗ Failed: 23-robustness_test.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [1]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 84
#      79 # ============================================================
#      80 # LOAD DATA
#      81 # ============================================================
#      83 print("Loading tradable universe...")
# ---> 84 trad = pd.read_parquet(UNIVERSE_TRADABLE)
#      85 trad["date"] = pd.to_datetime(trad["date"])
#      87 print("Loading full universe...")
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)    270         **kwargs,
#     271     )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\TWS API\\source\\pythonclient\\TradingIdeas\\Momentum System\\12-tradable_sp500_universe\\12-tradable_sp500_universe.parquet'
#
#
# ==================================================
# Running: 24-crash_test.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✗ Failed: 24-crash_test.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [1]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 68
#      61     return eq.iloc[-1] / eq.iloc[0] - 1.0
#      64 # ============================================================
#      65 # LOAD MOMENTUM EQUITY (CURRENT SCHEMA)
#      66 # ============================================================
# ---> 68 eq_df = pd.read_parquet(BASELINE_FILE)
#      70 # Normalize date handling
#      71 if "date" in eq_df.columns:
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)    270         **kwargs,
#     271     )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './13-trading_output_regression_insp500_spyfilter\\13-equity_curve_regression_insp500_spyfilter.parquet'
#
#
# ==================================================
# Running: 25-return_analysis.ipynb
# ==================================================
# Executing:   0%|          | 0/2 [00:00<?, ?cell/s]
# ✓ Completed: 25-return_analysis.ipynb
#
# ==================================================
# Running: 25a-cashflow.ipynb
# ==================================================
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# ✗ Failed: 25a-cashflow.ipynb
#   Error:
# ---------------------------------------------------------------------------
# Exception encountered at "In [2]":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 EQUITY_FILE = "./13-trading_output_regression_insp500_spyfilter/13-equity_curve_regression_insp500_spyfilter.parquet"
#       5 MIN_CASH_RESERVE = 2000.0
# ----> 7 eq = pd.read_parquet(EQUITY_FILE).copy()
#       8 eq["date"] = pd.to_datetime(eq["date"])
#       9 eq = eq.sort_values("date").set_index("date")
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)    270         **kwargs,
#     271     )
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\farty\anaconda3\envs\my_quant_lab\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './13-trading_output_regression_insp500_spyfilter/13-equity_curve_regression_insp500_spyfilter.parquet'
#
#
# ==================================================
# Running: 25b-monthly_profit.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 25b-monthly_profit.ipynb
#
# ==================================================
# Running: 25c-convexity_test.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 25c-convexity_test.ipynb
#
# ==================================================
# Running: 25d-Monthly-components.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 25d-Monthly-components.ipynb
#
# ==================================================
# Running: 25d-min_cash.ipynb
# ==================================================
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# ✓ Completed: 25d-min_cash.ipynb
#
# ==================================================
# Summary: 35/47 succeeded
# Failed: ['1-SP500MEMBERSHIPBUILDER.ipynb', '5-100D_MA_adjusted_all_prices.ipynb', '6-90Day_jump_filter_adjusted_all_prices.ipynb', '7b-explicitregressioncalc.ipynb', '12 - trim_to_sp500.ipynb', '14-math_verification.ipynb', '18-parameter_grid.ipynb', '18_risk_adjusted_full_report.ipynb', '22-bias_framework.ipynb', '23-robustness_test.ipynb', '24-crash_test.ipynb', '25a-cashflow.ipynb']
