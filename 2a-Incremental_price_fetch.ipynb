# %%
"""
Incrementally updates SHARADAR SEP price files for all tickers in the S&P 500 membership matrix.
Loads the Nasdaq Data Link API key, fetches full histories for missing tickers and only new rows
after the latest date for existing files, warns when data is stale beyond MAX_STALE_DAYS, and
persists per-ticker CSVs in ./2-all_prices/sharadar_sep_full.

Use case: run after executing 2b-Bootrap_All_Prices.ipynb to keep SHARADAR SEP data up to date.
"""
import os
import pandas as pd
import numpy as np
import nasdaqdatalink
from datetime import timedelta
from dotenv import load_dotenv
load_dotenv()

nasdaqdatalink_key = os.getenv("NASDAQ_DATA_LINK_API_KEY")
nasdaqdatalink.ApiConfig.api_key = nasdaqdatalink_key


INPUT_FOLDER  = "./2-all_prices/sharadar_sep_full"
OUTPUT_FOLDER = "./2-all_prices/sharadar_sep_full"

os.makedirs(OUTPUT_FOLDER, exist_ok=True)

MEMBERSHIP_FILE = "./1-sp500_membership_daily_matrix/sp500_membership_full.parquet"
membership = pd.read_parquet(MEMBERSHIP_FILE)
all_tickers = sorted(membership.index.tolist())

MAX_STALE_DAYS = 90   # warn if no update for > 90 days


def get_incremental_sep(ticker, last_date):
    """
    Safely fetch SEP rows strictly AFTER last_date.
    Handles long gaps, weekends, holidays.
    """
    start_date = last_date + timedelta(days=1)

    df_new = nasdaqdatalink.get_table(
        "SHARADAR/SEP",
        ticker=[ticker],
        date={'gte': start_date},
        paginate=True
    )

    if df_new is None or df_new.empty:
        return pd.DataFrame()

    df_new["date"] = pd.to_datetime(df_new["date"])
    df_new = df_new.sort_values("date")

    return df_new


print("\n=== INCREMENTAL SHARADAR SEP UPDATE ===\n")

for tk in all_tickers:

    file_path = os.path.join(INPUT_FOLDER, f"{tk}.csv")

    # -------------------------------
    # CASE 1: No existing file → full download
    # -------------------------------
    if not os.path.exists(file_path):
        print(f"[NEW] {tk}: downloading FULL history...")

        df = nasdaqdatalink.get_table(
            "SHARADAR/SEP",
            ticker=[tk],
            paginate=True
        )

        if df is None or df.empty:
            print(f"⚠ No data found for {tk}")
            continue

        df["date"] = pd.to_datetime(df["date"])
        df = df.sort_values("date").drop_duplicates(subset=["date"])

        df.to_csv(file_path, index=False)
        continue

    # -------------------------------
    # CASE 2: Incremental update
    # -------------------------------
    df_old = pd.read_csv(file_path)
    if df_old.empty:
        last_date = pd.Timestamp("1900-01-01")
    else:
        df_old["date"] = pd.to_datetime(df_old["date"])
        last_date = df_old["date"].max()

    days_stale = (pd.Timestamp.today().normalize() - last_date).days

    if days_stale > MAX_STALE_DAYS:
        print(f"⚠ WARNING: {tk} last update {days_stale} days ago (last date {last_date.date()})")

    print(f"[UPDATE] {tk}: last = {last_date.date()} → checking for new rows...")

    df_new = get_incremental_sep(tk, last_date)

    if df_new.empty:
        print("    → No new data")
        continue

    print(f"    → Appending {len(df_new)} new rows (through {df_new['date'].max().date()})")

    # merge and dedupe
    df_updated = pd.concat([df_old, df_new], ignore_index=True)
    df_updated = df_updated.sort_values("date").drop_duplicates(subset=["date"])

    df_updated.to_csv(file_path, index=False)

print("\n=== DONE: Incremental update complete ===")
# Out:
# === INCREMENTAL SHARADAR SEP UPDATE ===
#
# [UPDATE] A: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AAL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AAMRQ last update 4417 days ago (last date 2013-12-05)
# [UPDATE] AAMRQ: last = 2013-12-05 → checking for new rows...
#     → No new data
# [UPDATE] AAP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AAPL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ABBV: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ABI1 last update 6257 days ago (last date 2008-11-21)
# [UPDATE] ABI1: last = 2008-11-21 → checking for new rows...
#     → No new data
# ⚠ WARNING: ABKFQ last update 5532 days ago (last date 2010-11-16)
# [UPDATE] ABKFQ: last = 2010-11-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: ABMD last update 1114 days ago (last date 2022-12-21)
# [UPDATE] ABMD: last = 2022-12-21 → checking for new rows...
#     → No new data
# [UPDATE] ABNB: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ABS last update 7161 days ago (last date 2006-06-01)
# [UPDATE] ABS: last = 2006-06-01 → checking for new rows...
#     → No new data
# [UPDATE] ABT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ACAS last update 3292 days ago (last date 2017-01-03)
# [UPDATE] ACAS: last = 2017-01-03 → checking for new rows...
#     → No new data
# [UPDATE] ACGL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ACKHQ last update 6602 days ago (last date 2007-12-12)
# [UPDATE] ACKHQ: last = 2007-12-12 → checking for new rows...
#     → No new data
# [UPDATE] ACN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ACS last update 5816 days ago (last date 2010-02-05)
# [UPDATE] ACS: last = 2010-02-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: ACV1 last update 5357 days ago (last date 2011-05-10)
# [UPDATE] ACV1: last = 2011-05-10 → checking for new rows...
#     → No new data
# [NEW] AD2: downloading FULL history...
# ⚠ No data found for AD2
# [UPDATE] ADBE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ADCT1 last update 5509 days ago (last date 2010-12-09)
# [UPDATE] ADCT1: last = 2010-12-09 → checking for new rows...
#     → No new data
# [UPDATE] ADI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ADM: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ADP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ADSK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ADT1 last update 3541 days ago (last date 2016-04-29)
# [UPDATE] ADT1: last = 2016-04-29 → checking for new rows...
#     → No new data
# [UPDATE] AEE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AEP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AES: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AET last update 2598 days ago (last date 2018-11-28)
# [UPDATE] AET: last = 2018-11-28 → checking for new rows...
#     → No new data
# [UPDATE] AFL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AFS.A last update 9170 days ago (last date 2000-11-30)
# [UPDATE] AFS.A: last = 2000-11-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: AGC1 last update 8899 days ago (last date 2001-08-28)
# [UPDATE] AGC1: last = 2001-08-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: AGN last update 2071 days ago (last date 2020-05-08)
# [UPDATE] AGN: last = 2020-05-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: AGN1 last update 3951 days ago (last date 2015-03-16)
# [UPDATE] AGN1: last = 2015-03-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: AHM1 last update 9961 days ago (last date 1998-10-01)
# [UPDATE] AHM1: last = 1998-10-01 → checking for new rows...
#     → No new data
# [UPDATE] AIG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AIT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AIV: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AIZ: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AJG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AKAM: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AKS last update 2128 days ago (last date 2020-03-12)
# [UPDATE] AKS: last = 2020-03-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: AL1 last update 6631 days ago (last date 2007-11-13)
# [UPDATE] AL1: last = 2007-11-13 → checking for new rows...
#     → No new data
# [UPDATE] ALB: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ALGN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ALK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ALL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ALLE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ALTR1 last update 3668 days ago (last date 2015-12-24)
# [UPDATE] ALTR1: last = 2015-12-24 → checking for new rows...
#     → No new data
# ⚠ WARNING: ALXN last update 1632 days ago (last date 2021-07-21)
# [UPDATE] ALXN: last = 2021-07-21 → checking for new rows...
#     → No new data
# ⚠ WARNING: AM1 last update 4536 days ago (last date 2013-08-08)
# [UPDATE] AM1: last = 2013-08-08 → checking for new rows...
#     → No new data
# [UPDATE] AMAT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AMCC last update 3269 days ago (last date 2017-01-26)
# [UPDATE] AMCC: last = 2017-01-26 → checking for new rows...
#     → No new data
# [UPDATE] AMCR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AMD: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AME: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AMG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AMGN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AMP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AMP1 last update 9779 days ago (last date 1999-04-01)
# [UPDATE] AMP1: last = 1999-04-01 → checking for new rows...
#     → No new data
# [UPDATE] AMT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AMTM: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AMZN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AN1 last update 9870 days ago (last date 1998-12-31)
# [UPDATE] AN1: last = 1998-12-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANDV last update 2659 days ago (last date 2018-09-28)
# [UPDATE] ANDV: last = 2018-09-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANDW last update 6587 days ago (last date 2007-12-27)
# [UPDATE] ANDW: last = 2007-12-27 → checking for new rows...
#     → No new data
# [UPDATE] ANET: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ANF: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ANRZQ last update 3453 days ago (last date 2016-07-26)
# [UPDATE] ANRZQ: last = 2016-07-26 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANSS last update 175 days ago (last date 2025-07-17)
# [UPDATE] ANSS: last = 2025-07-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANV1 last update 9771 days ago (last date 1999-04-09)
# [UPDATE] ANV1: last = 1999-04-09 → checking for new rows...
#     → No new data
# [UPDATE] AON: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AOS: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] APA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: APC last update 2345 days ago (last date 2019-08-08)
# [UPDATE] APC: last = 2019-08-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: APCC last update 6903 days ago (last date 2007-02-14)
# [UPDATE] APCC: last = 2007-02-14 → checking for new rows...
#     → No new data
# [UPDATE] APD: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] APH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] APO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: APOL last update 3263 days ago (last date 2017-02-01)
# [UPDATE] APOL: last = 2017-02-01 → checking for new rows...
#     → No new data
# [UPDATE] APP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] APTV: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AR1 last update 9549 days ago (last date 1999-11-17)
# [UPDATE] AR1: last = 1999-11-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: ARC1 last update 9397 days ago (last date 2000-04-17)
# [UPDATE] ARC1: last = 2000-04-17 → checking for new rows...
#     → No new data
# [UPDATE] ARE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ARES: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ARG last update 3520 days ago (last date 2016-05-20)
# [UPDATE] ARG: last = 2016-05-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: AS1 last update 9597 days ago (last date 1999-09-30)
# [UPDATE] AS1: last = 1999-09-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: ASC1 last update 9696 days ago (last date 1999-06-23)
# [UPDATE] ASC1: last = 1999-06-23 → checking for new rows...
#     → No new data
# [UPDATE] ASH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ASN last update 6671 days ago (last date 2007-10-04)
# [UPDATE] ASN: last = 2007-10-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: ASND1 last update 9695 days ago (last date 1999-06-24)
# [UPDATE] ASND1: last = 1999-06-24 → checking for new rows...
#     → No new data
# ⚠ WARNING: ASO1 last update 7006 days ago (last date 2006-11-03)
# [UPDATE] ASO1: last = 2006-11-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: AT1 last update 6629 days ago (last date 2007-11-15)
# [UPDATE] AT1: last = 2007-11-15 → checking for new rows...
#     → No new data
# [UPDATE] ATGE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ATI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ATI1 last update 9690 days ago (last date 1999-06-29)
# [UPDATE] ATI1: last = 1999-06-29 → checking for new rows...
#     → No new data
# [UPDATE] ATO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ATVI last update 819 days ago (last date 2023-10-12)
# [UPDATE] ATVI: last = 2023-10-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: AV1 last update 6650 days ago (last date 2007-10-25)
# [UPDATE] AV1: last = 2007-10-25 → checking for new rows...
#     → No new data
# [UPDATE] AVB: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AVGO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AVP last update 2197 days ago (last date 2020-01-03)
# [UPDATE] AVP: last = 2020-01-03 → checking for new rows...
#     → No new data
# [UPDATE] AVY: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AW last update 6243 days ago (last date 2008-12-05)
# [UPDATE] AW: last = 2008-12-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: AWE last update 7744 days ago (last date 2004-10-26)
# [UPDATE] AWE: last = 2004-10-26 → checking for new rows...
#     → No new data
# [UPDATE] AWK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AXON: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] AXP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AYE last update 5431 days ago (last date 2011-02-25)
# [UPDATE] AYE: last = 2011-02-25 → checking for new rows...
#     → No new data
# [UPDATE] AYI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: AZA.A last update 8966 days ago (last date 2001-06-22)
# [UPDATE] AZA.A: last = 2001-06-22 → checking for new rows...
#     → No new data
# [UPDATE] AZO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] B: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BAC: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BAC1 last update 9962 days ago (last date 1998-09-30)
# [UPDATE] BAC1: last = 1998-09-30 → checking for new rows...
#     → No new data
# [UPDATE] BALL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BAX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BAY1 last update 9995 days ago (last date 1998-08-28)
# [UPDATE] BAY1: last = 1998-08-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: BBBYQ last update 982 days ago (last date 2023-05-02)
# [UPDATE] BBBYQ: last = 2023-05-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: BBI1 last update 10226 days ago (last date 1998-01-09)
# [UPDATE] BBI1: last = 1998-01-09 → checking for new rows...
#     → No new data
# [UPDATE] BBWI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BBY: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BC: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BCR last update 2933 days ago (last date 2017-12-28)
# [UPDATE] BCR: last = 2017-12-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: BDK last update 5781 days ago (last date 2010-03-12)
# [UPDATE] BDK: last = 2010-03-12 → checking for new rows...
#     → No new data
# [UPDATE] BDX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BEAM2 last update 4271 days ago (last date 2014-04-30)
# [UPDATE] BEAM2: last = 2014-04-30 → checking for new rows...
#     → No new data
# [UPDATE] BEN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BF.B: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BFH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BFI1 last update 9659 days ago (last date 1999-07-30)
# [UPDATE] BFI1: last = 1999-07-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: BFO1 last update 9227 days ago (last date 2000-10-04)
# [UPDATE] BFO1: last = 2000-10-04 → checking for new rows...
#     → No new data
# [UPDATE] BG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BGEN last update 8093 days ago (last date 2003-11-12)
# [UPDATE] BGEN: last = 2003-11-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: BGGSQ last update 1828 days ago (last date 2021-01-06)
# [UPDATE] BGGSQ: last = 2021-01-06 → checking for new rows...
#     → No new data
# [UPDATE] BHF: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BHI last update 3111 days ago (last date 2017-07-03)
# [UPDATE] BHI: last = 2017-07-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: BHMSQ last update 8039 days ago (last date 2004-01-05)
# [UPDATE] BHMSQ: last = 2004-01-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: BIGGQ last update 486 days ago (last date 2024-09-09)
# [UPDATE] BIGGQ: last = 2024-09-09 → checking for new rows...
#     → No new data
# [UPDATE] BIIB: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BIO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BJS last update 5734 days ago (last date 2010-04-28)
# [UPDATE] BJS: last = 2010-04-28 → checking for new rows...
#     → No new data
# [UPDATE] BK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BKB last update 9597 days ago (last date 1999-09-30)
# [UPDATE] BKB: last = 1999-09-30 → checking for new rows...
#     → No new data
# [UPDATE] BKNG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BKR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BLDR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BLK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BLS last update 6950 days ago (last date 2006-12-29)
# [UPDATE] BLS: last = 2006-12-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMC last update 4503 days ago (last date 2013-09-10)
# [UPDATE] BMC: last = 2013-09-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMET last update 6680 days ago (last date 2007-09-25)
# [UPDATE] BMET: last = 2007-09-25 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMGCA last update 9129 days ago (last date 2001-01-10)
# [UPDATE] BMGCA: last = 2001-01-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMS last update 2404 days ago (last date 2019-06-10)
# [UPDATE] BMS: last = 2019-06-10 → checking for new rows...
#     → No new data
# [UPDATE] BMY: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BNI last update 5809 days ago (last date 2010-02-12)
# [UPDATE] BNI: last = 2010-02-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: BNL1 last update 10054 days ago (last date 1998-06-30)
# [UPDATE] BNL1: last = 1998-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: BOL last update 6649 days ago (last date 2007-10-26)
# [UPDATE] BOL: last = 2007-10-26 → checking for new rows...
#     → No new data
# [UPDATE] BR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BR1 last update 7223 days ago (last date 2006-03-31)
# [UPDATE] BR1: last = 2006-03-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: BRCM last update 3632 days ago (last date 2016-01-29)
# [UPDATE] BRCM: last = 2016-01-29 → checking for new rows...
#     → No new data
# [UPDATE] BRK.B: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BRL last update 6226 days ago (last date 2008-12-22)
# [UPDATE] BRL: last = 2008-12-22 → checking for new rows...
#     → No new data
# [NEW] BRNO: downloading FULL history...
# ⚠ No data found for BRNO
# [UPDATE] BRO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BSC1 last update 6432 days ago (last date 2008-05-30)
# [UPDATE] BSC1: last = 2008-05-30 → checking for new rows...
#     → No new data
# [UPDATE] BSX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BT1 last update 9716 days ago (last date 1999-06-03)
# [UPDATE] BT1: last = 1999-06-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: BTUUQ last update 3202 days ago (last date 2017-04-03)
# [UPDATE] BTUUQ: last = 2017-04-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: BUD1 last update 6261 days ago (last date 2008-11-17)
# [UPDATE] BUD1: last = 2008-11-17 → checking for new rows...
#     → No new data
# [NEW] BV2: downloading FULL history...
# ⚠ No data found for BV2
# ⚠ WARNING: BVSN last update 2061 days ago (last date 2020-05-18)
# [UPDATE] BVSN: last = 2020-05-18 → checking for new rows...
#     → No new data
# [UPDATE] BWA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] BX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: BXLT last update 3507 days ago (last date 2016-06-02)
# [UPDATE] BXLT: last = 2016-06-02 → checking for new rows...
#     → No new data
# [UPDATE] BXP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] C: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: C1 last update 9919 days ago (last date 1998-11-12)
# [UPDATE] C1: last = 1998-11-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: CA1 last update 2621 days ago (last date 2018-11-05)
# [UPDATE] CA1: last = 2018-11-05 → checking for new rows...
#     → No new data
# [UPDATE] CAG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CAH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CAL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CAM2 last update 3569 days ago (last date 2016-04-01)
# [UPDATE] CAM2: last = 2016-04-01 → checking for new rows...
#     → No new data
# [UPDATE] CAR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CARR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CAT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CB: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CB1 last update 3647 days ago (last date 2016-01-14)
# [UPDATE] CB1: last = 2016-01-14 → checking for new rows...
#     → No new data
# [NEW] CBB1: downloading FULL history...
# ⚠ No data found for CBB1
# ⚠ WARNING: CBE last update 4787 days ago (last date 2012-11-30)
# [UPDATE] CBE: last = 2012-11-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: CBH1 last update 6495 days ago (last date 2008-03-28)
# [UPDATE] CBH1: last = 2008-03-28 → checking for new rows...
#     → No new data
# [UPDATE] CBOE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CBRE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CBS1 last update 9381 days ago (last date 2000-05-03)
# [UPDATE] CBS1: last = 2000-05-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: CBSS last update 6699 days ago (last date 2007-09-06)
# [UPDATE] CBSS: last = 2007-09-06 → checking for new rows...
#     → No new data
# ⚠ WARNING: CCE1 last update 3513 days ago (last date 2016-05-27)
# [UPDATE] CCE1: last = 2016-05-27 → checking for new rows...
#     → No new data
# [UPDATE] CCI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CCI1 last update 9955 days ago (last date 1998-10-07)
# [UPDATE] CCI1: last = 1998-10-07 → checking for new rows...
#     → No new data
# [UPDATE] CCK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CCL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CCTYQ last update 6197 days ago (last date 2009-01-20)
# [UPDATE] CCTYQ: last = 2009-01-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: CCU1 last update 6372 days ago (last date 2008-07-29)
# [UPDATE] CCU1: last = 2008-07-29 → checking for new rows...
#     → No new data
# [UPDATE] CDNS: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CDW: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CE1 last update 7987 days ago (last date 2004-02-26)
# [UPDATE] CE1: last = 2004-02-26 → checking for new rows...
#     → No new data
# [UPDATE] CEG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CEG1 last update 5050 days ago (last date 2012-03-12)
# [UPDATE] CEG1: last = 2012-03-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: CELG last update 2241 days ago (last date 2019-11-20)
# [UPDATE] CELG: last = 2019-11-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: CEM1 last update 8464 days ago (last date 2002-11-06)
# [UPDATE] CEM1: last = 2002-11-06 → checking for new rows...
#     → No new data
# ⚠ WARNING: CEN1 last update 6637 days ago (last date 2007-11-07)
# [UPDATE] CEN1: last = 2007-11-07 → checking for new rows...
#     → No new data
# ⚠ WARNING: CEPH last update 5201 days ago (last date 2011-10-13)
# [UPDATE] CEPH: last = 2011-10-13 → checking for new rows...
#     → No new data
# ⚠ WARNING: CERN last update 1311 days ago (last date 2022-06-07)
# [UPDATE] CERN: last = 2022-06-07 → checking for new rows...
#     → No new data
# [UPDATE] CF: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CF1 last update 7800 days ago (last date 2004-08-31)
# [UPDATE] CF1: last = 2004-08-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: CFC last update 6401 days ago (last date 2008-06-30)
# [UPDATE] CFC: last = 2008-06-30 → checking for new rows...
#     → No new data
# [UPDATE] CFG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CFL1 last update 10118 days ago (last date 1998-04-27)
# [UPDATE] CFL1: last = 1998-04-27 → checking for new rows...
#     → No new data
# ⚠ WARNING: CFN last update 3951 days ago (last date 2015-03-16)
# [UPDATE] CFN: last = 2015-03-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: CG1 last update 9199 days ago (last date 2000-11-01)
# [UPDATE] CG1: last = 2000-11-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CGP last update 9110 days ago (last date 2001-01-29)
# [UPDATE] CGP: last = 2001-01-29 → checking for new rows...
#     → No new data
# [NEW] CGW2: downloading FULL history...
# ⚠ No data found for CGW2
# ⚠ WARNING: CHA1 last update 9333 days ago (last date 2000-06-20)
# [UPDATE] CHA1: last = 2000-06-20 → checking for new rows...
#     → No new data
# [UPDATE] CHD: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CHIR1 last update 7204 days ago (last date 2006-04-19)
# [UPDATE] CHIR1: last = 2006-04-19 → checking for new rows...
#     → No new data
# ⚠ WARNING: CHKAQ last update 1793 days ago (last date 2021-02-10)
# [UPDATE] CHKAQ: last = 2021-02-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: CHRS1 last update 4956 days ago (last date 2012-06-14)
# [UPDATE] CHRS1: last = 2012-06-14 → checking for new rows...
#     → No new data
# [UPDATE] CHRW: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CHTR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CIEN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CIN last update 7223 days ago (last date 2006-03-31)
# [UPDATE] CIN: last = 2006-03-31 → checking for new rows...
#     → No new data
# [UPDATE] CINF: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CIT.A last update 8987 days ago (last date 2001-06-01)
# [UPDATE] CIT.A: last = 2001-06-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CITGQ last update 5874 days ago (last date 2009-12-09)
# [UPDATE] CITGQ: last = 2009-12-09 → checking for new rows...
#     → No new data
# [NEW] CKL: downloading FULL history...
# ⚠ No data found for CKL
# [UPDATE] CL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CLF: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CLX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CMA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [NEW] CMB: downloading FULL history...
# ⚠ No data found for CMB
# [UPDATE] CMCSA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CMCSK last update 3681 days ago (last date 2015-12-11)
# [UPDATE] CMCSK: last = 2015-12-11 → checking for new rows...
#     → No new data
# [UPDATE] CME: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CMG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CMI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CMS: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CMVT last update 4721 days ago (last date 2013-02-04)
# [UPDATE] CMVT: last = 2013-02-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: CMX last update 6867 days ago (last date 2007-03-22)
# [UPDATE] CMX: last = 2007-03-22 → checking for new rows...
#     → No new data
# [UPDATE] CNC: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CNCEQ last update 8554 days ago (last date 2002-08-08)
# [UPDATE] CNCEQ: last = 2002-08-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: CNG last update 9477 days ago (last date 2000-01-28)
# [UPDATE] CNG: last = 2000-01-28 → checking for new rows...
#     → No new data
# [UPDATE] CNP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CNW last update 3724 days ago (last date 2015-10-29)
# [UPDATE] CNW: last = 2015-10-29 → checking for new rows...
#     → No new data
# [UPDATE] CNX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CNXT1 last update 5379 days ago (last date 2011-04-18)
# [UPDATE] CNXT1: last = 2011-04-18 → checking for new rows...
#     → No new data
# ⚠ WARNING: COC last update 8532 days ago (last date 2002-08-30)
# [UPDATE] COC: last = 2002-08-30 → checking for new rows...
#     → No new data
# [UPDATE] COF: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] COIN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: COL last update 2600 days ago (last date 2018-11-26)
# [UPDATE] COL: last = 2018-11-26 → checking for new rows...
#     → No new data
# ⚠ WARNING: COMS1 last update 5754 days ago (last date 2010-04-08)
# [UPDATE] COMS1: last = 2010-04-08 → checking for new rows...
#     → No new data
# [UPDATE] COO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] COP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] COR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] COST: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: COT1 last update 9677 days ago (last date 1999-07-12)
# [UPDATE] COT1: last = 1999-07-12 → checking for new rows...
#     → No new data
# [UPDATE] COTY: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: COV last update 4000 days ago (last date 2015-01-26)
# [UPDATE] COV: last = 2015-01-26 → checking for new rows...
#     → No new data
# [UPDATE] CPAY: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CPB: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CPGX last update 3479 days ago (last date 2016-06-30)
# [UPDATE] CPGX: last = 2016-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: CPNLQ last update 6551 days ago (last date 2008-02-01)
# [UPDATE] CPNLQ: last = 2008-02-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CPPRQ last update 1802 days ago (last date 2021-02-01)
# [UPDATE] CPPRQ: last = 2021-02-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CPQ last update 8651 days ago (last date 2002-05-03)
# [UPDATE] CPQ: last = 2002-05-03 → checking for new rows...
#     → No new data
# [UPDATE] CPRI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CPRT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CPT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CPWR last update 4042 days ago (last date 2014-12-15)
# [UPDATE] CPWR: last = 2014-12-15 → checking for new rows...
#     → No new data
# [UPDATE] CRH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CRL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CRM: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CRWD: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CSC last update 3205 days ago (last date 2017-03-31)
# [UPDATE] CSC: last = 2017-03-31 → checking for new rows...
#     → No new data
# [UPDATE] CSCO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CSE1 last update 9554 days ago (last date 1999-11-12)
# [UPDATE] CSE1: last = 1999-11-12 → checking for new rows...
#     → No new data
# [UPDATE] CSGP: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CSR1 last update 9338 days ago (last date 2000-06-15)
# [UPDATE] CSR1: last = 2000-06-15 → checking for new rows...
#     → No new data
# ⚠ WARNING: CSRA last update 2837 days ago (last date 2018-04-03)
# [UPDATE] CSRA: last = 2018-04-03 → checking for new rows...
#     → No new data
# [UPDATE] CSX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CTAS: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CTB last update 1679 days ago (last date 2021-06-04)
# [UPDATE] CTB: last = 2021-06-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: CTLT last update 387 days ago (last date 2024-12-17)
# [UPDATE] CTLT: last = 2024-12-17 → checking for new rows...
#     → No new data
# [UPDATE] CTRA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CTSH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CTVA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CTX1 last update 5987 days ago (last date 2009-08-18)
# [UPDATE] CTX1: last = 2009-08-18 → checking for new rows...
#     → No new data
# ⚠ WARNING: CTXS last update 1197 days ago (last date 2022-09-29)
# [UPDATE] CTXS: last = 2022-09-29 → checking for new rows...
#     → No new data
# [NEW] CUE1: downloading FULL history...
# ⚠ No data found for CUE1
# ⚠ WARNING: CVC last update 3489 days ago (last date 2016-06-20)
# [UPDATE] CVC: last = 2016-06-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: CVG last update 2653 days ago (last date 2018-10-04)
# [UPDATE] CVG: last = 2018-10-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: CVGYQ last update 8687 days ago (last date 2002-03-28)
# [UPDATE] CVGYQ: last = 2002-03-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: CVH last update 4630 days ago (last date 2013-05-06)
# [UPDATE] CVH: last = 2013-05-06 → checking for new rows...
#     → No new data
# [UPDATE] CVNA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CVS: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] CVX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CXO last update 1819 days ago (last date 2021-01-15)
# [UPDATE] CXO: last = 2021-01-15 → checking for new rows...
#     → No new data
# [UPDATE] CXT: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: CYM last update 9534 days ago (last date 1999-12-02)
# [UPDATE] CYM: last = 1999-12-02 → checking for new rows...
#     → No new data
# [UPDATE] CZR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] D: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DAL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DALRQ last update 6831 days ago (last date 2007-04-27)
# [UPDATE] DALRQ: last = 2007-04-27 → checking for new rows...
#     → No new data
# [UPDATE] DASH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DAY: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DCNAQ last update 6552 days ago (last date 2008-01-31)
# [UPDATE] DCNAQ: last = 2008-01-31 → checking for new rows...
#     → No new data
# [UPDATE] DD: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DD1 last update 3052 days ago (last date 2017-08-31)
# [UPDATE] DD1: last = 2017-08-31 → checking for new rows...
#     → No new data
# [UPDATE] DDOG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DDS: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DEC1 last update 10073 days ago (last date 1998-06-11)
# [UPDATE] DEC1: last = 1998-06-11 → checking for new rows...
#     → No new data
# [UPDATE] DECK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DELL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DELL1 last update 4454 days ago (last date 2013-10-29)
# [UPDATE] DELL1: last = 2013-10-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: DFODQ last update 1681 days ago (last date 2021-06-02)
# [UPDATE] DFODQ: last = 2021-06-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: DFS last update 237 days ago (last date 2025-05-16)
# [UPDATE] DFS: last = 2025-05-16 → checking for new rows...
#     → No new data
# [UPDATE] DG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DG1 last update 6761 days ago (last date 2007-07-06)
# [UPDATE] DG1: last = 2007-07-06 → checking for new rows...
#     → No new data
# ⚠ WARNING: DGN last update 9585 days ago (last date 1999-10-12)
# [UPDATE] DGN: last = 1999-10-12 → checking for new rows...
#     → No new data
# [UPDATE] DGX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DHI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DHR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DI1 last update 9963 days ago (last date 1998-09-29)
# [UPDATE] DI1: last = 1998-09-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: DIGI2 last update 9988 days ago (last date 1998-09-04)
# [UPDATE] DIGI2: last = 1998-09-04 → checking for new rows...
#     → No new data
# [UPDATE] DINO: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DIS: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DISCK last update 1371 days ago (last date 2022-04-08)
# [UPDATE] DISCK: last = 2022-04-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: DISH last update 741 days ago (last date 2023-12-29)
# [UPDATE] DISH: last = 2023-12-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: DJ last update 6601 days ago (last date 2007-12-13)
# [UPDATE] DJ: last = 2007-12-13 → checking for new rows...
#     → No new data
# [UPDATE] DLR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DLTR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DLX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DNB1 last update 9229 days ago (last date 2000-10-02)
# [UPDATE] DNB1: last = 2000-10-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: DNB2 last update 10054 days ago (last date 1998-06-30)
# [UPDATE] DNB2: last = 1998-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: DNB3 last update 2527 days ago (last date 2019-02-07)
# [UPDATE] DNB3: last = 2019-02-07 → checking for new rows...
#     → No new data
# ⚠ WARNING: DNRCQ last update 1938 days ago (last date 2020-09-18)
# [UPDATE] DNRCQ: last = 2020-09-18 → checking for new rows...
#     → No new data
# [UPDATE] DOC: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DOFSQ last update 1721 days ago (last date 2021-04-23)
# [UPDATE] DOFSQ: last = 2021-04-23 → checking for new rows...
#     → No new data
# [UPDATE] DOV: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DOW: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DPHIQ last update 5937 days ago (last date 2009-10-07)
# [UPDATE] DPHIQ: last = 2009-10-07 → checking for new rows...
#     → No new data
# [UPDATE] DPZ: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DRE last update 1196 days ago (last date 2022-09-30)
# [UPDATE] DRE: last = 2022-09-30 → checking for new rows...
#     → No new data
# [UPDATE] DRI: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DTE: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DTV1 last update 3821 days ago (last date 2015-07-24)
# [UPDATE] DTV1: last = 2015-07-24 → checking for new rows...
#     → No new data
# [UPDATE] DUK: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DVA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DVN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DXC: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] DXCM: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: DYNIQ last update 4846 days ago (last date 2012-10-02)
# [UPDATE] DYNIQ: last = 2012-10-02 → checking for new rows...
#     → No new data
# [UPDATE] EA: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] EBAY: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: EC1 last update 7153 days ago (last date 2006-06-09)
# [UPDATE] EC1: last = 2006-06-09 → checking for new rows...
#     → No new data
# ⚠ WARNING: ECH1 last update 10045 days ago (last date 1998-07-09)
# [UPDATE] ECH1: last = 1998-07-09 → checking for new rows...
#     → No new data
# [UPDATE] ECL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ECO1 last update 8378 days ago (last date 2003-01-31)
# [UPDATE] ECO1: last = 2003-01-31 → checking for new rows...
#     → No new data
# [UPDATE] ED: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: EDS last update 6345 days ago (last date 2008-08-25)
# [UPDATE] EDS: last = 2008-08-25 → checking for new rows...
#     → No new data
# ⚠ WARNING: EFU1 last update 9192 days ago (last date 2000-11-08)
# [UPDATE] EFU1: last = 2000-11-08 → checking for new rows...
#     → No new data
# [UPDATE] EFX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] EG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] EHC: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] EIX: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: EKDKQ last update 4510 days ago (last date 2013-09-03)
# [UPDATE] EKDKQ: last = 2013-09-03 → checking for new rows...
#     → No new data
# [UPDATE] EL: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] ELV: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: EMC1 last update 3411 days ago (last date 2016-09-06)
# [UPDATE] EMC1: last = 2016-09-06 → checking for new rows...
#     → No new data
# [UPDATE] EME: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] EMN: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# [UPDATE] EMR: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ENDPQ last update 1232 days ago (last date 2022-08-25)
# [UPDATE] ENDPQ: last = 2022-08-25 → checking for new rows...
#     → No new data
# [UPDATE] ENPH: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: ENRNQ last update 7722 days ago (last date 2004-11-17)
# [UPDATE] ENRNQ: last = 2004-11-17 → checking for new rows...
#     → No new data
# [UPDATE] EOG: last = 2026-01-07 → checking for new rows...
#     → Appending 1 new rows (through 2026-01-08)
# ⚠ WARNING: EOP last update 6908 days ago (last date 2007-02-09)
# [UPDATE] EOP: last = 2007-02-09 → checking for new rows...
#     → No new data
# ⚠ WARNING: EP1 last update 4977 days ago (last date 2012-05-24)
# [UPDATE] EP1: last = 2012-05-24 → checking for new rows...
#     → No new data
# ...
#     → No new data
# [UPDATE] TKR: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TLAB last update 4420 days ago (last date 2013-12-02)
# [UPDATE] TLAB: last = 2013-12-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: TMC.A last update 9341 days ago (last date 2000-06-12)
# [UPDATE] TMC.A: last = 2000-06-12 → checking for new rows...
#     → No new data
# [UPDATE] TMO: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TMUS: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TNB last update 4985 days ago (last date 2012-05-16)
# [UPDATE] TNB: last = 2012-05-16 → checking for new rows...
#     → No new data
# [UPDATE] TNL: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TOS last update 8886 days ago (last date 2001-09-10)
# [UPDATE] TOS: last = 2001-09-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: TOY last update 7476 days ago (last date 2005-07-21)
# [UPDATE] TOY: last = 2005-07-21 → checking for new rows...
#     → No new data
# [UPDATE] TPL: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TPR: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TRB last update 6594 days ago (last date 2007-12-20)
# [UPDATE] TRB: last = 2007-12-20 → checking for new rows...
#     → No new data
# [UPDATE] TRGP: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TRIP: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TRMB: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TROW: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TRV: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TRW1 last update 8429 days ago (last date 2002-12-11)
# [UPDATE] TRW1: last = 2002-12-11 → checking for new rows...
#     → No new data
# [UPDATE] TSCO: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TSG1 last update 6860 days ago (last date 2007-03-29)
# [UPDATE] TSG1: last = 2007-03-29 → checking for new rows...
#     → No new data
# [UPDATE] TSLA: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TSN: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TSS last update 2305 days ago (last date 2019-09-17)
# [UPDATE] TSS: last = 2019-09-17 → checking for new rows...
#     → No new data
# [UPDATE] TT: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TT2 last update 6426 days ago (last date 2008-06-05)
# [UPDATE] TT2: last = 2008-06-05 → checking for new rows...
#     → No new data
# [UPDATE] TTD: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TTWO: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TUPBQ last update 478 days ago (last date 2024-09-17)
# [UPDATE] TUPBQ: last = 2024-09-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWC last update 3523 days ago (last date 2016-05-17)
# [UPDATE] TWC: last = 2016-05-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWTR last update 1169 days ago (last date 2022-10-27)
# [UPDATE] TWTR: last = 2022-10-27 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWX last update 2764 days ago (last date 2018-06-15)
# [UPDATE] TWX: last = 2018-06-15 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWX1 last update 9128 days ago (last date 2001-01-11)
# [UPDATE] TWX1: last = 2001-01-11 → checking for new rows...
#     → No new data
# ⚠ WARNING: TX1 last update 8857 days ago (last date 2001-10-09)
# [UPDATE] TX1: last = 2001-10-09 → checking for new rows...
#     → No new data
# [UPDATE] TXN: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] TXT: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: TXU last update 6665 days ago (last date 2007-10-10)
# [UPDATE] TXU: last = 2007-10-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: TYC last update 3415 days ago (last date 2016-09-02)
# [UPDATE] TYC: last = 2016-09-02 → checking for new rows...
#     → No new data
# [UPDATE] TYL: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UA: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UAA: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UAL: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: UAWGQ last update 8319 days ago (last date 2003-03-31)
# [UPDATE] UAWGQ: last = 2003-03-31 → checking for new rows...
#     → No new data
# [UPDATE] UBER: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: UCC1 last update 9750 days ago (last date 1999-04-30)
# [UPDATE] UCC1: last = 1999-04-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: UCL1 last update 7456 days ago (last date 2005-08-10)
# [UPDATE] UCL1: last = 2005-08-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: UCM last update 9211 days ago (last date 2000-10-20)
# [UPDATE] UCM: last = 2000-10-20 → checking for new rows...
#     → No new data
# [UPDATE] UDR: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UHS: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UIS: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: UK1 last update 9102 days ago (last date 2001-02-06)
# [UPDATE] UK1: last = 2001-02-06 → checking for new rows...
#     → No new data
# [UPDATE] UL: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] ULTA: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UNH: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UNM: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] UNP: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: UPC1 last update 7862 days ago (last date 2004-06-30)
# [UPDATE] UPC1: last = 2004-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: UPR last update 9309 days ago (last date 2000-07-14)
# [UPDATE] UPR: last = 2000-07-14 → checking for new rows...
#     → No new data
# [UPDATE] UPS: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] URBN: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] URI: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] USB: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: USB1 last update 9085 days ago (last date 2001-02-23)
# [UPDATE] USB1: last = 2001-02-23 → checking for new rows...
#     → No new data
# [NEW] USBC1: downloading FULL history...
# ⚠ No data found for USBC1
# ⚠ WARNING: USG1 last update 2452 days ago (last date 2019-04-23)
# [UPDATE] USG1: last = 2019-04-23 → checking for new rows...
#     → No new data
# ⚠ WARNING: USS1 last update 9961 days ago (last date 1998-10-01)
# [UPDATE] USS1: last = 1998-10-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: UST1 last update 6212 days ago (last date 2009-01-05)
# [UPDATE] UST1: last = 2009-01-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: USW last update 9323 days ago (last date 2000-06-30)
# [UPDATE] USW: last = 2000-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: UVN last update 6861 days ago (last date 2007-03-28)
# [UPDATE] UVN: last = 2007-03-28 → checking for new rows...
#     → No new data
# [UPDATE] V: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: VALPQ last update 1717 days ago (last date 2021-04-27)
# [UPDATE] VALPQ: last = 2021-04-27 → checking for new rows...
#     → No new data
# ⚠ WARNING: VAR last update 1730 days ago (last date 2021-04-14)
# [UPDATE] VAR: last = 2021-04-14 → checking for new rows...
#     → No new data
# [UPDATE] VFC: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: VIAB last update 2227 days ago (last date 2019-12-04)
# [UPDATE] VIAB: last = 2019-12-04 → checking for new rows...
#     → No new data
# [UPDATE] VIAV: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VICI: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VLO: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VLTO: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VMC: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VNO: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VNT: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: VO1 last update 9162 days ago (last date 2000-12-08)
# [UPDATE] VO1: last = 2000-12-08 → checking for new rows...
#     → No new data
# [UPDATE] VRSK: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VRSN: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: VRTS1 last update 7496 days ago (last date 2005-07-01)
# [UPDATE] VRTS1: last = 2005-07-01 → checking for new rows...
#     → No new data
# [UPDATE] VRTX: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VST: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: VSTNQ last update 5578 days ago (last date 2010-10-01)
# [UPDATE] VSTNQ: last = 2010-10-01 → checking for new rows...
#     → No new data
# [UPDATE] VTR: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VTRS: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: VTSS last update 3909 days ago (last date 2015-04-27)
# [UPDATE] VTSS: last = 2015-04-27 → checking for new rows...
#     → No new data
# [UPDATE] VYX: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] VZ: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WAB: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WAI1 last update 10013 days ago (last date 1998-08-10)
# [UPDATE] WAI1: last = 1998-08-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: WAMUQ last update 5042 days ago (last date 2012-03-20)
# [UPDATE] WAMUQ: last = 2012-03-20 → checking for new rows...
#     → No new data
# [UPDATE] WAT: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WB1 last update 6217 days ago (last date 2008-12-31)
# [UPDATE] WB1: last = 2008-12-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: WB2 last update 8896 days ago (last date 2001-08-31)
# [UPDATE] WB2: last = 2001-08-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: WBA last update 133 days ago (last date 2025-08-28)
# [UPDATE] WBA: last = 2025-08-28 → checking for new rows...
#     → No new data
# [UPDATE] WBD: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WCG last update 2177 days ago (last date 2020-01-23)
# [UPDATE] WCG: last = 2020-01-23 → checking for new rows...
#     → No new data
# ⚠ WARNING: WCOEQ last update 7934 days ago (last date 2004-04-19)
# [UPDATE] WCOEQ: last = 2004-04-19 → checking for new rows...
#     → No new data
# [UPDATE] WDAY: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WDC: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WEC: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WELL: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WEN: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WFC: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WFC1 last update 9929 days ago (last date 1998-11-02)
# [UPDATE] WFC1: last = 1998-11-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: WFM last update 3055 days ago (last date 2017-08-28)
# [UPDATE] WFM: last = 2017-08-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: WFTIQ last update 2218 days ago (last date 2019-12-13)
# [UPDATE] WFTIQ: last = 2019-12-13 → checking for new rows...
#     → No new data
# ⚠ WARNING: WGL last update 2743 days ago (last date 2018-07-06)
# [UPDATE] WGL: last = 2018-07-06 → checking for new rows...
#     → No new data
# [UPDATE] WHR: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WINMQ last update 1934 days ago (last date 2020-09-22)
# [UPDATE] WINMQ: last = 2020-09-22 → checking for new rows...
#     → No new data
# ⚠ WARNING: WLA last update 9334 days ago (last date 2000-06-19)
# [UPDATE] WLA: last = 2000-06-19 → checking for new rows...
#     → No new data
# ⚠ WARNING: WLL1 last update 8701 days ago (last date 2002-03-14)
# [UPDATE] WLL1: last = 2002-03-14 → checking for new rows...
#     → No new data
# ⚠ WARNING: WLP1 last update 7708 days ago (last date 2004-12-01)
# [UPDATE] WLP1: last = 2004-12-01 → checking for new rows...
#     → No new data
# [UPDATE] WM: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WMB: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WMT: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WNDXQ last update 6988 days ago (last date 2006-11-21)
# [UPDATE] WNDXQ: last = 2006-11-21 → checking for new rows...
#     → No new data
# [UPDATE] WOR: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WPX last update 1828 days ago (last date 2021-01-06)
# [UPDATE] WPX: last = 2021-01-06 → checking for new rows...
#     → No new data
# [UPDATE] WRB: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WRK last update 552 days ago (last date 2024-07-05)
# [UPDATE] WRK: last = 2024-07-05 → checking for new rows...
#     → No new data
# [UPDATE] WSM: last = 2026-01-08 → checking for new rows...
#     → No new data
# [NEW] WSN: downloading FULL history...
# ⚠ No data found for WSN
# [UPDATE] WST: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WTW: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] WU: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WWY last update 6303 days ago (last date 2008-10-06)
# [UPDATE] WWY: last = 2008-10-06 → checking for new rows...
#     → No new data
# [UPDATE] WY: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: WYE last update 5929 days ago (last date 2009-10-15)
# [UPDATE] WYE: last = 2009-10-15 → checking for new rows...
#     → No new data
# [UPDATE] WYNN: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: X last update 205 days ago (last date 2025-06-17)
# [UPDATE] X: last = 2025-06-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: XEC last update 1561 days ago (last date 2021-09-30)
# [UPDATE] XEC: last = 2021-09-30 → checking for new rows...
#     → No new data
# [UPDATE] XEL: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: XL1 last update 2676 days ago (last date 2018-09-11)
# [UPDATE] XL1: last = 2018-09-11 → checking for new rows...
#     → No new data
# ⚠ WARNING: XLNX last update 1427 days ago (last date 2022-02-11)
# [UPDATE] XLNX: last = 2022-02-11 → checking for new rows...
#     → No new data
# [UPDATE] XOM: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] XRAY: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] XRX: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: XTO last update 5676 days ago (last date 2010-06-25)
# [UPDATE] XTO: last = 2010-06-25 → checking for new rows...
#     → No new data
# [UPDATE] XYL: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] XYZ: last = 2026-01-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: YHOO last update 3128 days ago (last date 2017-06-16)
# [UPDATE] YHOO: last = 2017-06-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: YNR last update 9228 days ago (last date 2000-10-03)
# [UPDATE] YNR: last = 2000-10-03 → checking for new rows...
#     → No new data
# [UPDATE] YUM: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] ZBH: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] ZBRA: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] ZION: last = 2026-01-08 → checking for new rows...
#     → No new data
# [UPDATE] ZTS: last = 2026-01-08 → checking for new rows...
#     → No new data
#
# === DONE: Incremental update complete ===
