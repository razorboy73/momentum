# %%
"""
Incrementally updates SHARADAR SEP price files for all tickers in the S&P 500 membership matrix.
Loads the Nasdaq Data Link API key, fetches full histories for missing tickers and only new rows
after the latest date for existing files, warns when data is stale beyond MAX_STALE_DAYS, and
persists per-ticker CSVs in ./2-all_prices/sharadar_sep_full.

Use case: run after executing 2b-Bootrap_All_Prices.ipynb to keep SHARADAR SEP data up to date.
"""
import os
import pandas as pd
import numpy as np
import nasdaqdatalink
from datetime import timedelta
from dotenv import load_dotenv
load_dotenv()

nasdaqdatalink_key = os.getenv("NASDAQ_DATA_LINK_API_KEY")
nasdaqdatalink.ApiConfig.api_key = nasdaqdatalink_key


INPUT_FOLDER  = "./2-all_prices/sharadar_sep_full"
OUTPUT_FOLDER = "./2-all_prices/sharadar_sep_full"

os.makedirs(OUTPUT_FOLDER, exist_ok=True)

MEMBERSHIP_FILE = "./1-sp500_membership_daily_matrix/sp500_membership_full.parquet"
membership = pd.read_parquet(MEMBERSHIP_FILE)
all_tickers = sorted(membership.index.tolist())

MAX_STALE_DAYS = 90   # warn if no update for > 90 days


def get_incremental_sep(ticker, last_date):
    """
    Safely fetch SEP rows strictly AFTER last_date.
    Handles long gaps, weekends, holidays.
    """
    start_date = last_date + timedelta(days=1)

    df_new = nasdaqdatalink.get_table(
        "SHARADAR/SEP",
        ticker=[ticker],
        date={'gte': start_date},
        paginate=True
    )

    if df_new is None or df_new.empty:
        return pd.DataFrame()

    df_new["date"] = pd.to_datetime(df_new["date"])
    df_new = df_new.sort_values("date")

    return df_new


print("\n=== INCREMENTAL SHARADAR SEP UPDATE ===\n")

for tk in all_tickers:

    file_path = os.path.join(INPUT_FOLDER, f"{tk}.csv")

    # -------------------------------
    # CASE 1: No existing file → full download
    # -------------------------------
    if not os.path.exists(file_path):
        print(f"[NEW] {tk}: downloading FULL history...")

        df = nasdaqdatalink.get_table(
            "SHARADAR/SEP",
            ticker=[tk],
            paginate=True
        )

        if df is None or df.empty:
            print(f"⚠ No data found for {tk}")
            continue

        df["date"] = pd.to_datetime(df["date"])
        df = df.sort_values("date").drop_duplicates(subset=["date"])

        df.to_csv(file_path, index=False)
        continue

    # -------------------------------
    # CASE 2: Incremental update
    # -------------------------------
    df_old = pd.read_csv(file_path)
    if df_old.empty:
        last_date = pd.Timestamp("1900-01-01")
    else:
        df_old["date"] = pd.to_datetime(df_old["date"])
        last_date = df_old["date"].max()

    days_stale = (pd.Timestamp.today().normalize() - last_date).days

    if days_stale > MAX_STALE_DAYS:
        print(f"⚠ WARNING: {tk} last update {days_stale} days ago (last date {last_date.date()})")

    print(f"[UPDATE] {tk}: last = {last_date.date()} → checking for new rows...")

    df_new = get_incremental_sep(tk, last_date)

    if df_new.empty:
        print("    → No new data")
        continue

    print(f"    → Appending {len(df_new)} new rows (through {df_new['date'].max().date()})")

    # merge and dedupe
    df_updated = pd.concat([df_old, df_new], ignore_index=True)
    df_updated = df_updated.sort_values("date").drop_duplicates(subset=["date"])

    df_updated.to_csv(file_path, index=False)

print("\n=== DONE: Incremental update complete ===")
# Out:
# === INCREMENTAL SHARADAR SEP UPDATE ===
#
# [UPDATE] A: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AAL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AAMRQ last update 4409 days ago (last date 2013-12-05)
# [UPDATE] AAMRQ: last = 2013-12-05 → checking for new rows...
#     → No new data
# [UPDATE] AAP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AAPL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ABBV: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ABI1 last update 6249 days ago (last date 2008-11-21)
# [UPDATE] ABI1: last = 2008-11-21 → checking for new rows...
#     → No new data
# ⚠ WARNING: ABKFQ last update 5524 days ago (last date 2010-11-16)
# [UPDATE] ABKFQ: last = 2010-11-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: ABMD last update 1106 days ago (last date 2022-12-21)
# [UPDATE] ABMD: last = 2022-12-21 → checking for new rows...
#     → No new data
# [UPDATE] ABNB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ABS last update 7153 days ago (last date 2006-06-01)
# [UPDATE] ABS: last = 2006-06-01 → checking for new rows...
#     → No new data
# [UPDATE] ABT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ACAS last update 3284 days ago (last date 2017-01-03)
# [UPDATE] ACAS: last = 2017-01-03 → checking for new rows...
#     → No new data
# [UPDATE] ACGL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ACKHQ last update 6594 days ago (last date 2007-12-12)
# [UPDATE] ACKHQ: last = 2007-12-12 → checking for new rows...
#     → No new data
# [UPDATE] ACN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ACS last update 5808 days ago (last date 2010-02-05)
# [UPDATE] ACS: last = 2010-02-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: ACV1 last update 5349 days ago (last date 2011-05-10)
# [UPDATE] ACV1: last = 2011-05-10 → checking for new rows...
#     → No new data
# [NEW] AD2: downloading FULL history...
# ⚠ No data found for AD2
# [UPDATE] ADBE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ADCT1 last update 5501 days ago (last date 2010-12-09)
# [UPDATE] ADCT1: last = 2010-12-09 → checking for new rows...
#     → No new data
# [UPDATE] ADI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ADM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ADP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ADSK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ADT1 last update 3533 days ago (last date 2016-04-29)
# [UPDATE] ADT1: last = 2016-04-29 → checking for new rows...
#     → No new data
# [UPDATE] AEE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AEP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AES: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AET last update 2590 days ago (last date 2018-11-28)
# [UPDATE] AET: last = 2018-11-28 → checking for new rows...
#     → No new data
# [UPDATE] AFL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AFS.A last update 9162 days ago (last date 2000-11-30)
# [UPDATE] AFS.A: last = 2000-11-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: AGC1 last update 8891 days ago (last date 2001-08-28)
# [UPDATE] AGC1: last = 2001-08-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: AGN last update 2063 days ago (last date 2020-05-08)
# [UPDATE] AGN: last = 2020-05-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: AGN1 last update 3943 days ago (last date 2015-03-16)
# [UPDATE] AGN1: last = 2015-03-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: AHM1 last update 9953 days ago (last date 1998-10-01)
# [UPDATE] AHM1: last = 1998-10-01 → checking for new rows...
#     → No new data
# [UPDATE] AIG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AIT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AIV: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AIZ: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AJG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AKAM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AKS last update 2120 days ago (last date 2020-03-12)
# [UPDATE] AKS: last = 2020-03-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: AL1 last update 6623 days ago (last date 2007-11-13)
# [UPDATE] AL1: last = 2007-11-13 → checking for new rows...
#     → No new data
# [UPDATE] ALB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ALGN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ALK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ALL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ALLE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ALTR1 last update 3660 days ago (last date 2015-12-24)
# [UPDATE] ALTR1: last = 2015-12-24 → checking for new rows...
#     → No new data
# ⚠ WARNING: ALXN last update 1624 days ago (last date 2021-07-21)
# [UPDATE] ALXN: last = 2021-07-21 → checking for new rows...
#     → No new data
# ⚠ WARNING: AM1 last update 4528 days ago (last date 2013-08-08)
# [UPDATE] AM1: last = 2013-08-08 → checking for new rows...
#     → No new data
# [UPDATE] AMAT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AMCC last update 3261 days ago (last date 2017-01-26)
# [UPDATE] AMCC: last = 2017-01-26 → checking for new rows...
#     → No new data
# [UPDATE] AMCR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AMD: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AME: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AMG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AMGN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AMP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AMP1 last update 9771 days ago (last date 1999-04-01)
# [UPDATE] AMP1: last = 1999-04-01 → checking for new rows...
#     → No new data
# [UPDATE] AMT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AMTM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AMZN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AN1 last update 9862 days ago (last date 1998-12-31)
# [UPDATE] AN1: last = 1998-12-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANDV last update 2651 days ago (last date 2018-09-28)
# [UPDATE] ANDV: last = 2018-09-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANDW last update 6579 days ago (last date 2007-12-27)
# [UPDATE] ANDW: last = 2007-12-27 → checking for new rows...
#     → No new data
# [UPDATE] ANET: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ANF: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ANRZQ last update 3445 days ago (last date 2016-07-26)
# [UPDATE] ANRZQ: last = 2016-07-26 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANSS last update 167 days ago (last date 2025-07-17)
# [UPDATE] ANSS: last = 2025-07-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: ANV1 last update 9763 days ago (last date 1999-04-09)
# [UPDATE] ANV1: last = 1999-04-09 → checking for new rows...
#     → No new data
# [UPDATE] AON: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AOS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] APA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: APC last update 2337 days ago (last date 2019-08-08)
# [UPDATE] APC: last = 2019-08-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: APCC last update 6895 days ago (last date 2007-02-14)
# [UPDATE] APCC: last = 2007-02-14 → checking for new rows...
#     → No new data
# [UPDATE] APD: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] APH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] APO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: APOL last update 3255 days ago (last date 2017-02-01)
# [UPDATE] APOL: last = 2017-02-01 → checking for new rows...
#     → No new data
# [UPDATE] APP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] APTV: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AR1 last update 9541 days ago (last date 1999-11-17)
# [UPDATE] AR1: last = 1999-11-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: ARC1 last update 9389 days ago (last date 2000-04-17)
# [UPDATE] ARC1: last = 2000-04-17 → checking for new rows...
#     → No new data
# [UPDATE] ARE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ARES: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ARG last update 3512 days ago (last date 2016-05-20)
# [UPDATE] ARG: last = 2016-05-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: AS1 last update 9589 days ago (last date 1999-09-30)
# [UPDATE] AS1: last = 1999-09-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: ASC1 last update 9688 days ago (last date 1999-06-23)
# [UPDATE] ASC1: last = 1999-06-23 → checking for new rows...
#     → No new data
# [UPDATE] ASH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ASN last update 6663 days ago (last date 2007-10-04)
# [UPDATE] ASN: last = 2007-10-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: ASND1 last update 9687 days ago (last date 1999-06-24)
# [UPDATE] ASND1: last = 1999-06-24 → checking for new rows...
#     → No new data
# ⚠ WARNING: ASO1 last update 6998 days ago (last date 2006-11-03)
# [UPDATE] ASO1: last = 2006-11-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: AT1 last update 6621 days ago (last date 2007-11-15)
# [UPDATE] AT1: last = 2007-11-15 → checking for new rows...
#     → No new data
# [UPDATE] ATGE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ATI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ATI1 last update 9682 days ago (last date 1999-06-29)
# [UPDATE] ATI1: last = 1999-06-29 → checking for new rows...
#     → No new data
# [UPDATE] ATO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ATVI last update 811 days ago (last date 2023-10-12)
# [UPDATE] ATVI: last = 2023-10-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: AV1 last update 6642 days ago (last date 2007-10-25)
# [UPDATE] AV1: last = 2007-10-25 → checking for new rows...
#     → No new data
# [UPDATE] AVB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AVGO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AVP last update 2189 days ago (last date 2020-01-03)
# [UPDATE] AVP: last = 2020-01-03 → checking for new rows...
#     → No new data
# [UPDATE] AVY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AW last update 6235 days ago (last date 2008-12-05)
# [UPDATE] AW: last = 2008-12-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: AWE last update 7736 days ago (last date 2004-10-26)
# [UPDATE] AWE: last = 2004-10-26 → checking for new rows...
#     → No new data
# [UPDATE] AWK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AXON: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] AXP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AYE last update 5423 days ago (last date 2011-02-25)
# [UPDATE] AYE: last = 2011-02-25 → checking for new rows...
#     → No new data
# [UPDATE] AYI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: AZA.A last update 8958 days ago (last date 2001-06-22)
# [UPDATE] AZA.A: last = 2001-06-22 → checking for new rows...
#     → No new data
# [UPDATE] AZO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] B: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BAC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BAC1 last update 9954 days ago (last date 1998-09-30)
# [UPDATE] BAC1: last = 1998-09-30 → checking for new rows...
#     → No new data
# [UPDATE] BALL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BAX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BAY1 last update 9987 days ago (last date 1998-08-28)
# [UPDATE] BAY1: last = 1998-08-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: BBBYQ last update 974 days ago (last date 2023-05-02)
# [UPDATE] BBBYQ: last = 2023-05-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: BBI1 last update 10218 days ago (last date 1998-01-09)
# [UPDATE] BBI1: last = 1998-01-09 → checking for new rows...
#     → No new data
# [UPDATE] BBWI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BBY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BCR last update 2925 days ago (last date 2017-12-28)
# [UPDATE] BCR: last = 2017-12-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: BDK last update 5773 days ago (last date 2010-03-12)
# [UPDATE] BDK: last = 2010-03-12 → checking for new rows...
#     → No new data
# [UPDATE] BDX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BEAM2 last update 4263 days ago (last date 2014-04-30)
# [UPDATE] BEAM2: last = 2014-04-30 → checking for new rows...
#     → No new data
# [UPDATE] BEN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BF.B: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BFH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BFI1 last update 9651 days ago (last date 1999-07-30)
# [UPDATE] BFI1: last = 1999-07-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: BFO1 last update 9219 days ago (last date 2000-10-04)
# [UPDATE] BFO1: last = 2000-10-04 → checking for new rows...
#     → No new data
# [UPDATE] BG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BGEN last update 8085 days ago (last date 2003-11-12)
# [UPDATE] BGEN: last = 2003-11-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: BGGSQ last update 1820 days ago (last date 2021-01-06)
# [UPDATE] BGGSQ: last = 2021-01-06 → checking for new rows...
#     → No new data
# [UPDATE] BHF: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BHI last update 3103 days ago (last date 2017-07-03)
# [UPDATE] BHI: last = 2017-07-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: BHMSQ last update 8031 days ago (last date 2004-01-05)
# [UPDATE] BHMSQ: last = 2004-01-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: BIGGQ last update 478 days ago (last date 2024-09-09)
# [UPDATE] BIGGQ: last = 2024-09-09 → checking for new rows...
#     → No new data
# [UPDATE] BIIB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BIO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BJS last update 5726 days ago (last date 2010-04-28)
# [UPDATE] BJS: last = 2010-04-28 → checking for new rows...
#     → No new data
# [UPDATE] BK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BKB last update 9589 days ago (last date 1999-09-30)
# [UPDATE] BKB: last = 1999-09-30 → checking for new rows...
#     → No new data
# [UPDATE] BKNG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BKR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BLDR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BLK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BLS last update 6942 days ago (last date 2006-12-29)
# [UPDATE] BLS: last = 2006-12-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMC last update 4495 days ago (last date 2013-09-10)
# [UPDATE] BMC: last = 2013-09-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMET last update 6672 days ago (last date 2007-09-25)
# [UPDATE] BMET: last = 2007-09-25 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMGCA last update 9121 days ago (last date 2001-01-10)
# [UPDATE] BMGCA: last = 2001-01-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: BMS last update 2396 days ago (last date 2019-06-10)
# [UPDATE] BMS: last = 2019-06-10 → checking for new rows...
#     → No new data
# [UPDATE] BMY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BNI last update 5801 days ago (last date 2010-02-12)
# [UPDATE] BNI: last = 2010-02-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: BNL1 last update 10046 days ago (last date 1998-06-30)
# [UPDATE] BNL1: last = 1998-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: BOL last update 6641 days ago (last date 2007-10-26)
# [UPDATE] BOL: last = 2007-10-26 → checking for new rows...
#     → No new data
# [UPDATE] BR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BR1 last update 7215 days ago (last date 2006-03-31)
# [UPDATE] BR1: last = 2006-03-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: BRCM last update 3624 days ago (last date 2016-01-29)
# [UPDATE] BRCM: last = 2016-01-29 → checking for new rows...
#     → No new data
# [UPDATE] BRK.B: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BRL last update 6218 days ago (last date 2008-12-22)
# [UPDATE] BRL: last = 2008-12-22 → checking for new rows...
#     → No new data
# [NEW] BRNO: downloading FULL history...
# ⚠ No data found for BRNO
# [UPDATE] BRO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BSC1 last update 6424 days ago (last date 2008-05-30)
# [UPDATE] BSC1: last = 2008-05-30 → checking for new rows...
#     → No new data
# [UPDATE] BSX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BT1 last update 9708 days ago (last date 1999-06-03)
# [UPDATE] BT1: last = 1999-06-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: BTUUQ last update 3194 days ago (last date 2017-04-03)
# [UPDATE] BTUUQ: last = 2017-04-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: BUD1 last update 6253 days ago (last date 2008-11-17)
# [UPDATE] BUD1: last = 2008-11-17 → checking for new rows...
#     → No new data
# [NEW] BV2: downloading FULL history...
# ⚠ No data found for BV2
# ⚠ WARNING: BVSN last update 2053 days ago (last date 2020-05-18)
# [UPDATE] BVSN: last = 2020-05-18 → checking for new rows...
#     → No new data
# [UPDATE] BWA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] BX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: BXLT last update 3499 days ago (last date 2016-06-02)
# [UPDATE] BXLT: last = 2016-06-02 → checking for new rows...
#     → No new data
# [UPDATE] BXP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] C: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: C1 last update 9911 days ago (last date 1998-11-12)
# [UPDATE] C1: last = 1998-11-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: CA1 last update 2613 days ago (last date 2018-11-05)
# [UPDATE] CA1: last = 2018-11-05 → checking for new rows...
#     → No new data
# [UPDATE] CAG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CAH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CAL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CAM2 last update 3561 days ago (last date 2016-04-01)
# [UPDATE] CAM2: last = 2016-04-01 → checking for new rows...
#     → No new data
# [UPDATE] CAR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CARR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CAT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CB1 last update 3639 days ago (last date 2016-01-14)
# [UPDATE] CB1: last = 2016-01-14 → checking for new rows...
#     → No new data
# [NEW] CBB1: downloading FULL history...
# ⚠ No data found for CBB1
# ⚠ WARNING: CBE last update 4779 days ago (last date 2012-11-30)
# [UPDATE] CBE: last = 2012-11-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: CBH1 last update 6487 days ago (last date 2008-03-28)
# [UPDATE] CBH1: last = 2008-03-28 → checking for new rows...
#     → No new data
# [UPDATE] CBOE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CBRE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CBS1 last update 9373 days ago (last date 2000-05-03)
# [UPDATE] CBS1: last = 2000-05-03 → checking for new rows...
#     → No new data
# ⚠ WARNING: CBSS last update 6691 days ago (last date 2007-09-06)
# [UPDATE] CBSS: last = 2007-09-06 → checking for new rows...
#     → No new data
# ⚠ WARNING: CCE1 last update 3505 days ago (last date 2016-05-27)
# [UPDATE] CCE1: last = 2016-05-27 → checking for new rows...
#     → No new data
# [UPDATE] CCI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CCI1 last update 9947 days ago (last date 1998-10-07)
# [UPDATE] CCI1: last = 1998-10-07 → checking for new rows...
#     → No new data
# [UPDATE] CCK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CCL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CCTYQ last update 6189 days ago (last date 2009-01-20)
# [UPDATE] CCTYQ: last = 2009-01-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: CCU1 last update 6364 days ago (last date 2008-07-29)
# [UPDATE] CCU1: last = 2008-07-29 → checking for new rows...
#     → No new data
# [UPDATE] CDNS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CDW: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CE1 last update 7979 days ago (last date 2004-02-26)
# [UPDATE] CE1: last = 2004-02-26 → checking for new rows...
#     → No new data
# [UPDATE] CEG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CEG1 last update 5042 days ago (last date 2012-03-12)
# [UPDATE] CEG1: last = 2012-03-12 → checking for new rows...
#     → No new data
# ⚠ WARNING: CELG last update 2233 days ago (last date 2019-11-20)
# [UPDATE] CELG: last = 2019-11-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: CEM1 last update 8456 days ago (last date 2002-11-06)
# [UPDATE] CEM1: last = 2002-11-06 → checking for new rows...
#     → No new data
# ⚠ WARNING: CEN1 last update 6629 days ago (last date 2007-11-07)
# [UPDATE] CEN1: last = 2007-11-07 → checking for new rows...
#     → No new data
# ⚠ WARNING: CEPH last update 5193 days ago (last date 2011-10-13)
# [UPDATE] CEPH: last = 2011-10-13 → checking for new rows...
#     → No new data
# ⚠ WARNING: CERN last update 1303 days ago (last date 2022-06-07)
# [UPDATE] CERN: last = 2022-06-07 → checking for new rows...
#     → No new data
# [UPDATE] CF: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CF1 last update 7792 days ago (last date 2004-08-31)
# [UPDATE] CF1: last = 2004-08-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: CFC last update 6393 days ago (last date 2008-06-30)
# [UPDATE] CFC: last = 2008-06-30 → checking for new rows...
#     → No new data
# [UPDATE] CFG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CFL1 last update 10110 days ago (last date 1998-04-27)
# [UPDATE] CFL1: last = 1998-04-27 → checking for new rows...
#     → No new data
# ⚠ WARNING: CFN last update 3943 days ago (last date 2015-03-16)
# [UPDATE] CFN: last = 2015-03-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: CG1 last update 9191 days ago (last date 2000-11-01)
# [UPDATE] CG1: last = 2000-11-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CGP last update 9102 days ago (last date 2001-01-29)
# [UPDATE] CGP: last = 2001-01-29 → checking for new rows...
#     → No new data
# [NEW] CGW2: downloading FULL history...
# ⚠ No data found for CGW2
# ⚠ WARNING: CHA1 last update 9325 days ago (last date 2000-06-20)
# [UPDATE] CHA1: last = 2000-06-20 → checking for new rows...
#     → No new data
# [UPDATE] CHD: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CHIR1 last update 7196 days ago (last date 2006-04-19)
# [UPDATE] CHIR1: last = 2006-04-19 → checking for new rows...
#     → No new data
# ⚠ WARNING: CHKAQ last update 1785 days ago (last date 2021-02-10)
# [UPDATE] CHKAQ: last = 2021-02-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: CHRS1 last update 4948 days ago (last date 2012-06-14)
# [UPDATE] CHRS1: last = 2012-06-14 → checking for new rows...
#     → No new data
# [UPDATE] CHRW: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CHTR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CIEN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CIN last update 7215 days ago (last date 2006-03-31)
# [UPDATE] CIN: last = 2006-03-31 → checking for new rows...
#     → No new data
# [UPDATE] CINF: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CIT.A last update 8979 days ago (last date 2001-06-01)
# [UPDATE] CIT.A: last = 2001-06-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CITGQ last update 5866 days ago (last date 2009-12-09)
# [UPDATE] CITGQ: last = 2009-12-09 → checking for new rows...
#     → No new data
# [NEW] CKL: downloading FULL history...
# ⚠ No data found for CKL
# [UPDATE] CL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CLF: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CLX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CMA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [NEW] CMB: downloading FULL history...
# ⚠ No data found for CMB
# [UPDATE] CMCSA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CMCSK last update 3673 days ago (last date 2015-12-11)
# [UPDATE] CMCSK: last = 2015-12-11 → checking for new rows...
#     → No new data
# [UPDATE] CME: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CMG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CMI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CMS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CMVT last update 4713 days ago (last date 2013-02-04)
# [UPDATE] CMVT: last = 2013-02-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: CMX last update 6859 days ago (last date 2007-03-22)
# [UPDATE] CMX: last = 2007-03-22 → checking for new rows...
#     → No new data
# [UPDATE] CNC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CNCEQ last update 8546 days ago (last date 2002-08-08)
# [UPDATE] CNCEQ: last = 2002-08-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: CNG last update 9469 days ago (last date 2000-01-28)
# [UPDATE] CNG: last = 2000-01-28 → checking for new rows...
#     → No new data
# [UPDATE] CNP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CNW last update 3716 days ago (last date 2015-10-29)
# [UPDATE] CNW: last = 2015-10-29 → checking for new rows...
#     → No new data
# [UPDATE] CNX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CNXT1 last update 5371 days ago (last date 2011-04-18)
# [UPDATE] CNXT1: last = 2011-04-18 → checking for new rows...
#     → No new data
# ⚠ WARNING: COC last update 8524 days ago (last date 2002-08-30)
# [UPDATE] COC: last = 2002-08-30 → checking for new rows...
#     → No new data
# [UPDATE] COF: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] COIN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: COL last update 2592 days ago (last date 2018-11-26)
# [UPDATE] COL: last = 2018-11-26 → checking for new rows...
#     → No new data
# ⚠ WARNING: COMS1 last update 5746 days ago (last date 2010-04-08)
# [UPDATE] COMS1: last = 2010-04-08 → checking for new rows...
#     → No new data
# [UPDATE] COO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] COP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] COR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] COST: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: COT1 last update 9669 days ago (last date 1999-07-12)
# [UPDATE] COT1: last = 1999-07-12 → checking for new rows...
#     → No new data
# [UPDATE] COTY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: COV last update 3992 days ago (last date 2015-01-26)
# [UPDATE] COV: last = 2015-01-26 → checking for new rows...
#     → No new data
# [UPDATE] CPAY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CPB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CPGX last update 3471 days ago (last date 2016-06-30)
# [UPDATE] CPGX: last = 2016-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: CPNLQ last update 6543 days ago (last date 2008-02-01)
# [UPDATE] CPNLQ: last = 2008-02-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CPPRQ last update 1794 days ago (last date 2021-02-01)
# [UPDATE] CPPRQ: last = 2021-02-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: CPQ last update 8643 days ago (last date 2002-05-03)
# [UPDATE] CPQ: last = 2002-05-03 → checking for new rows...
#     → No new data
# [UPDATE] CPRI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CPRT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CPT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CPWR last update 4034 days ago (last date 2014-12-15)
# [UPDATE] CPWR: last = 2014-12-15 → checking for new rows...
#     → No new data
# [UPDATE] CRH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CRL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CRM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CRWD: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CSC last update 3197 days ago (last date 2017-03-31)
# [UPDATE] CSC: last = 2017-03-31 → checking for new rows...
#     → No new data
# [UPDATE] CSCO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CSE1 last update 9546 days ago (last date 1999-11-12)
# [UPDATE] CSE1: last = 1999-11-12 → checking for new rows...
#     → No new data
# [UPDATE] CSGP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CSR1 last update 9330 days ago (last date 2000-06-15)
# [UPDATE] CSR1: last = 2000-06-15 → checking for new rows...
#     → No new data
# ⚠ WARNING: CSRA last update 2829 days ago (last date 2018-04-03)
# [UPDATE] CSRA: last = 2018-04-03 → checking for new rows...
#     → No new data
# [UPDATE] CSX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CTAS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CTB last update 1671 days ago (last date 2021-06-04)
# [UPDATE] CTB: last = 2021-06-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: CTLT last update 379 days ago (last date 2024-12-17)
# [UPDATE] CTLT: last = 2024-12-17 → checking for new rows...
#     → No new data
# [UPDATE] CTRA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CTSH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CTVA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CTX1 last update 5979 days ago (last date 2009-08-18)
# [UPDATE] CTX1: last = 2009-08-18 → checking for new rows...
#     → No new data
# ⚠ WARNING: CTXS last update 1189 days ago (last date 2022-09-29)
# [UPDATE] CTXS: last = 2022-09-29 → checking for new rows...
#     → No new data
# [NEW] CUE1: downloading FULL history...
# ⚠ No data found for CUE1
# ⚠ WARNING: CVC last update 3481 days ago (last date 2016-06-20)
# [UPDATE] CVC: last = 2016-06-20 → checking for new rows...
#     → No new data
# ⚠ WARNING: CVG last update 2645 days ago (last date 2018-10-04)
# [UPDATE] CVG: last = 2018-10-04 → checking for new rows...
#     → No new data
# ⚠ WARNING: CVGYQ last update 8679 days ago (last date 2002-03-28)
# [UPDATE] CVGYQ: last = 2002-03-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: CVH last update 4622 days ago (last date 2013-05-06)
# [UPDATE] CVH: last = 2013-05-06 → checking for new rows...
#     → No new data
# [UPDATE] CVNA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CVS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] CVX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CXO last update 1811 days ago (last date 2021-01-15)
# [UPDATE] CXO: last = 2021-01-15 → checking for new rows...
#     → No new data
# [UPDATE] CXT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: CYM last update 9526 days ago (last date 1999-12-02)
# [UPDATE] CYM: last = 1999-12-02 → checking for new rows...
#     → No new data
# [UPDATE] CZR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] D: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DAL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DALRQ last update 6823 days ago (last date 2007-04-27)
# [UPDATE] DALRQ: last = 2007-04-27 → checking for new rows...
#     → No new data
# [UPDATE] DASH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DAY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DCNAQ last update 6544 days ago (last date 2008-01-31)
# [UPDATE] DCNAQ: last = 2008-01-31 → checking for new rows...
#     → No new data
# [UPDATE] DD: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DD1 last update 3044 days ago (last date 2017-08-31)
# [UPDATE] DD1: last = 2017-08-31 → checking for new rows...
#     → No new data
# [UPDATE] DDOG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DDS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DEC1 last update 10065 days ago (last date 1998-06-11)
# [UPDATE] DEC1: last = 1998-06-11 → checking for new rows...
#     → No new data
# [UPDATE] DECK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DELL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DELL1 last update 4446 days ago (last date 2013-10-29)
# [UPDATE] DELL1: last = 2013-10-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: DFODQ last update 1673 days ago (last date 2021-06-02)
# [UPDATE] DFODQ: last = 2021-06-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: DFS last update 229 days ago (last date 2025-05-16)
# [UPDATE] DFS: last = 2025-05-16 → checking for new rows...
#     → No new data
# [UPDATE] DG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DG1 last update 6753 days ago (last date 2007-07-06)
# [UPDATE] DG1: last = 2007-07-06 → checking for new rows...
#     → No new data
# ⚠ WARNING: DGN last update 9577 days ago (last date 1999-10-12)
# [UPDATE] DGN: last = 1999-10-12 → checking for new rows...
#     → No new data
# [UPDATE] DGX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DHI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DHR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DI1 last update 9955 days ago (last date 1998-09-29)
# [UPDATE] DI1: last = 1998-09-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: DIGI2 last update 9980 days ago (last date 1998-09-04)
# [UPDATE] DIGI2: last = 1998-09-04 → checking for new rows...
#     → No new data
# [UPDATE] DINO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DIS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DISCK last update 1363 days ago (last date 2022-04-08)
# [UPDATE] DISCK: last = 2022-04-08 → checking for new rows...
#     → No new data
# ⚠ WARNING: DISH last update 733 days ago (last date 2023-12-29)
# [UPDATE] DISH: last = 2023-12-29 → checking for new rows...
#     → No new data
# ⚠ WARNING: DJ last update 6593 days ago (last date 2007-12-13)
# [UPDATE] DJ: last = 2007-12-13 → checking for new rows...
#     → No new data
# [UPDATE] DLR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DLTR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DLX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DNB1 last update 9221 days ago (last date 2000-10-02)
# [UPDATE] DNB1: last = 2000-10-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: DNB2 last update 10046 days ago (last date 1998-06-30)
# [UPDATE] DNB2: last = 1998-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: DNB3 last update 2519 days ago (last date 2019-02-07)
# [UPDATE] DNB3: last = 2019-02-07 → checking for new rows...
#     → No new data
# ⚠ WARNING: DNRCQ last update 1930 days ago (last date 2020-09-18)
# [UPDATE] DNRCQ: last = 2020-09-18 → checking for new rows...
#     → No new data
# [UPDATE] DOC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DOFSQ last update 1713 days ago (last date 2021-04-23)
# [UPDATE] DOFSQ: last = 2021-04-23 → checking for new rows...
#     → No new data
# [UPDATE] DOV: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DOW: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DPHIQ last update 5929 days ago (last date 2009-10-07)
# [UPDATE] DPHIQ: last = 2009-10-07 → checking for new rows...
#     → No new data
# [UPDATE] DPZ: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DRE last update 1188 days ago (last date 2022-09-30)
# [UPDATE] DRE: last = 2022-09-30 → checking for new rows...
#     → No new data
# [UPDATE] DRI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DTE: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DTV1 last update 3813 days ago (last date 2015-07-24)
# [UPDATE] DTV1: last = 2015-07-24 → checking for new rows...
#     → No new data
# [UPDATE] DUK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DVA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DVN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DXC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] DXCM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: DYNIQ last update 4838 days ago (last date 2012-10-02)
# [UPDATE] DYNIQ: last = 2012-10-02 → checking for new rows...
#     → No new data
# [UPDATE] EA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] EBAY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: EC1 last update 7145 days ago (last date 2006-06-09)
# [UPDATE] EC1: last = 2006-06-09 → checking for new rows...
#     → No new data
# ⚠ WARNING: ECH1 last update 10037 days ago (last date 1998-07-09)
# [UPDATE] ECH1: last = 1998-07-09 → checking for new rows...
#     → No new data
# [UPDATE] ECL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ECO1 last update 8370 days ago (last date 2003-01-31)
# [UPDATE] ECO1: last = 2003-01-31 → checking for new rows...
#     → No new data
# [UPDATE] ED: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: EDS last update 6337 days ago (last date 2008-08-25)
# [UPDATE] EDS: last = 2008-08-25 → checking for new rows...
#     → No new data
# ⚠ WARNING: EFU1 last update 9184 days ago (last date 2000-11-08)
# [UPDATE] EFU1: last = 2000-11-08 → checking for new rows...
#     → No new data
# [UPDATE] EFX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] EG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] EHC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] EIX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: EKDKQ last update 4502 days ago (last date 2013-09-03)
# [UPDATE] EKDKQ: last = 2013-09-03 → checking for new rows...
#     → No new data
# [UPDATE] EL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ELV: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: EMC1 last update 3403 days ago (last date 2016-09-06)
# [UPDATE] EMC1: last = 2016-09-06 → checking for new rows...
#     → No new data
# [UPDATE] EME: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] EMN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] EMR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ENDPQ last update 1224 days ago (last date 2022-08-25)
# [UPDATE] ENDPQ: last = 2022-08-25 → checking for new rows...
#     → No new data
# [UPDATE] ENPH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: ENRNQ last update 7714 days ago (last date 2004-11-17)
# [UPDATE] ENRNQ: last = 2004-11-17 → checking for new rows...
#     → No new data
# [UPDATE] EOG: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: EOP last update 6900 days ago (last date 2007-02-09)
# [UPDATE] EOP: last = 2007-02-09 → checking for new rows...
#     → No new data
# ⚠ WARNING: EP1 last update 4969 days ago (last date 2012-05-24)
# [UPDATE] EP1: last = 2012-05-24 → checking for new rows...
#     → No new data
# ...
# [UPDATE] TSN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: TSS last update 2297 days ago (last date 2019-09-17)
# [UPDATE] TSS: last = 2019-09-17 → checking for new rows...
#     → No new data
# [UPDATE] TT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: TT2 last update 6418 days ago (last date 2008-06-05)
# [UPDATE] TT2: last = 2008-06-05 → checking for new rows...
#     → No new data
# [UPDATE] TTD: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] TTWO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: TUPBQ last update 470 days ago (last date 2024-09-17)
# [UPDATE] TUPBQ: last = 2024-09-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWC last update 3515 days ago (last date 2016-05-17)
# [UPDATE] TWC: last = 2016-05-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWTR last update 1161 days ago (last date 2022-10-27)
# [UPDATE] TWTR: last = 2022-10-27 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWX last update 2756 days ago (last date 2018-06-15)
# [UPDATE] TWX: last = 2018-06-15 → checking for new rows...
#     → No new data
# ⚠ WARNING: TWX1 last update 9120 days ago (last date 2001-01-11)
# [UPDATE] TWX1: last = 2001-01-11 → checking for new rows...
#     → No new data
# ⚠ WARNING: TX1 last update 8849 days ago (last date 2001-10-09)
# [UPDATE] TX1: last = 2001-10-09 → checking for new rows...
#     → No new data
# [UPDATE] TXN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] TXT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: TXU last update 6657 days ago (last date 2007-10-10)
# [UPDATE] TXU: last = 2007-10-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: TYC last update 3407 days ago (last date 2016-09-02)
# [UPDATE] TYC: last = 2016-09-02 → checking for new rows...
#     → No new data
# [UPDATE] TYL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UAA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UAL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: UAWGQ last update 8311 days ago (last date 2003-03-31)
# [UPDATE] UAWGQ: last = 2003-03-31 → checking for new rows...
#     → No new data
# [UPDATE] UBER: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: UCC1 last update 9742 days ago (last date 1999-04-30)
# [UPDATE] UCC1: last = 1999-04-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: UCL1 last update 7448 days ago (last date 2005-08-10)
# [UPDATE] UCL1: last = 2005-08-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: UCM last update 9203 days ago (last date 2000-10-20)
# [UPDATE] UCM: last = 2000-10-20 → checking for new rows...
#     → No new data
# [UPDATE] UDR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UHS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UIS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: UK1 last update 9094 days ago (last date 2001-02-06)
# [UPDATE] UK1: last = 2001-02-06 → checking for new rows...
#     → No new data
# [UPDATE] UL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ULTA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UNH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UNM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] UNP: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: UPC1 last update 7854 days ago (last date 2004-06-30)
# [UPDATE] UPC1: last = 2004-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: UPR last update 9301 days ago (last date 2000-07-14)
# [UPDATE] UPR: last = 2000-07-14 → checking for new rows...
#     → No new data
# [UPDATE] UPS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] URBN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] URI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] USB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: USB1 last update 9077 days ago (last date 2001-02-23)
# [UPDATE] USB1: last = 2001-02-23 → checking for new rows...
#     → No new data
# [NEW] USBC1: downloading FULL history...
# ⚠ No data found for USBC1
# ⚠ WARNING: USG1 last update 2444 days ago (last date 2019-04-23)
# [UPDATE] USG1: last = 2019-04-23 → checking for new rows...
#     → No new data
# ⚠ WARNING: USS1 last update 9953 days ago (last date 1998-10-01)
# [UPDATE] USS1: last = 1998-10-01 → checking for new rows...
#     → No new data
# ⚠ WARNING: UST1 last update 6204 days ago (last date 2009-01-05)
# [UPDATE] UST1: last = 2009-01-05 → checking for new rows...
#     → No new data
# ⚠ WARNING: USW last update 9315 days ago (last date 2000-06-30)
# [UPDATE] USW: last = 2000-06-30 → checking for new rows...
#     → No new data
# ⚠ WARNING: UVN last update 6853 days ago (last date 2007-03-28)
# [UPDATE] UVN: last = 2007-03-28 → checking for new rows...
#     → No new data
# [UPDATE] V: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: VALPQ last update 1709 days ago (last date 2021-04-27)
# [UPDATE] VALPQ: last = 2021-04-27 → checking for new rows...
#     → No new data
# ⚠ WARNING: VAR last update 1722 days ago (last date 2021-04-14)
# [UPDATE] VAR: last = 2021-04-14 → checking for new rows...
#     → No new data
# [UPDATE] VFC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: VIAB last update 2219 days ago (last date 2019-12-04)
# [UPDATE] VIAB: last = 2019-12-04 → checking for new rows...
#     → No new data
# [UPDATE] VIAV: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VICI: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VLO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VLTO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VMC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VNO: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VNT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: VO1 last update 9154 days ago (last date 2000-12-08)
# [UPDATE] VO1: last = 2000-12-08 → checking for new rows...
#     → No new data
# [UPDATE] VRSK: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VRSN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: VRTS1 last update 7488 days ago (last date 2005-07-01)
# [UPDATE] VRTS1: last = 2005-07-01 → checking for new rows...
#     → No new data
# [UPDATE] VRTX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VST: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: VSTNQ last update 5570 days ago (last date 2010-10-01)
# [UPDATE] VSTNQ: last = 2010-10-01 → checking for new rows...
#     → No new data
# [UPDATE] VTR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VTRS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: VTSS last update 3901 days ago (last date 2015-04-27)
# [UPDATE] VTSS: last = 2015-04-27 → checking for new rows...
#     → No new data
# [UPDATE] VYX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] VZ: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WAB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WAI1 last update 10005 days ago (last date 1998-08-10)
# [UPDATE] WAI1: last = 1998-08-10 → checking for new rows...
#     → No new data
# ⚠ WARNING: WAMUQ last update 5034 days ago (last date 2012-03-20)
# [UPDATE] WAMUQ: last = 2012-03-20 → checking for new rows...
#     → No new data
# [UPDATE] WAT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WB1 last update 6209 days ago (last date 2008-12-31)
# [UPDATE] WB1: last = 2008-12-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: WB2 last update 8888 days ago (last date 2001-08-31)
# [UPDATE] WB2: last = 2001-08-31 → checking for new rows...
#     → No new data
# ⚠ WARNING: WBA last update 125 days ago (last date 2025-08-28)
# [UPDATE] WBA: last = 2025-08-28 → checking for new rows...
#     → No new data
# [UPDATE] WBD: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WCG last update 2169 days ago (last date 2020-01-23)
# [UPDATE] WCG: last = 2020-01-23 → checking for new rows...
#     → No new data
# ⚠ WARNING: WCOEQ last update 7926 days ago (last date 2004-04-19)
# [UPDATE] WCOEQ: last = 2004-04-19 → checking for new rows...
#     → No new data
# [UPDATE] WDAY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WDC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WEC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WELL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WEN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WFC: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WFC1 last update 9921 days ago (last date 1998-11-02)
# [UPDATE] WFC1: last = 1998-11-02 → checking for new rows...
#     → No new data
# ⚠ WARNING: WFM last update 3047 days ago (last date 2017-08-28)
# [UPDATE] WFM: last = 2017-08-28 → checking for new rows...
#     → No new data
# ⚠ WARNING: WFTIQ last update 2210 days ago (last date 2019-12-13)
# [UPDATE] WFTIQ: last = 2019-12-13 → checking for new rows...
#     → No new data
# ⚠ WARNING: WGL last update 2735 days ago (last date 2018-07-06)
# [UPDATE] WGL: last = 2018-07-06 → checking for new rows...
#     → No new data
# [UPDATE] WHR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WINMQ last update 1926 days ago (last date 2020-09-22)
# [UPDATE] WINMQ: last = 2020-09-22 → checking for new rows...
#     → No new data
# ⚠ WARNING: WLA last update 9326 days ago (last date 2000-06-19)
# [UPDATE] WLA: last = 2000-06-19 → checking for new rows...
#     → No new data
# ⚠ WARNING: WLL1 last update 8693 days ago (last date 2002-03-14)
# [UPDATE] WLL1: last = 2002-03-14 → checking for new rows...
#     → No new data
# ⚠ WARNING: WLP1 last update 7700 days ago (last date 2004-12-01)
# [UPDATE] WLP1: last = 2004-12-01 → checking for new rows...
#     → No new data
# [UPDATE] WM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WMB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WMT: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WNDXQ last update 6980 days ago (last date 2006-11-21)
# [UPDATE] WNDXQ: last = 2006-11-21 → checking for new rows...
#     → No new data
# [UPDATE] WOR: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WPX last update 1820 days ago (last date 2021-01-06)
# [UPDATE] WPX: last = 2021-01-06 → checking for new rows...
#     → No new data
# [UPDATE] WRB: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WRK last update 544 days ago (last date 2024-07-05)
# [UPDATE] WRK: last = 2024-07-05 → checking for new rows...
#     → No new data
# [UPDATE] WSM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [NEW] WSN: downloading FULL history...
# ⚠ No data found for WSN
# [UPDATE] WST: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WTW: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] WU: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WWY last update 6295 days ago (last date 2008-10-06)
# [UPDATE] WWY: last = 2008-10-06 → checking for new rows...
#     → No new data
# [UPDATE] WY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: WYE last update 5921 days ago (last date 2009-10-15)
# [UPDATE] WYE: last = 2009-10-15 → checking for new rows...
#     → No new data
# [UPDATE] WYNN: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: X last update 197 days ago (last date 2025-06-17)
# [UPDATE] X: last = 2025-06-17 → checking for new rows...
#     → No new data
# ⚠ WARNING: XEC last update 1553 days ago (last date 2021-09-30)
# [UPDATE] XEC: last = 2021-09-30 → checking for new rows...
#     → No new data
# [UPDATE] XEL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: XL1 last update 2668 days ago (last date 2018-09-11)
# [UPDATE] XL1: last = 2018-09-11 → checking for new rows...
#     → No new data
# ⚠ WARNING: XLNX last update 1419 days ago (last date 2022-02-11)
# [UPDATE] XLNX: last = 2022-02-11 → checking for new rows...
#     → No new data
# [UPDATE] XOM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] XRAY: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] XRX: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: XTO last update 5668 days ago (last date 2010-06-25)
# [UPDATE] XTO: last = 2010-06-25 → checking for new rows...
#     → No new data
# [UPDATE] XYL: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] XYZ: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# ⚠ WARNING: YHOO last update 3120 days ago (last date 2017-06-16)
# [UPDATE] YHOO: last = 2017-06-16 → checking for new rows...
#     → No new data
# ⚠ WARNING: YNR last update 9220 days ago (last date 2000-10-03)
# [UPDATE] YNR: last = 2000-10-03 → checking for new rows...
#     → No new data
# [UPDATE] YUM: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ZBH: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ZBRA: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ZION: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
# [UPDATE] ZTS: last = 2025-12-24 → checking for new rows...
#     → Appending 3 new rows (through 2025-12-30)
#
# === DONE: Incremental update complete ===
