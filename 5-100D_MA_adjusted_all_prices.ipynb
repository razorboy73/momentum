# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime

# ============================================================
# CONFIG
# ============================================================

INPUT_DIR  = "./3-adjusted_All_Prices_OHLC"
OUTPUT_DIR = "./5-100D_MA_adjusted_all_prices"
VER_DIR    = "./system_verification/5-100D_MA_adjusted_all_prices"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(VER_DIR, exist_ok=True)

print(f"\nLoading adjusted OHLC files from: {INPUT_DIR}")
files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith('.parquet')])
print(f"Found {len(files)} tickers.\n")

REQUIRED = {"date", "close_adj"}

# ============================================================
# VALIDATION STORAGE
# ============================================================

validation_rows = []

def add_validation(ticker, issue, detail=""):
    row = {"ticker": ticker, "issue": issue, "detail": detail}
    validation_rows.append(row)
    print(f"⚠ VALIDATION: {ticker} | {issue} | {detail}")


# ============================================================
# MA100 CALCULATION
# ============================================================

def compute_ma100(df, ticker):

    # Ensure required columns exist
    if not REQUIRED.issubset(df.columns):
        missing = REQUIRED - set(df.columns)
        add_validation(ticker, "missing_required_columns", f"missing: {missing}")
        return None

    # Date handling
    df["date"] = pd.to_datetime(df["date"])
    if not df["date"].is_monotonic_increasing:
        add_validation(ticker, "non_monotonic_dates")
        df = df.sort_values("date").reset_index(drop=True)

    # ============================================================
    # VALIDATION: LARGE GAPS IN TRADING CALENDAR
    # ============================================================

    gaps = df["date"].diff().dt.days
    if (gaps > 10).any():
        idx = gaps.idxmax()
        add_validation(
            ticker,
            "large_date_gap",
            f"max gap = {int(gaps.max())} days (from {df.loc[idx-1,'date'].date()} to {df.loc[idx,'date'].date()})"
        )

    # ============================================================
    # VALIDATION: NON-POSITIVE ADJUSTED CLOSES
    # ============================================================

    bad_close = df[df["close_adj"] <= 0]
    if not bad_close.empty:
        dates_str = ", ".join(str(d.date()) for d in bad_close["date"])
        add_validation(
            ticker,
            "nonpositive_close_adj",
            f"{len(bad_close)} rows → {dates_str}"
        )

    # ============================================================
    # INSUFFICIENT HISTORY CHECK
    # ============================================================

    if len(df) < 100:
        last_dt = df["date"].max().date()
        add_validation(
            ticker,
            "insufficient_history_for_ma100",
            f"only {len(df)} rows, last date {last_dt}"
        )
        # still compute MA100 (will be all NaNs)
        df["ma100"] = np.nan
        df["valid_ma100"] = False
        return df

    # ============================================================
    # COMPUTE 100-DAY TRADING MA
    # ============================================================
    df["ma100"] = df["close_adj"].rolling(window=100, min_periods=100).mean()
    df["valid_ma100"] = df["ma100"].notna()

    # ============================================================
    # VALIDATION: MA100 NEGATIVE?
    # ============================================================

    bad_ma = df[df["ma100"] < 0]
    if not bad_ma.empty:
        dates_str = ", ".join(str(d.date()) for d in bad_ma["date"])
        add_validation(
            ticker,
            "negative_MA100_detected",
            f"dates: {dates_str}"
        )

    # ============================================================
    # VALIDATION: PRICE SPIKES (20× ABOVE MEDIAN)
    # ============================================================

    if len(df) > 50:
        median_close = df["close_adj"].median()
        max_close = df["close_adj"].max()

        if median_close > 0 and max_close > median_close * 20:
            spike_date = df.loc[df["close_adj"].idxmax(), "date"].date()
            add_validation(
                ticker,
                "price_spike_detected",
                f"max close {max_close:.2f} on {spike_date}, median {median_close:.2f}"
            )

    return df


# ============================================================
# MAIN LOOP
# ============================================================

for file in files:
    ticker = file.replace(".parquet", "")
    in_path = os.path.join(INPUT_DIR, file)
    out_path = os.path.join(OUTPUT_DIR, f"{ticker}.parquet")

    print(f"Processing {ticker}...")

    try:
        df = pd.read_parquet(in_path)
        df2 = compute_ma100(df, ticker)

        if df2 is not None:
            df2.to_parquet(out_path, index=False)
            print(f"✔ {ticker}: saved MA100 → {out_path}\n")
        else:
            print(f"❌ {ticker}: MA100 not computed.\n")

    except Exception as e:
        add_validation(ticker, "processing_error", str(e))
        print(f"❌ ERROR for {ticker}: {e}\n")


# ============================================================
# SAVE VALIDATION REPORT
# ============================================================

validation_df = pd.DataFrame(validation_rows)

val_file = os.path.join(
    VER_DIR,
    f"ma100_validation-{datetime.now().strftime('%Y%m%d-%H%M%S')}.csv"
)

validation_df.to_csv(val_file, index=False)

print("\n====================================================")
print(" MA100 VALIDATION SUMMARY")
print("====================================================")

if validation_df.empty:
    print("No validation issues detected.")
else:
    print(validation_df)

print("\nValidation log saved to:")
print(val_file)
print("====================================================\n")
# Out:
# Loading adjusted OHLC files from: ./3-adjusted_All_Prices_OHLC
# Found 1167 tickers.
#
# Processing A...
# ✔ A: saved MA100 → ./5-100D_MA_adjusted_all_prices\A.parquet
#
# Processing AAL...
# ✔ AAL: saved MA100 → ./5-100D_MA_adjusted_all_prices\AAL.parquet
#
# Processing AAMRQ...
# ✔ AAMRQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\AAMRQ.parquet
#
# Processing AAP...
# ✔ AAP: saved MA100 → ./5-100D_MA_adjusted_all_prices\AAP.parquet
#
# Processing AAPL...
# ⚠ VALIDATION: AAPL | price_spike_detected | max close 286.19 on 2025-12-02, median 12.19
# ✔ AAPL: saved MA100 → ./5-100D_MA_adjusted_all_prices\AAPL.parquet
#
# Processing ABBV...
# ✔ ABBV: saved MA100 → ./5-100D_MA_adjusted_all_prices\ABBV.parquet
#
# Processing ABI1...
# ✔ ABI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ABI1.parquet
#
# Processing ABKFQ...
# ✔ ABKFQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\ABKFQ.parquet
#
# Processing ABMD...
# ⚠ VALIDATION: ABMD | price_spike_detected | max close 449.75 on 2018-09-28, median 18.06
# ✔ ABMD: saved MA100 → ./5-100D_MA_adjusted_all_prices\ABMD.parquet
#
# Processing ABNB...
# ✔ ABNB: saved MA100 → ./5-100D_MA_adjusted_all_prices\ABNB.parquet
#
# Processing ABS...
# ✔ ABS: saved MA100 → ./5-100D_MA_adjusted_all_prices\ABS.parquet
#
# Processing ABT...
# ✔ ABT: saved MA100 → ./5-100D_MA_adjusted_all_prices\ABT.parquet
#
# Processing ACAS...
# ✔ ACAS: saved MA100 → ./5-100D_MA_adjusted_all_prices\ACAS.parquet
#
# Processing ACGL...
# ✔ ACGL: saved MA100 → ./5-100D_MA_adjusted_all_prices\ACGL.parquet
#
# Processing ACKHQ...
# ⚠ VALIDATION: ACKHQ | price_spike_detected | max close 90.00 on 1998-04-20, median 2.40
# ✔ ACKHQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\ACKHQ.parquet
#
# Processing ACN...
# ✔ ACN: saved MA100 → ./5-100D_MA_adjusted_all_prices\ACN.parquet
#
# Processing ACS...
# ✔ ACS: saved MA100 → ./5-100D_MA_adjusted_all_prices\ACS.parquet
#
# Processing ACV1...
# ✔ ACV1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ACV1.parquet
#
# Processing ADBE...
# ✔ ADBE: saved MA100 → ./5-100D_MA_adjusted_all_prices\ADBE.parquet
#
# Processing ADCT1...
# ✔ ADCT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ADCT1.parquet
#
# Processing ADI...
# ✔ ADI: saved MA100 → ./5-100D_MA_adjusted_all_prices\ADI.parquet
#
# Processing ADM...
# ✔ ADM: saved MA100 → ./5-100D_MA_adjusted_all_prices\ADM.parquet
#
# Processing ADP...
# ✔ ADP: saved MA100 → ./5-100D_MA_adjusted_all_prices\ADP.parquet
#
# Processing ADSK...
# ✔ ADSK: saved MA100 → ./5-100D_MA_adjusted_all_prices\ADSK.parquet
#
# Processing ADT1...
# ✔ ADT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ADT1.parquet
#
# Processing AEE...
# ✔ AEE: saved MA100 → ./5-100D_MA_adjusted_all_prices\AEE.parquet
#
# Processing AEP...
# ✔ AEP: saved MA100 → ./5-100D_MA_adjusted_all_prices\AEP.parquet
#
# Processing AES...
# ✔ AES: saved MA100 → ./5-100D_MA_adjusted_all_prices\AES.parquet
#
# Processing AET...
# ✔ AET: saved MA100 → ./5-100D_MA_adjusted_all_prices\AET.parquet
#
# Processing AFL...
# ✔ AFL: saved MA100 → ./5-100D_MA_adjusted_all_prices\AFL.parquet
#
# Processing AFS.A...
# ✔ AFS.A: saved MA100 → ./5-100D_MA_adjusted_all_prices\AFS.A.parquet
#
# Processing AGC1...
# ✔ AGC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AGC1.parquet
#
# Processing AGN...
# ✔ AGN: saved MA100 → ./5-100D_MA_adjusted_all_prices\AGN.parquet
#
# Processing AGN1...
# ✔ AGN1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AGN1.parquet
#
# Processing AHM1...
# ✔ AHM1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AHM1.parquet
#
# Processing AIG...
# ⚠ VALIDATION: AIG | price_spike_detected | max close 1238.60 on 2000-12-08, median 53.62
# ✔ AIG: saved MA100 → ./5-100D_MA_adjusted_all_prices\AIG.parquet
#
# Processing AIT...
# ✔ AIT: saved MA100 → ./5-100D_MA_adjusted_all_prices\AIT.parquet
#
# Processing AIV...
# ✔ AIV: saved MA100 → ./5-100D_MA_adjusted_all_prices\AIV.parquet
#
# Processing AIZ...
# ✔ AIZ: saved MA100 → ./5-100D_MA_adjusted_all_prices\AIZ.parquet
#
# Processing AJG...
# ✔ AJG: saved MA100 → ./5-100D_MA_adjusted_all_prices\AJG.parquet
#
# Processing AKAM...
# ✔ AKAM: saved MA100 → ./5-100D_MA_adjusted_all_prices\AKAM.parquet
#
# Processing AKS...
# ✔ AKS: saved MA100 → ./5-100D_MA_adjusted_all_prices\AKS.parquet
#
# Processing AL1...
# ✔ AL1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AL1.parquet
#
# Processing ALB...
# ✔ ALB: saved MA100 → ./5-100D_MA_adjusted_all_prices\ALB.parquet
#
# Processing ALGN...
# ✔ ALGN: saved MA100 → ./5-100D_MA_adjusted_all_prices\ALGN.parquet
#
# Processing ALK...
# ✔ ALK: saved MA100 → ./5-100D_MA_adjusted_all_prices\ALK.parquet
#
# Processing ALL...
# ✔ ALL: saved MA100 → ./5-100D_MA_adjusted_all_prices\ALL.parquet
#
# Processing ALLE...
# ✔ ALLE: saved MA100 → ./5-100D_MA_adjusted_all_prices\ALLE.parquet
#
# Processing ALTR1...
# ✔ ALTR1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ALTR1.parquet
#
# Processing ALXN...
# ✔ ALXN: saved MA100 → ./5-100D_MA_adjusted_all_prices\ALXN.parquet
#
# Processing AM1...
# ✔ AM1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AM1.parquet
#
# Processing AMAT...
# ✔ AMAT: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMAT.parquet
#
# Processing AMCC...
# ⚠ VALIDATION: AMCC | price_spike_detected | max close 428.00 on 2000-09-28, median 10.96
# ✔ AMCC: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMCC.parquet
#
# Processing AMCR...
# ✔ AMCR: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMCR.parquet
#
# Processing AMD...
# ✔ AMD: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMD.parquet
#
# Processing AME...
# ✔ AME: saved MA100 → ./5-100D_MA_adjusted_all_prices\AME.parquet
#
# Processing AMG...
# ✔ AMG: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMG.parquet
#
# Processing AMGN...
# ✔ AMGN: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMGN.parquet
#
# Processing AMP...
# ✔ AMP: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMP.parquet
#
# Processing AMP1...
# ✔ AMP1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMP1.parquet
#
# Processing AMT...
# ✔ AMT: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMT.parquet
#
# Processing AMTM...
# ✔ AMTM: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMTM.parquet
#
# Processing AMZN...
# ⚠ VALIDATION: AMZN | price_spike_detected | max close 254.00 on 2025-11-03, median 10.23
# ✔ AMZN: saved MA100 → ./5-100D_MA_adjusted_all_prices\AMZN.parquet
#
# Processing AN...
# ✔ AN: saved MA100 → ./5-100D_MA_adjusted_all_prices\AN.parquet
#
# Processing AN1...
# ✔ AN1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AN1.parquet
#
# Processing ANDV...
# ✔ ANDV: saved MA100 → ./5-100D_MA_adjusted_all_prices\ANDV.parquet
#
# Processing ANDW...
# ✔ ANDW: saved MA100 → ./5-100D_MA_adjusted_all_prices\ANDW.parquet
#
# Processing ANET...
# ✔ ANET: saved MA100 → ./5-100D_MA_adjusted_all_prices\ANET.parquet
#
# Processing ANF...
# ✔ ANF: saved MA100 → ./5-100D_MA_adjusted_all_prices\ANF.parquet
#
# Processing ANRZQ...
# ✔ ANRZQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\ANRZQ.parquet
#
# Processing ANSS...
# ✔ ANSS: saved MA100 → ./5-100D_MA_adjusted_all_prices\ANSS.parquet
#
# Processing ANV1...
# ✔ ANV1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ANV1.parquet
#
# Processing AON...
# ✔ AON: saved MA100 → ./5-100D_MA_adjusted_all_prices\AON.parquet
#
# Processing AOS...
# ✔ AOS: saved MA100 → ./5-100D_MA_adjusted_all_prices\AOS.parquet
#
# Processing APA...
# ✔ APA: saved MA100 → ./5-100D_MA_adjusted_all_prices\APA.parquet
#
# Processing APC...
# ✔ APC: saved MA100 → ./5-100D_MA_adjusted_all_prices\APC.parquet
#
# Processing APCC...
# ✔ APCC: saved MA100 → ./5-100D_MA_adjusted_all_prices\APCC.parquet
#
# Processing APD...
# ✔ APD: saved MA100 → ./5-100D_MA_adjusted_all_prices\APD.parquet
#
# Processing APH...
# ⚠ VALIDATION: APH | price_spike_detected | max close 143.85 on 2025-11-10, median 6.03
# ✔ APH: saved MA100 → ./5-100D_MA_adjusted_all_prices\APH.parquet
#
# Processing APO...
# ✔ APO: saved MA100 → ./5-100D_MA_adjusted_all_prices\APO.parquet
#
# Processing APOL...
# ✔ APOL: saved MA100 → ./5-100D_MA_adjusted_all_prices\APOL.parquet
#
# Processing APP...
# ✔ APP: saved MA100 → ./5-100D_MA_adjusted_all_prices\APP.parquet
#
# Processing APTV...
# ✔ APTV: saved MA100 → ./5-100D_MA_adjusted_all_prices\APTV.parquet
#
# Processing AR1...
# ✔ AR1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AR1.parquet
#
# Processing ARC1...
# ✔ ARC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ARC1.parquet
#
# Processing ARE...
# ✔ ARE: saved MA100 → ./5-100D_MA_adjusted_all_prices\ARE.parquet
#
# Processing ARES...
# ✔ ARES: saved MA100 → ./5-100D_MA_adjusted_all_prices\ARES.parquet
#
# Processing ARG...
# ✔ ARG: saved MA100 → ./5-100D_MA_adjusted_all_prices\ARG.parquet
#
# Processing AS1...
# ✔ AS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AS1.parquet
#
# Processing ASC1...
# ✔ ASC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ASC1.parquet
#
# Processing ASH...
# ✔ ASH: saved MA100 → ./5-100D_MA_adjusted_all_prices\ASH.parquet
#
# Processing ASN...
# ✔ ASN: saved MA100 → ./5-100D_MA_adjusted_all_prices\ASN.parquet
#
# Processing ASND1...
# ✔ ASND1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ASND1.parquet
#
# Processing ASO1...
# ✔ ASO1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ASO1.parquet
#
# Processing AT1...
# ✔ AT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AT1.parquet
#
# Processing ATGE...
# ✔ ATGE: saved MA100 → ./5-100D_MA_adjusted_all_prices\ATGE.parquet
#
# Processing ATI...
# ✔ ATI: saved MA100 → ./5-100D_MA_adjusted_all_prices\ATI.parquet
#
# Processing ATI1...
# ✔ ATI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ATI1.parquet
#
# Processing ATO...
# ✔ ATO: saved MA100 → ./5-100D_MA_adjusted_all_prices\ATO.parquet
#
# Processing ATVI...
# ✔ ATVI: saved MA100 → ./5-100D_MA_adjusted_all_prices\ATVI.parquet
#
# Processing AV1...
# ✔ AV1: saved MA100 → ./5-100D_MA_adjusted_all_prices\AV1.parquet
#
# Processing AVB...
# ✔ AVB: saved MA100 → ./5-100D_MA_adjusted_all_prices\AVB.parquet
#
# Processing AVGO...
# ⚠ VALIDATION: AVGO | price_spike_detected | max close 412.97 on 2025-12-10, median 18.96
# ✔ AVGO: saved MA100 → ./5-100D_MA_adjusted_all_prices\AVGO.parquet
#
# Processing AVP...
# ✔ AVP: saved MA100 → ./5-100D_MA_adjusted_all_prices\AVP.parquet
#
# Processing AVY...
# ✔ AVY: saved MA100 → ./5-100D_MA_adjusted_all_prices\AVY.parquet
#
# Processing AW...
# ✔ AW: saved MA100 → ./5-100D_MA_adjusted_all_prices\AW.parquet
#
# Processing AWE...
# ✔ AWE: saved MA100 → ./5-100D_MA_adjusted_all_prices\AWE.parquet
#
# Processing AWK...
# ✔ AWK: saved MA100 → ./5-100D_MA_adjusted_all_prices\AWK.parquet
#
# Processing AXON...
# ⚠ VALIDATION: AXON | price_spike_detected | max close 870.97 on 2025-08-07, median 16.17
# ✔ AXON: saved MA100 → ./5-100D_MA_adjusted_all_prices\AXON.parquet
#
# Processing AXP...
# ✔ AXP: saved MA100 → ./5-100D_MA_adjusted_all_prices\AXP.parquet
#
# Processing AYE...
# ✔ AYE: saved MA100 → ./5-100D_MA_adjusted_all_prices\AYE.parquet
#
# Processing AYI...
# ✔ AYI: saved MA100 → ./5-100D_MA_adjusted_all_prices\AYI.parquet
#
# Processing AZA.A...
# ✔ AZA.A: saved MA100 → ./5-100D_MA_adjusted_all_prices\AZA.A.parquet
#
# Processing AZO...
# ✔ AZO: saved MA100 → ./5-100D_MA_adjusted_all_prices\AZO.parquet
#
# Processing B...
# ✔ B: saved MA100 → ./5-100D_MA_adjusted_all_prices\B.parquet
#
# Processing BA...
# ✔ BA: saved MA100 → ./5-100D_MA_adjusted_all_prices\BA.parquet
#
# Processing BAC...
# ✔ BAC: saved MA100 → ./5-100D_MA_adjusted_all_prices\BAC.parquet
#
# Processing BAC1...
# ✔ BAC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BAC1.parquet
#
# Processing BALL...
# ✔ BALL: saved MA100 → ./5-100D_MA_adjusted_all_prices\BALL.parquet
#
# Processing BAX...
# ✔ BAX: saved MA100 → ./5-100D_MA_adjusted_all_prices\BAX.parquet
#
# Processing BAY1...
# ✔ BAY1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BAY1.parquet
#
# Processing BBBYQ...
# ✔ BBBYQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\BBBYQ.parquet
#
# Processing BBI1...
# ⚠ VALIDATION: BBI1 | insufficient_history_for_ma100 | only 7 rows, last date 1998-01-09
# ✔ BBI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BBI1.parquet
#
# Processing BBWI...
# ✔ BBWI: saved MA100 → ./5-100D_MA_adjusted_all_prices\BBWI.parquet
#
# Processing BBY...
# ✔ BBY: saved MA100 → ./5-100D_MA_adjusted_all_prices\BBY.parquet
#
# Processing BC...
# ✔ BC: saved MA100 → ./5-100D_MA_adjusted_all_prices\BC.parquet
#
# Processing BCR...
# ✔ BCR: saved MA100 → ./5-100D_MA_adjusted_all_prices\BCR.parquet
#
# Processing BDK...
# ✔ BDK: saved MA100 → ./5-100D_MA_adjusted_all_prices\BDK.parquet
#
# Processing BDX...
# ✔ BDX: saved MA100 → ./5-100D_MA_adjusted_all_prices\BDX.parquet
#
# Processing BEAM2...
# ✔ BEAM2: saved MA100 → ./5-100D_MA_adjusted_all_prices\BEAM2.parquet
#
# Processing BEN...
# ✔ BEN: saved MA100 → ./5-100D_MA_adjusted_all_prices\BEN.parquet
#
# Processing BF.B...
# ✔ BF.B: saved MA100 → ./5-100D_MA_adjusted_all_prices\BF.B.parquet
#
# Processing BFH...
# ✔ BFH: saved MA100 → ./5-100D_MA_adjusted_all_prices\BFH.parquet
#
# Processing BFI1...
# ✔ BFI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BFI1.parquet
#
# Processing BFO1...
# ✔ BFO1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BFO1.parquet
#
# Processing BG...
# ✔ BG: saved MA100 → ./5-100D_MA_adjusted_all_prices\BG.parquet
#
# Processing BGEN...
# ✔ BGEN: saved MA100 → ./5-100D_MA_adjusted_all_prices\BGEN.parquet
#
# Processing BGGSQ...
# ✔ BGGSQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\BGGSQ.parquet
#
# Processing BHF...
# ✔ BHF: saved MA100 → ./5-100D_MA_adjusted_all_prices\BHF.parquet
#
# Processing BHI...
# ✔ BHI: saved MA100 → ./5-100D_MA_adjusted_all_prices\BHI.parquet
#
# Processing BHMSQ...
# ✔ BHMSQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\BHMSQ.parquet
#
# Processing BIGGQ...
# ✔ BIGGQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\BIGGQ.parquet
#
# Processing BIIB...
# ✔ BIIB: saved MA100 → ./5-100D_MA_adjusted_all_prices\BIIB.parquet
#
# Processing BIO...
# ✔ BIO: saved MA100 → ./5-100D_MA_adjusted_all_prices\BIO.parquet
#
# Processing BJS...
# ✔ BJS: saved MA100 → ./5-100D_MA_adjusted_all_prices\BJS.parquet
#
# Processing BK...
# ✔ BK: saved MA100 → ./5-100D_MA_adjusted_all_prices\BK.parquet
#
# Processing BKB...
# ✔ BKB: saved MA100 → ./5-100D_MA_adjusted_all_prices\BKB.parquet
#
# Processing BKNG...
# ✔ BKNG: saved MA100 → ./5-100D_MA_adjusted_all_prices\BKNG.parquet
#
# Processing BKR...
# ✔ BKR: saved MA100 → ./5-100D_MA_adjusted_all_prices\BKR.parquet
#
# Processing BLDR...
# ✔ BLDR: saved MA100 → ./5-100D_MA_adjusted_all_prices\BLDR.parquet
#
# Processing BLK...
# ✔ BLK: saved MA100 → ./5-100D_MA_adjusted_all_prices\BLK.parquet
#
# Processing BLS...
# ✔ BLS: saved MA100 → ./5-100D_MA_adjusted_all_prices\BLS.parquet
#
# Processing BMC...
# ✔ BMC: saved MA100 → ./5-100D_MA_adjusted_all_prices\BMC.parquet
#
# Processing BMET...
# ✔ BMET: saved MA100 → ./5-100D_MA_adjusted_all_prices\BMET.parquet
#
# Processing BMGCA...
# ✔ BMGCA: saved MA100 → ./5-100D_MA_adjusted_all_prices\BMGCA.parquet
#
# Processing BMS...
# ✔ BMS: saved MA100 → ./5-100D_MA_adjusted_all_prices\BMS.parquet
#
# Processing BMY...
# ✔ BMY: saved MA100 → ./5-100D_MA_adjusted_all_prices\BMY.parquet
#
# Processing BNI...
# ✔ BNI: saved MA100 → ./5-100D_MA_adjusted_all_prices\BNI.parquet
#
# Processing BNL1...
# ✔ BNL1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BNL1.parquet
#
# Processing BOL...
# ✔ BOL: saved MA100 → ./5-100D_MA_adjusted_all_prices\BOL.parquet
#
# Processing BR...
# ✔ BR: saved MA100 → ./5-100D_MA_adjusted_all_prices\BR.parquet
#
# Processing BR1...
# ✔ BR1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BR1.parquet
#
# Processing BRCM...
# ✔ BRCM: saved MA100 → ./5-100D_MA_adjusted_all_prices\BRCM.parquet
#
# Processing BRK.B...
# ✔ BRK.B: saved MA100 → ./5-100D_MA_adjusted_all_prices\BRK.B.parquet
#
# Processing BRL...
# ✔ BRL: saved MA100 → ./5-100D_MA_adjusted_all_prices\BRL.parquet
#
# Processing BRO...
# ✔ BRO: saved MA100 → ./5-100D_MA_adjusted_all_prices\BRO.parquet
#
# Processing BSC1...
# ✔ BSC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BSC1.parquet
#
# Processing BSX...
# ✔ BSX: saved MA100 → ./5-100D_MA_adjusted_all_prices\BSX.parquet
#
# Processing BT1...
# ✔ BT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BT1.parquet
#
# Processing BTUUQ...
# ✔ BTUUQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\BTUUQ.parquet
#
# Processing BUD1...
# ✔ BUD1: saved MA100 → ./5-100D_MA_adjusted_all_prices\BUD1.parquet
#
# Processing BVSN...
# ⚠ VALIDATION: BVSN | price_spike_detected | max close 20394.75 on 2000-03-06, median 13.70
# ✔ BVSN: saved MA100 → ./5-100D_MA_adjusted_all_prices\BVSN.parquet
#
# Processing BWA...
# ✔ BWA: saved MA100 → ./5-100D_MA_adjusted_all_prices\BWA.parquet
#
# Processing BX...
# ✔ BX: saved MA100 → ./5-100D_MA_adjusted_all_prices\BX.parquet
#
# Processing BXLT...
# ✔ BXLT: saved MA100 → ./5-100D_MA_adjusted_all_prices\BXLT.parquet
#
# Processing BXP...
# ✔ BXP: saved MA100 → ./5-100D_MA_adjusted_all_prices\BXP.parquet
#
# Processing C...
# ✔ C: saved MA100 → ./5-100D_MA_adjusted_all_prices\C.parquet
#
# Processing C1...
# ✔ C1: saved MA100 → ./5-100D_MA_adjusted_all_prices\C1.parquet
#
# Processing CA1...
# ✔ CA1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CA1.parquet
#
# Processing CAG...
# ✔ CAG: saved MA100 → ./5-100D_MA_adjusted_all_prices\CAG.parquet
#
# Processing CAH...
# ✔ CAH: saved MA100 → ./5-100D_MA_adjusted_all_prices\CAH.parquet
#
# Processing CAL...
# ✔ CAL: saved MA100 → ./5-100D_MA_adjusted_all_prices\CAL.parquet
#
# Processing CAM2...
# ✔ CAM2: saved MA100 → ./5-100D_MA_adjusted_all_prices\CAM2.parquet
#
# Processing CAR...
# ✔ CAR: saved MA100 → ./5-100D_MA_adjusted_all_prices\CAR.parquet
#
# Processing CARR...
# ✔ CARR: saved MA100 → ./5-100D_MA_adjusted_all_prices\CARR.parquet
#
# Processing CAT...
# ✔ CAT: saved MA100 → ./5-100D_MA_adjusted_all_prices\CAT.parquet
#
# Processing CB...
# ✔ CB: saved MA100 → ./5-100D_MA_adjusted_all_prices\CB.parquet
#
# Processing CB1...
# ✔ CB1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CB1.parquet
#
# Processing CBE...
# ✔ CBE: saved MA100 → ./5-100D_MA_adjusted_all_prices\CBE.parquet
#
# Processing CBH1...
# ✔ CBH1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CBH1.parquet
#
# Processing CBOE...
# ✔ CBOE: saved MA100 → ./5-100D_MA_adjusted_all_prices\CBOE.parquet
#
# Processing CBRE...
# ✔ CBRE: saved MA100 → ./5-100D_MA_adjusted_all_prices\CBRE.parquet
#
# Processing CBS1...
# ✔ CBS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CBS1.parquet
#
# Processing CBSS...
# ✔ CBSS: saved MA100 → ./5-100D_MA_adjusted_all_prices\CBSS.parquet
#
# Processing CCE1...
# ✔ CCE1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CCE1.parquet
#
# Processing CCI...
# ✔ CCI: saved MA100 → ./5-100D_MA_adjusted_all_prices\CCI.parquet
#
# Processing CCI1...
# ✔ CCI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CCI1.parquet
#
# Processing CCK...
# ✔ CCK: saved MA100 → ./5-100D_MA_adjusted_all_prices\CCK.parquet
#
# Processing CCL...
# ✔ CCL: saved MA100 → ./5-100D_MA_adjusted_all_prices\CCL.parquet
#
# Processing CCTYQ...
# ✔ CCTYQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CCTYQ.parquet
#
# Processing CCU1...
# ✔ CCU1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CCU1.parquet
#
# Processing CDNS...
# ✔ CDNS: saved MA100 → ./5-100D_MA_adjusted_all_prices\CDNS.parquet
#
# Processing CDW...
# ✔ CDW: saved MA100 → ./5-100D_MA_adjusted_all_prices\CDW.parquet
#
# Processing CE...
# ✔ CE: saved MA100 → ./5-100D_MA_adjusted_all_prices\CE.parquet
#
# Processing CE1...
# ✔ CE1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CE1.parquet
#
# Processing CEG...
# ✔ CEG: saved MA100 → ./5-100D_MA_adjusted_all_prices\CEG.parquet
#
# Processing CEG1...
# ✔ CEG1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CEG1.parquet
#
# Processing CELG...
# ✔ CELG: saved MA100 → ./5-100D_MA_adjusted_all_prices\CELG.parquet
#
# Processing CEM1...
# ✔ CEM1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CEM1.parquet
#
# Processing CEN1...
# ✔ CEN1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CEN1.parquet
#
# Processing CEPH...
# ✔ CEPH: saved MA100 → ./5-100D_MA_adjusted_all_prices\CEPH.parquet
#
# Processing CERN...
# ✔ CERN: saved MA100 → ./5-100D_MA_adjusted_all_prices\CERN.parquet
#
# Processing CF...
# ✔ CF: saved MA100 → ./5-100D_MA_adjusted_all_prices\CF.parquet
#
# Processing CF1...
# ✔ CF1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CF1.parquet
#
# Processing CFC...
# ✔ CFC: saved MA100 → ./5-100D_MA_adjusted_all_prices\CFC.parquet
#
# Processing CFG...
# ✔ CFG: saved MA100 → ./5-100D_MA_adjusted_all_prices\CFG.parquet
#
# Processing CFL1...
# ⚠ VALIDATION: CFL1 | insufficient_history_for_ma100 | only 80 rows, last date 1998-04-27
# ✔ CFL1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CFL1.parquet
#
# Processing CFN...
# ✔ CFN: saved MA100 → ./5-100D_MA_adjusted_all_prices\CFN.parquet
#
# Processing CG1...
# ✔ CG1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CG1.parquet
#
# Processing CGP...
# ✔ CGP: saved MA100 → ./5-100D_MA_adjusted_all_prices\CGP.parquet
#
# Processing CHA1...
# ✔ CHA1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CHA1.parquet
#
# Processing CHD...
# ✔ CHD: saved MA100 → ./5-100D_MA_adjusted_all_prices\CHD.parquet
#
# Processing CHIR1...
# ✔ CHIR1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CHIR1.parquet
#
# Processing CHKAQ...
# ✔ CHKAQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CHKAQ.parquet
#
# Processing CHRS1...
# ✔ CHRS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CHRS1.parquet
#
# Processing CHRW...
# ✔ CHRW: saved MA100 → ./5-100D_MA_adjusted_all_prices\CHRW.parquet
#
# Processing CHTR...
# ✔ CHTR: saved MA100 → ./5-100D_MA_adjusted_all_prices\CHTR.parquet
#
# Processing CI...
# ✔ CI: saved MA100 → ./5-100D_MA_adjusted_all_prices\CI.parquet
#
# Processing CIEN...
# ⚠ VALIDATION: CIEN | price_spike_detected | max close 1046.50 on 2000-10-20, median 31.06
# ✔ CIEN: saved MA100 → ./5-100D_MA_adjusted_all_prices\CIEN.parquet
#
# Processing CIN...
# ✔ CIN: saved MA100 → ./5-100D_MA_adjusted_all_prices\CIN.parquet
#
# Processing CINF...
# ✔ CINF: saved MA100 → ./5-100D_MA_adjusted_all_prices\CINF.parquet
#
# Processing CIT.A...
# ✔ CIT.A: saved MA100 → ./5-100D_MA_adjusted_all_prices\CIT.A.parquet
#
# Processing CITGQ...
# ✔ CITGQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CITGQ.parquet
#
# Processing CL...
# ✔ CL: saved MA100 → ./5-100D_MA_adjusted_all_prices\CL.parquet
#
# Processing CLF...
# ✔ CLF: saved MA100 → ./5-100D_MA_adjusted_all_prices\CLF.parquet
#
# Processing CLX...
# ✔ CLX: saved MA100 → ./5-100D_MA_adjusted_all_prices\CLX.parquet
#
# Processing CMA...
# ✔ CMA: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMA.parquet
#
# Processing CMCSA...
# ✔ CMCSA: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMCSA.parquet
#
# Processing CMCSK...
# ✔ CMCSK: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMCSK.parquet
#
# Processing CME...
# ✔ CME: saved MA100 → ./5-100D_MA_adjusted_all_prices\CME.parquet
#
# Processing CMG...
# ✔ CMG: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMG.parquet
#
# Processing CMI...
# ✔ CMI: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMI.parquet
#
# Processing CMS...
# ✔ CMS: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMS.parquet
#
# Processing CMVT...
# ✔ CMVT: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMVT.parquet
#
# Processing CMX...
# ✔ CMX: saved MA100 → ./5-100D_MA_adjusted_all_prices\CMX.parquet
#
# Processing CNC...
# ✔ CNC: saved MA100 → ./5-100D_MA_adjusted_all_prices\CNC.parquet
#
# Processing CNCEQ...
# ✔ CNCEQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CNCEQ.parquet
#
# Processing CNG...
# ✔ CNG: saved MA100 → ./5-100D_MA_adjusted_all_prices\CNG.parquet
#
# Processing CNP...
# ✔ CNP: saved MA100 → ./5-100D_MA_adjusted_all_prices\CNP.parquet
#
# Processing CNW...
# ✔ CNW: saved MA100 → ./5-100D_MA_adjusted_all_prices\CNW.parquet
#
# Processing CNX...
# ✔ CNX: saved MA100 → ./5-100D_MA_adjusted_all_prices\CNX.parquet
#
# Processing CNXT1...
# ⚠ VALIDATION: CNXT1 | price_spike_detected | max close 447.18 on 2000-02-22, median 18.50
# ✔ CNXT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CNXT1.parquet
#
# Processing COC...
# ✔ COC: saved MA100 → ./5-100D_MA_adjusted_all_prices\COC.parquet
#
# Processing COF...
# ✔ COF: saved MA100 → ./5-100D_MA_adjusted_all_prices\COF.parquet
#
# Processing COIN...
# ✔ COIN: saved MA100 → ./5-100D_MA_adjusted_all_prices\COIN.parquet
#
# Processing COL...
# ✔ COL: saved MA100 → ./5-100D_MA_adjusted_all_prices\COL.parquet
#
# Processing COMS1...
# ✔ COMS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\COMS1.parquet
#
# Processing COO...
# ✔ COO: saved MA100 → ./5-100D_MA_adjusted_all_prices\COO.parquet
#
# Processing COP...
# ✔ COP: saved MA100 → ./5-100D_MA_adjusted_all_prices\COP.parquet
#
# Processing COR...
# ✔ COR: saved MA100 → ./5-100D_MA_adjusted_all_prices\COR.parquet
#
# Processing COST...
# ✔ COST: saved MA100 → ./5-100D_MA_adjusted_all_prices\COST.parquet
#
# Processing COT1...
# ✔ COT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\COT1.parquet
#
# Processing COTY...
# ✔ COTY: saved MA100 → ./5-100D_MA_adjusted_all_prices\COTY.parquet
#
# Processing COV...
# ✔ COV: saved MA100 → ./5-100D_MA_adjusted_all_prices\COV.parquet
#
# Processing CPAY...
# ✔ CPAY: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPAY.parquet
#
# Processing CPB...
# ✔ CPB: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPB.parquet
#
# Processing CPGX...
# ✔ CPGX: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPGX.parquet
#
# Processing CPNLQ...
# ✔ CPNLQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPNLQ.parquet
#
# Processing CPPRQ...
# ✔ CPPRQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPPRQ.parquet
#
# Processing CPQ...
# ✔ CPQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPQ.parquet
#
# Processing CPRI...
# ✔ CPRI: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPRI.parquet
#
# Processing CPRT...
# ⚠ VALIDATION: CPRT | price_spike_detected | max close 63.84 on 2025-05-16, median 2.93
# ✔ CPRT: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPRT.parquet
#
# Processing CPT...
# ✔ CPT: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPT.parquet
#
# Processing CPWR...
# ✔ CPWR: saved MA100 → ./5-100D_MA_adjusted_all_prices\CPWR.parquet
#
# Processing CRH...
# ✔ CRH: saved MA100 → ./5-100D_MA_adjusted_all_prices\CRH.parquet
#
# Processing CRL...
# ✔ CRL: saved MA100 → ./5-100D_MA_adjusted_all_prices\CRL.parquet
#
# Processing CRM...
# ✔ CRM: saved MA100 → ./5-100D_MA_adjusted_all_prices\CRM.parquet
#
# Processing CRWD...
# ✔ CRWD: saved MA100 → ./5-100D_MA_adjusted_all_prices\CRWD.parquet
#
# Processing CSC...
# ✔ CSC: saved MA100 → ./5-100D_MA_adjusted_all_prices\CSC.parquet
#
# Processing CSCO...
# ✔ CSCO: saved MA100 → ./5-100D_MA_adjusted_all_prices\CSCO.parquet
#
# Processing CSE1...
# ✔ CSE1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CSE1.parquet
#
# Processing CSGP...
# ✔ CSGP: saved MA100 → ./5-100D_MA_adjusted_all_prices\CSGP.parquet
#
# Processing CSR1...
# ✔ CSR1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CSR1.parquet
#
# Processing CSRA...
# ✔ CSRA: saved MA100 → ./5-100D_MA_adjusted_all_prices\CSRA.parquet
#
# Processing CSX...
# ✔ CSX: saved MA100 → ./5-100D_MA_adjusted_all_prices\CSX.parquet
#
# Processing CTAS...
# ⚠ VALIDATION: CTAS | price_spike_detected | max close 226.64 on 2025-06-06, median 9.05
# ✔ CTAS: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTAS.parquet
#
# Processing CTB...
# ✔ CTB: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTB.parquet
#
# Processing CTLT...
# ✔ CTLT: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTLT.parquet
#
# Processing CTRA...
# ✔ CTRA: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTRA.parquet
#
# Processing CTSH...
# ✔ CTSH: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTSH.parquet
#
# Processing CTVA...
# ✔ CTVA: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTVA.parquet
#
# Processing CTX1...
# ✔ CTX1: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTX1.parquet
#
# Processing CTXS...
# ✔ CTXS: saved MA100 → ./5-100D_MA_adjusted_all_prices\CTXS.parquet
#
# Processing CVC...
# ✔ CVC: saved MA100 → ./5-100D_MA_adjusted_all_prices\CVC.parquet
#
# Processing CVG...
# ✔ CVG: saved MA100 → ./5-100D_MA_adjusted_all_prices\CVG.parquet
#
# Processing CVGYQ...
# ✔ CVGYQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\CVGYQ.parquet
#
# Processing CVH...
# ✔ CVH: saved MA100 → ./5-100D_MA_adjusted_all_prices\CVH.parquet
#
# Processing CVNA...
# ✔ CVNA: saved MA100 → ./5-100D_MA_adjusted_all_prices\CVNA.parquet
#
# Processing CVS...
# ✔ CVS: saved MA100 → ./5-100D_MA_adjusted_all_prices\CVS.parquet
#
# Processing CVX...
# ✔ CVX: saved MA100 → ./5-100D_MA_adjusted_all_prices\CVX.parquet
#
# Processing CXO...
# ✔ CXO: saved MA100 → ./5-100D_MA_adjusted_all_prices\CXO.parquet
#
# Processing CXT...
# ✔ CXT: saved MA100 → ./5-100D_MA_adjusted_all_prices\CXT.parquet
#
# Processing CYM...
# ✔ CYM: saved MA100 → ./5-100D_MA_adjusted_all_prices\CYM.parquet
#
# Processing CZR...
# ✔ CZR: saved MA100 → ./5-100D_MA_adjusted_all_prices\CZR.parquet
#
# Processing D...
# ✔ D: saved MA100 → ./5-100D_MA_adjusted_all_prices\D.parquet
#
# Processing DAL...
# ✔ DAL: saved MA100 → ./5-100D_MA_adjusted_all_prices\DAL.parquet
#
# Processing DALRQ...
# ✔ DALRQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DALRQ.parquet
#
# Processing DASH...
# ✔ DASH: saved MA100 → ./5-100D_MA_adjusted_all_prices\DASH.parquet
#
# Processing DAY...
# ✔ DAY: saved MA100 → ./5-100D_MA_adjusted_all_prices\DAY.parquet
#
# Processing DCNAQ...
# ✔ DCNAQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DCNAQ.parquet
#
# Processing DD...
# ✔ DD: saved MA100 → ./5-100D_MA_adjusted_all_prices\DD.parquet
#
# Processing DD1...
# ✔ DD1: saved MA100 → ./5-100D_MA_adjusted_all_prices\DD1.parquet
#
# Processing DDOG...
# ✔ DDOG: saved MA100 → ./5-100D_MA_adjusted_all_prices\DDOG.parquet
#
# Processing DDS...
# ⚠ VALIDATION: DDS | price_spike_detected | max close 730.73 on 2025-12-10, median 32.72
# ✔ DDS: saved MA100 → ./5-100D_MA_adjusted_all_prices\DDS.parquet
#
# Processing DE...
# ✔ DE: saved MA100 → ./5-100D_MA_adjusted_all_prices\DE.parquet
#
# Processing DEC1...
# ✔ DEC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\DEC1.parquet
#
# Processing DECK...
# ⚠ VALIDATION: DECK | price_spike_detected | max close 223.11 on 2025-01-30, median 8.77
# ✔ DECK: saved MA100 → ./5-100D_MA_adjusted_all_prices\DECK.parquet
#
# Processing DELL...
# ✔ DELL: saved MA100 → ./5-100D_MA_adjusted_all_prices\DELL.parquet
#
# Processing DELL1...
# ✔ DELL1: saved MA100 → ./5-100D_MA_adjusted_all_prices\DELL1.parquet
#
# Processing DFODQ...
# ✔ DFODQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DFODQ.parquet
#
# Processing DFS...
# ✔ DFS: saved MA100 → ./5-100D_MA_adjusted_all_prices\DFS.parquet
#
# Processing DG...
# ✔ DG: saved MA100 → ./5-100D_MA_adjusted_all_prices\DG.parquet
#
# Processing DG1...
# ✔ DG1: saved MA100 → ./5-100D_MA_adjusted_all_prices\DG1.parquet
#
# Processing DGN...
# ✔ DGN: saved MA100 → ./5-100D_MA_adjusted_all_prices\DGN.parquet
#
# Processing DGX...
# ✔ DGX: saved MA100 → ./5-100D_MA_adjusted_all_prices\DGX.parquet
#
# Processing DHI...
# ✔ DHI: saved MA100 → ./5-100D_MA_adjusted_all_prices\DHI.parquet
#
# Processing DHR...
# ✔ DHR: saved MA100 → ./5-100D_MA_adjusted_all_prices\DHR.parquet
#
# Processing DI1...
# ✔ DI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\DI1.parquet
#
# Processing DIGI2...
# ✔ DIGI2: saved MA100 → ./5-100D_MA_adjusted_all_prices\DIGI2.parquet
#
# Processing DINO...
# ✔ DINO: saved MA100 → ./5-100D_MA_adjusted_all_prices\DINO.parquet
#
# Processing DIS...
# ✔ DIS: saved MA100 → ./5-100D_MA_adjusted_all_prices\DIS.parquet
#
# Processing DISCK...
# ✔ DISCK: saved MA100 → ./5-100D_MA_adjusted_all_prices\DISCK.parquet
#
# Processing DISH...
# ✔ DISH: saved MA100 → ./5-100D_MA_adjusted_all_prices\DISH.parquet
#
# Processing DJ...
# ✔ DJ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DJ.parquet
#
# Processing DLR...
# ✔ DLR: saved MA100 → ./5-100D_MA_adjusted_all_prices\DLR.parquet
#
# Processing DLTR...
# ✔ DLTR: saved MA100 → ./5-100D_MA_adjusted_all_prices\DLTR.parquet
#
# Processing DLX...
# ✔ DLX: saved MA100 → ./5-100D_MA_adjusted_all_prices\DLX.parquet
#
# Processing DNB1...
# ✔ DNB1: saved MA100 → ./5-100D_MA_adjusted_all_prices\DNB1.parquet
#
# Processing DNB2...
# ✔ DNB2: saved MA100 → ./5-100D_MA_adjusted_all_prices\DNB2.parquet
#
# Processing DNB3...
# ✔ DNB3: saved MA100 → ./5-100D_MA_adjusted_all_prices\DNB3.parquet
#
# Processing DNRCQ...
# ✔ DNRCQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DNRCQ.parquet
#
# Processing DOC...
# ✔ DOC: saved MA100 → ./5-100D_MA_adjusted_all_prices\DOC.parquet
#
# Processing DOFSQ...
# ✔ DOFSQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DOFSQ.parquet
#
# Processing DOV...
# ✔ DOV: saved MA100 → ./5-100D_MA_adjusted_all_prices\DOV.parquet
#
# Processing DOW...
# ✔ DOW: saved MA100 → ./5-100D_MA_adjusted_all_prices\DOW.parquet
#
# Processing DPHIQ...
# ✔ DPHIQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DPHIQ.parquet
#
# Processing DPZ...
# ✔ DPZ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DPZ.parquet
#
# Processing DRE...
# ✔ DRE: saved MA100 → ./5-100D_MA_adjusted_all_prices\DRE.parquet
#
# Processing DRI...
# ✔ DRI: saved MA100 → ./5-100D_MA_adjusted_all_prices\DRI.parquet
#
# Processing DTE...
# ✔ DTE: saved MA100 → ./5-100D_MA_adjusted_all_prices\DTE.parquet
#
# Processing DTV1...
# ✔ DTV1: saved MA100 → ./5-100D_MA_adjusted_all_prices\DTV1.parquet
#
# Processing DUK...
# ✔ DUK: saved MA100 → ./5-100D_MA_adjusted_all_prices\DUK.parquet
#
# Processing DVA...
# ✔ DVA: saved MA100 → ./5-100D_MA_adjusted_all_prices\DVA.parquet
#
# Processing DVN...
# ✔ DVN: saved MA100 → ./5-100D_MA_adjusted_all_prices\DVN.parquet
#
# Processing DXC...
# ✔ DXC: saved MA100 → ./5-100D_MA_adjusted_all_prices\DXC.parquet
#
# Processing DXCM...
# ✔ DXCM: saved MA100 → ./5-100D_MA_adjusted_all_prices\DXCM.parquet
#
# Processing DYNIQ...
# ✔ DYNIQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\DYNIQ.parquet
#
# Processing EA...
# ✔ EA: saved MA100 → ./5-100D_MA_adjusted_all_prices\EA.parquet
#
# Processing EBAY...
# ✔ EBAY: saved MA100 → ./5-100D_MA_adjusted_all_prices\EBAY.parquet
#
# Processing EC1...
# ✔ EC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\EC1.parquet
#
# Processing ECH1...
# ✔ ECH1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ECH1.parquet
#
# Processing ECL...
# ✔ ECL: saved MA100 → ./5-100D_MA_adjusted_all_prices\ECL.parquet
#
# Processing ECO1...
# ✔ ECO1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ECO1.parquet
#
# Processing ED...
# ✔ ED: saved MA100 → ./5-100D_MA_adjusted_all_prices\ED.parquet
#
# Processing EDS...
# ✔ EDS: saved MA100 → ./5-100D_MA_adjusted_all_prices\EDS.parquet
#
# Processing EFU1...
# ✔ EFU1: saved MA100 → ./5-100D_MA_adjusted_all_prices\EFU1.parquet
#
# Processing EFX...
# ✔ EFX: saved MA100 → ./5-100D_MA_adjusted_all_prices\EFX.parquet
#
# Processing EG...
# ✔ EG: saved MA100 → ./5-100D_MA_adjusted_all_prices\EG.parquet
#
# Processing EHC...
# ✔ EHC: saved MA100 → ./5-100D_MA_adjusted_all_prices\EHC.parquet
#
# Processing EIX...
# ✔ EIX: saved MA100 → ./5-100D_MA_adjusted_all_prices\EIX.parquet
#
# Processing EKDKQ...
# ✔ EKDKQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\EKDKQ.parquet
#
# Processing EL...
# ✔ EL: saved MA100 → ./5-100D_MA_adjusted_all_prices\EL.parquet
#
# Processing ELV...
# ✔ ELV: saved MA100 → ./5-100D_MA_adjusted_all_prices\ELV.parquet
#
# Processing EMC1...
# ✔ EMC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\EMC1.parquet
#
# Processing EME...
# ⚠ VALIDATION: EME | price_spike_detected | max close 777.00 on 2025-10-29, median 28.45
# ✔ EME: saved MA100 → ./5-100D_MA_adjusted_all_prices\EME.parquet
#
# Processing EMN...
# ✔ EMN: saved MA100 → ./5-100D_MA_adjusted_all_prices\EMN.parquet
#
# Processing EMR...
# ✔ EMR: saved MA100 → ./5-100D_MA_adjusted_all_prices\EMR.parquet
#
# Processing ENDPQ...
# ✔ ENDPQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\ENDPQ.parquet
#
# Processing ENPH...
# ⚠ VALIDATION: ENPH | price_spike_detected | max close 336.00 on 2022-12-02, median 13.84
# ✔ ENPH: saved MA100 → ./5-100D_MA_adjusted_all_prices\ENPH.parquet
#
# Processing ENRNQ...
# ✔ ENRNQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\ENRNQ.parquet
#
# Processing EOG...
# ✔ EOG: saved MA100 → ./5-100D_MA_adjusted_all_prices\EOG.parquet
#
# Processing EOP...
# ✔ EOP: saved MA100 → ./5-100D_MA_adjusted_all_prices\EOP.parquet
#
# Processing EP1...
# ✔ EP1: saved MA100 → ./5-100D_MA_adjusted_all_prices\EP1.parquet
#
# Processing EPAM...
# ✔ EPAM: saved MA100 → ./5-100D_MA_adjusted_all_prices\EPAM.parquet
#
# Processing EQ1...
# ✔ EQ1: saved MA100 → ./5-100D_MA_adjusted_all_prices\EQ1.parquet
#
# Processing EQIX...
# ✔ EQIX: saved MA100 → ./5-100D_MA_adjusted_all_prices\EQIX.parquet
#
# Processing EQR...
# ✔ EQR: saved MA100 → ./5-100D_MA_adjusted_all_prices\EQR.parquet
#
# Processing EQT...
# ✔ EQT: saved MA100 → ./5-100D_MA_adjusted_all_prices\EQT.parquet
#
# Processing ERIE...
# ✔ ERIE: saved MA100 → ./5-100D_MA_adjusted_all_prices\ERIE.parquet
#
# Processing ES...
# ✔ ES: saved MA100 → ./5-100D_MA_adjusted_all_prices\ES.parquet
#
# Processing ESRX...
# ✔ ESRX: saved MA100 → ./5-100D_MA_adjusted_all_prices\ESRX.parquet
#
# Processing ESS...
# ✔ ESS: saved MA100 → ./5-100D_MA_adjusted_all_prices\ESS.parquet
#
# Processing ETFC...
# ✔ ETFC: saved MA100 → ./5-100D_MA_adjusted_all_prices\ETFC.parquet
#
# Processing ETN...
# ✔ ETN: saved MA100 → ./5-100D_MA_adjusted_all_prices\ETN.parquet
#
# Processing ETR...
# ✔ ETR: saved MA100 → ./5-100D_MA_adjusted_all_prices\ETR.parquet
#
# Processing ETS1...
# ✔ ETS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\ETS1.parquet
#
# Processing ETSY...
# ✔ ETSY: saved MA100 → ./5-100D_MA_adjusted_all_prices\ETSY.parquet
#
# Processing EVHC...
# ✔ EVHC: saved MA100 → ./5-100D_MA_adjusted_all_prices\EVHC.parquet
#
# Processing EVRG...
# ✔ EVRG: saved MA100 → ./5-100D_MA_adjusted_all_prices\EVRG.parquet
#
# Processing EW...
# ✔ EW: saved MA100 → ./5-100D_MA_adjusted_all_prices\EW.parquet
#
# Processing EXC...
# ✔ EXC: saved MA100 → ./5-100D_MA_adjusted_all_prices\EXC.parquet
#
# Processing EXE...
# ✔ EXE: saved MA100 → ./5-100D_MA_adjusted_all_prices\EXE.parquet
#
# Processing EXPD...
# ✔ EXPD: saved MA100 → ./5-100D_MA_adjusted_all_prices\EXPD.parquet
#
# Processing EXPE...
# ✔ EXPE: saved MA100 → ./5-100D_MA_adjusted_all_prices\EXPE.parquet
#
# Processing EXR...
# ✔ EXR: saved MA100 → ./5-100D_MA_adjusted_all_prices\EXR.parquet
#
# Processing F...
# ✔ F: saved MA100 → ./5-100D_MA_adjusted_all_prices\F.parquet
#
# Processing FANG...
# ✔ FANG: saved MA100 → ./5-100D_MA_adjusted_all_prices\FANG.parquet
#
# Processing FAST...
# ✔ FAST: saved MA100 → ./5-100D_MA_adjusted_all_prices\FAST.parquet
#
# Processing FBF...
# ✔ FBF: saved MA100 → ./5-100D_MA_adjusted_all_prices\FBF.parquet
#
# Processing FBIN...
# ✔ FBIN: saved MA100 → ./5-100D_MA_adjusted_all_prices\FBIN.parquet
#
# Processing FCN1...
# ✔ FCN1: saved MA100 → ./5-100D_MA_adjusted_all_prices\FCN1.parquet
#
# Processing FCX...
# ✔ FCX: saved MA100 → ./5-100D_MA_adjusted_all_prices\FCX.parquet
#
# Processing FDC1...
# ✔ FDC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\FDC1.parquet
#
# Processing FDO...
# ✔ FDO: saved MA100 → ./5-100D_MA_adjusted_all_prices\FDO.parquet
#
# Processing FDS...
# ✔ FDS: saved MA100 → ./5-100D_MA_adjusted_all_prices\FDS.parquet
#
# Processing FDX...
# ✔ FDX: saved MA100 → ./5-100D_MA_adjusted_all_prices\FDX.parquet
#
# Processing FE...
# ✔ FE: saved MA100 → ./5-100D_MA_adjusted_all_prices\FE.parquet
#
# Processing FFIV...
# ✔ FFIV: saved MA100 → ./5-100D_MA_adjusted_all_prices\FFIV.parquet
#
# Processing FG1...
# ⚠ VALIDATION: FG1 | insufficient_history_for_ma100 | only 79 rows, last date 1998-04-24
# ✔ FG1: saved MA100 → ./5-100D_MA_adjusted_all_prices\FG1.parquet
#
# Processing FHI...
# ✔ FHI: saved MA100 → ./5-100D_MA_adjusted_all_prices\FHI.parquet
#
# Processing FHN...
# ✔ FHN: saved MA100 → ./5-100D_MA_adjusted_all_prices\FHN.parquet
#
# Processing FICO...
# ⚠ VALIDATION: FICO | price_spike_detected | max close 2382.40 on 2024-11-26, median 41.47
# ✔ FICO: saved MA100 → ./5-100D_MA_adjusted_all_prices\FICO.parquet
#
# Processing FIS...
# ✔ FIS: saved MA100 → ./5-100D_MA_adjusted_all_prices\FIS.parquet
#
# Processing FISV...
# ✔ FISV: saved MA100 → ./5-100D_MA_adjusted_all_prices\FISV.parquet
#
# Processing FITB...
# ✔ FITB: saved MA100 → ./5-100D_MA_adjusted_all_prices\FITB.parquet
#
# Processing FIX...
# ⚠ VALIDATION: FIX | price_spike_detected | max close 1024.92 on 2025-12-11, median 12.47
# ✔ FIX: saved MA100 → ./5-100D_MA_adjusted_all_prices\FIX.parquet
#
# Processing FJ...
# ✔ FJ: saved MA100 → ./5-100D_MA_adjusted_all_prices\FJ.parquet
#
# Processing FL...
# ✔ FL: saved MA100 → ./5-100D_MA_adjusted_all_prices\FL.parquet
#
# Processing FLIR...
# ✔ FLIR: saved MA100 → ./5-100D_MA_adjusted_all_prices\FLIR.parquet
#
# Processing FLMIQ...
# ✔ FLMIQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\FLMIQ.parquet
#
# Processing FLR...
# ✔ FLR: saved MA100 → ./5-100D_MA_adjusted_all_prices\FLR.parquet
#
# Processing FLS...
# ✔ FLS: saved MA100 → ./5-100D_MA_adjusted_all_prices\FLS.parquet
#
# Processing FLTWQ...
# ✔ FLTWQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\FLTWQ.parquet
#
# Processing FMC...
# ✔ FMC: saved MA100 → ./5-100D_MA_adjusted_all_prices\FMC.parquet
#
# Processing FMCC...
# ⚠ VALIDATION: FMCC | price_spike_detected | max close 66.96 on 2006-11-08, median 2.63
# ✔ FMCC: saved MA100 → ./5-100D_MA_adjusted_all_prices\FMCC.parquet
#
# Processing FMY1...
# ✔ FMY1: saved MA100 → ./5-100D_MA_adjusted_all_prices\FMY1.parquet
#
# Processing FNMA...
# ⚠ VALIDATION: FNMA | price_spike_detected | max close 73.24 on 2001-06-22, median 2.76
# ✔ FNMA: saved MA100 → ./5-100D_MA_adjusted_all_prices\FNMA.parquet
#
# Processing FOSL...
# ✔ FOSL: saved MA100 → ./5-100D_MA_adjusted_all_prices\FOSL.parquet
#
# Processing FOX...
# ✔ FOX: saved MA100 → ./5-100D_MA_adjusted_all_prices\FOX.parquet
#
# Processing FOXA...
# ✔ FOXA: saved MA100 → ./5-100D_MA_adjusted_all_prices\FOXA.parquet
#
# Processing FPC...
# ✔ FPC: saved MA100 → ./5-100D_MA_adjusted_all_prices\FPC.parquet
#
# Processing FRCB...
# ✔ FRCB: saved MA100 → ./5-100D_MA_adjusted_all_prices\FRCB.parquet
#
# Processing FRO1...
# ✔ FRO1: saved MA100 → ./5-100D_MA_adjusted_all_prices\FRO1.parquet
#
# Processing FRT...
# ✔ FRT: saved MA100 → ./5-100D_MA_adjusted_all_prices\FRT.parquet
#
# Processing FRX1...
# ✔ FRX1: saved MA100 → ./5-100D_MA_adjusted_all_prices\FRX1.parquet
#
# Processing FSH...
# ✔ FSH: saved MA100 → ./5-100D_MA_adjusted_all_prices\FSH.parquet
#
# Processing FSL.B...
# ✔ FSL.B: saved MA100 → ./5-100D_MA_adjusted_all_prices\FSL.B.parquet
#
# Processing FSLR...
# ✔ FSLR: saved MA100 → ./5-100D_MA_adjusted_all_prices\FSLR.parquet
#
# Processing FTI...
# ✔ FTI: saved MA100 → ./5-100D_MA_adjusted_all_prices\FTI.parquet
#
# Processing FTI1...
# ✔ FTI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\FTI1.parquet
#
# Processing FTL.A...
# ✔ FTL.A: saved MA100 → ./5-100D_MA_adjusted_all_prices\FTL.A.parquet
#
# Processing FTNT...
# ✔ FTNT: saved MA100 → ./5-100D_MA_adjusted_all_prices\FTNT.parquet
#
# Processing FTRCQ...
# ✔ FTRCQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\FTRCQ.parquet
#
# Processing FTV...
# ✔ FTV: saved MA100 → ./5-100D_MA_adjusted_all_prices\FTV.parquet
#
# Processing FWLT...
# ✔ FWLT: saved MA100 → ./5-100D_MA_adjusted_all_prices\FWLT.parquet
#
# Processing G1...
# ✔ G1: saved MA100 → ./5-100D_MA_adjusted_all_prices\G1.parquet
#
# Processing GAP...
# ✔ GAP: saved MA100 → ./5-100D_MA_adjusted_all_prices\GAP.parquet
#
# Processing GAPTQ...
# ✔ GAPTQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\GAPTQ.parquet
#
# Processing GAS...
# ✔ GAS: saved MA100 → ./5-100D_MA_adjusted_all_prices\GAS.parquet
#
# Processing GAS1...
# ✔ GAS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GAS1.parquet
#
# Processing GD...
# ✔ GD: saved MA100 → ./5-100D_MA_adjusted_all_prices\GD.parquet
#
# Processing GDDY...
# ✔ GDDY: saved MA100 → ./5-100D_MA_adjusted_all_prices\GDDY.parquet
#
# Processing GDT...
# ✔ GDT: saved MA100 → ./5-100D_MA_adjusted_all_prices\GDT.parquet
#
# Processing GDW...
# ✔ GDW: saved MA100 → ./5-100D_MA_adjusted_all_prices\GDW.parquet
#
# Processing GE...
# ✔ GE: saved MA100 → ./5-100D_MA_adjusted_all_prices\GE.parquet
#
# Processing GEHC...
# ✔ GEHC: saved MA100 → ./5-100D_MA_adjusted_all_prices\GEHC.parquet
#
# Processing GEN...
# ✔ GEN: saved MA100 → ./5-100D_MA_adjusted_all_prices\GEN.parquet
#
# Processing GEN1...
# ✔ GEN1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GEN1.parquet
#
# Processing GENZ...
# ✔ GENZ: saved MA100 → ./5-100D_MA_adjusted_all_prices\GENZ.parquet
#
# Processing GEV...
# ✔ GEV: saved MA100 → ./5-100D_MA_adjusted_all_prices\GEV.parquet
#
# Processing GFS.A...
# ✔ GFS.A: saved MA100 → ./5-100D_MA_adjusted_all_prices\GFS.A.parquet
#
# Processing GGP...
# ✔ GGP: saved MA100 → ./5-100D_MA_adjusted_all_prices\GGP.parquet
#
# Processing GHC...
# ✔ GHC: saved MA100 → ./5-100D_MA_adjusted_all_prices\GHC.parquet
#
# Processing GIC1...
# ✔ GIC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GIC1.parquet
#
# Processing GILD...
# ✔ GILD: saved MA100 → ./5-100D_MA_adjusted_all_prices\GILD.parquet
#
# Processing GIS...
# ✔ GIS: saved MA100 → ./5-100D_MA_adjusted_all_prices\GIS.parquet
#
# Processing GL...
# ✔ GL: saved MA100 → ./5-100D_MA_adjusted_all_prices\GL.parquet
#
# Processing GLK1...
# ✔ GLK1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GLK1.parquet
#
# Processing GLW...
# ✔ GLW: saved MA100 → ./5-100D_MA_adjusted_all_prices\GLW.parquet
#
# Processing GM...
# ✔ GM: saved MA100 → ./5-100D_MA_adjusted_all_prices\GM.parquet
#
# Processing GMCR...
# ⚠ VALIDATION: GMCR | price_spike_detected | max close 154.44 on 2014-11-18, median 4.08
# ✔ GMCR: saved MA100 → ./5-100D_MA_adjusted_all_prices\GMCR.parquet
#
# Processing GME...
# ✔ GME: saved MA100 → ./5-100D_MA_adjusted_all_prices\GME.parquet
#
# Processing GNRC...
# ✔ GNRC: saved MA100 → ./5-100D_MA_adjusted_all_prices\GNRC.parquet
#
# Processing GNT1...
# ✔ GNT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GNT1.parquet
#
# Processing GNW...
# ✔ GNW: saved MA100 → ./5-100D_MA_adjusted_all_prices\GNW.parquet
#
# Processing GOOG...
# ✔ GOOG: saved MA100 → ./5-100D_MA_adjusted_all_prices\GOOG.parquet
#
# Processing GOOGL...
# ✔ GOOGL: saved MA100 → ./5-100D_MA_adjusted_all_prices\GOOGL.parquet
#
# Processing GOSHA...
# ✔ GOSHA: saved MA100 → ./5-100D_MA_adjusted_all_prices\GOSHA.parquet
#
# Processing GP1...
# ✔ GP1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GP1.parquet
#
# Processing GPC...
# ✔ GPC: saved MA100 → ./5-100D_MA_adjusted_all_prices\GPC.parquet
#
# Processing GPN...
# ✔ GPN: saved MA100 → ./5-100D_MA_adjusted_all_prices\GPN.parquet
#
# Processing GPU...
# ✔ GPU: saved MA100 → ./5-100D_MA_adjusted_all_prices\GPU.parquet
#
# Processing GR...
# ✔ GR: saved MA100 → ./5-100D_MA_adjusted_all_prices\GR.parquet
#
# Processing GRA...
# ✔ GRA: saved MA100 → ./5-100D_MA_adjusted_all_prices\GRA.parquet
#
# Processing GRMN...
# ✔ GRMN: saved MA100 → ./5-100D_MA_adjusted_all_prices\GRMN.parquet
#
# Processing GRN1...
# ✔ GRN1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GRN1.parquet
#
# Processing GS...
# ✔ GS: saved MA100 → ./5-100D_MA_adjusted_all_prices\GS.parquet
#
# Processing GSX1...
# ✔ GSX1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GSX1.parquet
#
# Processing GT...
# ✔ GT: saved MA100 → ./5-100D_MA_adjusted_all_prices\GT.parquet
#
# Processing GTE1...
# ✔ GTE1: saved MA100 → ./5-100D_MA_adjusted_all_prices\GTE1.parquet
#
# Processing GTW...
# ✔ GTW: saved MA100 → ./5-100D_MA_adjusted_all_prices\GTW.parquet
#
# Processing GWOW...
# ✔ GWOW: saved MA100 → ./5-100D_MA_adjusted_all_prices\GWOW.parquet
#
# Processing GWW...
# ✔ GWW: saved MA100 → ./5-100D_MA_adjusted_all_prices\GWW.parquet
#
# Processing GX...
# ✔ GX: saved MA100 → ./5-100D_MA_adjusted_all_prices\GX.parquet
#
# Processing H1...
# ✔ H1: saved MA100 → ./5-100D_MA_adjusted_all_prices\H1.parquet
#
# Processing H2...
# ✔ H2: saved MA100 → ./5-100D_MA_adjusted_all_prices\H2.parquet
#
# Processing HAL...
# ✔ HAL: saved MA100 → ./5-100D_MA_adjusted_all_prices\HAL.parquet
#
# Processing HAR...
# ✔ HAR: saved MA100 → ./5-100D_MA_adjusted_all_prices\HAR.parquet
#
# Processing HAS...
# ✔ HAS: saved MA100 → ./5-100D_MA_adjusted_all_prices\HAS.parquet
#
# Processing HBAN...
# ✔ HBAN: saved MA100 → ./5-100D_MA_adjusted_all_prices\HBAN.parquet
#
# Processing HBI...
# ✔ HBI: saved MA100 → ./5-100D_MA_adjusted_all_prices\HBI.parquet
#
# Processing HBOC...
# ✔ HBOC: saved MA100 → ./5-100D_MA_adjusted_all_prices\HBOC.parquet
#
# Processing HCA...
# ✔ HCA: saved MA100 → ./5-100D_MA_adjusted_all_prices\HCA.parquet
#
# Processing HCA1...
# ✔ HCA1: saved MA100 → ./5-100D_MA_adjusted_all_prices\HCA1.parquet
#
# Processing HCBK...
# ✔ HCBK: saved MA100 → ./5-100D_MA_adjusted_all_prices\HCBK.parquet
#
# Processing HCR1...
# ✔ HCR1: saved MA100 → ./5-100D_MA_adjusted_all_prices\HCR1.parquet
#
# Processing HD...
# ✔ HD: saved MA100 → ./5-100D_MA_adjusted_all_prices\HD.parquet
#
# Processing HES...
# ✔ HES: saved MA100 → ./5-100D_MA_adjusted_all_prices\HES.parquet
#
# Processing HET...
# ✔ HET: saved MA100 → ./5-100D_MA_adjusted_all_prices\HET.parquet
#
# Processing HI1...
# ✔ HI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\HI1.parquet
#
# Processing HIG...
# ✔ HIG: saved MA100 → ./5-100D_MA_adjusted_all_prices\HIG.parquet
#
# Processing HII...
# ✔ HII: saved MA100 → ./5-100D_MA_adjusted_all_prices\HII.parquet
#
# Processing HLT...
# ✔ HLT: saved MA100 → ./5-100D_MA_adjusted_all_prices\HLT.parquet
#
# Processing HLT1...
# ✔ HLT1: saved MA100 → ./5-100D_MA_adjusted_all_prices\HLT1.parquet
#
# Processing HM...
# ✔ HM: saved MA100 → ./5-100D_MA_adjusted_all_prices\HM.parquet
#
# Processing HMA1...
# ✔ HMA1: saved MA100 → ./5-100D_MA_adjusted_all_prices\HMA1.parquet
#
# Processing HNZ...
# ✔ HNZ: saved MA100 → ./5-100D_MA_adjusted_all_prices\HNZ.parquet
#
# Processing HOG...
# ✔ HOG: saved MA100 → ./5-100D_MA_adjusted_all_prices\HOG.parquet
#
# Processing HOLX...
# ✔ HOLX: saved MA100 → ./5-100D_MA_adjusted_all_prices\HOLX.parquet
#
# Processing HON...
# ✔ HON: saved MA100 → ./5-100D_MA_adjusted_all_prices\HON.parquet
#
# Processing HON1...
# ✔ HON1: saved MA100 → ./5-100D_MA_adjusted_all_prices\HON1.parquet
#
# Processing HOOD...
# ✔ HOOD: saved MA100 → ./5-100D_MA_adjusted_all_prices\HOOD.parquet
#
# Processing HOT...
# ✔ HOT: saved MA100 → ./5-100D_MA_adjusted_all_prices\HOT.parquet
#
# Processing HP...
# ✔ HP: saved MA100 → ./5-100D_MA_adjusted_all_prices\HP.parquet
#
# Processing HPC...
# ...
# ✔ TYC: saved MA100 → ./5-100D_MA_adjusted_all_prices\TYC.parquet
#
# Processing TYL...
# ⚠ VALIDATION: TYL | price_spike_detected | max close 646.74 on 2025-02-13, median 32.00
# ✔ TYL: saved MA100 → ./5-100D_MA_adjusted_all_prices\TYL.parquet
#
# Processing UA...
# ✔ UA: saved MA100 → ./5-100D_MA_adjusted_all_prices\UA.parquet
#
# Processing UAA...
# ✔ UAA: saved MA100 → ./5-100D_MA_adjusted_all_prices\UAA.parquet
#
# Processing UAL...
# ✔ UAL: saved MA100 → ./5-100D_MA_adjusted_all_prices\UAL.parquet
#
# Processing UAWGQ...
# ✔ UAWGQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\UAWGQ.parquet
#
# Processing UBER...
# ✔ UBER: saved MA100 → ./5-100D_MA_adjusted_all_prices\UBER.parquet
#
# Processing UCC1...
# ✔ UCC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\UCC1.parquet
#
# Processing UCL1...
# ✔ UCL1: saved MA100 → ./5-100D_MA_adjusted_all_prices\UCL1.parquet
#
# Processing UCM...
# ✔ UCM: saved MA100 → ./5-100D_MA_adjusted_all_prices\UCM.parquet
#
# Processing UDR...
# ✔ UDR: saved MA100 → ./5-100D_MA_adjusted_all_prices\UDR.parquet
#
# Processing UHS...
# ✔ UHS: saved MA100 → ./5-100D_MA_adjusted_all_prices\UHS.parquet
#
# Processing UIS...
# ⚠ VALIDATION: UIS | price_spike_detected | max close 493.10 on 1999-09-20, median 24.32
# ✔ UIS: saved MA100 → ./5-100D_MA_adjusted_all_prices\UIS.parquet
#
# Processing UK1...
# ✔ UK1: saved MA100 → ./5-100D_MA_adjusted_all_prices\UK1.parquet
#
# Processing UL...
# ✔ UL: saved MA100 → ./5-100D_MA_adjusted_all_prices\UL.parquet
#
# Processing ULTA...
# ✔ ULTA: saved MA100 → ./5-100D_MA_adjusted_all_prices\ULTA.parquet
#
# Processing UNH...
# ✔ UNH: saved MA100 → ./5-100D_MA_adjusted_all_prices\UNH.parquet
#
# Processing UNM...
# ✔ UNM: saved MA100 → ./5-100D_MA_adjusted_all_prices\UNM.parquet
#
# Processing UNP...
# ✔ UNP: saved MA100 → ./5-100D_MA_adjusted_all_prices\UNP.parquet
#
# Processing UPC1...
# ✔ UPC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\UPC1.parquet
#
# Processing UPR...
# ✔ UPR: saved MA100 → ./5-100D_MA_adjusted_all_prices\UPR.parquet
#
# Processing UPS...
# ✔ UPS: saved MA100 → ./5-100D_MA_adjusted_all_prices\UPS.parquet
#
# Processing URBN...
# ✔ URBN: saved MA100 → ./5-100D_MA_adjusted_all_prices\URBN.parquet
#
# Processing URI...
# ⚠ VALIDATION: URI | price_spike_detected | max close 1017.88 on 2025-10-15, median 33.46
# ✔ URI: saved MA100 → ./5-100D_MA_adjusted_all_prices\URI.parquet
#
# Processing USB...
# ✔ USB: saved MA100 → ./5-100D_MA_adjusted_all_prices\USB.parquet
#
# Processing USB1...
# ✔ USB1: saved MA100 → ./5-100D_MA_adjusted_all_prices\USB1.parquet
#
# Processing USG1...
# ✔ USG1: saved MA100 → ./5-100D_MA_adjusted_all_prices\USG1.parquet
#
# Processing USS1...
# ✔ USS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\USS1.parquet
#
# Processing UST1...
# ✔ UST1: saved MA100 → ./5-100D_MA_adjusted_all_prices\UST1.parquet
#
# Processing USW...
# ✔ USW: saved MA100 → ./5-100D_MA_adjusted_all_prices\USW.parquet
#
# Processing UVN...
# ✔ UVN: saved MA100 → ./5-100D_MA_adjusted_all_prices\UVN.parquet
#
# Processing V...
# ✔ V: saved MA100 → ./5-100D_MA_adjusted_all_prices\V.parquet
#
# Processing VALPQ...
# ✔ VALPQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\VALPQ.parquet
#
# Processing VAR...
# ✔ VAR: saved MA100 → ./5-100D_MA_adjusted_all_prices\VAR.parquet
#
# Processing VFC...
# ✔ VFC: saved MA100 → ./5-100D_MA_adjusted_all_prices\VFC.parquet
#
# Processing VIAB...
# ✔ VIAB: saved MA100 → ./5-100D_MA_adjusted_all_prices\VIAB.parquet
#
# Processing VIAV...
# ⚠ VALIDATION: VIAV | price_spike_detected | max close 669.24 on 2000-03-06, median 10.25
# ✔ VIAV: saved MA100 → ./5-100D_MA_adjusted_all_prices\VIAV.parquet
#
# Processing VICI...
# ✔ VICI: saved MA100 → ./5-100D_MA_adjusted_all_prices\VICI.parquet
#
# Processing VLO...
# ✔ VLO: saved MA100 → ./5-100D_MA_adjusted_all_prices\VLO.parquet
#
# Processing VLTO...
# ✔ VLTO: saved MA100 → ./5-100D_MA_adjusted_all_prices\VLTO.parquet
#
# Processing VMC...
# ✔ VMC: saved MA100 → ./5-100D_MA_adjusted_all_prices\VMC.parquet
#
# Processing VNO...
# ✔ VNO: saved MA100 → ./5-100D_MA_adjusted_all_prices\VNO.parquet
#
# Processing VNT...
# ✔ VNT: saved MA100 → ./5-100D_MA_adjusted_all_prices\VNT.parquet
#
# Processing VO1...
# ✔ VO1: saved MA100 → ./5-100D_MA_adjusted_all_prices\VO1.parquet
#
# Processing VRSK...
# ✔ VRSK: saved MA100 → ./5-100D_MA_adjusted_all_prices\VRSK.parquet
#
# Processing VRSN...
# ✔ VRSN: saved MA100 → ./5-100D_MA_adjusted_all_prices\VRSN.parquet
#
# Processing VRTS1...
# ✔ VRTS1: saved MA100 → ./5-100D_MA_adjusted_all_prices\VRTS1.parquet
#
# Processing VRTX...
# ✔ VRTX: saved MA100 → ./5-100D_MA_adjusted_all_prices\VRTX.parquet
#
# Processing VST...
# ✔ VST: saved MA100 → ./5-100D_MA_adjusted_all_prices\VST.parquet
#
# Processing VSTNQ...
# ✔ VSTNQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\VSTNQ.parquet
#
# Processing VTR...
# ✔ VTR: saved MA100 → ./5-100D_MA_adjusted_all_prices\VTR.parquet
#
# Processing VTRS...
# ✔ VTRS: saved MA100 → ./5-100D_MA_adjusted_all_prices\VTRS.parquet
#
# Processing VTSS...
# ⚠ VALIDATION: VTSS | price_spike_detected | max close 2122.50 on 2000-03-01, median 23.60
# ✔ VTSS: saved MA100 → ./5-100D_MA_adjusted_all_prices\VTSS.parquet
#
# Processing VYX...
# ✔ VYX: saved MA100 → ./5-100D_MA_adjusted_all_prices\VYX.parquet
#
# Processing VZ...
# ✔ VZ: saved MA100 → ./5-100D_MA_adjusted_all_prices\VZ.parquet
#
# Processing WAB...
# ✔ WAB: saved MA100 → ./5-100D_MA_adjusted_all_prices\WAB.parquet
#
# Processing WAI1...
# ✔ WAI1: saved MA100 → ./5-100D_MA_adjusted_all_prices\WAI1.parquet
#
# Processing WAMUQ...
# ✔ WAMUQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\WAMUQ.parquet
#
# Processing WAT...
# ✔ WAT: saved MA100 → ./5-100D_MA_adjusted_all_prices\WAT.parquet
#
# Processing WB1...
# ✔ WB1: saved MA100 → ./5-100D_MA_adjusted_all_prices\WB1.parquet
#
# Processing WB2...
# ✔ WB2: saved MA100 → ./5-100D_MA_adjusted_all_prices\WB2.parquet
#
# Processing WBA...
# ✔ WBA: saved MA100 → ./5-100D_MA_adjusted_all_prices\WBA.parquet
#
# Processing WBD...
# ✔ WBD: saved MA100 → ./5-100D_MA_adjusted_all_prices\WBD.parquet
#
# Processing WCG...
# ✔ WCG: saved MA100 → ./5-100D_MA_adjusted_all_prices\WCG.parquet
#
# Processing WCOEQ...
# ✔ WCOEQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\WCOEQ.parquet
#
# Processing WDAY...
# ✔ WDAY: saved MA100 → ./5-100D_MA_adjusted_all_prices\WDAY.parquet
#
# Processing WDC...
# ✔ WDC: saved MA100 → ./5-100D_MA_adjusted_all_prices\WDC.parquet
#
# Processing WEC...
# ✔ WEC: saved MA100 → ./5-100D_MA_adjusted_all_prices\WEC.parquet
#
# Processing WELL...
# ✔ WELL: saved MA100 → ./5-100D_MA_adjusted_all_prices\WELL.parquet
#
# Processing WEN...
# ✔ WEN: saved MA100 → ./5-100D_MA_adjusted_all_prices\WEN.parquet
#
# Processing WFC...
# ✔ WFC: saved MA100 → ./5-100D_MA_adjusted_all_prices\WFC.parquet
#
# Processing WFC1...
# ✔ WFC1: saved MA100 → ./5-100D_MA_adjusted_all_prices\WFC1.parquet
#
# Processing WFM...
# ✔ WFM: saved MA100 → ./5-100D_MA_adjusted_all_prices\WFM.parquet
#
# Processing WFTIQ...
# ✔ WFTIQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\WFTIQ.parquet
#
# Processing WGL...
# ✔ WGL: saved MA100 → ./5-100D_MA_adjusted_all_prices\WGL.parquet
#
# Processing WHR...
# ✔ WHR: saved MA100 → ./5-100D_MA_adjusted_all_prices\WHR.parquet
#
# Processing WINMQ...
# ✔ WINMQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\WINMQ.parquet
#
# Processing WLA...
# ✔ WLA: saved MA100 → ./5-100D_MA_adjusted_all_prices\WLA.parquet
#
# Processing WLL1...
# ✔ WLL1: saved MA100 → ./5-100D_MA_adjusted_all_prices\WLL1.parquet
#
# Processing WLP1...
# ✔ WLP1: saved MA100 → ./5-100D_MA_adjusted_all_prices\WLP1.parquet
#
# Processing WM...
# ✔ WM: saved MA100 → ./5-100D_MA_adjusted_all_prices\WM.parquet
#
# Processing WMB...
# ✔ WMB: saved MA100 → ./5-100D_MA_adjusted_all_prices\WMB.parquet
#
# Processing WMT...
# ✔ WMT: saved MA100 → ./5-100D_MA_adjusted_all_prices\WMT.parquet
#
# Processing WNDXQ...
# ✔ WNDXQ: saved MA100 → ./5-100D_MA_adjusted_all_prices\WNDXQ.parquet
#
# Processing WOR...
# ✔ WOR: saved MA100 → ./5-100D_MA_adjusted_all_prices\WOR.parquet
#
# Processing WPX...
# ✔ WPX: saved MA100 → ./5-100D_MA_adjusted_all_prices\WPX.parquet
#
# Processing WRB...
# ✔ WRB: saved MA100 → ./5-100D_MA_adjusted_all_prices\WRB.parquet
#
# Processing WRK...
# ✔ WRK: saved MA100 → ./5-100D_MA_adjusted_all_prices\WRK.parquet
#
# Processing WSM...
# ✔ WSM: saved MA100 → ./5-100D_MA_adjusted_all_prices\WSM.parquet
#
# Processing WST...
# ⚠ VALIDATION: WST | price_spike_detected | max close 466.47 on 2021-12-30, median 21.25
# ✔ WST: saved MA100 → ./5-100D_MA_adjusted_all_prices\WST.parquet
#
# Processing WTW...
# ✔ WTW: saved MA100 → ./5-100D_MA_adjusted_all_prices\WTW.parquet
#
# Processing WU...
# ✔ WU: saved MA100 → ./5-100D_MA_adjusted_all_prices\WU.parquet
#
# Processing WWY...
# ✔ WWY: saved MA100 → ./5-100D_MA_adjusted_all_prices\WWY.parquet
#
# Processing WY...
# ✔ WY: saved MA100 → ./5-100D_MA_adjusted_all_prices\WY.parquet
#
# Processing WYE...
# ✔ WYE: saved MA100 → ./5-100D_MA_adjusted_all_prices\WYE.parquet
#
# Processing WYNN...
# ✔ WYNN: saved MA100 → ./5-100D_MA_adjusted_all_prices\WYNN.parquet
#
# Processing X...
# ✔ X: saved MA100 → ./5-100D_MA_adjusted_all_prices\X.parquet
#
# Processing XEC...
# ✔ XEC: saved MA100 → ./5-100D_MA_adjusted_all_prices\XEC.parquet
#
# Processing XEL...
# ✔ XEL: saved MA100 → ./5-100D_MA_adjusted_all_prices\XEL.parquet
#
# Processing XL1...
# ✔ XL1: saved MA100 → ./5-100D_MA_adjusted_all_prices\XL1.parquet
#
# Processing XLNX...
# ✔ XLNX: saved MA100 → ./5-100D_MA_adjusted_all_prices\XLNX.parquet
#
# Processing XOM...
# ✔ XOM: saved MA100 → ./5-100D_MA_adjusted_all_prices\XOM.parquet
#
# Processing XRAY...
# ✔ XRAY: saved MA100 → ./5-100D_MA_adjusted_all_prices\XRAY.parquet
#
# Processing XRX...
# ✔ XRX: saved MA100 → ./5-100D_MA_adjusted_all_prices\XRX.parquet
#
# Processing XTO...
# ✔ XTO: saved MA100 → ./5-100D_MA_adjusted_all_prices\XTO.parquet
#
# Processing XYL...
# ✔ XYL: saved MA100 → ./5-100D_MA_adjusted_all_prices\XYL.parquet
#
# Processing XYZ...
# ✔ XYZ: saved MA100 → ./5-100D_MA_adjusted_all_prices\XYZ.parquet
#
# Processing YHOO...
# ✔ YHOO: saved MA100 → ./5-100D_MA_adjusted_all_prices\YHOO.parquet
#
# Processing YNR...
# ✔ YNR: saved MA100 → ./5-100D_MA_adjusted_all_prices\YNR.parquet
#
# Processing YUM...
# ✔ YUM: saved MA100 → ./5-100D_MA_adjusted_all_prices\YUM.parquet
#
# Processing ZBH...
# ✔ ZBH: saved MA100 → ./5-100D_MA_adjusted_all_prices\ZBH.parquet
#
# Processing ZBRA...
# ✔ ZBRA: saved MA100 → ./5-100D_MA_adjusted_all_prices\ZBRA.parquet
#
# Processing ZION...
# ✔ ZION: saved MA100 → ./5-100D_MA_adjusted_all_prices\ZION.parquet
#
# Processing ZTS...
# ✔ ZTS: saved MA100 → ./5-100D_MA_adjusted_all_prices\ZTS.parquet
#
#
# ====================================================
#  MA100 VALIDATION SUMMARY
# ====================================================
#    ticker                           issue  \
# 0    AAPL            price_spike_detected
# 1    ABMD            price_spike_detected
# 2   ACKHQ            price_spike_detected
# 3     AIG            price_spike_detected
# 4    AMCC            price_spike_detected
# 5    AMZN            price_spike_detected
# 6     APH            price_spike_detected
# 7    AVGO            price_spike_detected
# 8    AXON            price_spike_detected
# 9    BBI1  insufficient_history_for_ma100
# 10   BVSN            price_spike_detected
# 11   CFL1  insufficient_history_for_ma100
# 12   CIEN            price_spike_detected
# 13  CNXT1            price_spike_detected
# 14   CPRT            price_spike_detected
# 15   CTAS            price_spike_detected
# 16    DDS            price_spike_detected
# 17   DECK            price_spike_detected
# 18    EME            price_spike_detected
# 19   ENPH            price_spike_detected
# 20    FG1  insufficient_history_for_ma100
# 21   FICO            price_spike_detected
# 22    FIX            price_spike_detected
# 23   FMCC            price_spike_detected
# 24   FNMA            price_spike_detected
# 25   GMCR            price_spike_detected
# 26   ITT1  insufficient_history_for_ma100
# 27   KLAC            price_spike_detected
# 28    LLY            price_spike_detected
# 29   LRCX            price_spike_detected
# 30   LVLT            price_spike_detected
# 31   MPWR            price_spike_detected
# 32   MSFT            price_spike_detected
# 33   NFLX            price_spike_detected
# 34  NRTLQ            price_spike_detected
# 35   NVDA            price_spike_detected
# 36   ODFL            price_spike_detected
# 37   ORLY            price_spike_detected
# 38  OWENQ            price_spike_detected
# 39   PALM            price_spike_detected
# 40   PMCS            price_spike_detected
# 41      Q  insufficient_history_for_ma100
# 42    SK1  insufficient_history_for_ma100
# 43   SMCI            price_spike_detected
# 44   SNPS            price_spike_detected
# 45   SOLS  insufficient_history_for_ma100
# 46    TPL            price_spike_detected
# 47   TSLA            price_spike_detected
# 48     TT            price_spike_detected
# 49    TYL            price_spike_detected
# 50    UIS            price_spike_detected
# 51    URI            price_spike_detected
# 52   VIAV            price_spike_detected
# 53   VTSS            price_spike_detected
# 54    WST            price_spike_detected
#
#                                             detail
# 0     max close 286.19 on 2025-12-02, median 12.19
# 1     max close 449.75 on 2018-09-28, median 18.06
# 2       max close 90.00 on 1998-04-20, median 2.40
# 3    max close 1238.60 on 2000-12-08, median 53.62
# 4     max close 428.00 on 2000-09-28, median 10.96
# 5     max close 254.00 on 2025-11-03, median 10.23
# 6      max close 143.85 on 2025-11-10, median 6.03
# 7     max close 412.97 on 2025-12-10, median 18.96
# 8     max close 870.97 on 2025-08-07, median 16.17
# 9                only 7 rows, last date 1998-01-09
# 10  max close 20394.75 on 2000-03-06, median 13.70
# 11              only 80 rows, last date 1998-04-27
# 12   max close 1046.50 on 2000-10-20, median 31.06
# 13    max close 447.18 on 2000-02-22, median 18.50
# 14      max close 63.84 on 2025-05-16, median 2.93
# 15     max close 226.64 on 2025-06-06, median 9.05
# 16    max close 730.73 on 2025-12-10, median 32.72
# 17     max close 223.11 on 2025-01-30, median 8.77
# 18    max close 777.00 on 2025-10-29, median 28.45
# 19    max close 336.00 on 2022-12-02, median 13.84
# 20              only 79 rows, last date 1998-04-24
# 21   max close 2382.40 on 2024-11-26, median 41.47
# 22   max close 1024.92 on 2025-12-11, median 12.47
# 23      max close 66.96 on 2006-11-08, median 2.63
# 24      max close 73.24 on 2001-06-22, median 2.76
# 25     max close 154.44 on 2014-11-18, median 4.08
# 26              only 36 rows, last date 1998-02-23
# 27   max close 1279.60 on 2025-12-26, median 31.14
# 28   max close 1109.94 on 2025-11-25, median 40.38
# 29     max close 178.07 on 2025-12-26, median 4.06
# 30   max close 1952.85 on 2000-03-10, median 51.31
# 31   max close 1105.05 on 2025-10-27, median 47.16
# 32    max close 541.04 on 2025-10-28, median 24.77
# 33     max close 133.91 on 2025-06-30, median 5.02
# 34    max close 836.13 on 2000-07-26, median 26.90
# 35     max close 207.03 on 2025-10-29, median 0.45
# 36     max close 229.93 on 2024-11-11, median 8.54
# 37     max close 107.82 on 2025-09-11, median 5.36
# 38      max close 43.49 on 1998-07-17, median 2.14
# 39     max close 461.73 on 2000-03-02, median 7.52
# 40     max close 245.44 on 2000-03-10, median 8.43
# 41              only 40 rows, last date 2025-12-30
# 42              only 97 rows, last date 1998-05-20
# 43     max close 118.81 on 2024-03-13, median 2.21
# 44    max close 645.35 on 2025-07-30, median 31.25
# 45              only 42 rows, last date 2025-12-30
# 46   max close 1720.71 on 2024-11-22, median 14.55
# 47    max close 489.88 on 2025-12-16, median 19.92
# 48    max close 471.47 on 2025-07-28, median 22.70
# 49    max close 646.74 on 2025-02-13, median 32.00
# 50    max close 493.10 on 1999-09-20, median 24.32
# 51   max close 1017.88 on 2025-10-15, median 33.46
# 52    max close 669.24 on 2000-03-06, median 10.25
# 53   max close 2122.50 on 2000-03-01, median 23.60
# 54    max close 466.47 on 2021-12-30, median 21.25
#
# Validation log saved to:
# ./system_verification/5-100D_MA_adjusted_all_prices\ma100_validation-20251231-083849.csv
# ====================================================
