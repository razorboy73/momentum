# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime

# ============================================================
# CONFIG
# ============================================================

INPUT_DIR  = "./3-adjusted_All_Prices_OHLC"
OUTPUT_DIR = "./4-ATR20_adjusted_All_Prices"
VER_DIR    = "./system_verification/4-ATR20_adjusted_All_Prices"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(VER_DIR, exist_ok=True)

print(f"\nLoading adjusted price files from: {INPUT_DIR}")
files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".parquet")])
print(f"Found {len(files)} tickers.\n")

REQUIRED = {"open_adj", "high_adj", "low_adj", "close_adj"}


# ============================================================
# VALIDATION STORAGE
# ============================================================

validation_rows = []

def add_validation(ticker, issue, detail=""):
    row = {"ticker": ticker, "issue": issue, "detail": detail}
    validation_rows.append(row)
    print(f"⚠ VALIDATION: {ticker} | {issue} | {detail}")


# ============================================================
# ATR20 COMPUTATION — SIMPLE + CORRECT
# ============================================================

def compute_atr20(df, ticker):

    # --- Date validation ---
    if "date" not in df.columns:
        add_validation(ticker, "missing_date_column")
        return None

    df["date"] = pd.to_datetime(df["date"])
    if not df["date"].is_monotonic_increasing:
        add_validation(ticker, "non_monotonic_dates")
        df = df.sort_values("date")

    df = df.reset_index(drop=True)

    # --- Required columns ---
    if not REQUIRED.issubset(df.columns):
        missing = REQUIRED - set(df.columns)
        add_validation(ticker, "missing_adjusted_columns", str(missing))
        return None

    if len(df) < 20:
        add_validation(ticker, "insufficient_history", f"{len(df)} rows (<20)")
        return None

    # ============================================================
    # TRUE RANGE (using adjusted prices)
    # ============================================================

    df["prev_close"] = df["close_adj"].shift(1)

    tr1 = df["high_adj"] - df["low_adj"]
    tr2 = (df["high_adj"] - df["prev_close"]).abs()
    tr3 = (df["low_adj"]  - df["prev_close"]).abs()

    df["tr"] = np.maximum(tr1, np.maximum(tr2, tr3))

    # TR must be non-negative
    if (df["tr"] < 0).any():
        add_validation(ticker, "negative_TR_detected")

    # ============================================================
    # ATR20 = SIMPLE 20-DAY ROLLING MEAN
    # ============================================================

    df["atr20"] = df["tr"].rolling(window=20, min_periods=20).mean()

    # Optional: detect absurd ATR spikes
    if len(df) > 30:
        median_atr = df["atr20"].median()
        if median_atr > 0:
            max_atr = df["atr20"].max()
            if max_atr > median_atr * 20:
                add_validation(
                    ticker,
                    "ATR_spike_detected",
                    f"max ATR = {max_atr:.4f}, median = {median_atr:.4f}"
                )

    return df


# ============================================================
# MAIN LOOP
# ============================================================

for file in files:
    ticker = file.replace(".parquet", "")
    in_path = os.path.join(INPUT_DIR, file)
    out_path = os.path.join(OUTPUT_DIR, f"{ticker}.parquet")

    print(f"Processing {ticker}...")

    try:
        df = pd.read_parquet(in_path)
        df2 = compute_atr20(df, ticker)

        if df2 is not None:
            df2.to_parquet(out_path, index=False)
            print(f"✔ {ticker}: saved ATR20 → {out_path}\n")
        else:
            print(f"❌ {ticker}: ATR20 not computed.\n")

    except Exception as e:
        add_validation(ticker, "processing_error", str(e))
        print(f"❌ ERROR for {ticker}: {e}\n")


# ============================================================
# SAVE VALIDATION REPORT
# ============================================================

validation_df = pd.DataFrame(validation_rows)

val_file = os.path.join(
    VER_DIR,
    f"atr20_validation-{datetime.now().strftime('%Y%m%d-%H%M%S')}.csv"
)

validation_df.to_csv(val_file, index=False)

print("\n====================================================")
print(" ATR20 VALIDATION SUMMARY")
print("====================================================")

if validation_df.empty:
    print("No validation issues detected.")
else:
    print(validation_df)

print("\nValidation log saved to:")
print(val_file)
print("====================================================\n")
# Out:
# Loading adjusted price files from: ./3-adjusted_All_Prices_OHLC
# Found 1167 tickers.
#
# Processing A...
# ✔ A: saved ATR20 → ./4-ATR20_adjusted_All_Prices\A.parquet
#
# Processing AAL...
# ✔ AAL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AAL.parquet
#
# Processing AAMRQ...
# ✔ AAMRQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AAMRQ.parquet
#
# Processing AAP...
# ✔ AAP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AAP.parquet
#
# Processing AAPL...
# ⚠ VALIDATION: AAPL | ATR_spike_detected | max ATR = 11.3977, median = 0.2763
# ✔ AAPL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AAPL.parquet
#
# Processing ABBV...
# ✔ ABBV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ABBV.parquet
#
# Processing ABI1...
# ⚠ VALIDATION: ABI1 | ATR_spike_detected | max ATR = 15.1383, median = 0.7150
# ✔ ABI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ABI1.parquet
#
# Processing ABKFQ...
# ✔ ABKFQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ABKFQ.parquet
#
# Processing ABMD...
# ⚠ VALIDATION: ABMD | ATR_spike_detected | max ATR = 26.4475, median = 0.8270
# ✔ ABMD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ABMD.parquet
#
# Processing ABNB...
# ✔ ABNB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ABNB.parquet
#
# Processing ABS...
# ✔ ABS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ABS.parquet
#
# Processing ABT...
# ✔ ABT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ABT.parquet
#
# Processing ACAS...
# ✔ ACAS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ACAS.parquet
#
# Processing ACGL...
# ✔ ACGL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ACGL.parquet
#
# Processing ACKHQ...
# ✔ ACKHQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ACKHQ.parquet
#
# Processing ACN...
# ✔ ACN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ACN.parquet
#
# Processing ACS...
# ✔ ACS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ACS.parquet
#
# Processing ACV1...
# ✔ ACV1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ACV1.parquet
#
# Processing ADBE...
# ⚠ VALIDATION: ADBE | ATR_spike_detected | max ATR = 30.6894, median = 1.2203
# ✔ ADBE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ADBE.parquet
#
# Processing ADCT1...
# ⚠ VALIDATION: ADCT1 | ATR_spike_detected | max ATR = 28.7875, median = 0.8785
# ✔ ADCT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ADCT1.parquet
#
# Processing ADI...
# ✔ ADI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ADI.parquet
#
# Processing ADM...
# ✔ ADM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ADM.parquet
#
# Processing ADP...
# ✔ ADP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ADP.parquet
#
# Processing ADSK...
# ✔ ADSK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ADSK.parquet
#
# Processing ADT1...
# ✔ ADT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ADT1.parquet
#
# Processing AEE...
# ✔ AEE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AEE.parquet
#
# Processing AEP...
# ✔ AEP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AEP.parquet
#
# Processing AES...
# ✔ AES: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AES.parquet
#
# Processing AET...
# ✔ AET: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AET.parquet
#
# Processing AFL...
# ✔ AFL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AFL.parquet
#
# Processing AFS.A...
# ✔ AFS.A: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AFS.A.parquet
#
# Processing AGC1...
# ✔ AGC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AGC1.parquet
#
# Processing AGN...
# ✔ AGN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AGN.parquet
#
# Processing AGN1...
# ✔ AGN1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AGN1.parquet
#
# Processing AHM1...
# ✔ AHM1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AHM1.parquet
#
# Processing AIG...
# ⚠ VALIDATION: AIG | ATR_spike_detected | max ATR = 44.2242, median = 1.4329
# ✔ AIG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AIG.parquet
#
# Processing AIT...
# ✔ AIT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AIT.parquet
#
# Processing AIV...
# ✔ AIV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AIV.parquet
#
# Processing AIZ...
# ✔ AIZ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AIZ.parquet
#
# Processing AJG...
# ⚠ VALIDATION: AJG | ATR_spike_detected | max ATR = 12.4195, median = 0.4715
# ✔ AJG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AJG.parquet
#
# Processing AKAM...
# ⚠ VALIDATION: AKAM | ATR_spike_detected | max ATR = 30.7812, median = 1.4292
# ✔ AKAM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AKAM.parquet
#
# Processing AKS...
# ✔ AKS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AKS.parquet
#
# Processing AL1...
# ✔ AL1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AL1.parquet
#
# Processing ALB...
# ✔ ALB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ALB.parquet
#
# Processing ALGN...
# ⚠ VALIDATION: ALGN | ATR_spike_detected | max ATR = 28.4330, median = 1.1755
# ✔ ALGN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ALGN.parquet
#
# Processing ALK...
# ✔ ALK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ALK.parquet
#
# Processing ALL...
# ✔ ALL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ALL.parquet
#
# Processing ALLE...
# ✔ ALLE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ALLE.parquet
#
# Processing ALTR1...
# ✔ ALTR1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ALTR1.parquet
#
# Processing ALXN...
# ✔ ALXN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ALXN.parquet
#
# Processing AM1...
# ✔ AM1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AM1.parquet
#
# Processing AMAT...
# ⚠ VALIDATION: AMAT | ATR_spike_detected | max ATR = 11.6588, median = 0.5636
# ✔ AMAT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMAT.parquet
#
# Processing AMCC...
# ⚠ VALIDATION: AMCC | ATR_spike_detected | max ATR = 43.0093, median = 0.5040
# ✔ AMCC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMCC.parquet
#
# Processing AMCR...
# ✔ AMCR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMCR.parquet
#
# Processing AMD...
# ⚠ VALIDATION: AMD | ATR_spike_detected | max ATR = 15.2828, median = 0.5950
# ✔ AMD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMD.parquet
#
# Processing AME...
# ✔ AME: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AME.parquet
#
# Processing AMG...
# ✔ AMG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMG.parquet
#
# Processing AMGN...
# ✔ AMGN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMGN.parquet
#
# Processing AMP...
# ✔ AMP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMP.parquet
#
# Processing AMP1...
# ✔ AMP1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMP1.parquet
#
# Processing AMT...
# ✔ AMT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMT.parquet
#
# Processing AMTM...
# ✔ AMTM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMTM.parquet
#
# Processing AMZN...
# ⚠ VALIDATION: AMZN | ATR_spike_detected | max ATR = 10.9484, median = 0.2979
# ✔ AMZN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AMZN.parquet
#
# Processing AN...
# ✔ AN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AN.parquet
#
# Processing AN1...
# ✔ AN1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AN1.parquet
#
# Processing ANDV...
# ✔ ANDV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ANDV.parquet
#
# Processing ANDW...
# ✔ ANDW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ANDW.parquet
#
# Processing ANET...
# ✔ ANET: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ANET.parquet
#
# Processing ANF...
# ✔ ANF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ANF.parquet
#
# Processing ANRZQ...
# ✔ ANRZQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ANRZQ.parquet
#
# Processing ANSS...
# ✔ ANSS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ANSS.parquet
#
# Processing ANV1...
# ✔ ANV1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ANV1.parquet
#
# Processing AON...
# ✔ AON: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AON.parquet
#
# Processing AOS...
# ✔ AOS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AOS.parquet
#
# Processing APA...
# ✔ APA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APA.parquet
#
# Processing APC...
# ✔ APC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APC.parquet
#
# Processing APCC...
# ✔ APCC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APCC.parquet
#
# Processing APD...
# ✔ APD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APD.parquet
#
# Processing APH...
# ⚠ VALIDATION: APH | ATR_spike_detected | max ATR = 4.9005, median = 0.1397
# ✔ APH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APH.parquet
#
# Processing APO...
# ✔ APO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APO.parquet
#
# Processing APOL...
# ✔ APOL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APOL.parquet
#
# Processing APP...
# ✔ APP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APP.parquet
#
# Processing APTV...
# ✔ APTV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\APTV.parquet
#
# Processing AR1...
# ✔ AR1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AR1.parquet
#
# Processing ARC1...
# ✔ ARC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ARC1.parquet
#
# Processing ARE...
# ✔ ARE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ARE.parquet
#
# Processing ARES...
# ✔ ARES: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ARES.parquet
#
# Processing ARG...
# ✔ ARG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ARG.parquet
#
# Processing AS1...
# ✔ AS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AS1.parquet
#
# Processing ASC1...
# ✔ ASC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ASC1.parquet
#
# Processing ASH...
# ✔ ASH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ASH.parquet
#
# Processing ASN...
# ✔ ASN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ASN.parquet
#
# Processing ASND1...
# ✔ ASND1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ASND1.parquet
#
# Processing ASO1...
# ✔ ASO1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ASO1.parquet
#
# Processing AT1...
# ✔ AT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AT1.parquet
#
# Processing ATGE...
# ✔ ATGE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ATGE.parquet
#
# Processing ATI...
# ✔ ATI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ATI.parquet
#
# Processing ATI1...
# ✔ ATI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ATI1.parquet
#
# Processing ATO...
# ✔ ATO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ATO.parquet
#
# Processing ATVI...
# ✔ ATVI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ATVI.parquet
#
# Processing AV1...
# ✔ AV1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AV1.parquet
#
# Processing AVB...
# ✔ AVB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AVB.parquet
#
# Processing AVGO...
# ⚠ VALIDATION: AVGO | ATR_spike_detected | max ATR = 19.4468, median = 0.4284
# ✔ AVGO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AVGO.parquet
#
# Processing AVP...
# ✔ AVP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AVP.parquet
#
# Processing AVY...
# ✔ AVY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AVY.parquet
#
# Processing AW...
# ✔ AW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AW.parquet
#
# Processing AWE...
# ✔ AWE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AWE.parquet
#
# Processing AWK...
# ✔ AWK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AWK.parquet
#
# Processing AXON...
# ⚠ VALIDATION: AXON | ATR_spike_detected | max ATR = 41.4243, median = 0.7272
# ✔ AXON: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AXON.parquet
#
# Processing AXP...
# ✔ AXP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AXP.parquet
#
# Processing AYE...
# ✔ AYE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AYE.parquet
#
# Processing AYI...
# ✔ AYI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AYI.parquet
#
# Processing AZA.A...
# ✔ AZA.A: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AZA.A.parquet
#
# Processing AZO...
# ✔ AZO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\AZO.parquet
#
# Processing B...
# ✔ B: saved ATR20 → ./4-ATR20_adjusted_All_Prices\B.parquet
#
# Processing BA...
# ✔ BA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BA.parquet
#
# Processing BAC...
# ✔ BAC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BAC.parquet
#
# Processing BAC1...
# ✔ BAC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BAC1.parquet
#
# Processing BALL...
# ✔ BALL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BALL.parquet
#
# Processing BAX...
# ✔ BAX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BAX.parquet
#
# Processing BAY1...
# ✔ BAY1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BAY1.parquet
#
# Processing BBBYQ...
# ✔ BBBYQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BBBYQ.parquet
#
# Processing BBI1...
# ⚠ VALIDATION: BBI1 | insufficient_history | 7 rows (<20)
# ❌ BBI1: ATR20 not computed.
#
# Processing BBWI...
# ✔ BBWI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BBWI.parquet
#
# Processing BBY...
# ✔ BBY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BBY.parquet
#
# Processing BC...
# ✔ BC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BC.parquet
#
# Processing BCR...
# ✔ BCR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BCR.parquet
#
# Processing BDK...
# ✔ BDK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BDK.parquet
#
# Processing BDX...
# ✔ BDX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BDX.parquet
#
# Processing BEAM2...
# ✔ BEAM2: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BEAM2.parquet
#
# Processing BEN...
# ✔ BEN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BEN.parquet
#
# Processing BF.B...
# ✔ BF.B: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BF.B.parquet
#
# Processing BFH...
# ✔ BFH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BFH.parquet
#
# Processing BFI1...
# ✔ BFI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BFI1.parquet
#
# Processing BFO1...
# ✔ BFO1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BFO1.parquet
#
# Processing BG...
# ✔ BG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BG.parquet
#
# Processing BGEN...
# ✔ BGEN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BGEN.parquet
#
# Processing BGGSQ...
# ✔ BGGSQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BGGSQ.parquet
#
# Processing BHF...
# ✔ BHF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BHF.parquet
#
# Processing BHI...
# ✔ BHI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BHI.parquet
#
# Processing BHMSQ...
# ✔ BHMSQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BHMSQ.parquet
#
# Processing BIGGQ...
# ✔ BIGGQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BIGGQ.parquet
#
# Processing BIIB...
# ✔ BIIB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BIIB.parquet
#
# Processing BIO...
# ✔ BIO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BIO.parquet
#
# Processing BJS...
# ✔ BJS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BJS.parquet
#
# Processing BK...
# ✔ BK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BK.parquet
#
# Processing BKB...
# ✔ BKB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BKB.parquet
#
# Processing BKNG...
# ✔ BKNG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BKNG.parquet
#
# Processing BKR...
# ✔ BKR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BKR.parquet
#
# Processing BLDR...
# ✔ BLDR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BLDR.parquet
#
# Processing BLK...
# ✔ BLK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BLK.parquet
#
# Processing BLS...
# ✔ BLS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BLS.parquet
#
# Processing BMC...
# ✔ BMC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BMC.parquet
#
# Processing BMET...
# ✔ BMET: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BMET.parquet
#
# Processing BMGCA...
# ✔ BMGCA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BMGCA.parquet
#
# Processing BMS...
# ✔ BMS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BMS.parquet
#
# Processing BMY...
# ✔ BMY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BMY.parquet
#
# Processing BNI...
# ✔ BNI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BNI.parquet
#
# Processing BNL1...
# ✔ BNL1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BNL1.parquet
#
# Processing BOL...
# ✔ BOL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BOL.parquet
#
# Processing BR...
# ✔ BR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BR.parquet
#
# Processing BR1...
# ✔ BR1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BR1.parquet
#
# Processing BRCM...
# ✔ BRCM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BRCM.parquet
#
# Processing BRK.B...
# ✔ BRK.B: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BRK.B.parquet
#
# Processing BRL...
# ✔ BRL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BRL.parquet
#
# Processing BRO...
# ✔ BRO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BRO.parquet
#
# Processing BSC1...
# ✔ BSC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BSC1.parquet
#
# Processing BSX...
# ✔ BSX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BSX.parquet
#
# Processing BT1...
# ✔ BT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BT1.parquet
#
# Processing BTUUQ...
# ✔ BTUUQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BTUUQ.parquet
#
# Processing BUD1...
# ✔ BUD1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BUD1.parquet
#
# Processing BVSN...
# ⚠ VALIDATION: BVSN | ATR_spike_detected | max ATR = 1902.8250, median = 0.7922
# ✔ BVSN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BVSN.parquet
#
# Processing BWA...
# ✔ BWA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BWA.parquet
#
# Processing BX...
# ✔ BX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BX.parquet
#
# Processing BXLT...
# ✔ BXLT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BXLT.parquet
#
# Processing BXP...
# ✔ BXP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\BXP.parquet
#
# Processing C...
# ✔ C: saved ATR20 → ./4-ATR20_adjusted_All_Prices\C.parquet
#
# Processing C1...
# ✔ C1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\C1.parquet
#
# Processing CA1...
# ✔ CA1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CA1.parquet
#
# Processing CAG...
# ✔ CAG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CAG.parquet
#
# Processing CAH...
# ✔ CAH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CAH.parquet
#
# Processing CAL...
# ✔ CAL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CAL.parquet
#
# Processing CAM2...
# ✔ CAM2: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CAM2.parquet
#
# Processing CAR...
# ⚠ VALIDATION: CAR | ATR_spike_detected | max ATR = 42.4667, median = 1.0444
# ✔ CAR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CAR.parquet
#
# Processing CARR...
# ✔ CARR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CARR.parquet
#
# Processing CAT...
# ✔ CAT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CAT.parquet
#
# Processing CB...
# ✔ CB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CB.parquet
#
# Processing CB1...
# ✔ CB1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CB1.parquet
#
# Processing CBE...
# ✔ CBE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CBE.parquet
#
# Processing CBH1...
# ✔ CBH1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CBH1.parquet
#
# Processing CBOE...
# ✔ CBOE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CBOE.parquet
#
# Processing CBRE...
# ✔ CBRE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CBRE.parquet
#
# Processing CBS1...
# ✔ CBS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CBS1.parquet
#
# Processing CBSS...
# ✔ CBSS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CBSS.parquet
#
# Processing CCE1...
# ✔ CCE1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CCE1.parquet
#
# Processing CCI...
# ✔ CCI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CCI.parquet
#
# Processing CCI1...
# ✔ CCI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CCI1.parquet
#
# Processing CCK...
# ✔ CCK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CCK.parquet
#
# Processing CCL...
# ✔ CCL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CCL.parquet
#
# Processing CCTYQ...
# ✔ CCTYQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CCTYQ.parquet
#
# Processing CCU1...
# ✔ CCU1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CCU1.parquet
#
# Processing CDNS...
# ⚠ VALIDATION: CDNS | ATR_spike_detected | max ATR = 14.2393, median = 0.5995
# ✔ CDNS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CDNS.parquet
#
# Processing CDW...
# ✔ CDW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CDW.parquet
#
# Processing CE...
# ✔ CE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CE.parquet
#
# Processing CE1...
# ✔ CE1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CE1.parquet
#
# Processing CEG...
# ✔ CEG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CEG.parquet
#
# Processing CEG1...
# ✔ CEG1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CEG1.parquet
#
# Processing CELG...
# ✔ CELG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CELG.parquet
#
# Processing CEM1...
# ✔ CEM1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CEM1.parquet
#
# Processing CEN1...
# ✔ CEN1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CEN1.parquet
#
# Processing CEPH...
# ✔ CEPH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CEPH.parquet
#
# Processing CERN...
# ✔ CERN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CERN.parquet
#
# Processing CF...
# ✔ CF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CF.parquet
#
# Processing CF1...
# ✔ CF1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CF1.parquet
#
# Processing CFC...
# ✔ CFC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CFC.parquet
#
# Processing CFG...
# ✔ CFG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CFG.parquet
#
# Processing CFL1...
# ✔ CFL1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CFL1.parquet
#
# Processing CFN...
# ✔ CFN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CFN.parquet
#
# Processing CG1...
# ✔ CG1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CG1.parquet
#
# Processing CGP...
# ✔ CGP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CGP.parquet
#
# Processing CHA1...
# ✔ CHA1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CHA1.parquet
#
# Processing CHD...
# ✔ CHD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CHD.parquet
#
# Processing CHIR1...
# ✔ CHIR1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CHIR1.parquet
#
# Processing CHKAQ...
# ✔ CHKAQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CHKAQ.parquet
#
# Processing CHRS1...
# ✔ CHRS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CHRS1.parquet
#
# Processing CHRW...
# ✔ CHRW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CHRW.parquet
#
# Processing CHTR...
# ✔ CHTR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CHTR.parquet
#
# Processing CI...
# ✔ CI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CI.parquet
#
# Processing CIEN...
# ⚠ VALIDATION: CIEN | ATR_spike_detected | max ATR = 106.5855, median = 1.1792
# ✔ CIEN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CIEN.parquet
#
# Processing CIN...
# ✔ CIN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CIN.parquet
#
# Processing CINF...
# ✔ CINF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CINF.parquet
#
# Processing CIT.A...
# ✔ CIT.A: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CIT.A.parquet
#
# Processing CITGQ...
# ✔ CITGQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CITGQ.parquet
#
# Processing CL...
# ✔ CL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CL.parquet
#
# Processing CLF...
# ✔ CLF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CLF.parquet
#
# Processing CLX...
# ✔ CLX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CLX.parquet
#
# Processing CMA...
# ✔ CMA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMA.parquet
#
# Processing CMCSA...
# ✔ CMCSA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMCSA.parquet
#
# Processing CMCSK...
# ✔ CMCSK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMCSK.parquet
#
# Processing CME...
# ✔ CME: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CME.parquet
#
# Processing CMG...
# ✔ CMG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMG.parquet
#
# Processing CMI...
# ✔ CMI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMI.parquet
#
# Processing CMS...
# ✔ CMS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMS.parquet
#
# Processing CMVT...
# ✔ CMVT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMVT.parquet
#
# Processing CMX...
# ✔ CMX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CMX.parquet
#
# Processing CNC...
# ✔ CNC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CNC.parquet
#
# Processing CNCEQ...
# ✔ CNCEQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CNCEQ.parquet
#
# Processing CNG...
# ✔ CNG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CNG.parquet
#
# Processing CNP...
# ✔ CNP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CNP.parquet
#
# Processing CNW...
# ✔ CNW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CNW.parquet
#
# Processing CNX...
# ✔ CNX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CNX.parquet
#
# Processing CNXT1...
# ⚠ VALIDATION: CNXT1 | ATR_spike_detected | max ATR = 42.5954, median = 1.1800
# ✔ CNXT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CNXT1.parquet
#
# Processing COC...
# ✔ COC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COC.parquet
#
# Processing COF...
# ✔ COF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COF.parquet
#
# Processing COIN...
# ✔ COIN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COIN.parquet
#
# Processing COL...
# ✔ COL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COL.parquet
#
# Processing COMS1...
# ✔ COMS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COMS1.parquet
#
# Processing COO...
# ✔ COO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COO.parquet
#
# Processing COP...
# ✔ COP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COP.parquet
#
# Processing COR...
# ✔ COR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COR.parquet
#
# Processing COST...
# ⚠ VALIDATION: COST | ATR_spike_detected | max ATR = 36.3887, median = 1.2439
# ✔ COST: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COST.parquet
#
# Processing COT1...
# ✔ COT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COT1.parquet
#
# Processing COTY...
# ✔ COTY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COTY.parquet
#
# Processing COV...
# ✔ COV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\COV.parquet
#
# Processing CPAY...
# ✔ CPAY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPAY.parquet
#
# Processing CPB...
# ✔ CPB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPB.parquet
#
# Processing CPGX...
# ✔ CPGX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPGX.parquet
#
# Processing CPNLQ...
# ✔ CPNLQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPNLQ.parquet
#
# Processing CPPRQ...
# ✔ CPPRQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPPRQ.parquet
#
# Processing CPQ...
# ✔ CPQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPQ.parquet
#
# Processing CPRI...
# ✔ CPRI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPRI.parquet
#
# Processing CPRT...
# ⚠ VALIDATION: CPRT | ATR_spike_detected | max ATR = 2.0343, median = 0.0704
# ✔ CPRT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPRT.parquet
#
# Processing CPT...
# ✔ CPT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPT.parquet
#
# Processing CPWR...
# ✔ CPWR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CPWR.parquet
#
# Processing CRH...
# ✔ CRH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CRH.parquet
#
# Processing CRL...
# ✔ CRL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CRL.parquet
#
# Processing CRM...
# ✔ CRM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CRM.parquet
#
# Processing CRWD...
# ✔ CRWD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CRWD.parquet
#
# Processing CSC...
# ✔ CSC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CSC.parquet
#
# Processing CSCO...
# ✔ CSCO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CSCO.parquet
#
# Processing CSE1...
# ✔ CSE1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CSE1.parquet
#
# Processing CSGP...
# ⚠ VALIDATION: CSGP | ATR_spike_detected | max ATR = 4.8813, median = 0.2247
# ✔ CSGP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CSGP.parquet
#
# Processing CSR1...
# ✔ CSR1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CSR1.parquet
#
# Processing CSRA...
# ✔ CSRA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CSRA.parquet
#
# Processing CSX...
# ✔ CSX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CSX.parquet
#
# Processing CTAS...
# ⚠ VALIDATION: CTAS | ATR_spike_detected | max ATR = 7.4886, median = 0.2931
# ✔ CTAS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTAS.parquet
#
# Processing CTB...
# ✔ CTB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTB.parquet
#
# Processing CTLT...
# ✔ CTLT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTLT.parquet
#
# Processing CTRA...
# ✔ CTRA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTRA.parquet
#
# Processing CTSH...
# ✔ CTSH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTSH.parquet
#
# Processing CTVA...
# ✔ CTVA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTVA.parquet
#
# Processing CTX1...
# ✔ CTX1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTX1.parquet
#
# Processing CTXS...
# ✔ CTXS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CTXS.parquet
#
# Processing CVC...
# ✔ CVC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CVC.parquet
#
# Processing CVG...
# ✔ CVG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CVG.parquet
#
# Processing CVGYQ...
# ✔ CVGYQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CVGYQ.parquet
#
# Processing CVH...
# ✔ CVH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CVH.parquet
#
# Processing CVNA...
# ✔ CVNA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CVNA.parquet
#
# Processing CVS...
# ✔ CVS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CVS.parquet
#
# Processing CVX...
# ✔ CVX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CVX.parquet
#
# Processing CXO...
# ✔ CXO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CXO.parquet
#
# Processing CXT...
# ✔ CXT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CXT.parquet
#
# Processing CYM...
# ✔ CYM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CYM.parquet
#
# Processing CZR...
# ✔ CZR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\CZR.parquet
#
# Processing D...
# ✔ D: saved ATR20 → ./4-ATR20_adjusted_All_Prices\D.parquet
#
# Processing DAL...
# ✔ DAL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DAL.parquet
#
# Processing DALRQ...
# ✔ DALRQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DALRQ.parquet
#
# Processing DASH...
# ✔ DASH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DASH.parquet
#
# Processing DAY...
# ✔ DAY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DAY.parquet
#
# Processing DCNAQ...
# ✔ DCNAQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DCNAQ.parquet
#
# Processing DD...
# ✔ DD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DD.parquet
#
# Processing DD1...
# ✔ DD1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DD1.parquet
#
# Processing DDOG...
# ✔ DDOG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DDOG.parquet
#
# Processing DDS...
# ⚠ VALIDATION: DDS | ATR_spike_detected | max ATR = 33.1412, median = 1.1574
# ✔ DDS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DDS.parquet
#
# Processing DE...
# ✔ DE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DE.parquet
#
# Processing DEC1...
# ✔ DEC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DEC1.parquet
#
# Processing DECK...
# ⚠ VALIDATION: DECK | ATR_spike_detected | max ATR = 8.4683, median = 0.3176
# ✔ DECK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DECK.parquet
#
# Processing DELL...
# ✔ DELL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DELL.parquet
#
# Processing DELL1...
# ✔ DELL1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DELL1.parquet
#
# Processing DFODQ...
# ✔ DFODQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DFODQ.parquet
#
# Processing DFS...
# ✔ DFS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DFS.parquet
#
# Processing DG...
# ✔ DG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DG.parquet
#
# Processing DG1...
# ✔ DG1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DG1.parquet
#
# Processing DGN...
# ✔ DGN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DGN.parquet
#
# Processing DGX...
# ✔ DGX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DGX.parquet
#
# Processing DHI...
# ✔ DHI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DHI.parquet
#
# Processing DHR...
# ✔ DHR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DHR.parquet
#
# Processing DI1...
# ✔ DI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DI1.parquet
#
# Processing DIGI2...
# ✔ DIGI2: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DIGI2.parquet
#
# Processing DINO...
# ✔ DINO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DINO.parquet
#
# Processing DIS...
# ✔ DIS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DIS.parquet
#
# Processing DISCK...
# ✔ DISCK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DISCK.parquet
#
# Processing DISH...
# ✔ DISH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DISH.parquet
#
# Processing DJ...
# ✔ DJ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DJ.parquet
#
# Processing DLR...
# ✔ DLR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DLR.parquet
#
# Processing DLTR...
# ✔ DLTR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DLTR.parquet
#
# Processing DLX...
# ✔ DLX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DLX.parquet
#
# Processing DNB1...
# ✔ DNB1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DNB1.parquet
#
# Processing DNB2...
# ✔ DNB2: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DNB2.parquet
#
# Processing DNB3...
# ✔ DNB3: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DNB3.parquet
#
# Processing DNRCQ...
# ✔ DNRCQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DNRCQ.parquet
#
# Processing DOC...
# ✔ DOC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DOC.parquet
#
# Processing DOFSQ...
# ✔ DOFSQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DOFSQ.parquet
#
# Processing DOV...
# ✔ DOV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DOV.parquet
#
# Processing DOW...
# ✔ DOW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DOW.parquet
#
# Processing DPHIQ...
# ✔ DPHIQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DPHIQ.parquet
#
# Processing DPZ...
# ✔ DPZ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DPZ.parquet
#
# Processing DRE...
# ✔ DRE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DRE.parquet
#
# Processing DRI...
# ✔ DRI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DRI.parquet
#
# Processing DTE...
# ✔ DTE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DTE.parquet
#
# Processing DTV1...
# ✔ DTV1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DTV1.parquet
#
# Processing DUK...
# ✔ DUK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DUK.parquet
#
# Processing DVA...
# ✔ DVA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DVA.parquet
#
# Processing DVN...
# ✔ DVN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DVN.parquet
#
# Processing DXC...
# ✔ DXC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DXC.parquet
#
# Processing DXCM...
# ✔ DXCM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DXCM.parquet
#
# Processing DYNIQ...
# ✔ DYNIQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\DYNIQ.parquet
#
# Processing EA...
# ✔ EA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EA.parquet
#
# Processing EBAY...
# ✔ EBAY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EBAY.parquet
#
# Processing EC1...
# ✔ EC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EC1.parquet
#
# Processing ECH1...
# ✔ ECH1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ECH1.parquet
#
# Processing ECL...
# ✔ ECL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ECL.parquet
#
# Processing ECO1...
# ✔ ECO1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ECO1.parquet
#
# Processing ED...
# ✔ ED: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ED.parquet
#
# Processing EDS...
# ✔ EDS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EDS.parquet
#
# Processing EFU1...
# ✔ EFU1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EFU1.parquet
#
# Processing EFX...
# ✔ EFX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EFX.parquet
#
# Processing EG...
# ✔ EG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EG.parquet
#
# Processing EHC...
# ✔ EHC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EHC.parquet
#
# Processing EIX...
# ✔ EIX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EIX.parquet
#
# Processing EKDKQ...
# ✔ EKDKQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EKDKQ.parquet
#
# Processing EL...
# ✔ EL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EL.parquet
#
# Processing ELV...
# ✔ ELV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ELV.parquet
#
# Processing EMC1...
# ✔ EMC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EMC1.parquet
#
# Processing EME...
# ⚠ VALIDATION: EME | ATR_spike_detected | max ATR = 31.7055, median = 0.8376
# ✔ EME: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EME.parquet
#
# Processing EMN...
# ✔ EMN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EMN.parquet
#
# Processing EMR...
# ✔ EMR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EMR.parquet
#
# Processing ENDPQ...
# ✔ ENDPQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ENDPQ.parquet
#
# Processing ENPH...
# ⚠ VALIDATION: ENPH | ATR_spike_detected | max ATR = 19.8885, median = 0.8397
# ✔ ENPH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ENPH.parquet
#
# Processing ENRNQ...
# ✔ ENRNQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ENRNQ.parquet
#
# Processing EOG...
# ✔ EOG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EOG.parquet
#
# Processing EOP...
# ✔ EOP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EOP.parquet
#
# Processing EP1...
# ✔ EP1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EP1.parquet
#
# Processing EPAM...
# ✔ EPAM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EPAM.parquet
#
# Processing EQ1...
# ✔ EQ1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EQ1.parquet
#
# Processing EQIX...
# ✔ EQIX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EQIX.parquet
#
# Processing EQR...
# ✔ EQR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EQR.parquet
#
# Processing EQT...
# ✔ EQT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EQT.parquet
#
# Processing ERIE...
# ⚠ VALIDATION: ERIE | ATR_spike_detected | max ATR = 18.2917, median = 0.8880
# ✔ ERIE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ERIE.parquet
#
# Processing ES...
# ✔ ES: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ES.parquet
#
# Processing ESRX...
# ✔ ESRX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ESRX.parquet
#
# Processing ESS...
# ✔ ESS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ESS.parquet
#
# Processing ETFC...
# ⚠ VALIDATION: ETFC | ATR_spike_detected | max ATR = 82.2666, median = 1.7215
# ✔ ETFC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ETFC.parquet
#
# Processing ETN...
# ✔ ETN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ETN.parquet
#
# Processing ETR...
# ✔ ETR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ETR.parquet
#
# Processing ETS1...
# ✔ ETS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ETS1.parquet
#
# Processing ETSY...
# ✔ ETSY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ETSY.parquet
#
# Processing EVHC...
# ✔ EVHC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EVHC.parquet
#
# Processing EVRG...
# ✔ EVRG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EVRG.parquet
#
# Processing EW...
# ✔ EW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EW.parquet
#
# Processing EXC...
# ✔ EXC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EXC.parquet
#
# Processing EXE...
# ✔ EXE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EXE.parquet
#
# Processing EXPD...
# ✔ EXPD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EXPD.parquet
#
# Processing EXPE...
# ✔ EXPE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EXPE.parquet
#
# Processing EXR...
# ✔ EXR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\EXR.parquet
#
# Processing F...
# ✔ F: saved ATR20 → ./4-ATR20_adjusted_All_Prices\F.parquet
#
# Processing FANG...
# ✔ FANG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FANG.parquet
#
# Processing FAST...
# ✔ FAST: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FAST.parquet
#
# Processing FBF...
# ✔ FBF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FBF.parquet
#
# Processing FBIN...
# ✔ FBIN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FBIN.parquet
#
# Processing FCN1...
# ✔ FCN1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FCN1.parquet
#
# Processing FCX...
# ✔ FCX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FCX.parquet
#
# Processing FDC1...
# ✔ FDC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FDC1.parquet
#
# Processing FDO...
# ✔ FDO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FDO.parquet
#
# Processing FDS...
# ✔ FDS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FDS.parquet
#
# Processing FDX...
# ✔ FDX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FDX.parquet
#
# Processing FE...
# ✔ FE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FE.parquet
#
# Processing FFIV...
# ✔ FFIV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FFIV.parquet
#
# Processing FG1...
# ✔ FG1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FG1.parquet
#
# Processing FHI...
# ✔ FHI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FHI.parquet
#
# Processing FHN...
# ✔ FHN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FHN.parquet
#
# Processing FICO...
# ⚠ VALIDATION: FICO | ATR_spike_detected | max ATR = 103.1373, median = 1.0496
# ✔ FICO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FICO.parquet
#
# Processing FIS...
# ✔ FIS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FIS.parquet
#
# Processing FISV...
# ⚠ VALIDATION: FISV | ATR_spike_detected | max ATR = 10.8578, median = 0.3876
# ✔ FISV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FISV.parquet
#
# Processing FITB...
# ✔ FITB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FITB.parquet
#
# Processing FIX...
# ⚠ VALIDATION: FIX | ATR_spike_detected | max ATR = 53.8013, median = 0.4537
# ✔ FIX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FIX.parquet
#
# Processing FJ...
# ✔ FJ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FJ.parquet
#
# Processing FL...
# ✔ FL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FL.parquet
#
# Processing FLIR...
# ✔ FLIR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FLIR.parquet
#
# Processing FLMIQ...
# ✔ FLMIQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FLMIQ.parquet
#
# Processing FLR...
# ✔ FLR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FLR.parquet
#
# Processing FLS...
# ✔ FLS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FLS.parquet
#
# Processing FLTWQ...
# ✔ FLTWQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FLTWQ.parquet
#
# Processing FMC...
# ✔ FMC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FMC.parquet
#
# Processing FMCC...
# ⚠ VALIDATION: FMCC | ATR_spike_detected | max ATR = 3.7687, median = 0.1560
# ✔ FMCC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FMCC.parquet
#
# Processing FMY1...
# ✔ FMY1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FMY1.parquet
#
# Processing FNMA...
# ⚠ VALIDATION: FNMA | ATR_spike_detected | max ATR = 4.2678, median = 0.1675
# ✔ FNMA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FNMA.parquet
#
# Processing FOSL...
# ✔ FOSL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FOSL.parquet
#
# Processing FOX...
# ✔ FOX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FOX.parquet
#
# Processing FOXA...
# ✔ FOXA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FOXA.parquet
#
# Processing FPC...
# ✔ FPC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FPC.parquet
#
# Processing FRCB...
# ✔ FRCB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FRCB.parquet
#
# Processing FRO1...
# ✔ FRO1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FRO1.parquet
#
# Processing FRT...
# ✔ FRT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FRT.parquet
#
# Processing FRX1...
# ✔ FRX1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FRX1.parquet
#
# Processing FSH...
# ✔ FSH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FSH.parquet
#
# Processing FSL.B...
# ✔ FSL.B: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FSL.B.parquet
#
# Processing FSLR...
# ✔ FSLR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FSLR.parquet
#
# Processing FTI...
# ✔ FTI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FTI.parquet
#
# Processing FTI1...
# ✔ FTI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FTI1.parquet
#
# Processing FTL.A...
# ✔ FTL.A: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FTL.A.parquet
#
# Processing FTNT...
# ✔ FTNT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FTNT.parquet
#
# Processing FTRCQ...
# ✔ FTRCQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FTRCQ.parquet
#
# Processing FTV...
# ✔ FTV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FTV.parquet
#
# Processing FWLT...
# ✔ FWLT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\FWLT.parquet
#
# Processing G1...
# ✔ G1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\G1.parquet
#
# Processing GAP...
# ✔ GAP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GAP.parquet
#
# Processing GAPTQ...
# ✔ GAPTQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GAPTQ.parquet
#
# Processing GAS...
# ✔ GAS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GAS.parquet
#
# Processing GAS1...
# ✔ GAS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GAS1.parquet
#
# Processing GD...
# ✔ GD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GD.parquet
#
# Processing GDDY...
# ✔ GDDY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GDDY.parquet
#
# Processing GDT...
# ✔ GDT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GDT.parquet
#
# Processing GDW...
# ✔ GDW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GDW.parquet
#
# Processing GE...
# ✔ GE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GE.parquet
#
# Processing GEHC...
# ✔ GEHC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GEHC.parquet
#
# Processing GEN...
# ✔ GEN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GEN.parquet
#
# Processing GEN1...
# ✔ GEN1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GEN1.parquet
#
# Processing GENZ...
# ✔ GENZ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GENZ.parquet
#
# Processing GEV...
# ✔ GEV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GEV.parquet
#
# Processing GFS.A...
# ✔ GFS.A: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GFS.A.parquet
#
# Processing GGP...
# ✔ GGP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GGP.parquet
#
# Processing GHC...
# ✔ GHC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GHC.parquet
#
# Processing GIC1...
# ✔ GIC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GIC1.parquet
#
# Processing GILD...
# ✔ GILD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GILD.parquet
#
# Processing GIS...
# ✔ GIS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GIS.parquet
#
# Processing GL...
# ✔ GL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GL.parquet
#
# Processing GLK1...
# ✔ GLK1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GLK1.parquet
#
# Processing GLW...
# ✔ GLW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GLW.parquet
#
# Processing GM...
# ✔ GM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GM.parquet
#
# Processing GMCR...
# ⚠ VALIDATION: GMCR | ATR_spike_detected | max ATR = 7.9099, median = 0.1645
# ✔ GMCR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GMCR.parquet
#
# Processing GME...
# ⚠ VALIDATION: GME | ATR_spike_detected | max ATR = 18.8521, median = 0.1584
# ✔ GME: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GME.parquet
#
# Processing GNRC...
# ✔ GNRC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GNRC.parquet
#
# Processing GNT1...
# ✔ GNT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GNT1.parquet
#
# Processing GNW...
# ✔ GNW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GNW.parquet
#
# Processing GOOG...
# ✔ GOOG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GOOG.parquet
#
# Processing GOOGL...
# ⚠ VALIDATION: GOOGL | ATR_spike_detected | max ATR = 11.3001, median = 0.5297
# ✔ GOOGL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GOOGL.parquet
#
# Processing GOSHA...
# ✔ GOSHA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GOSHA.parquet
#
# Processing GP1...
# ✔ GP1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GP1.parquet
#
# Processing GPC...
# ✔ GPC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GPC.parquet
#
# Processing GPN...
# ⚠ VALIDATION: GPN | ATR_spike_detected | max ATR = 15.9407, median = 0.6407
# ✔ GPN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GPN.parquet
#
# Processing GPU...
# ✔ GPU: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GPU.parquet
#
# Processing GR...
# ✔ GR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GR.parquet
#
# Processing GRA...
# ✔ GRA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GRA.parquet
#
# Processing GRMN...
# ✔ GRMN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GRMN.parquet
#
# Processing GRN1...
# ✔ GRN1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GRN1.parquet
#
# Processing GS...
# ✔ GS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GS.parquet
#
# Processing GSX1...
# ✔ GSX1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GSX1.parquet
#
# Processing GT...
# ✔ GT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GT.parquet
#
# Processing GTE1...
# ✔ GTE1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GTE1.parquet
#
# Processing GTW...
# ✔ GTW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GTW.parquet
#
# Processing GWOW...
# ✔ GWOW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GWOW.parquet
#
# Processing GWW...
# ✔ GWW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GWW.parquet
#
# Processing GX...
# ✔ GX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\GX.parquet
#
# Processing H1...
# ✔ H1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\H1.parquet
#
# Processing H2...
# ✔ H2: saved ATR20 → ./4-ATR20_adjusted_All_Prices\H2.parquet
#
# Processing HAL...
# ✔ HAL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HAL.parquet
#
# Processing HAR...
# ✔ HAR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HAR.parquet
#
# Processing HAS...
# ✔ HAS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HAS.parquet
#
# Processing HBAN...
# ✔ HBAN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HBAN.parquet
#
# Processing HBI...
# ✔ HBI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HBI.parquet
#
# Processing HBOC...
# ✔ HBOC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HBOC.parquet
#
# Processing HCA...
# ✔ HCA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HCA.parquet
#
# Processing HCA1...
# ✔ HCA1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HCA1.parquet
#
# Processing HCBK...
# ✔ HCBK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HCBK.parquet
#
# Processing HCR1...
# ✔ HCR1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HCR1.parquet
#
# Processing HD...
# ✔ HD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HD.parquet
#
# Processing HES...
# ✔ HES: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HES.parquet
#
# Processing HET...
# ✔ HET: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HET.parquet
#
# Processing HI1...
# ✔ HI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HI1.parquet
#
# Processing HIG...
# ✔ HIG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HIG.parquet
#
# Processing HII...
# ✔ HII: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HII.parquet
#
# Processing HLT...
# ✔ HLT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HLT.parquet
#
# Processing HLT1...
# ✔ HLT1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HLT1.parquet
#
# Processing HM...
# ✔ HM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HM.parquet
#
# Processing HMA1...
# ✔ HMA1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HMA1.parquet
#
# Processing HNZ...
# ✔ HNZ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HNZ.parquet
#
# Processing HOG...
# ✔ HOG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HOG.parquet
#
# Processing HOLX...
# ✔ HOLX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HOLX.parquet
#
# Processing HON...
# ✔ HON: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HON.parquet
#
# Processing HON1...
# ✔ HON1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HON1.parquet
#
# Processing HOOD...
# ✔ HOOD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HOOD.parquet
#
# Processing HOT...
# ✔ HOT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HOT.parquet
#
# Processing HP...
# ✔ HP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HP.parquet
#
# Processing HPC...
# ✔ HPC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HPC.parquet
#
# Processing HPE...
# ✔ HPE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HPE.parquet
#
# Processing HPQ...
# ✔ HPQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\HPQ.parquet
#
# Processing HRB...
# ...
#
# Processing TEL...
# ✔ TEL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TEL.parquet
#
# Processing TEN1...
# ✔ TEN1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TEN1.parquet
#
# Processing TER...
# ✔ TER: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TER.parquet
#
# Processing TEX...
# ✔ TEX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TEX.parquet
#
# Processing TFC...
# ✔ TFC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TFC.parquet
#
# Processing TFCF...
# ✔ TFCF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TFCF.parquet
#
# Processing TFCFA...
# ✔ TFCFA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TFCFA.parquet
#
# Processing TFX...
# ⚠ VALIDATION: TFX | ATR_spike_detected | max ATR = 27.4460, median = 1.2211
# ✔ TFX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TFX.parquet
#
# Processing TGNA...
# ✔ TGNA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TGNA.parquet
#
# Processing TGT...
# ✔ TGT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TGT.parquet
#
# Processing THC...
# ✔ THC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\THC.parquet
#
# Processing TIE...
# ✔ TIE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TIE.parquet
#
# Processing TIF...
# ✔ TIF: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TIF.parquet
#
# Processing TIN...
# ✔ TIN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TIN.parquet
#
# Processing TJX...
# ✔ TJX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TJX.parquet
#
# Processing TKO...
# ✔ TKO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TKO.parquet
#
# Processing TKR...
# ✔ TKR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TKR.parquet
#
# Processing TLAB...
# ✔ TLAB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TLAB.parquet
#
# Processing TMC.A...
# ✔ TMC.A: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TMC.A.parquet
#
# Processing TMO...
# ✔ TMO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TMO.parquet
#
# Processing TMUS...
# ✔ TMUS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TMUS.parquet
#
# Processing TNB...
# ✔ TNB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TNB.parquet
#
# Processing TNL...
# ✔ TNL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TNL.parquet
#
# Processing TOS...
# ✔ TOS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TOS.parquet
#
# Processing TOY...
# ✔ TOY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TOY.parquet
#
# Processing TPL...
# ⚠ VALIDATION: TPL | ATR_spike_detected | max ATR = 101.5143, median = 0.5366
# ✔ TPL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TPL.parquet
#
# Processing TPR...
# ✔ TPR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TPR.parquet
#
# Processing TRB...
# ✔ TRB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TRB.parquet
#
# Processing TRGP...
# ✔ TRGP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TRGP.parquet
#
# Processing TRIP...
# ✔ TRIP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TRIP.parquet
#
# Processing TRMB...
# ✔ TRMB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TRMB.parquet
#
# Processing TROW...
# ✔ TROW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TROW.parquet
#
# Processing TRV...
# ✔ TRV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TRV.parquet
#
# Processing TRW1...
# ✔ TRW1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TRW1.parquet
#
# Processing TSCO...
# ✔ TSCO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TSCO.parquet
#
# Processing TSG1...
# ✔ TSG1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TSG1.parquet
#
# Processing TSLA...
# ⚠ VALIDATION: TSLA | ATR_spike_detected | max ATR = 27.5080, median = 0.7181
# ✔ TSLA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TSLA.parquet
#
# Processing TSN...
# ✔ TSN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TSN.parquet
#
# Processing TSS...
# ✔ TSS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TSS.parquet
#
# Processing TT...
# ⚠ VALIDATION: TT | ATR_spike_detected | max ATR = 15.9280, median = 0.5953
# ✔ TT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TT.parquet
#
# Processing TT2...
# ✔ TT2: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TT2.parquet
#
# Processing TTD...
# ✔ TTD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TTD.parquet
#
# Processing TTWO...
# ✔ TTWO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TTWO.parquet
#
# Processing TUPBQ...
# ✔ TUPBQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TUPBQ.parquet
#
# Processing TWC...
# ✔ TWC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TWC.parquet
#
# Processing TWTR...
# ✔ TWTR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TWTR.parquet
#
# Processing TWX...
# ✔ TWX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TWX.parquet
#
# Processing TWX1...
# ✔ TWX1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TWX1.parquet
#
# Processing TX1...
# ✔ TX1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TX1.parquet
#
# Processing TXN...
# ✔ TXN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TXN.parquet
#
# Processing TXT...
# ✔ TXT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TXT.parquet
#
# Processing TXU...
# ✔ TXU: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TXU.parquet
#
# Processing TYC...
# ✔ TYC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TYC.parquet
#
# Processing TYL...
# ⚠ VALIDATION: TYL | ATR_spike_detected | max ATR = 22.3565, median = 0.8375
# ✔ TYL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\TYL.parquet
#
# Processing UA...
# ✔ UA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UA.parquet
#
# Processing UAA...
# ✔ UAA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UAA.parquet
#
# Processing UAL...
# ✔ UAL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UAL.parquet
#
# Processing UAWGQ...
# ✔ UAWGQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UAWGQ.parquet
#
# Processing UBER...
# ✔ UBER: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UBER.parquet
#
# Processing UCC1...
# ✔ UCC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UCC1.parquet
#
# Processing UCL1...
# ✔ UCL1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UCL1.parquet
#
# Processing UCM...
# ✔ UCM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UCM.parquet
#
# Processing UDR...
# ✔ UDR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UDR.parquet
#
# Processing UHS...
# ✔ UHS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UHS.parquet
#
# Processing UIS...
# ⚠ VALIDATION: UIS | ATR_spike_detected | max ATR = 29.1300, median = 0.9737
# ✔ UIS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UIS.parquet
#
# Processing UK1...
# ✔ UK1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UK1.parquet
#
# Processing UL...
# ✔ UL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UL.parquet
#
# Processing ULTA...
# ✔ ULTA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ULTA.parquet
#
# Processing UNH...
# ⚠ VALIDATION: UNH | ATR_spike_detected | max ATR = 25.7180, median = 1.0431
# ✔ UNH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UNH.parquet
#
# Processing UNM...
# ✔ UNM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UNM.parquet
#
# Processing UNP...
# ✔ UNP: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UNP.parquet
#
# Processing UPC1...
# ✔ UPC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UPC1.parquet
#
# Processing UPR...
# ✔ UPR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UPR.parquet
#
# Processing UPS...
# ✔ UPS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UPS.parquet
#
# Processing URBN...
# ✔ URBN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\URBN.parquet
#
# Processing URI...
# ⚠ VALIDATION: URI | ATR_spike_detected | max ATR = 36.8907, median = 1.4812
# ✔ URI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\URI.parquet
#
# Processing USB...
# ✔ USB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\USB.parquet
#
# Processing USB1...
# ✔ USB1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\USB1.parquet
#
# Processing USG1...
# ✔ USG1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\USG1.parquet
#
# Processing USS1...
# ✔ USS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\USS1.parquet
#
# Processing UST1...
# ✔ UST1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UST1.parquet
#
# Processing USW...
# ✔ USW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\USW.parquet
#
# Processing UVN...
# ✔ UVN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\UVN.parquet
#
# Processing V...
# ✔ V: saved ATR20 → ./4-ATR20_adjusted_All_Prices\V.parquet
#
# Processing VALPQ...
# ✔ VALPQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VALPQ.parquet
#
# Processing VAR...
# ✔ VAR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VAR.parquet
#
# Processing VFC...
# ✔ VFC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VFC.parquet
#
# Processing VIAB...
# ✔ VIAB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VIAB.parquet
#
# Processing VIAV...
# ⚠ VALIDATION: VIAV | ATR_spike_detected | max ATR = 63.9277, median = 0.3403
# ✔ VIAV: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VIAV.parquet
#
# Processing VICI...
# ✔ VICI: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VICI.parquet
#
# Processing VLO...
# ✔ VLO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VLO.parquet
#
# Processing VLTO...
# ✔ VLTO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VLTO.parquet
#
# Processing VMC...
# ✔ VMC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VMC.parquet
#
# Processing VNO...
# ✔ VNO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VNO.parquet
#
# Processing VNT...
# ✔ VNT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VNT.parquet
#
# Processing VO1...
# ✔ VO1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VO1.parquet
#
# Processing VRSK...
# ✔ VRSK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VRSK.parquet
#
# Processing VRSN...
# ✔ VRSN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VRSN.parquet
#
# Processing VRTS1...
# ✔ VRTS1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VRTS1.parquet
#
# Processing VRTX...
# ✔ VRTX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VRTX.parquet
#
# Processing VST...
# ⚠ VALIDATION: VST | ATR_spike_detected | max ATR = 14.2286, median = 0.5446
# ✔ VST: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VST.parquet
#
# Processing VSTNQ...
# ✔ VSTNQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VSTNQ.parquet
#
# Processing VTR...
# ✔ VTR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VTR.parquet
#
# Processing VTRS...
# ✔ VTRS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VTRS.parquet
#
# Processing VTSS...
# ⚠ VALIDATION: VTSS | ATR_spike_detected | max ATR = 240.5625, median = 1.3200
# ✔ VTSS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VTSS.parquet
#
# Processing VYX...
# ✔ VYX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VYX.parquet
#
# Processing VZ...
# ✔ VZ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\VZ.parquet
#
# Processing WAB...
# ✔ WAB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WAB.parquet
#
# Processing WAI1...
# ✔ WAI1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WAI1.parquet
#
# Processing WAMUQ...
# ✔ WAMUQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WAMUQ.parquet
#
# Processing WAT...
# ✔ WAT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WAT.parquet
#
# Processing WB1...
# ✔ WB1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WB1.parquet
#
# Processing WB2...
# ✔ WB2: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WB2.parquet
#
# Processing WBA...
# ✔ WBA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WBA.parquet
#
# Processing WBD...
# ✔ WBD: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WBD.parquet
#
# Processing WCG...
# ✔ WCG: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WCG.parquet
#
# Processing WCOEQ...
# ✔ WCOEQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WCOEQ.parquet
#
# Processing WDAY...
# ✔ WDAY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WDAY.parquet
#
# Processing WDC...
# ✔ WDC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WDC.parquet
#
# Processing WEC...
# ⚠ VALIDATION: WEC | ATR_spike_detected | max ATR = 8.1301, median = 0.3208
# ✔ WEC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WEC.parquet
#
# Processing WELL...
# ✔ WELL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WELL.parquet
#
# Processing WEN...
# ✔ WEN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WEN.parquet
#
# Processing WFC...
# ✔ WFC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WFC.parquet
#
# Processing WFC1...
# ✔ WFC1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WFC1.parquet
#
# Processing WFM...
# ✔ WFM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WFM.parquet
#
# Processing WFTIQ...
# ✔ WFTIQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WFTIQ.parquet
#
# Processing WGL...
# ✔ WGL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WGL.parquet
#
# Processing WHR...
# ✔ WHR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WHR.parquet
#
# Processing WINMQ...
# ✔ WINMQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WINMQ.parquet
#
# Processing WLA...
# ✔ WLA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WLA.parquet
#
# Processing WLL1...
# ✔ WLL1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WLL1.parquet
#
# Processing WLP1...
# ✔ WLP1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WLP1.parquet
#
# Processing WM...
# ✔ WM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WM.parquet
#
# Processing WMB...
# ✔ WMB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WMB.parquet
#
# Processing WMT...
# ✔ WMT: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WMT.parquet
#
# Processing WNDXQ...
# ✔ WNDXQ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WNDXQ.parquet
#
# Processing WOR...
# ✔ WOR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WOR.parquet
#
# Processing WPX...
# ✔ WPX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WPX.parquet
#
# Processing WRB...
# ✔ WRB: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WRB.parquet
#
# Processing WRK...
# ✔ WRK: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WRK.parquet
#
# Processing WSM...
# ⚠ VALIDATION: WSM | ATR_spike_detected | max ATR = 11.8258, median = 0.4152
# ✔ WSM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WSM.parquet
#
# Processing WST...
# ⚠ VALIDATION: WST | ATR_spike_detected | max ATR = 16.1599, median = 0.5765
# ✔ WST: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WST.parquet
#
# Processing WTW...
# ✔ WTW: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WTW.parquet
#
# Processing WU...
# ✔ WU: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WU.parquet
#
# Processing WWY...
# ✔ WWY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WWY.parquet
#
# Processing WY...
# ✔ WY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WY.parquet
#
# Processing WYE...
# ✔ WYE: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WYE.parquet
#
# Processing WYNN...
# ✔ WYNN: saved ATR20 → ./4-ATR20_adjusted_All_Prices\WYNN.parquet
#
# Processing X...
# ✔ X: saved ATR20 → ./4-ATR20_adjusted_All_Prices\X.parquet
#
# Processing XEC...
# ✔ XEC: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XEC.parquet
#
# Processing XEL...
# ✔ XEL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XEL.parquet
#
# Processing XL1...
# ✔ XL1: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XL1.parquet
#
# Processing XLNX...
# ✔ XLNX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XLNX.parquet
#
# Processing XOM...
# ✔ XOM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XOM.parquet
#
# Processing XRAY...
# ✔ XRAY: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XRAY.parquet
#
# Processing XRX...
# ✔ XRX: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XRX.parquet
#
# Processing XTO...
# ✔ XTO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XTO.parquet
#
# Processing XYL...
# ✔ XYL: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XYL.parquet
#
# Processing XYZ...
# ✔ XYZ: saved ATR20 → ./4-ATR20_adjusted_All_Prices\XYZ.parquet
#
# Processing YHOO...
# ✔ YHOO: saved ATR20 → ./4-ATR20_adjusted_All_Prices\YHOO.parquet
#
# Processing YNR...
# ✔ YNR: saved ATR20 → ./4-ATR20_adjusted_All_Prices\YNR.parquet
#
# Processing YUM...
# ✔ YUM: saved ATR20 → ./4-ATR20_adjusted_All_Prices\YUM.parquet
#
# Processing ZBH...
# ✔ ZBH: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ZBH.parquet
#
# Processing ZBRA...
# ✔ ZBRA: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ZBRA.parquet
#
# Processing ZION...
# ✔ ZION: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ZION.parquet
#
# Processing ZTS...
# ✔ ZTS: saved ATR20 → ./4-ATR20_adjusted_All_Prices\ZTS.parquet
#
#
# ====================================================
#  ATR20 VALIDATION SUMMARY
# ====================================================
#    ticker               issue                               detail
# 0    AAPL  ATR_spike_detected   max ATR = 11.3977, median = 0.2763
# 1    ABI1  ATR_spike_detected   max ATR = 15.1383, median = 0.7150
# 2    ABMD  ATR_spike_detected   max ATR = 26.4475, median = 0.8270
# 3    ADBE  ATR_spike_detected   max ATR = 30.6894, median = 1.2203
# 4   ADCT1  ATR_spike_detected   max ATR = 28.7875, median = 0.8785
# ..    ...                 ...                                  ...
# 93    VST  ATR_spike_detected   max ATR = 14.2286, median = 0.5446
# 94   VTSS  ATR_spike_detected  max ATR = 240.5625, median = 1.3200
# 95    WEC  ATR_spike_detected    max ATR = 8.1301, median = 0.3208
# 96    WSM  ATR_spike_detected   max ATR = 11.8258, median = 0.4152
# 97    WST  ATR_spike_detected   max ATR = 16.1599, median = 0.5765
#
# [98 rows x 3 columns]
#
# Validation log saved to:
# ./system_verification/4-ATR20_adjusted_All_Prices\atr20_validation-20251231-083656.csv
# ====================================================

# %%
import pandas as pd
df_ranking = pd.read_parquet("./4-ATR20_adjusted_All_Prices/AAPL.parquet")

print("Ranking Dataset Info:")
print("="*60)
print(f"Shape: {df_ranking.shape}")
print(f"\nColumns: {df_ranking.columns.tolist()}")
print(f"\nData types:\n{df_ranking.dtypes}")
print(f"\nFirst few rows:")
print(df_ranking.head(22))
print(f"\nLast few rows:")
print(df_ranking.tail(10))
print(f"\nSummary statistics:")
print(df_ranking.describe())
print(f"\nNull values:")
print(df_ranking.isnull().sum())
# Out:
# Ranking Dataset Info:
# ============================================================
# Shape: (7043, 18)
#
# Columns: ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'closeadj', 'closeunadj', 'lastupdated', 'adj_factor', 'open_adj', 'high_adj', 'low_adj', 'close_adj', 'prev_close', 'tr', 'atr20']
#
# Data types:
# ticker                 object
# date           datetime64[ns]
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# volume                float64
# closeadj              float64
# closeunadj            float64
# lastupdated    datetime64[ms]
# adj_factor            float64
# open_adj              float64
# high_adj              float64
# low_adj               float64
# close_adj             float64
# prev_close            float64
# tr                    float64
# atr20                 float64
# dtype: object
#
# First few rows:
#    ticker       date   open   high    low  close        volume  closeadj  \
# 0    AAPL 1997-12-31  0.117  0.122  0.116  0.117  4.063580e+08     0.098
# 1    AAPL 1998-01-02  0.122  0.145  0.120  0.145  7.181100e+08     0.122
# 2    AAPL 1998-01-05  0.147  0.148  0.136  0.142  6.518740e+08     0.119
# 3    AAPL 1998-01-06  0.142  0.178  0.132  0.169  1.812474e+09     0.142
# 4    AAPL 1998-01-07  0.168  0.170  0.154  0.156  1.041622e+09     0.131
# 5    AAPL 1998-01-08  0.156  0.166  0.151  0.163  7.740210e+08     0.136
# 6    AAPL 1998-01-09  0.162  0.173  0.156  0.163  8.865470e+08     0.136
# 7    AAPL 1998-01-12  0.156  0.166  0.153  0.163  5.163980e+08     0.137
# 8    AAPL 1998-01-13  0.166  0.175  0.165  0.174  6.368540e+08     0.146
# 9    AAPL 1998-01-14  0.177  0.178  0.172  0.176  5.892660e+08     0.148
# 10   AAPL 1998-01-15  0.171  0.176  0.166  0.171  5.592720e+08     0.144
# 11   AAPL 1998-01-16  0.173  0.173  0.167  0.168  2.463550e+08     0.141
# 12   AAPL 1998-01-20  0.170  0.172  0.166  0.170  2.415620e+08     0.143
# 13   AAPL 1998-01-21  0.168  0.170  0.166  0.169  1.902100e+08     0.142
# 14   AAPL 1998-01-22  0.167  0.176  0.166  0.172  3.297280e+08     0.144
# 15   AAPL 1998-01-23  0.173  0.176  0.172  0.174  2.331620e+08     0.146
# 16   AAPL 1998-01-26  0.173  0.175  0.168  0.173  1.464400e+08     0.146
# 17   AAPL 1998-01-27  0.171  0.176  0.170  0.171  1.122350e+08     0.143
# 18   AAPL 1998-01-28  0.171  0.173  0.166  0.171  1.511220e+08     0.144
# 19   AAPL 1998-01-29  0.169  0.171  0.165  0.165  2.118820e+08     0.139
# 20   AAPL 1998-01-30  0.164  0.169  0.163  0.164  1.624450e+08     0.137
# 21   AAPL 1998-02-02  0.165  0.165  0.155  0.158  6.367420e+08     0.133
#
#     closeunadj lastupdated  adj_factor  open_adj  high_adj   low_adj  \
# 0        13.13  2025-11-10    0.837607  0.098000  0.102188  0.097162
# 1        16.25  2025-11-10    0.841379  0.102648  0.122000  0.100966
# 2        15.88  2025-11-10    0.838028  0.123190  0.124028  0.113972
# 3        18.94  2025-11-10    0.840237  0.119314  0.149562  0.110911
# 4        17.50  2025-11-10    0.839744  0.141077  0.142756  0.129321
# 5        18.19  2025-11-10    0.834356  0.130160  0.138503  0.125988
# 6        18.19  2025-11-10    0.834356  0.135166  0.144344  0.130160
# 7        18.25  2025-11-10    0.840491  0.131117  0.139521  0.128595
# 8        19.50  2025-11-10    0.839080  0.139287  0.146839  0.138448
# 9        19.75  2025-11-10    0.840909  0.148841  0.149682  0.144636
# 10       19.19  2025-11-10    0.842105  0.144000  0.148211  0.139789
# 11       18.81  2025-11-10    0.839286  0.145196  0.145196  0.140161
# 12       19.06  2025-11-10    0.841176  0.143000  0.144682  0.139635
# 13       18.91  2025-11-10    0.840237  0.141160  0.142840  0.139479
# 14       19.25  2025-11-10    0.837209  0.139814  0.147349  0.138977
# 15       19.50  2025-11-10    0.839080  0.145161  0.147678  0.144322
# 16       19.44  2025-11-10    0.843931  0.146000  0.147688  0.141780
# 17       19.12  2025-11-10    0.836257  0.143000  0.147181  0.142164
# 18       19.19  2025-11-10    0.842105  0.144000  0.145684  0.139789
# 19       18.50  2025-11-10    0.842424  0.142370  0.144055  0.139000
# 20       18.31  2025-11-10    0.835366  0.137000  0.141177  0.136165
# 21       17.69  2025-11-10    0.841772  0.138892  0.138892  0.130475
#
#     close_adj  prev_close        tr     atr20
# 0       0.098         NaN       NaN       NaN
# 1       0.122       0.098  0.024000       NaN
# 2       0.119       0.122  0.010056       NaN
# 3       0.142       0.119  0.038651       NaN
# 4       0.131       0.142  0.013436       NaN
# 5       0.136       0.131  0.012515       NaN
# 6       0.136       0.136  0.014184       NaN
# 7       0.137       0.136  0.010926       NaN
# 8       0.146       0.137  0.009839       NaN
# 9       0.148       0.146  0.005045       NaN
# 10      0.144       0.148  0.008421       NaN
# 11      0.141       0.144  0.005036       NaN
# 12      0.143       0.141  0.005047       NaN
# 13      0.142       0.143  0.003521       NaN
# 14      0.144       0.142  0.008372       NaN
# 15      0.146       0.144  0.003678       NaN
# 16      0.146       0.146  0.005908       NaN
# 17      0.143       0.146  0.005018       NaN
# 18      0.144       0.143  0.005895       NaN
# 19      0.139       0.144  0.005055       NaN
# 20      0.137       0.139  0.005012  0.009981
# 21      0.133       0.137  0.008418  0.009202
#
# Last few rows:
#      ticker       date     open    high     low   close       volume  \
# 7033   AAPL 2025-12-16  272.820  275.50  271.79  274.61   37590000.0
# 7034   AAPL 2025-12-17  275.010  276.16  271.64  271.84   50101000.0
# 7035   AAPL 2025-12-18  273.605  273.62  266.96  272.19   51510000.0
# 7036   AAPL 2025-12-19  272.150  274.60  269.90  273.67  144599000.0
# 7037   AAPL 2025-12-22  272.860  273.88  270.51  270.97   36493000.0
# 7038   AAPL 2025-12-23  270.840  272.45  269.56  272.36   29357000.0
# 7039   AAPL 2025-12-24  272.340  275.43  272.20  273.81   17911000.0
# 7040   AAPL 2025-12-26  274.160  275.37  272.86  273.40   21455000.0
# 7041   AAPL 2025-12-29  272.690  274.36  272.35  273.76   23700000.0
# 7042   AAPL 2025-12-30  272.835  274.08  272.28  273.08   22090000.0
#
#       closeadj  closeunadj lastupdated  adj_factor  open_adj  high_adj  \
# 7033    274.61      274.61  2025-12-16         1.0   272.820    275.50
# 7034    271.84      271.84  2025-12-17         1.0   275.010    276.16
# 7035    272.19      272.19  2025-12-18         1.0   273.605    273.62
# 7036    273.67      273.67  2025-12-20         1.0   272.150    274.60
# 7037    270.97      270.97  2025-12-22         1.0   272.860    273.88
# 7038    272.36      272.36  2025-12-23         1.0   270.840    272.45
# 7039    273.81      273.81  2025-12-24         1.0   272.340    275.43
# 7040    273.40      273.40  2025-12-27         1.0   274.160    275.37
# 7041    273.76      273.76  2025-12-29         1.0   272.690    274.36
# 7042    273.08      273.08  2025-12-30         1.0   272.835    274.08
#
#       low_adj  close_adj  prev_close    tr    atr20
# 7033   271.79     274.61      274.11  3.71  5.08975
# 7034   271.64     271.84      274.61  4.52  5.04650
# 7035   266.96     272.19      271.84  6.66  5.04400
# 7036   269.90     273.67      272.19  4.70  4.80350
# 7037   270.51     270.97      273.67  3.37  4.58900
# 7038   269.56     272.36      270.97  2.89  4.42850
# 7039   272.20     273.81      272.36  3.23  4.33350
# 7040   272.86     273.40      273.81  2.51  4.31400
# 7041   272.35     273.76      273.40  2.01  4.26400
# 7042   272.28     273.08      273.76  1.80  3.99000
#
# Summary statistics:
#                                 date         open         high          low  \
# count                           7043  7043.000000  7043.000000  7043.000000
# mean   2011-12-30 06:33:47.204316160    46.348504    46.850248    45.878712
# min              1997-12-31 00:00:00     0.117000     0.122000     0.116000
# 25%              2005-01-01 12:00:00     1.220500     1.244500     1.183000
# 50%              2011-12-28 00:00:00    14.463000    14.607000    14.304000
# 75%              2018-12-27 12:00:00    47.945000    48.450000    47.652500
# max              2025-12-30 00:00:00   286.200000   288.610000   283.540000
# std                              NaN    68.289413    69.023068    67.625347
#
#              close        volume     closeadj   closeunadj  \
# count  7043.000000  7.043000e+03  7043.000000  7043.000000
# mean     46.386012  3.821342e+08    44.921425   167.869031
# min       0.117000  1.791100e+07     0.098000    13.120000
# 25%       1.216500  1.122385e+08     1.021500    62.225000
# 50%      14.464000  2.698300e+08    12.192000   135.250000
# 75%      48.013500  5.135240e+08    45.622000   207.550000
# max     286.190000  7.421641e+09   286.190000   702.100000
# std      68.359826  3.816358e+08    67.997713   143.642336
#
#                       lastupdated   adj_factor     open_adj     high_adj  \
# count                        7043  7043.000000  7043.000000  7043.000000
# mean   2025-11-10 02:54:24.177000     0.888659    44.884219    45.370582
# min           2025-11-10 00:00:00     0.834356     0.098000     0.102188
# 25%           2025-11-10 00:00:00     0.839728     1.024807     1.044870
# 50%           2025-11-10 00:00:00     0.841163    12.223495    12.297336
# 75%           2025-11-10 00:00:00     0.950878    45.573997    45.996170
# max           2025-12-30 00:00:00     1.000000   286.200000   288.610000
# std                           NaN     0.060703    67.927751    68.657178
#
#            low_adj    close_adj   prev_close           tr        atr20
# count  7043.000000  7043.000000  7042.000000  7042.000000  7023.000000
# mean     44.430217    44.921425    44.889026     1.040426     1.038355
# min       0.097162     0.098000     0.098000     0.001840     0.005003
# 25%       0.993301     1.021500     1.020250     0.039511     0.047003
# 50%      12.071104    12.192000    12.187500     0.231121     0.276266
# 75%      45.213781    45.622000    45.601500     0.978141     0.971970
# max     283.540000   286.190000   286.190000    28.624243    11.397720
# std      67.267521    67.997713    67.948151     1.888413     1.650924
#
# Null values:
# ticker          0
# date            0
# open            0
# high            0
# low             0
# close           0
# volume          0
# closeadj        0
# closeunadj      0
# lastupdated     0
# adj_factor      0
# open_adj        0
# high_adj        0
# low_adj         0
# close_adj       0
# prev_close      1
# tr              1
# atr20          20
# dtype: int64

# %%
# Use existing df_ranking to export as CSV (no re-imports)
csv_path = "./4-ATR20_adjusted_All_Prices/AAPL.csv"
df_ranking.to_csv(csv_path, index=False)
print(f"✔ Exported to CSV → {csv_path}")
# Out:
# ✔ Exported to CSV → ./4-ATR20_adjusted_All_Prices/AAPL.csv
