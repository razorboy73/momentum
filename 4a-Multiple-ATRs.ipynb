# %%
#!/usr/bin/env python3
import os
import pandas as pd
import numpy as np
from datetime import datetime

"""
Purpose:
    Compute ATR for multiple lookback windows (simple rolling mean of True Range)
    and save outputs into per-window subdirectories.

Outputs:
    OUTPUT_ROOT/atr_{W}D/{ticker}.parquet  with columns: date, tr, atr{W}
    VER_ROOT/atr_{W}D/atr_validation-<timestamp>.csv (per-window)
    VER_ROOT/atr_multi_validation-<timestamp>.csv (combined)
"""

# ============================================================
# CONFIG
# ============================================================

INPUT_DIR   = "./3-adjusted_All_Prices_OHLC"
OUTPUT_ROOT = "./4-ATR20_adjusted_All_Prices"  # keep existing dir as root
VER_ROOT    = "./system_verification/4-ATR20_adjusted_All_Prices"

os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(VER_ROOT, exist_ok=True)

# 5 reasonable ATR windows (trading days)
ATR_WINDOWS = [14, 20, 28, 42, 63]

REQUIRED = {"open_adj", "high_adj", "low_adj", "close_adj", "date"}

print(f"\nLoading adjusted price files from: {INPUT_DIR}")
files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".parquet")])
print(f"Found {len(files)} tickers.\n")

# ============================================================
# VALIDATION STORAGE
# ============================================================

validation_rows = []

def add_validation(ticker, window, issue, detail=""):
    row = {"ticker": ticker, "window": int(window), "issue": issue, "detail": detail}
    validation_rows.append(row)
    print(f"⚠ VALIDATION: {ticker} | W={window} | {issue} | {detail}")

# ============================================================
# ATR BASE COMPUTATION (TR only, once per ticker)
# ============================================================

def compute_true_range(df: pd.DataFrame, ticker: str) -> pd.DataFrame | None:
    # --- Required columns ---
    if not REQUIRED.issubset(df.columns):
        missing = REQUIRED - set(df.columns)
        add_validation(ticker, -1, "missing_columns", str(missing))
        return None

    # --- Date validation / sorting ---
    df = df.copy()
    df["date"] = pd.to_datetime(df["date"])
    if not df["date"].is_monotonic_increasing:
        add_validation(ticker, -1, "non_monotonic_dates", "sorting by date")
        df = df.sort_values("date")

    df = df.reset_index(drop=True)

    # --- Basic sanity checks ---
    if (df["close_adj"] <= 0).any():
        add_validation(ticker, -1, "nonpositive_close_adj", f"{int((df['close_adj'] <= 0).sum())} rows")

    # TRUE RANGE requires prev close
    df["prev_close"] = df["close_adj"].shift(1)

    tr1 = (df["high_adj"] - df["low_adj"]).astype(float)
    tr2 = (df["high_adj"] - df["prev_close"]).abs().astype(float)
    tr3 = (df["low_adj"]  - df["prev_close"]).abs().astype(float)

    df["tr"] = np.maximum(tr1, np.maximum(tr2, tr3))

    if (df["tr"] < 0).any():
        add_validation(ticker, -1, "negative_TR_detected", f"{int((df['tr'] < 0).sum())} rows")

    return df

# ============================================================
# MAIN LOOP
# ============================================================

# per-window validation collection (so we can also write window-specific logs)
validation_by_window = {w: [] for w in ATR_WINDOWS}

for file in files:
    ticker = file.replace(".parquet", "")
    in_path = os.path.join(INPUT_DIR, file)

    print(f"Processing {ticker}...")

    try:
        raw = pd.read_parquet(in_path)
        base = compute_true_range(raw, ticker)

        if base is None:
            print(f"❌ {ticker}: TR not computed (validation issue).\n")
            continue

        n = len(base)

        # Compute and save each ATR window into its own subdir
        for W in ATR_WINDOWS:
            out_dir = os.path.join(OUTPUT_ROOT, f"atr_{W}D")
            ver_dir = os.path.join(VER_ROOT,  f"atr_{W}D")
            os.makedirs(out_dir, exist_ok=True)
            os.makedirs(ver_dir, exist_ok=True)

            if n < W:
                last_date = base["date"].max().date()
                add_validation(ticker, W, "insufficient_history", f"{n} rows (<{W}), last={last_date}")
                validation_by_window[W].append(validation_rows[-1])
                continue

            atr_col = f"atr{W}"
            atr = base["tr"].rolling(window=W, min_periods=W).mean()

            # Optional: detect absurd ATR spikes (window-specific)
            if n > (W + 10):
                median_atr = float(np.nanmedian(atr.values))
                if median_atr > 0:
                    max_atr = float(np.nanmax(atr.values))
                    if max_atr > median_atr * 20:
                        add_validation(
                            ticker, W, "ATR_spike_detected",
                            f"max {atr_col}={max_atr:.4f}, median={median_atr:.4f}"
                        )
                        validation_by_window[W].append(validation_rows[-1])

            df_out = base[["date", "tr"]].copy()
            df_out[atr_col] = atr.values

            out_path = os.path.join(out_dir, f"{ticker}.parquet")
            df_out.to_parquet(out_path, index=False)

        print(f"✔ {ticker}: saved {len(ATR_WINDOWS)} ATR lookbacks\n")

    except Exception as e:
        add_validation(ticker, -1, "processing_error", str(e))
        print(f"❌ ERROR for {ticker}: {e}\n")

# ============================================================
# SAVE VALIDATION REPORTS
# ============================================================

ts = datetime.now().strftime("%Y%m%d-%H%M%S")
validation_df = pd.DataFrame(validation_rows)

# Combined validation file
val_file_all = os.path.join(VER_ROOT, f"atr_multi_validation-{ts}.csv")
validation_df.to_csv(val_file_all, index=False)

# Per-window validation files (only rows for that window)
for W in ATR_WINDOWS:
    df_w = validation_df[validation_df["window"] == W].copy()
    val_file_w = os.path.join(VER_ROOT, f"atr_{W}D", f"atr_validation-{ts}.csv")
    df_w.to_csv(val_file_w, index=False)

print("\n====================================================")
print(" MULTI-ATR VALIDATION SUMMARY")
print("====================================================")
if validation_df.empty:
    print("No validation issues detected.")
else:
    print(validation_df)

print("\nValidation logs saved to:")
print(f"  → {val_file_all}")
for W in ATR_WINDOWS:
    print(f"  → {os.path.join(VER_ROOT, f'atr_{W}D', f'atr_validation-{ts}.csv')}")
print("====================================================\n")
# Out:
# Loading adjusted price files from: ./3-adjusted_All_Prices_OHLC
# Found 1167 tickers.
#
# Processing A...
# ✔ A: saved 5 ATR lookbacks
#
# Processing AAL...
# ✔ AAL: saved 5 ATR lookbacks
#
# Processing AAMRQ...
# ✔ AAMRQ: saved 5 ATR lookbacks
#
# Processing AAP...
# ✔ AAP: saved 5 ATR lookbacks
#
# Processing AAPL...
# ⚠ VALIDATION: AAPL | W=14 | ATR_spike_detected | max atr14=13.8029, median=0.2692
# ⚠ VALIDATION: AAPL | W=20 | ATR_spike_detected | max atr20=11.3977, median=0.2763
# ⚠ VALIDATION: AAPL | W=28 | ATR_spike_detected | max atr28=9.9184, median=0.2817
# ⚠ VALIDATION: AAPL | W=42 | ATR_spike_detected | max atr42=8.9032, median=0.2811
# ⚠ VALIDATION: AAPL | W=63 | ATR_spike_detected | max atr63=7.8908, median=0.2798
# ✔ AAPL: saved 5 ATR lookbacks
#
# Processing ABBV...
# ✔ ABBV: saved 5 ATR lookbacks
#
# Processing ABI1...
# ⚠ VALIDATION: ABI1 | W=14 | ATR_spike_detected | max atr14=16.5366, median=0.7155
# ⚠ VALIDATION: ABI1 | W=20 | ATR_spike_detected | max atr20=15.1383, median=0.7150
# ✔ ABI1: saved 5 ATR lookbacks
#
# Processing ABKFQ...
# ✔ ABKFQ: saved 5 ATR lookbacks
#
# Processing ABMD...
# ⚠ VALIDATION: ABMD | W=14 | ATR_spike_detected | max atr14=27.7223, median=0.8205
# ⚠ VALIDATION: ABMD | W=20 | ATR_spike_detected | max atr20=26.4475, median=0.8270
# ⚠ VALIDATION: ABMD | W=28 | ATR_spike_detected | max atr28=24.4118, median=0.8191
# ⚠ VALIDATION: ABMD | W=42 | ATR_spike_detected | max atr42=23.2152, median=0.8094
# ⚠ VALIDATION: ABMD | W=63 | ATR_spike_detected | max atr63=20.6337, median=0.8153
# ✔ ABMD: saved 5 ATR lookbacks
#
# Processing ABNB...
# ✔ ABNB: saved 5 ATR lookbacks
#
# Processing ABS...
# ✔ ABS: saved 5 ATR lookbacks
#
# Processing ABT...
# ✔ ABT: saved 5 ATR lookbacks
#
# Processing ACAS...
# ✔ ACAS: saved 5 ATR lookbacks
#
# Processing ACGL...
# ✔ ACGL: saved 5 ATR lookbacks
#
# Processing ACKHQ...
# ✔ ACKHQ: saved 5 ATR lookbacks
#
# Processing ACN...
# ✔ ACN: saved 5 ATR lookbacks
#
# Processing ACS...
# ✔ ACS: saved 5 ATR lookbacks
#
# Processing ACV1...
# ✔ ACV1: saved 5 ATR lookbacks
#
# Processing ADBE...
# ⚠ VALIDATION: ADBE | W=14 | ATR_spike_detected | max atr14=33.6731, median=1.2281
# ⚠ VALIDATION: ADBE | W=20 | ATR_spike_detected | max atr20=30.6894, median=1.2203
# ⚠ VALIDATION: ADBE | W=28 | ATR_spike_detected | max atr28=26.1610, median=1.2316
# ✔ ADBE: saved 5 ATR lookbacks
#
# Processing ADCT1...
# ⚠ VALIDATION: ADCT1 | W=14 | ATR_spike_detected | max atr14=33.8437, median=0.8900
# ⚠ VALIDATION: ADCT1 | W=20 | ATR_spike_detected | max atr20=28.7875, median=0.8785
# ⚠ VALIDATION: ADCT1 | W=28 | ATR_spike_detected | max atr28=27.4062, median=0.8675
# ⚠ VALIDATION: ADCT1 | W=42 | ATR_spike_detected | max atr42=24.9427, median=0.8750
# ⚠ VALIDATION: ADCT1 | W=63 | ATR_spike_detected | max atr63=22.6736, median=0.8933
# ✔ ADCT1: saved 5 ATR lookbacks
#
# Processing ADI...
# ✔ ADI: saved 5 ATR lookbacks
#
# Processing ADM...
# ✔ ADM: saved 5 ATR lookbacks
#
# Processing ADP...
# ✔ ADP: saved 5 ATR lookbacks
#
# Processing ADSK...
# ✔ ADSK: saved 5 ATR lookbacks
#
# Processing ADT1...
# ✔ ADT1: saved 5 ATR lookbacks
#
# Processing AEE...
# ✔ AEE: saved 5 ATR lookbacks
#
# Processing AEP...
# ✔ AEP: saved 5 ATR lookbacks
#
# Processing AES...
# ✔ AES: saved 5 ATR lookbacks
#
# Processing AET...
# ✔ AET: saved 5 ATR lookbacks
#
# Processing AFL...
# ✔ AFL: saved 5 ATR lookbacks
#
# Processing AFS.A...
# ✔ AFS.A: saved 5 ATR lookbacks
#
# Processing AGC1...
# ✔ AGC1: saved 5 ATR lookbacks
#
# Processing AGN...
# ✔ AGN: saved 5 ATR lookbacks
#
# Processing AGN1...
# ✔ AGN1: saved 5 ATR lookbacks
#
# Processing AHM1...
# ✔ AHM1: saved 5 ATR lookbacks
#
# Processing AIG...
# ⚠ VALIDATION: AIG | W=14 | ATR_spike_detected | max atr14=47.3702, median=1.4398
# ⚠ VALIDATION: AIG | W=20 | ATR_spike_detected | max atr20=44.2242, median=1.4329
# ⚠ VALIDATION: AIG | W=28 | ATR_spike_detected | max atr28=41.2211, median=1.4394
# ⚠ VALIDATION: AIG | W=42 | ATR_spike_detected | max atr42=36.8558, median=1.4472
# ⚠ VALIDATION: AIG | W=63 | ATR_spike_detected | max atr63=35.1740, median=1.4346
# ✔ AIG: saved 5 ATR lookbacks
#
# Processing AIT...
# ✔ AIT: saved 5 ATR lookbacks
#
# Processing AIV...
# ✔ AIV: saved 5 ATR lookbacks
#
# Processing AIZ...
# ✔ AIZ: saved 5 ATR lookbacks
#
# Processing AJG...
# ⚠ VALIDATION: AJG | W=14 | ATR_spike_detected | max atr14=13.5500, median=0.4701
# ⚠ VALIDATION: AJG | W=20 | ATR_spike_detected | max atr20=12.4195, median=0.4715
# ⚠ VALIDATION: AJG | W=28 | ATR_spike_detected | max atr28=10.9783, median=0.4827
# ✔ AJG: saved 5 ATR lookbacks
#
# Processing AKAM...
# ⚠ VALIDATION: AKAM | W=14 | ATR_spike_detected | max atr14=32.6741, median=1.4200
# ⚠ VALIDATION: AKAM | W=20 | ATR_spike_detected | max atr20=30.7812, median=1.4292
# ⚠ VALIDATION: AKAM | W=28 | ATR_spike_detected | max atr28=29.0268, median=1.4448
# ✔ AKAM: saved 5 ATR lookbacks
#
# Processing AKS...
# ✔ AKS: saved 5 ATR lookbacks
#
# Processing AL1...
# ✔ AL1: saved 5 ATR lookbacks
#
# Processing ALB...
# ✔ ALB: saved 5 ATR lookbacks
#
# Processing ALGN...
# ⚠ VALIDATION: ALGN | W=14 | ATR_spike_detected | max atr14=29.3209, median=1.1957
# ⚠ VALIDATION: ALGN | W=20 | ATR_spike_detected | max atr20=28.4330, median=1.1755
# ⚠ VALIDATION: ALGN | W=28 | ATR_spike_detected | max atr28=28.4030, median=1.1911
# ⚠ VALIDATION: ALGN | W=42 | ATR_spike_detected | max atr42=26.5126, median=1.1867
# ⚠ VALIDATION: ALGN | W=63 | ATR_spike_detected | max atr63=25.8969, median=1.1987
# ✔ ALGN: saved 5 ATR lookbacks
#
# Processing ALK...
# ✔ ALK: saved 5 ATR lookbacks
#
# Processing ALL...
# ✔ ALL: saved 5 ATR lookbacks
#
# Processing ALLE...
# ✔ ALLE: saved 5 ATR lookbacks
#
# Processing ALTR1...
# ✔ ALTR1: saved 5 ATR lookbacks
#
# Processing ALXN...
# ✔ ALXN: saved 5 ATR lookbacks
#
# Processing AM1...
# ✔ AM1: saved 5 ATR lookbacks
#
# Processing AMAT...
# ⚠ VALIDATION: AMAT | W=14 | ATR_spike_detected | max atr14=12.7574, median=0.5673
# ⚠ VALIDATION: AMAT | W=20 | ATR_spike_detected | max atr20=11.6588, median=0.5636
# ✔ AMAT: saved 5 ATR lookbacks
#
# Processing AMCC...
# ⚠ VALIDATION: AMCC | W=14 | ATR_spike_detected | max atr14=49.4732, median=0.5032
# ⚠ VALIDATION: AMCC | W=20 | ATR_spike_detected | max atr20=43.0093, median=0.5040
# ⚠ VALIDATION: AMCC | W=28 | ATR_spike_detected | max atr28=40.4442, median=0.5071
# ⚠ VALIDATION: AMCC | W=42 | ATR_spike_detected | max atr42=36.8691, median=0.5057
# ⚠ VALIDATION: AMCC | W=63 | ATR_spike_detected | max atr63=35.5357, median=0.5029
# ✔ AMCC: saved 5 ATR lookbacks
#
# Processing AMCR...
# ✔ AMCR: saved 5 ATR lookbacks
#
# Processing AMD...
# ⚠ VALIDATION: AMD | W=14 | ATR_spike_detected | max atr14=17.2440, median=0.5929
# ⚠ VALIDATION: AMD | W=20 | ATR_spike_detected | max atr20=15.2828, median=0.5950
# ⚠ VALIDATION: AMD | W=28 | ATR_spike_detected | max atr28=14.9117, median=0.5939
# ⚠ VALIDATION: AMD | W=42 | ATR_spike_detected | max atr42=14.5353, median=0.5865
# ⚠ VALIDATION: AMD | W=63 | ATR_spike_detected | max atr63=12.1445, median=0.6003
# ✔ AMD: saved 5 ATR lookbacks
#
# Processing AME...
# ✔ AME: saved 5 ATR lookbacks
#
# Processing AMG...
# ✔ AMG: saved 5 ATR lookbacks
#
# Processing AMGN...
# ✔ AMGN: saved 5 ATR lookbacks
#
# Processing AMP...
# ✔ AMP: saved 5 ATR lookbacks
#
# Processing AMP1...
# ✔ AMP1: saved 5 ATR lookbacks
#
# Processing AMT...
# ✔ AMT: saved 5 ATR lookbacks
#
# Processing AMTM...
# ✔ AMTM: saved 5 ATR lookbacks
#
# Processing AMZN...
# ⚠ VALIDATION: AMZN | W=14 | ATR_spike_detected | max atr14=12.3360, median=0.2950
# ⚠ VALIDATION: AMZN | W=20 | ATR_spike_detected | max atr20=10.9484, median=0.2979
# ⚠ VALIDATION: AMZN | W=28 | ATR_spike_detected | max atr28=9.5971, median=0.2958
# ⚠ VALIDATION: AMZN | W=42 | ATR_spike_detected | max atr42=8.9132, median=0.3000
# ⚠ VALIDATION: AMZN | W=63 | ATR_spike_detected | max atr63=7.9448, median=0.3030
# ✔ AMZN: saved 5 ATR lookbacks
#
# Processing AN...
# ✔ AN: saved 5 ATR lookbacks
#
# Processing AN1...
# ✔ AN1: saved 5 ATR lookbacks
#
# Processing ANDV...
# ✔ ANDV: saved 5 ATR lookbacks
#
# Processing ANDW...
# ✔ ANDW: saved 5 ATR lookbacks
#
# Processing ANET...
# ✔ ANET: saved 5 ATR lookbacks
#
# Processing ANF...
# ✔ ANF: saved 5 ATR lookbacks
#
# Processing ANRZQ...
# ✔ ANRZQ: saved 5 ATR lookbacks
#
# Processing ANSS...
# ✔ ANSS: saved 5 ATR lookbacks
#
# Processing ANV1...
# ✔ ANV1: saved 5 ATR lookbacks
#
# Processing AON...
# ✔ AON: saved 5 ATR lookbacks
#
# Processing AOS...
# ✔ AOS: saved 5 ATR lookbacks
#
# Processing APA...
# ✔ APA: saved 5 ATR lookbacks
#
# Processing APC...
# ✔ APC: saved 5 ATR lookbacks
#
# Processing APCC...
# ✔ APCC: saved 5 ATR lookbacks
#
# Processing APD...
# ✔ APD: saved 5 ATR lookbacks
#
# Processing APH...
# ⚠ VALIDATION: APH | W=14 | ATR_spike_detected | max atr14=5.2761, median=0.1404
# ⚠ VALIDATION: APH | W=20 | ATR_spike_detected | max atr20=4.9005, median=0.1397
# ⚠ VALIDATION: APH | W=28 | ATR_spike_detected | max atr28=4.8727, median=0.1397
# ⚠ VALIDATION: APH | W=42 | ATR_spike_detected | max atr42=4.6381, median=0.1403
# ⚠ VALIDATION: APH | W=63 | ATR_spike_detected | max atr63=4.2032, median=0.1412
# ✔ APH: saved 5 ATR lookbacks
#
# Processing APO...
# ✔ APO: saved 5 ATR lookbacks
#
# Processing APOL...
# ✔ APOL: saved 5 ATR lookbacks
#
# Processing APP...
# ✔ APP: saved 5 ATR lookbacks
#
# Processing APTV...
# ✔ APTV: saved 5 ATR lookbacks
#
# Processing AR1...
# ✔ AR1: saved 5 ATR lookbacks
#
# Processing ARC1...
# ✔ ARC1: saved 5 ATR lookbacks
#
# Processing ARE...
# ✔ ARE: saved 5 ATR lookbacks
#
# Processing ARES...
# ✔ ARES: saved 5 ATR lookbacks
#
# Processing ARG...
# ✔ ARG: saved 5 ATR lookbacks
#
# Processing AS1...
# ✔ AS1: saved 5 ATR lookbacks
#
# Processing ASC1...
# ✔ ASC1: saved 5 ATR lookbacks
#
# Processing ASH...
# ✔ ASH: saved 5 ATR lookbacks
#
# Processing ASN...
# ✔ ASN: saved 5 ATR lookbacks
#
# Processing ASND1...
# ✔ ASND1: saved 5 ATR lookbacks
#
# Processing ASO1...
# ✔ ASO1: saved 5 ATR lookbacks
#
# Processing AT1...
# ✔ AT1: saved 5 ATR lookbacks
#
# Processing ATGE...
# ✔ ATGE: saved 5 ATR lookbacks
#
# Processing ATI...
# ✔ ATI: saved 5 ATR lookbacks
#
# Processing ATI1...
# ✔ ATI1: saved 5 ATR lookbacks
#
# Processing ATO...
# ⚠ VALIDATION: ATO | W=14 | ATR_spike_detected | max atr14=8.9404, median=0.4248
# ✔ ATO: saved 5 ATR lookbacks
#
# Processing ATVI...
# ✔ ATVI: saved 5 ATR lookbacks
#
# Processing AV1...
# ✔ AV1: saved 5 ATR lookbacks
#
# Processing AVB...
# ✔ AVB: saved 5 ATR lookbacks
#
# Processing AVGO...
# ⚠ VALIDATION: AVGO | W=14 | ATR_spike_detected | max atr14=18.3800, median=0.4187
# ⚠ VALIDATION: AVGO | W=20 | ATR_spike_detected | max atr20=19.4468, median=0.4284
# ⚠ VALIDATION: AVGO | W=28 | ATR_spike_detected | max atr28=17.8968, median=0.4319
# ⚠ VALIDATION: AVGO | W=42 | ATR_spike_detected | max atr42=16.2420, median=0.4359
# ⚠ VALIDATION: AVGO | W=63 | ATR_spike_detected | max atr63=15.2197, median=0.4592
# ✔ AVGO: saved 5 ATR lookbacks
#
# Processing AVP...
# ✔ AVP: saved 5 ATR lookbacks
#
# Processing AVY...
# ✔ AVY: saved 5 ATR lookbacks
#
# Processing AW...
# ✔ AW: saved 5 ATR lookbacks
#
# Processing AWE...
# ✔ AWE: saved 5 ATR lookbacks
#
# Processing AWK...
# ✔ AWK: saved 5 ATR lookbacks
#
# Processing AXON...
# ⚠ VALIDATION: AXON | W=14 | ATR_spike_detected | max atr14=46.3161, median=0.7136
# ⚠ VALIDATION: AXON | W=20 | ATR_spike_detected | max atr20=41.4243, median=0.7272
# ⚠ VALIDATION: AXON | W=28 | ATR_spike_detected | max atr28=35.2311, median=0.7325
# ⚠ VALIDATION: AXON | W=42 | ATR_spike_detected | max atr42=34.4582, median=0.7342
# ⚠ VALIDATION: AXON | W=63 | ATR_spike_detected | max atr63=31.2603, median=0.7508
# ✔ AXON: saved 5 ATR lookbacks
#
# Processing AXP...
# ✔ AXP: saved 5 ATR lookbacks
#
# Processing AYE...
# ✔ AYE: saved 5 ATR lookbacks
#
# Processing AYI...
# ✔ AYI: saved 5 ATR lookbacks
#
# Processing AZA.A...
# ✔ AZA.A: saved 5 ATR lookbacks
#
# Processing AZO...
# ⚠ VALIDATION: AZO | W=14 | ATR_spike_detected | max atr14=126.5757, median=5.9100
# ✔ AZO: saved 5 ATR lookbacks
#
# Processing B...
# ✔ B: saved 5 ATR lookbacks
#
# Processing BA...
# ✔ BA: saved 5 ATR lookbacks
#
# Processing BAC...
# ✔ BAC: saved 5 ATR lookbacks
#
# Processing BAC1...
# ✔ BAC1: saved 5 ATR lookbacks
#
# Processing BALL...
# ⚠ VALIDATION: BALL | W=14 | ATR_spike_detected | max atr14=6.2566, median=0.3033
# ✔ BALL: saved 5 ATR lookbacks
#
# Processing BAX...
# ✔ BAX: saved 5 ATR lookbacks
#
# Processing BAY1...
# ✔ BAY1: saved 5 ATR lookbacks
#
# Processing BBBYQ...
# ✔ BBBYQ: saved 5 ATR lookbacks
#
# Processing BBI1...
# ⚠ VALIDATION: BBI1 | W=14 | insufficient_history | 7 rows (<14), last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=20 | insufficient_history | 7 rows (<20), last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=28 | insufficient_history | 7 rows (<28), last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=42 | insufficient_history | 7 rows (<42), last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=63 | insufficient_history | 7 rows (<63), last=1998-01-09
# ✔ BBI1: saved 5 ATR lookbacks
#
# Processing BBWI...
# ✔ BBWI: saved 5 ATR lookbacks
#
# Processing BBY...
# ✔ BBY: saved 5 ATR lookbacks
#
# Processing BC...
# ✔ BC: saved 5 ATR lookbacks
#
# Processing BCR...
# ✔ BCR: saved 5 ATR lookbacks
#
# Processing BDK...
# ✔ BDK: saved 5 ATR lookbacks
#
# Processing BDX...
# ✔ BDX: saved 5 ATR lookbacks
#
# Processing BEAM2...
# ✔ BEAM2: saved 5 ATR lookbacks
#
# Processing BEN...
# ✔ BEN: saved 5 ATR lookbacks
#
# Processing BF.B...
# ✔ BF.B: saved 5 ATR lookbacks
#
# Processing BFH...
# ✔ BFH: saved 5 ATR lookbacks
#
# Processing BFI1...
# ✔ BFI1: saved 5 ATR lookbacks
#
# Processing BFO1...
# ✔ BFO1: saved 5 ATR lookbacks
#
# Processing BG...
# ✔ BG: saved 5 ATR lookbacks
#
# Processing BGEN...
# ✔ BGEN: saved 5 ATR lookbacks
#
# Processing BGGSQ...
# ✔ BGGSQ: saved 5 ATR lookbacks
#
# Processing BHF...
# ✔ BHF: saved 5 ATR lookbacks
#
# Processing BHI...
# ✔ BHI: saved 5 ATR lookbacks
#
# Processing BHMSQ...
# ✔ BHMSQ: saved 5 ATR lookbacks
#
# Processing BIGGQ...
# ✔ BIGGQ: saved 5 ATR lookbacks
#
# Processing BIIB...
# ✔ BIIB: saved 5 ATR lookbacks
#
# Processing BIO...
# ✔ BIO: saved 5 ATR lookbacks
#
# Processing BJS...
# ✔ BJS: saved 5 ATR lookbacks
#
# Processing BK...
# ✔ BK: saved 5 ATR lookbacks
#
# Processing BKB...
# ✔ BKB: saved 5 ATR lookbacks
#
# Processing BKNG...
# ✔ BKNG: saved 5 ATR lookbacks
#
# Processing BKR...
# ✔ BKR: saved 5 ATR lookbacks
#
# Processing BLDR...
# ✔ BLDR: saved 5 ATR lookbacks
#
# Processing BLK...
# ✔ BLK: saved 5 ATR lookbacks
#
# Processing BLS...
# ✔ BLS: saved 5 ATR lookbacks
#
# Processing BMC...
# ✔ BMC: saved 5 ATR lookbacks
#
# Processing BMET...
# ✔ BMET: saved 5 ATR lookbacks
#
# Processing BMGCA...
# ✔ BMGCA: saved 5 ATR lookbacks
#
# Processing BMS...
# ✔ BMS: saved 5 ATR lookbacks
#
# Processing BMY...
# ✔ BMY: saved 5 ATR lookbacks
#
# Processing BNI...
# ✔ BNI: saved 5 ATR lookbacks
#
# Processing BNL1...
# ✔ BNL1: saved 5 ATR lookbacks
#
# Processing BOL...
# ✔ BOL: saved 5 ATR lookbacks
#
# Processing BR...
# ✔ BR: saved 5 ATR lookbacks
#
# Processing BR1...
# ✔ BR1: saved 5 ATR lookbacks
#
# Processing BRCM...
# ✔ BRCM: saved 5 ATR lookbacks
#
# Processing BRK.B...
# ✔ BRK.B: saved 5 ATR lookbacks
#
# Processing BRL...
# ✔ BRL: saved 5 ATR lookbacks
#
# Processing BRO...
# ✔ BRO: saved 5 ATR lookbacks
#
# Processing BSC1...
# ✔ BSC1: saved 5 ATR lookbacks
#
# Processing BSX...
# ✔ BSX: saved 5 ATR lookbacks
#
# Processing BT1...
# ✔ BT1: saved 5 ATR lookbacks
#
# Processing BTUUQ...
# ✔ BTUUQ: saved 5 ATR lookbacks
#
# Processing BUD1...
# ✔ BUD1: saved 5 ATR lookbacks
#
# Processing BVSN...
# ⚠ VALIDATION: BVSN | W=14 | ATR_spike_detected | max atr14=2140.0714, median=0.7857
# ⚠ VALIDATION: BVSN | W=20 | ATR_spike_detected | max atr20=1902.8250, median=0.7922
# ⚠ VALIDATION: BVSN | W=28 | ATR_spike_detected | max atr28=1927.8482, median=0.7980
# ⚠ VALIDATION: BVSN | W=42 | ATR_spike_detected | max atr42=1750.2679, median=0.8271
# ⚠ VALIDATION: BVSN | W=63 | ATR_spike_detected | max atr63=1528.7381, median=0.8989
# ✔ BVSN: saved 5 ATR lookbacks
#
# Processing BWA...
# ✔ BWA: saved 5 ATR lookbacks
#
# Processing BX...
# ⚠ VALIDATION: BX | W=14 | ATR_spike_detected | max atr14=10.2792, median=0.5030
# ✔ BX: saved 5 ATR lookbacks
#
# Processing BXLT...
# ✔ BXLT: saved 5 ATR lookbacks
#
# Processing BXP...
# ✔ BXP: saved 5 ATR lookbacks
#
# Processing C...
# ✔ C: saved 5 ATR lookbacks
#
# Processing C1...
# ✔ C1: saved 5 ATR lookbacks
#
# Processing CA1...
# ✔ CA1: saved 5 ATR lookbacks
#
# Processing CAG...
# ✔ CAG: saved 5 ATR lookbacks
#
# Processing CAH...
# ✔ CAH: saved 5 ATR lookbacks
#
# Processing CAL...
# ✔ CAL: saved 5 ATR lookbacks
#
# Processing CAM2...
# ✔ CAM2: saved 5 ATR lookbacks
#
# Processing CAR...
# ⚠ VALIDATION: CAR | W=14 | ATR_spike_detected | max atr14=49.7004, median=1.0434
# ⚠ VALIDATION: CAR | W=20 | ATR_spike_detected | max atr20=42.4667, median=1.0444
# ⚠ VALIDATION: CAR | W=28 | ATR_spike_detected | max atr28=36.1203, median=1.0522
# ⚠ VALIDATION: CAR | W=42 | ATR_spike_detected | max atr42=28.0145, median=1.0620
# ⚠ VALIDATION: CAR | W=63 | ATR_spike_detected | max atr63=22.0436, median=1.0459
# ✔ CAR: saved 5 ATR lookbacks
#
# Processing CARR...
# ✔ CARR: saved 5 ATR lookbacks
#
# Processing CAT...
# ✔ CAT: saved 5 ATR lookbacks
#
# Processing CB...
# ✔ CB: saved 5 ATR lookbacks
#
# Processing CB1...
# ✔ CB1: saved 5 ATR lookbacks
#
# Processing CBE...
# ✔ CBE: saved 5 ATR lookbacks
#
# Processing CBH1...
# ✔ CBH1: saved 5 ATR lookbacks
#
# Processing CBOE...
# ✔ CBOE: saved 5 ATR lookbacks
#
# Processing CBRE...
# ✔ CBRE: saved 5 ATR lookbacks
#
# Processing CBS1...
# ✔ CBS1: saved 5 ATR lookbacks
#
# Processing CBSS...
# ✔ CBSS: saved 5 ATR lookbacks
#
# Processing CCE1...
# ✔ CCE1: saved 5 ATR lookbacks
#
# Processing CCI...
# ✔ CCI: saved 5 ATR lookbacks
#
# Processing CCI1...
# ✔ CCI1: saved 5 ATR lookbacks
#
# Processing CCK...
# ✔ CCK: saved 5 ATR lookbacks
#
# Processing CCL...
# ✔ CCL: saved 5 ATR lookbacks
#
# Processing CCTYQ...
# ✔ CCTYQ: saved 5 ATR lookbacks
#
# Processing CCU1...
# ✔ CCU1: saved 5 ATR lookbacks
#
# Processing CDNS...
# ⚠ VALIDATION: CDNS | W=14 | ATR_spike_detected | max atr14=14.9787, median=0.5951
# ⚠ VALIDATION: CDNS | W=20 | ATR_spike_detected | max atr20=14.2393, median=0.5995
# ⚠ VALIDATION: CDNS | W=28 | ATR_spike_detected | max atr28=12.3877, median=0.5807
# ⚠ VALIDATION: CDNS | W=42 | ATR_spike_detected | max atr42=11.3805, median=0.5647
# ⚠ VALIDATION: CDNS | W=63 | ATR_spike_detected | max atr63=11.0993, median=0.5407
# ✔ CDNS: saved 5 ATR lookbacks
#
# Processing CDW...
# ✔ CDW: saved 5 ATR lookbacks
#
# Processing CE...
# ✔ CE: saved 5 ATR lookbacks
#
# Processing CE1...
# ✔ CE1: saved 5 ATR lookbacks
#
# Processing CEG...
# ✔ CEG: saved 5 ATR lookbacks
#
# Processing CEG1...
# ✔ CEG1: saved 5 ATR lookbacks
#
# Processing CELG...
# ✔ CELG: saved 5 ATR lookbacks
#
# Processing CEM1...
# ✔ CEM1: saved 5 ATR lookbacks
#
# Processing CEN1...
# ✔ CEN1: saved 5 ATR lookbacks
#
# Processing CEPH...
# ✔ CEPH: saved 5 ATR lookbacks
#
# Processing CERN...
# ✔ CERN: saved 5 ATR lookbacks
#
# Processing CF...
# ✔ CF: saved 5 ATR lookbacks
#
# Processing CF1...
# ✔ CF1: saved 5 ATR lookbacks
#
# Processing CFC...
# ✔ CFC: saved 5 ATR lookbacks
#
# Processing CFG...
# ✔ CFG: saved 5 ATR lookbacks
#
# Processing CFL1...
# ✔ CFL1: saved 5 ATR lookbacks
#
# Processing CFN...
# ✔ CFN: saved 5 ATR lookbacks
#
# Processing CG1...
# ✔ CG1: saved 5 ATR lookbacks
#
# Processing CGP...
# ✔ CGP: saved 5 ATR lookbacks
#
# Processing CHA1...
# ✔ CHA1: saved 5 ATR lookbacks
#
# Processing CHD...
# ✔ CHD: saved 5 ATR lookbacks
#
# Processing CHIR1...
# ✔ CHIR1: saved 5 ATR lookbacks
#
# Processing CHKAQ...
# ✔ CHKAQ: saved 5 ATR lookbacks
#
# Processing CHRS1...
# ✔ CHRS1: saved 5 ATR lookbacks
#
# Processing CHRW...
# ✔ CHRW: saved 5 ATR lookbacks
#
# Processing CHTR...
# ✔ CHTR: saved 5 ATR lookbacks
#
# Processing CI...
# ✔ CI: saved 5 ATR lookbacks
#
# Processing CIEN...
# ⚠ VALIDATION: CIEN | W=14 | ATR_spike_detected | max atr14=118.2350, median=1.1650
# ⚠ VALIDATION: CIEN | W=20 | ATR_spike_detected | max atr20=106.5855, median=1.1792
# ⚠ VALIDATION: CIEN | W=28 | ATR_spike_detected | max atr28=100.4425, median=1.1798
# ⚠ VALIDATION: CIEN | W=42 | ATR_spike_detected | max atr42=93.6900, median=1.1867
# ⚠ VALIDATION: CIEN | W=63 | ATR_spike_detected | max atr63=92.0400, median=1.1800
# ✔ CIEN: saved 5 ATR lookbacks
#
# Processing CIN...
# ✔ CIN: saved 5 ATR lookbacks
#
# Processing CINF...
# ✔ CINF: saved 5 ATR lookbacks
#
# Processing CIT.A...
# ✔ CIT.A: saved 5 ATR lookbacks
#
# Processing CITGQ...
# ✔ CITGQ: saved 5 ATR lookbacks
#
# Processing CL...
# ✔ CL: saved 5 ATR lookbacks
#
# Processing CLF...
# ✔ CLF: saved 5 ATR lookbacks
#
# Processing CLX...
# ✔ CLX: saved 5 ATR lookbacks
#
# Processing CMA...
# ✔ CMA: saved 5 ATR lookbacks
#
# Processing CMCSA...
# ✔ CMCSA: saved 5 ATR lookbacks
#
# Processing CMCSK...
# ✔ CMCSK: saved 5 ATR lookbacks
#
# Processing CME...
# ✔ CME: saved 5 ATR lookbacks
#
# Processing CMG...
# ✔ CMG: saved 5 ATR lookbacks
#
# Processing CMI...
# ✔ CMI: saved 5 ATR lookbacks
#
# Processing CMS...
# ✔ CMS: saved 5 ATR lookbacks
#
# Processing CMVT...
# ✔ CMVT: saved 5 ATR lookbacks
#
# Processing CMX...
# ✔ CMX: saved 5 ATR lookbacks
#
# Processing CNC...
# ✔ CNC: saved 5 ATR lookbacks
#
# Processing CNCEQ...
# ✔ CNCEQ: saved 5 ATR lookbacks
#
# Processing CNG...
# ✔ CNG: saved 5 ATR lookbacks
#
# Processing CNP...
# ✔ CNP: saved 5 ATR lookbacks
#
# Processing CNW...
# ✔ CNW: saved 5 ATR lookbacks
#
# Processing CNX...
# ✔ CNX: saved 5 ATR lookbacks
#
# Processing CNXT1...
# ⚠ VALIDATION: CNXT1 | W=14 | ATR_spike_detected | max atr14=47.6474, median=1.1714
# ⚠ VALIDATION: CNXT1 | W=20 | ATR_spike_detected | max atr20=42.5954, median=1.1800
# ⚠ VALIDATION: CNXT1 | W=28 | ATR_spike_detected | max atr28=38.7515, median=1.1679
# ⚠ VALIDATION: CNXT1 | W=42 | ATR_spike_detected | max atr42=35.6205, median=1.1905
# ⚠ VALIDATION: CNXT1 | W=63 | ATR_spike_detected | max atr63=33.1588, median=1.2319
# ✔ CNXT1: saved 5 ATR lookbacks
#
# Processing COC...
# ✔ COC: saved 5 ATR lookbacks
#
# Processing COF...
# ✔ COF: saved 5 ATR lookbacks
#
# Processing COIN...
# ✔ COIN: saved 5 ATR lookbacks
#
# Processing COL...
# ✔ COL: saved 5 ATR lookbacks
#
# Processing COMS1...
# ✔ COMS1: saved 5 ATR lookbacks
#
# Processing COO...
# ✔ COO: saved 5 ATR lookbacks
#
# Processing COP...
# ✔ COP: saved 5 ATR lookbacks
#
# Processing COR...
# ✔ COR: saved 5 ATR lookbacks
#
# Processing COST...
# ⚠ VALIDATION: COST | W=14 | ATR_spike_detected | max atr14=40.6228, median=1.2467
# ⚠ VALIDATION: COST | W=20 | ATR_spike_detected | max atr20=36.3887, median=1.2439
# ⚠ VALIDATION: COST | W=28 | ATR_spike_detected | max atr28=32.9987, median=1.2565
# ⚠ VALIDATION: COST | W=42 | ATR_spike_detected | max atr42=30.7042, median=1.2688
# ⚠ VALIDATION: COST | W=63 | ATR_spike_detected | max atr63=26.9956, median=1.2688
# ✔ COST: saved 5 ATR lookbacks
#
# Processing COT1...
# ✔ COT1: saved 5 ATR lookbacks
#
# Processing COTY...
# ✔ COTY: saved 5 ATR lookbacks
#
# Processing COV...
# ✔ COV: saved 5 ATR lookbacks
#
# Processing CPAY...
# ✔ CPAY: saved 5 ATR lookbacks
#
# Processing CPB...
# ✔ CPB: saved 5 ATR lookbacks
#
# Processing CPGX...
# ✔ CPGX: saved 5 ATR lookbacks
#
# Processing CPNLQ...
# ✔ CPNLQ: saved 5 ATR lookbacks
#
# Processing CPPRQ...
# ✔ CPPRQ: saved 5 ATR lookbacks
#
# Processing CPQ...
# ✔ CPQ: saved 5 ATR lookbacks
#
# Processing CPRI...
# ✔ CPRI: saved 5 ATR lookbacks
#
# Processing CPRT...
# ⚠ VALIDATION: CPRT | W=14 | ATR_spike_detected | max atr14=2.1880, median=0.0701
# ⚠ VALIDATION: CPRT | W=20 | ATR_spike_detected | max atr20=2.0343, median=0.0704
# ⚠ VALIDATION: CPRT | W=28 | ATR_spike_detected | max atr28=1.8036, median=0.0702
# ⚠ VALIDATION: CPRT | W=42 | ATR_spike_detected | max atr42=1.6950, median=0.0709
# ⚠ VALIDATION: CPRT | W=63 | ATR_spike_detected | max atr63=1.5163, median=0.0709
# ✔ CPRT: saved 5 ATR lookbacks
#
# Processing CPT...
# ✔ CPT: saved 5 ATR lookbacks
#
# Processing CPWR...
# ✔ CPWR: saved 5 ATR lookbacks
#
# Processing CRH...
# ✔ CRH: saved 5 ATR lookbacks
#
# Processing CRL...
# ✔ CRL: saved 5 ATR lookbacks
#
# Processing CRM...
# ✔ CRM: saved 5 ATR lookbacks
#
# Processing CRWD...
# ✔ CRWD: saved 5 ATR lookbacks
#
# Processing CSC...
# ✔ CSC: saved 5 ATR lookbacks
#
# Processing CSCO...
# ✔ CSCO: saved 5 ATR lookbacks
#
# Processing CSE1...
# ✔ CSE1: saved 5 ATR lookbacks
#
# Processing CSGP...
# ⚠ VALIDATION: CSGP | W=14 | ATR_spike_detected | max atr14=5.2544, median=0.2260
# ⚠ VALIDATION: CSGP | W=20 | ATR_spike_detected | max atr20=4.8813, median=0.2247
# ⚠ VALIDATION: CSGP | W=28 | ATR_spike_detected | max atr28=4.5243, median=0.2245
# ✔ CSGP: saved 5 ATR lookbacks
#
# Processing CSR1...
# ✔ CSR1: saved 5 ATR lookbacks
#
# Processing CSRA...
# ✔ CSRA: saved 5 ATR lookbacks
#
# Processing CSX...
# ✔ CSX: saved 5 ATR lookbacks
#
# Processing CTAS...
# ⚠ VALIDATION: CTAS | W=14 | ATR_spike_detected | max atr14=8.4456, median=0.2889
# ⚠ VALIDATION: CTAS | W=20 | ATR_spike_detected | max atr20=7.4886, median=0.2931
# ⚠ VALIDATION: CTAS | W=28 | ATR_spike_detected | max atr28=6.5446, median=0.2966
# ✔ CTAS: saved 5 ATR lookbacks
#
# Processing CTB...
# ✔ CTB: saved 5 ATR lookbacks
#
# Processing CTLT...
# ✔ CTLT: saved 5 ATR lookbacks
#
# Processing CTRA...
# ✔ CTRA: saved 5 ATR lookbacks
#
# Processing CTSH...
# ✔ CTSH: saved 5 ATR lookbacks
#
# Processing CTVA...
# ✔ CTVA: saved 5 ATR lookbacks
#
# Processing CTX1...
# ✔ CTX1: saved 5 ATR lookbacks
#
# Processing CTXS...
# ✔ CTXS: saved 5 ATR lookbacks
#
# Processing CVC...
# ✔ CVC: saved 5 ATR lookbacks
#
# Processing CVG...
# ✔ CVG: saved 5 ATR lookbacks
#
# Processing CVGYQ...
# ✔ CVGYQ: saved 5 ATR lookbacks
#
# Processing CVH...
# ✔ CVH: saved 5 ATR lookbacks
#
# Processing CVNA...
# ✔ CVNA: saved 5 ATR lookbacks
#
# Processing CVS...
# ✔ CVS: saved 5 ATR lookbacks
#
# Processing CVX...
# ✔ CVX: saved 5 ATR lookbacks
#
# Processing CXO...
# ✔ CXO: saved 5 ATR lookbacks
#
# Processing CXT...
# ✔ CXT: saved 5 ATR lookbacks
#
# Processing CYM...
# ✔ CYM: saved 5 ATR lookbacks
#
# Processing CZR...
# ✔ CZR: saved 5 ATR lookbacks
#
# Processing D...
# ✔ D: saved 5 ATR lookbacks
#
# Processing DAL...
# ✔ DAL: saved 5 ATR lookbacks
#
# Processing DALRQ...
# ✔ DALRQ: saved 5 ATR lookbacks
#
# Processing DASH...
# ✔ DASH: saved 5 ATR lookbacks
#
# Processing DAY...
# ✔ DAY: saved 5 ATR lookbacks
#
# Processing DCNAQ...
# ✔ DCNAQ: saved 5 ATR lookbacks
#
# Processing DD...
# ✔ DD: saved 5 ATR lookbacks
#
# Processing DD1...
# ✔ DD1: saved 5 ATR lookbacks
#
# Processing DDOG...
# ✔ DDOG: saved 5 ATR lookbacks
#
# Processing DDS...
# ⚠ VALIDATION: DDS | W=14 | ATR_spike_detected | max atr14=36.0811, median=1.1347
# ⚠ VALIDATION: DDS | W=20 | ATR_spike_detected | max atr20=33.1412, median=1.1574
# ⚠ VALIDATION: DDS | W=28 | ATR_spike_detected | max atr28=32.8207, median=1.1724
# ⚠ VALIDATION: DDS | W=42 | ATR_spike_detected | max atr42=28.0439, median=1.1802
# ⚠ VALIDATION: DDS | W=63 | ATR_spike_detected | max atr63=25.6560, median=1.1874
# ✔ DDS: saved 5 ATR lookbacks
#
# Processing DE...
# ✔ DE: saved 5 ATR lookbacks
#
# Processing DEC1...
# ✔ DEC1: saved 5 ATR lookbacks
#
# Processing DECK...
# ⚠ VALIDATION: DECK | W=14 | ATR_spike_detected | max atr14=9.2286, median=0.3120
# ⚠ VALIDATION: DECK | W=20 | ATR_spike_detected | max atr20=8.4683, median=0.3176
# ⚠ VALIDATION: DECK | W=28 | ATR_spike_detected | max atr28=7.5598, median=0.3191
# ⚠ VALIDATION: DECK | W=42 | ATR_spike_detected | max atr42=7.0471, median=0.3213
# ⚠ VALIDATION: DECK | W=63 | ATR_spike_detected | max atr63=7.1633, median=0.3251
# ✔ DECK: saved 5 ATR lookbacks
#
# Processing DELL...
# ✔ DELL: saved 5 ATR lookbacks
#
# Processing DELL1...
# ✔ DELL1: saved 5 ATR lookbacks
#
# Processing DFODQ...
# ✔ DFODQ: saved 5 ATR lookbacks
#
# Processing DFS...
# ✔ DFS: saved 5 ATR lookbacks
#
# Processing DG...
# ✔ DG: saved 5 ATR lookbacks
#
# Processing DG1...
# ✔ DG1: saved 5 ATR lookbacks
#
# Processing DGN...
# ✔ DGN: saved 5 ATR lookbacks
#
# Processing DGX...
# ✔ DGX: saved 5 ATR lookbacks
#
# Processing DHI...
# ✔ DHI: saved 5 ATR lookbacks
#
# Processing DHR...
# ✔ DHR: saved 5 ATR lookbacks
#
# Processing DI1...
# ✔ DI1: saved 5 ATR lookbacks
#
# Processing DIGI2...
# ✔ DIGI2: saved 5 ATR lookbacks
#
# Processing DINO...
# ✔ DINO: saved 5 ATR lookbacks
#
# Processing DIS...
# ✔ DIS: saved 5 ATR lookbacks
#
# Processing DISCK...
# ✔ DISCK: saved 5 ATR lookbacks
#
# Processing DISH...
# ✔ DISH: saved 5 ATR lookbacks
#
# Processing DJ...
# ✔ DJ: saved 5 ATR lookbacks
#
# Processing DLR...
# ✔ DLR: saved 5 ATR lookbacks
#
# Processing DLTR...
# ✔ DLTR: saved 5 ATR lookbacks
#
# Processing DLX...
# ✔ DLX: saved 5 ATR lookbacks
#
# Processing DNB1...
# ✔ DNB1: saved 5 ATR lookbacks
#
# Processing DNB2...
# ✔ DNB2: saved 5 ATR lookbacks
#
# Processing DNB3...
# ✔ DNB3: saved 5 ATR lookbacks
#
# Processing DNRCQ...
# ✔ DNRCQ: saved 5 ATR lookbacks
#
# Processing DOC...
# ✔ DOC: saved 5 ATR lookbacks
#
# Processing DOFSQ...
# ✔ DOFSQ: saved 5 ATR lookbacks
#
# Processing DOV...
# ✔ DOV: saved 5 ATR lookbacks
#
# Processing DOW...
# ✔ DOW: saved 5 ATR lookbacks
#
# Processing DPHIQ...
# ✔ DPHIQ: saved 5 ATR lookbacks
#
# Processing DPZ...
# ✔ DPZ: saved 5 ATR lookbacks
#
# Processing DRE...
# ✔ DRE: saved 5 ATR lookbacks
#
# Processing DRI...
# ✔ DRI: saved 5 ATR lookbacks
#
# Processing DTE...
# ✔ DTE: saved 5 ATR lookbacks
#
# Processing DTV1...
# ✔ DTV1: saved 5 ATR lookbacks
#
# Processing DUK...
# ✔ DUK: saved 5 ATR lookbacks
#
# Processing DVA...
# ✔ DVA: saved 5 ATR lookbacks
#
# Processing DVN...
# ✔ DVN: saved 5 ATR lookbacks
#
# Processing DXC...
# ✔ DXC: saved 5 ATR lookbacks
#
# Processing DXCM...
# ✔ DXCM: saved 5 ATR lookbacks
#
# Processing DYNIQ...
# ✔ DYNIQ: saved 5 ATR lookbacks
#
# Processing EA...
# ✔ EA: saved 5 ATR lookbacks
#
# Processing EBAY...
# ✔ EBAY: saved 5 ATR lookbacks
#
# Processing EC1...
# ✔ EC1: saved 5 ATR lookbacks
#
# Processing ECH1...
# ✔ ECH1: saved 5 ATR lookbacks
#
# Processing ECL...
# ✔ ECL: saved 5 ATR lookbacks
#
# Processing ECO1...
# ✔ ECO1: saved 5 ATR lookbacks
#
# Processing ED...
# ✔ ED: saved 5 ATR lookbacks
#
# Processing EDS...
# ✔ EDS: saved 5 ATR lookbacks
#
# Processing EFU1...
# ✔ EFU1: saved 5 ATR lookbacks
#
# Processing EFX...
# ✔ EFX: saved 5 ATR lookbacks
#
# Processing EG...
# ✔ EG: saved 5 ATR lookbacks
#
# Processing EHC...
# ✔ EHC: saved 5 ATR lookbacks
#
# Processing EIX...
# ✔ EIX: saved 5 ATR lookbacks
#
# Processing EKDKQ...
# ✔ EKDKQ: saved 5 ATR lookbacks
#
# Processing EL...
# ✔ EL: saved 5 ATR lookbacks
#
# Processing ELV...
# ✔ ELV: saved 5 ATR lookbacks
#
# Processing EMC1...
# ✔ EMC1: saved 5 ATR lookbacks
#
# Processing EME...
# ⚠ VALIDATION: EME | W=14 | ATR_spike_detected | max atr14=35.9571, median=0.8439
# ⚠ VALIDATION: EME | W=20 | ATR_spike_detected | max atr20=31.7055, median=0.8376
# ⚠ VALIDATION: EME | W=28 | ATR_spike_detected | max atr28=29.6811, median=0.8392
# ⚠ VALIDATION: EME | W=42 | ATR_spike_detected | max atr42=26.6249, median=0.8300
# ⚠ VALIDATION: EME | W=63 | ATR_spike_detected | max atr63=24.3588, median=0.8285
# ✔ EME: saved 5 ATR lookbacks
#
# Processing EMN...
# ✔ EMN: saved 5 ATR lookbacks
#
# Processing EMR...
# ✔ EMR: saved 5 ATR lookbacks
#
# Processing ENDPQ...
# ✔ ENDPQ: saved 5 ATR lookbacks
#
# Processing ENPH...
# ⚠ VALIDATION: ENPH | W=14 | ATR_spike_detected | max atr14=21.3145, median=0.8479
# ⚠ VALIDATION: ENPH | W=20 | ATR_spike_detected | max atr20=19.8885, median=0.8397
# ⚠ VALIDATION: ENPH | W=28 | ATR_spike_detected | max atr28=18.5109, median=0.8418
# ⚠ VALIDATION: ENPH | W=42 | ATR_spike_detected | max atr42=18.1080, median=0.8423
# ⚠ VALIDATION: ENPH | W=63 | ATR_spike_detected | max atr63=17.3240, median=0.8554
# ✔ ENPH: saved 5 ATR lookbacks
#
# Processing ENRNQ...
# ✔ ENRNQ: saved 5 ATR lookbacks
#
# Processing EOG...
# ✔ EOG: saved 5 ATR lookbacks
#
# Processing EOP...
# ✔ EOP: saved 5 ATR lookbacks
#
# Processing EP1...
# ✔ EP1: saved 5 ATR lookbacks
#
# Processing EPAM...
# ✔ EPAM: saved 5 ATR lookbacks
#
# Processing EQ1...
# ✔ EQ1: saved 5 ATR lookbacks
#
# Processing EQIX...
# ✔ EQIX: saved 5 ATR lookbacks
#
# Processing EQR...
# ✔ EQR: saved 5 ATR lookbacks
#
# Processing EQT...
# ✔ EQT: saved 5 ATR lookbacks
#
# Processing ERIE...
# ⚠ VALIDATION: ERIE | W=14 | ATR_spike_detected | max atr14=21.0689, median=0.8646
# ⚠ VALIDATION: ERIE | W=20 | ATR_spike_detected | max atr20=18.2917, median=0.8880
# ✔ ERIE: saved 5 ATR lookbacks
#
# Processing ES...
# ⚠ VALIDATION: ES | W=14 | ATR_spike_detected | max atr14=7.6312, median=0.3732
# ✔ ES: saved 5 ATR lookbacks
#
# Processing ESRX...
# ✔ ESRX: saved 5 ATR lookbacks
#
# Processing ESS...
# ✔ ESS: saved 5 ATR lookbacks
#
# Processing ETFC...
# ⚠ VALIDATION: ETFC | W=14 | ATR_spike_detected | max atr14=91.8000, median=1.6932
# ⚠ VALIDATION: ETFC | W=20 | ATR_spike_detected | max atr20=82.2666, median=1.7215
# ⚠ VALIDATION: ETFC | W=28 | ATR_spike_detected | max atr28=72.0054, median=1.7431
# ⚠ VALIDATION: ETFC | W=42 | ATR_spike_detected | max atr42=62.4688, median=1.7799
# ⚠ VALIDATION: ETFC | W=63 | ATR_spike_detected | max atr63=52.2421, median=1.8783
# ✔ ETFC: saved 5 ATR lookbacks
#
# Processing ETN...
# ⚠ VALIDATION: ETN | W=14 | ATR_spike_detected | max atr14=18.0638, median=0.7930
# ✔ ETN: saved 5 ATR lookbacks
#
# Processing ETR...
# ✔ ETR: saved 5 ATR lookbacks
#
# Processing ETS1...
# ✔ ETS1: saved 5 ATR lookbacks
#
# Processing ETSY...
# ✔ ETSY: saved 5 ATR lookbacks
#
# Processing EVHC...
# ✔ EVHC: saved 5 ATR lookbacks
#
# Processing EVRG...
# ✔ EVRG: saved 5 ATR lookbacks
#
# Processing EW...
# ✔ EW: saved 5 ATR lookbacks
#
# Processing EXC...
# ✔ EXC: saved 5 ATR lookbacks
#
# Processing EXE...
# ✔ EXE: saved 5 ATR lookbacks
#
# Processing EXPD...
# ✔ EXPD: saved 5 ATR lookbacks
#
# Processing EXPE...
# ✔ EXPE: saved 5 ATR lookbacks
#
# Processing EXR...
# ✔ EXR: saved 5 ATR lookbacks
#
# Processing F...
# ✔ F: saved 5 ATR lookbacks
#
# Processing FANG...
# ✔ FANG: saved 5 ATR lookbacks
#
# Processing FAST...
# ✔ FAST: saved 5 ATR lookbacks
#
# Processing FBF...
# ✔ FBF: saved 5 ATR lookbacks
#
# Processing FBIN...
# ✔ FBIN: saved 5 ATR lookbacks
#
# Processing FCN1...
# ✔ FCN1: saved 5 ATR lookbacks
#
# Processing FCX...
# ✔ FCX: saved 5 ATR lookbacks
#
# Processing FDC1...
# ✔ FDC1: saved 5 ATR lookbacks
#
# Processing FDO...
# ✔ FDO: saved 5 ATR lookbacks
#
# Processing FDS...
# ✔ FDS: saved 5 ATR lookbacks
#
# Processing FDX...
# ✔ FDX: saved 5 ATR lookbacks
#
# Processing FE...
# ✔ FE: saved 5 ATR lookbacks
#
# Processing FFIV...
# ✔ FFIV: saved 5 ATR lookbacks
#
# Processing FG1...
# ✔ FG1: saved 5 ATR lookbacks
#
# Processing FHI...
# ✔ FHI: saved 5 ATR lookbacks
#
# Processing FHN...
# ✔ FHN: saved 5 ATR lookbacks
#
# Processing FICO...
# ⚠ VALIDATION: FICO | W=14 | ATR_spike_detected | max atr14=119.1275, median=1.0470
# ⚠ VALIDATION: FICO | W=20 | ATR_spike_detected | max atr20=103.1373, median=1.0496
# ⚠ VALIDATION: FICO | W=28 | ATR_spike_detected | max atr28=92.4966, median=1.0495
# ⚠ VALIDATION: FICO | W=42 | ATR_spike_detected | max atr42=92.9180, median=1.0263
# ⚠ VALIDATION: FICO | W=63 | ATR_spike_detected | max atr63=84.2355, median=1.0012
# ✔ FICO: saved 5 ATR lookbacks
#
# Processing FIS...
# ✔ FIS: saved 5 ATR lookbacks
#
# Processing FISV...
# ⚠ VALIDATION: FISV | W=14 | ATR_spike_detected | max atr14=12.6124, median=0.3869
# ⚠ VALIDATION: FISV | W=20 | ATR_spike_detected | max atr20=10.8578, median=0.3876
# ⚠ VALIDATION: FISV | W=28 | ATR_spike_detected | max atr28=9.1890, median=0.3896
# ⚠ VALIDATION: FISV | W=42 | ATR_spike_detected | max atr42=8.2381, median=0.3915
# ✔ FISV: saved 5 ATR lookbacks
#
# Processing FITB...
# ✔ FITB: saved 5 ATR lookbacks
#
# Processing FIX...
# ⚠ VALIDATION: FIX | W=14 | ATR_spike_detected | max atr14=53.4826, median=0.4522
# ⚠ VALIDATION: FIX | W=20 | ATR_spike_detected | max atr20=53.8013, median=0.4537
# ⚠ VALIDATION: FIX | W=28 | ATR_spike_detected | max atr28=51.4395, median=0.4549
# ⚠ VALIDATION: FIX | W=42 | ATR_spike_detected | max atr42=51.3455, median=0.4505
# ⚠ VALIDATION: FIX | W=63 | ATR_spike_detected | max atr63=44.4808, median=0.4481
# ✔ FIX: saved 5 ATR lookbacks
#
# Processing FJ...
# ✔ FJ: saved 5 ATR lookbacks
#
# Processing FL...
# ✔ FL: saved 5 ATR lookbacks
#
# Processing FLIR...
# ✔ FLIR: saved 5 ATR lookbacks
#
# Processing FLMIQ...
# ✔ FLMIQ: saved 5 ATR lookbacks
#
# Processing FLR...
# ✔ FLR: saved 5 ATR lookbacks
#
# Processing FLS...
# ✔ FLS: saved 5 ATR lookbacks
#
# Processing FLTWQ...
# ✔ FLTWQ: saved 5 ATR lookbacks
#
# Processing FMC...
# ✔ FMC: saved 5 ATR lookbacks
#
# Processing FMCC...
# ⚠ VALIDATION: FMCC | W=14 | ATR_spike_detected | max atr14=3.9406, median=0.1579
# ⚠ VALIDATION: FMCC | W=20 | ATR_spike_detected | max atr20=3.7687, median=0.1560
# ⚠ VALIDATION: FMCC | W=28 | ATR_spike_detected | max atr28=3.4459, median=0.1546
# ✔ FMCC: saved 5 ATR lookbacks
#
# Processing FMY1...
# ✔ FMY1: saved 5 ATR lookbacks
#
# Processing FNMA...
# ⚠ VALIDATION: FNMA | W=14 | ATR_spike_detected | max atr14=4.6817, median=0.1693
# ⚠ VALIDATION: FNMA | W=20 | ATR_spike_detected | max atr20=4.2678, median=0.1675
# ⚠ VALIDATION: FNMA | W=28 | ATR_spike_detected | max atr28=4.0095, median=0.1661
# ⚠ VALIDATION: FNMA | W=42 | ATR_spike_detected | max atr42=3.5640, median=0.1667
# ✔ FNMA: saved 5 ATR lookbacks
#
# Processing FOSL...
# ✔ FOSL: saved 5 ATR lookbacks
#
# Processing FOX...
# ✔ FOX: saved 5 ATR lookbacks
#
# Processing FOXA...
# ✔ FOXA: saved 5 ATR lookbacks
#
# Processing FPC...
# ✔ FPC: saved 5 ATR lookbacks
#
# Processing FRCB...
# ✔ FRCB: saved 5 ATR lookbacks
#
# Processing FRO1...
# ✔ FRO1: saved 5 ATR lookbacks
#
# Processing FRT...
# ✔ FRT: saved 5 ATR lookbacks
#
# Processing FRX1...
# ✔ FRX1: saved 5 ATR lookbacks
#
# Processing FSH...
# ✔ FSH: saved 5 ATR lookbacks
#
# Processing FSL.B...
# ✔ FSL.B: saved 5 ATR lookbacks
#
# Processing FSLR...
# ✔ FSLR: saved 5 ATR lookbacks
#
# Processing FTI...
# ✔ FTI: saved 5 ATR lookbacks
#
# Processing FTI1...
# ✔ FTI1: saved 5 ATR lookbacks
#
# Processing FTL.A...
# ✔ FTL.A: saved 5 ATR lookbacks
#
# Processing FTNT...
# ⚠ VALIDATION: FTNT | W=14 | ATR_spike_detected | max atr14=5.5850, median=0.2726
# ✔ FTNT: saved 5 ATR lookbacks
#
# Processing FTRCQ...
# ✔ FTRCQ: saved 5 ATR lookbacks
#
# Processing FTV...
# ✔ FTV: saved 5 ATR lookbacks
#
# Processing FWLT...
# ✔ FWLT: saved 5 ATR lookbacks
#
# Processing G1...
# ✔ G1: saved 5 ATR lookbacks
#
# Processing GAP...
# ✔ GAP: saved 5 ATR lookbacks
#
# Processing GAPTQ...
# ✔ GAPTQ: saved 5 ATR lookbacks
#
# Processing GAS...
# ✔ GAS: saved 5 ATR lookbacks
#
# Processing GAS1...
# ✔ GAS1: saved 5 ATR lookbacks
#
# Processing GD...
# ✔ GD: saved 5 ATR lookbacks
#
# Processing GDDY...
# ✔ GDDY: saved 5 ATR lookbacks
#
# Processing GDT...
# ✔ GDT: saved 5 ATR lookbacks
#
# Processing GDW...
# ✔ GDW: saved 5 ATR lookbacks
#
# Processing GE...
# ✔ GE: saved 5 ATR lookbacks
#
# Processing GEHC...
# ✔ GEHC: saved 5 ATR lookbacks
#
# Processing GEN...
# ✔ GEN: saved 5 ATR lookbacks
#
# Processing GEN1...
# ✔ GEN1: saved 5 ATR lookbacks
#
# Processing GENZ...
# ✔ GENZ: saved 5 ATR lookbacks
#
# Processing GEV...
# ✔ GEV: saved 5 ATR lookbacks
#
# Processing GFS.A...
# ✔ GFS.A: saved 5 ATR lookbacks
#
# Processing GGP...
# ✔ GGP: saved 5 ATR lookbacks
#
# Processing GHC...
# ✔ GHC: saved 5 ATR lookbacks
#
# Processing GIC1...
# ✔ GIC1: saved 5 ATR lookbacks
#
# Processing GILD...
# ✔ GILD: saved 5 ATR lookbacks
#
# Processing GIS...
# ✔ GIS: saved 5 ATR lookbacks
#
# Processing GL...
# ✔ GL: saved 5 ATR lookbacks
#
# Processing GLK1...
# ✔ GLK1: saved 5 ATR lookbacks
#
# Processing GLW...
# ✔ GLW: saved 5 ATR lookbacks
#
# Processing GM...
# ✔ GM: saved 5 ATR lookbacks
#
# Processing GMCR...
# ⚠ VALIDATION: GMCR | W=14 | ATR_spike_detected | max atr14=7.8483, median=0.1683
# ⚠ VALIDATION: GMCR | W=20 | ATR_spike_detected | max atr20=7.9099, median=0.1645
# ⚠ VALIDATION: GMCR | W=28 | ATR_spike_detected | max atr28=7.1042, median=0.1631
# ⚠ VALIDATION: GMCR | W=42 | ATR_spike_detected | max atr42=6.9308, median=0.1673
# ⚠ VALIDATION: GMCR | W=63 | ATR_spike_detected | max atr63=6.5206, median=0.1604
# ✔ GMCR: saved 5 ATR lookbacks
#
# Processing GME...
# ⚠ VALIDATION: GME | W=14 | ATR_spike_detected | max atr14=25.8601, median=0.1604
# ⚠ VALIDATION: GME | W=20 | ATR_spike_detected | max atr20=18.8521, median=0.1584
# ⚠ VALIDATION: GME | W=28 | ATR_spike_detected | max atr28=15.7843, median=0.1563
# ⚠ VALIDATION: GME | W=42 | ATR_spike_detected | max atr42=14.9480, median=0.1541
# ⚠ VALIDATION: GME | W=63 | ATR_spike_detected | max atr63=11.8161, median=0.1493
# ✔ GME: saved 5 ATR lookbacks
#
# Processing GNRC...
# ✔ GNRC: saved 5 ATR lookbacks
#
# Processing GNT1...
# ✔ GNT1: saved 5 ATR lookbacks
#
# Processing GNW...
# ✔ GNW: saved 5 ATR lookbacks
#
# Processing GOOG...
# ✔ GOOG: saved 5 ATR lookbacks
#
# Processing GOOGL...
# ⚠ VALIDATION: GOOGL | W=14 | ATR_spike_detected | max atr14=12.2057, median=0.5385
# ⚠ VALIDATION: GOOGL | W=20 | ATR_spike_detected | max atr20=11.3001, median=0.5297
# ✔ GOOGL: saved 5 ATR lookbacks
#
# Processing GOSHA...
# ✔ GOSHA: saved 5 ATR lookbacks
#
# Processing GP1...
# ✔ GP1: saved 5 ATR lookbacks
#
# Processing GPC...
# ✔ GPC: saved 5 ATR lookbacks
#
# Processing GPN...
# ⚠ VALIDATION: GPN | W=14 | ATR_spike_detected | max atr14=18.3682, median=0.6470
# ⚠ VALIDATION: GPN | W=20 | ATR_spike_detected | max atr20=15.9407, median=0.6407
# ⚠ VALIDATION: GPN | W=28 | ATR_spike_detected | max atr28=14.1992, median=0.6234
# ✔ GPN: saved 5 ATR lookbacks
#
# Processing GPU...
# ✔ GPU: saved 5 ATR lookbacks
#
# Processing GR...
# ✔ GR: saved 5 ATR lookbacks
#
# Processing GRA...
# ✔ GRA: saved 5 ATR lookbacks
#
# Processing GRMN...
# ✔ GRMN: saved 5 ATR lookbacks
#
# Processing GRN1...
# ✔ GRN1: saved 5 ATR lookbacks
#
# Processing GS...
# ✔ GS: saved 5 ATR lookbacks
#
# Processing GSX1...
# ✔ GSX1: saved 5 ATR lookbacks
#
# Processing GT...
# ✔ GT: saved 5 ATR lookbacks
#
# Processing GTE1...
# ✔ GTE1: saved 5 ATR lookbacks
#
# Processing GTW...
# ✔ GTW: saved 5 ATR lookbacks
#
# Processing GWOW...
# ✔ GWOW: saved 5 ATR lookbacks
#
# Processing GWW...
# ✔ GWW: saved 5 ATR lookbacks
#
# Processing GX...
# ✔ GX: saved 5 ATR lookbacks
#
# Processing H1...
# ✔ H1: saved 5 ATR lookbacks
#
# Processing H2...
# ✔ H2: saved 5 ATR lookbacks
#
# Processing HAL...
# ✔ HAL: saved 5 ATR lookbacks
#
# Processing HAR...
# ✔ HAR: saved 5 ATR lookbacks
#
# Processing HAS...
# ✔ HAS: saved 5 ATR lookbacks
#
# Processing HBAN...
# ✔ HBAN: saved 5 ATR lookbacks
#
# Processing HBI...
# ✔ HBI: saved 5 ATR lookbacks
#
# Processing HBOC...
# ✔ HBOC: saved 5 ATR lookbacks
#
# Processing HCA...
# ✔ HCA: saved 5 ATR lookbacks
#
# Processing HCA1...
# ✔ HCA1: saved 5 ATR lookbacks
#
# Processing HCBK...
# ✔ HCBK: saved 5 ATR lookbacks
#
# Processing HCR1...
# ✔ HCR1: saved 5 ATR lookbacks
#
# Processing HD...
# ✔ HD: saved 5 ATR lookbacks
#
# Processing HES...
# ✔ HES: saved 5 ATR lookbacks
#
# Processing HET...
# ✔ HET: saved 5 ATR lookbacks
#
# Processing HI1...
# ✔ HI1: saved 5 ATR lookbacks
#
# Processing HIG...
# ✔ HIG: saved 5 ATR lookbacks
#
# Processing HII...
# ✔ HII: saved 5 ATR lookbacks
#
# Processing HLT...
# ✔ HLT: saved 5 ATR lookbacks
#
# Processing HLT1...
# ✔ HLT1: saved 5 ATR lookbacks
#
# Processing HM...
# ✔ HM: saved 5 ATR lookbacks
#
# Processing HMA1...
# ✔ HMA1: saved 5 ATR lookbacks
#
# Processing HNZ...
# ✔ HNZ: saved 5 ATR lookbacks
#
# Processing HOG...
# ✔ HOG: saved 5 ATR lookbacks
#
# Processing HOLX...
# ✔ HOLX: saved 5 ATR lookbacks
#
# Processing HON...
# ✔ HON: saved 5 ATR lookbacks
#
# Processing HON1...
# ✔ HON1: saved 5 ATR lookbacks
#
# Processing HOOD...
# ✔ HOOD: saved 5 ATR lookbacks
#
# Processing HOT...
# ✔ HOT: saved 5 ATR lookbacks
#
# Processing HP...
# ✔ HP: saved 5 ATR lookbacks
#
# Processing HPC...
# ✔ HPC: saved 5 ATR lookbacks
#
# Processing HPE...
# ✔ HPE: saved 5 ATR lookbacks
#
# Processing HPQ...
# ✔ HPQ: saved 5 ATR lookbacks
#
# Processing HRB...
# ✔ HRB: saved 5 ATR lookbacks
#
# Processing HRL...
# ✔ HRL: saved 5 ATR lookbacks
#
# Processing HRZIQ...
# ✔ HRZIQ: saved 5 ATR lookbacks
#
# Processing HSH...
# ✔ HSH: saved 5 ATR lookbacks
#
# Processing HSIC...
# ✔ HSIC: saved 5 ATR lookbacks
#
# Processing HSP...
# ✔ HSP: saved 5 ATR lookbacks
#
# Processing HST...
# ✔ HST: saved 5 ATR lookbacks
#
# Processing HSY...
# ✔ HSY: saved 5 ATR lookbacks
#
# Processing HUBB...
# ✔ HUBB: saved 5 ATR lookbacks
#
# Processing HUM...
# ✔ HUM: saved 5 ATR lookbacks
#
# Processing HWM...
# ✔ HWM: saved 5 ATR lookbacks
#
# Processing IBKR...
# ✔ IBKR: saved 5 ATR lookbacks
#
# Processing IBM...
# ✔ IBM: saved 5 ATR lookbacks
#
# Processing ICE...
# ✔ ICE: saved 5 ATR lookbacks
#
# Processing IDXX...
# ⚠ VALIDATION: IDXX | W=14 | ATR_spike_detected | max atr14=28.9832, median=0.8854
# ⚠ VALIDATION: IDXX | W=20 | ATR_spike_detected | max atr20=25.5675, median=0.8767
# ⚠ VALIDATION: IDXX | W=28 | ATR_spike_detected | max atr28=22.9025, median=0.8769
# ⚠ VALIDATION: IDXX | W=42 | ATR_spike_detected | max atr42=20.9792, median=0.8710
# ⚠ VALIDATION: IDXX | W=63 | ATR_spike_detected | max atr63=20.2598, median=0.8689
# ✔ IDXX: saved 5 ATR lookbacks
#
# Processing IEX...
# ✔ IEX: saved 5 ATR lookbacks
#
# Processing IFF...
# ✔ IFF: saved 5 ATR lookbacks
#
# Processing IGT1...
# ✔ IGT1: saved 5 ATR lookbacks
#
# Processing IKN...
# ✔ IKN: saved 5 ATR lookbacks
#
# Processing ILMN...
# ✔ ILMN: saved 5 ATR lookbacks
#
# Processing IMNX...
# ✔ IMNX: saved 5 ATR lookbacks
#
# Processing INCLF...
# ✔ INCLF: saved 5 ATR lookbacks
#
# Processing INCY...
# ✔ INCY: saved 5 ATR lookbacks
#
# Processing INFO1...
# ✔ INFO1: saved 5 ATR lookbacks
#
# Processing INTC...
# ✔ INTC: saved 5 ATR lookbacks
#
# Processing INTU...
# ⚠ VALIDATION: INTU | W=14 | ATR_spike_detected | max atr14=28.9932, median=1.1396
# ⚠ VALIDATION: INTU | W=20 | ATR_spike_detected | max atr20=27.1502, median=1.1381
# ⚠ VALIDATION: INTU | W=28 | ATR_spike_detected | max atr28=24.1738, median=1.1321
# ⚠ VALIDATION: INTU | W=42 | ATR_spike_detected | max atr42=22.7207, median=1.1183
# ✔ INTU: saved 5 ATR lookbacks
#
# Processing INVH...
# ✔ INVH: saved 5 ATR lookbacks
#
# Processing IP...
# ✔ IP: saved 5 ATR lookbacks
#
# Processing IPG...
# ✔ IPG: saved 5 ATR lookbacks
#
# Processing IPGP...
# ✔ IPGP: saved 5 ATR lookbacks
#
# Processing IQV...
# ✔ IQV: saved 5 ATR lookbacks
#
# Processing IR...
# ✔ IR: saved 5 ATR lookbacks
#
# Processing IRM...
# ✔ IRM: saved 5 ATR lookbacks
#
# Processing ISRG...
# ⚠ VALIDATION: ISRG | W=14 | ATR_spike_detected | max atr14=31.5539, median=1.1983
# ⚠ VALIDATION: ISRG | W=20 | ATR_spike_detected | max atr20=27.2778, median=1.2114
# ⚠ VALIDATION: ISRG | W=28 | ATR_spike_detected | max atr28=25.7734, median=1.2346
# ✔ ISRG: saved 5 ATR lookbacks
#
# Processing IT...
# ✔ IT: saved 5 ATR lookbacks
#
# Processing ITT...
# ✔ ITT: saved 5 ATR lookbacks
#
# Processing ITT1...
# ⚠ VALIDATION: ITT1 | W=42 | insufficient_history | 36 rows (<42), last=1998-02-23
# ⚠ VALIDATION: ITT1 | W=63 | insufficient_history | 36 rows (<63), last=1998-02-23
# ✔ ITT1: saved 5 ATR lookbacks
#
# Processing ITW...
# ✔ ITW: saved 5 ATR lookbacks
#
# Processing IVZ...
# ✔ IVZ: saved 5 ATR lookbacks
#
# Processing J...
# ✔ J: saved 5 ATR lookbacks
#
# Processing JAVA1...
# ⚠ VALIDATION: JAVA1 | W=14 | ATR_spike_detected | max atr14=18.3929, median=0.7589
# ⚠ VALIDATION: JAVA1 | W=20 | ATR_spike_detected | max atr20=17.5609, median=0.7499
# ⚠ VALIDATION: JAVA1 | W=28 | ATR_spike_detected | max atr28=16.3504, median=0.7429
# ⚠ VALIDATION: JAVA1 | W=42 | ATR_spike_detected | max atr42=16.1681, median=0.7304
# ⚠ VALIDATION: JAVA1 | W=63 | ATR_spike_detected | max atr63=15.6631, median=0.7330
# ✔ JAVA1: saved 5 ATR lookbacks
#
# Processing JBHT...
# ✔ JBHT: saved 5 ATR lookbacks
#
# Processing JBL...
# ✔ JBL: saved 5 ATR lookbacks
#
# Processing JCI...
# ✔ JCI: saved 5 ATR lookbacks
#
# Processing JEF...
# ✔ JEF: saved 5 ATR lookbacks
#
# Processing JH...
# ✔ JH: saved 5 ATR lookbacks
#
# Processing JHF...
# ✔ JHF: saved 5 ATR lookbacks
#
# Processing JKHY...
# ✔ JKHY: saved 5 ATR lookbacks
#
# Processing JM...
# ✔ JM: saved 5 ATR lookbacks
#
# Processing JNJ...
# ✔ JNJ: saved 5 ATR lookbacks
#
# Processing JNPR...
# ⚠ VALIDATION: JNPR | W=14 | ATR_spike_detected | max atr14=17.3417, median=0.5349
# ⚠ VALIDATION: JNPR | W=20 | ATR_spike_detected | max atr20=16.5656, median=0.5386
# ⚠ VALIDATION: JNPR | W=28 | ATR_spike_detected | max atr28=15.6064, median=0.5374
# ⚠ VALIDATION: JNPR | W=42 | ATR_spike_detected | max atr42=14.9679, median=0.5327
# ⚠ VALIDATION: JNPR | W=63 | ATR_spike_detected | max atr63=14.4890, median=0.5282
# ✔ JNPR: saved 5 ATR lookbacks
#
# Processing JNS...
# ✔ JNS: saved 5 ATR lookbacks
#
# Processing JNY...
# ✔ JNY: saved 5 ATR lookbacks
#
# Processing JOS...
# ✔ JOS: saved 5 ATR lookbacks
#
# Processing JOY...
# ✔ JOY: saved 5 ATR lookbacks
#
# Processing JP1...
# ✔ JP1: saved 5 ATR lookbacks
#
# Processing JPM...
# ✔ JPM: saved 5 ATR lookbacks
#
# Processing JPM1...
# ✔ JPM1: saved 5 ATR lookbacks
#
# Processing JWN...
# ✔ JWN: saved 5 ATR lookbacks
#
# Processing K...
# ✔ K: saved 5 ATR lookbacks
#
# Processing KATE...
# ✔ KATE: saved 5 ATR lookbacks
#
# Processing KBH...
# ✔ KBH: saved 5 ATR lookbacks
#
# Processing KDP...
# ✔ KDP: saved 5 ATR lookbacks
#
# Processing KEY...
# ✔ KEY: saved 5 ATR lookbacks
#
# Processing KEYS...
# ✔ KEYS: saved 5 ATR lookbacks
#
# Processing KG1...
# ✔ KG1: saved 5 ATR lookbacks
#
# Processing KHC...
# ✔ KHC: saved 5 ATR lookbacks
#
# Processing KIM...
# ✔ KIM: saved 5 ATR lookbacks
#
# Processing KKR...
# ✔ KKR: saved 5 ATR lookbacks
#
# Processing KLAC...
# ⚠ VALIDATION: KLAC | W=14 | ATR_spike_detected | max atr14=50.6241, median=1.0233
# ⚠ VALIDATION: KLAC | W=20 | ATR_spike_detected | max atr20=47.5797, median=1.0058
# ⚠ VALIDATION: KLAC | W=28 | ATR_spike_detected | max atr28=45.3401, median=0.9947
# ⚠ VALIDATION: KLAC | W=42 | ATR_spike_detected | max atr42=44.4844, median=1.0040
# ⚠ VALIDATION: KLAC | W=63 | ATR_spike_detected | max atr63=41.8903, median=0.9809
# ✔ KLAC: saved 5 ATR lookbacks
#
# Processing KM...
# ✔ KM: saved 5 ATR lookbacks
#
# Processing KMB...
# ✔ KMB: saved 5 ATR lookbacks
#
# Processing KMG1...
# ✔ KMG1: saved 5 ATR lookbacks
#
# Processing KMI...
# ✔ KMI: saved 5 ATR lookbacks
#
# Processing KMI1...
# ✔ KMI1: saved 5 ATR lookbacks
#
# Processing KMX...
# ✔ KMX: saved 5 ATR lookbacks
#
# Processing KO...
# ✔ KO: saved 5 ATR lookbacks
#
# Processing KR...
# ✔ KR: saved 5 ATR lookbacks
#
# Processing KRB...
# ✔ KRB: saved 5 ATR lookbacks
#
# Processing KRFT...
# ✔ KRFT: saved 5 ATR lookbacks
#
# Processing KRI...
# ✔ KRI: saved 5 ATR lookbacks
#
# Processing KSE...
# ✔ KSE: saved 5 ATR lookbacks
#
# Processing KSS...
# ✔ KSS: saved 5 ATR lookbacks
#
# Processing KSU...
# ✔ KSU: saved 5 ATR lookbacks
#
# Processing KVUE...
# ✔ KVUE: saved 5 ATR lookbacks
#
# Processing KWP...
# ✔ KWP: saved 5 ATR lookbacks
#
# Processing L...
# ✔ L: saved 5 ATR lookbacks
#
# Processing LDG...
# ...
# ⚠ VALIDATION: SXCL | W=42 | ATR_spike_detected | max atr42=34.1667, median=1.4905
# ⚠ VALIDATION: SXCL | W=63 | ATR_spike_detected | max atr63=34.2659, median=1.4865
# ✔ SXCL: saved 5 ATR lookbacks
#
# Processing SYF...
# ✔ SYF: saved 5 ATR lookbacks
#
# Processing SYK...
# ✔ SYK: saved 5 ATR lookbacks
#
# Processing SYY...
# ✔ SYY: saved 5 ATR lookbacks
#
# Processing T...
# ✔ T: saved 5 ATR lookbacks
#
# Processing T1...
# ✔ T1: saved 5 ATR lookbacks
#
# Processing TA2...
# ✔ TA2: saved 5 ATR lookbacks
#
# Processing TAP.B...
# ✔ TAP.B: saved 5 ATR lookbacks
#
# Processing TAP...
# ✔ TAP: saved 5 ATR lookbacks
#
# Processing TCOMA...
# ✔ TCOMA: saved 5 ATR lookbacks
#
# Processing TDC...
# ✔ TDC: saved 5 ATR lookbacks
#
# Processing TDG...
# ⚠ VALIDATION: TDG | W=14 | ATR_spike_detected | max atr14=66.4900, median=2.9629
# ✔ TDG: saved 5 ATR lookbacks
#
# Processing TDY...
# ✔ TDY: saved 5 ATR lookbacks
#
# Processing TE1...
# ✔ TE1: saved 5 ATR lookbacks
#
# Processing TECH...
# ✔ TECH: saved 5 ATR lookbacks
#
# Processing TEG...
# ✔ TEG: saved 5 ATR lookbacks
#
# Processing TEK1...
# ✔ TEK1: saved 5 ATR lookbacks
#
# Processing TEL...
# ✔ TEL: saved 5 ATR lookbacks
#
# Processing TEN1...
# ✔ TEN1: saved 5 ATR lookbacks
#
# Processing TER...
# ✔ TER: saved 5 ATR lookbacks
#
# Processing TEX...
# ✔ TEX: saved 5 ATR lookbacks
#
# Processing TFC...
# ✔ TFC: saved 5 ATR lookbacks
#
# Processing TFCF...
# ✔ TFCF: saved 5 ATR lookbacks
#
# Processing TFCFA...
# ✔ TFCFA: saved 5 ATR lookbacks
#
# Processing TFX...
# ⚠ VALIDATION: TFX | W=14 | ATR_spike_detected | max atr14=30.7789, median=1.2435
# ⚠ VALIDATION: TFX | W=20 | ATR_spike_detected | max atr20=27.4460, median=1.2211
# ⚠ VALIDATION: TFX | W=28 | ATR_spike_detected | max atr28=25.2725, median=1.2298
# ✔ TFX: saved 5 ATR lookbacks
#
# Processing TGNA...
# ✔ TGNA: saved 5 ATR lookbacks
#
# Processing TGT...
# ✔ TGT: saved 5 ATR lookbacks
#
# Processing THC...
# ✔ THC: saved 5 ATR lookbacks
#
# Processing TIE...
# ✔ TIE: saved 5 ATR lookbacks
#
# Processing TIF...
# ✔ TIF: saved 5 ATR lookbacks
#
# Processing TIN...
# ✔ TIN: saved 5 ATR lookbacks
#
# Processing TJX...
# ✔ TJX: saved 5 ATR lookbacks
#
# Processing TKO...
# ✔ TKO: saved 5 ATR lookbacks
#
# Processing TKR...
# ✔ TKR: saved 5 ATR lookbacks
#
# Processing TLAB...
# ✔ TLAB: saved 5 ATR lookbacks
#
# Processing TMC.A...
# ✔ TMC.A: saved 5 ATR lookbacks
#
# Processing TMO...
# ✔ TMO: saved 5 ATR lookbacks
#
# Processing TMUS...
# ✔ TMUS: saved 5 ATR lookbacks
#
# Processing TNB...
# ✔ TNB: saved 5 ATR lookbacks
#
# Processing TNL...
# ✔ TNL: saved 5 ATR lookbacks
#
# Processing TOS...
# ✔ TOS: saved 5 ATR lookbacks
#
# Processing TOY...
# ✔ TOY: saved 5 ATR lookbacks
#
# Processing TPL...
# ⚠ VALIDATION: TPL | W=14 | ATR_spike_detected | max atr14=117.1289, median=0.5307
# ⚠ VALIDATION: TPL | W=20 | ATR_spike_detected | max atr20=101.5143, median=0.5366
# ⚠ VALIDATION: TPL | W=28 | ATR_spike_detected | max atr28=90.1902, median=0.5347
# ⚠ VALIDATION: TPL | W=42 | ATR_spike_detected | max atr42=82.8277, median=0.5406
# ⚠ VALIDATION: TPL | W=63 | ATR_spike_detected | max atr63=73.3500, median=0.5465
# ✔ TPL: saved 5 ATR lookbacks
#
# Processing TPR...
# ✔ TPR: saved 5 ATR lookbacks
#
# Processing TRB...
# ✔ TRB: saved 5 ATR lookbacks
#
# Processing TRGP...
# ✔ TRGP: saved 5 ATR lookbacks
#
# Processing TRIP...
# ✔ TRIP: saved 5 ATR lookbacks
#
# Processing TRMB...
# ✔ TRMB: saved 5 ATR lookbacks
#
# Processing TROW...
# ✔ TROW: saved 5 ATR lookbacks
#
# Processing TRV...
# ✔ TRV: saved 5 ATR lookbacks
#
# Processing TRW1...
# ✔ TRW1: saved 5 ATR lookbacks
#
# Processing TSCO...
# ✔ TSCO: saved 5 ATR lookbacks
#
# Processing TSG1...
# ✔ TSG1: saved 5 ATR lookbacks
#
# Processing TSLA...
# ⚠ VALIDATION: TSLA | W=14 | ATR_spike_detected | max atr14=29.8479, median=0.7154
# ⚠ VALIDATION: TSLA | W=20 | ATR_spike_detected | max atr20=27.5080, median=0.7181
# ⚠ VALIDATION: TSLA | W=28 | ATR_spike_detected | max atr28=25.9846, median=0.7186
# ⚠ VALIDATION: TSLA | W=42 | ATR_spike_detected | max atr42=23.1968, median=0.7104
# ⚠ VALIDATION: TSLA | W=63 | ATR_spike_detected | max atr63=22.1064, median=0.7055
# ✔ TSLA: saved 5 ATR lookbacks
#
# Processing TSN...
# ✔ TSN: saved 5 ATR lookbacks
#
# Processing TSS...
# ✔ TSS: saved 5 ATR lookbacks
#
# Processing TT...
# ⚠ VALIDATION: TT | W=14 | ATR_spike_detected | max atr14=16.9591, median=0.5953
# ⚠ VALIDATION: TT | W=20 | ATR_spike_detected | max atr20=15.9280, median=0.5953
# ⚠ VALIDATION: TT | W=28 | ATR_spike_detected | max atr28=14.7079, median=0.5994
# ⚠ VALIDATION: TT | W=42 | ATR_spike_detected | max atr42=12.8464, median=0.6004
# ✔ TT: saved 5 ATR lookbacks
#
# Processing TT2...
# ✔ TT2: saved 5 ATR lookbacks
#
# Processing TTD...
# ✔ TTD: saved 5 ATR lookbacks
#
# Processing TTWO...
# ✔ TTWO: saved 5 ATR lookbacks
#
# Processing TUPBQ...
# ✔ TUPBQ: saved 5 ATR lookbacks
#
# Processing TWC...
# ✔ TWC: saved 5 ATR lookbacks
#
# Processing TWTR...
# ✔ TWTR: saved 5 ATR lookbacks
#
# Processing TWX...
# ✔ TWX: saved 5 ATR lookbacks
#
# Processing TWX1...
# ✔ TWX1: saved 5 ATR lookbacks
#
# Processing TX1...
# ✔ TX1: saved 5 ATR lookbacks
#
# Processing TXN...
# ✔ TXN: saved 5 ATR lookbacks
#
# Processing TXT...
# ✔ TXT: saved 5 ATR lookbacks
#
# Processing TXU...
# ✔ TXU: saved 5 ATR lookbacks
#
# Processing TYC...
# ✔ TYC: saved 5 ATR lookbacks
#
# Processing TYL...
# ⚠ VALIDATION: TYL | W=14 | ATR_spike_detected | max atr14=25.4084, median=0.8264
# ⚠ VALIDATION: TYL | W=20 | ATR_spike_detected | max atr20=22.3565, median=0.8375
# ⚠ VALIDATION: TYL | W=28 | ATR_spike_detected | max atr28=19.3189, median=0.8625
# ⚠ VALIDATION: TYL | W=42 | ATR_spike_detected | max atr42=18.6585, median=0.8507
# ⚠ VALIDATION: TYL | W=63 | ATR_spike_detected | max atr63=17.6925, median=0.8621
# ✔ TYL: saved 5 ATR lookbacks
#
# Processing UA...
# ✔ UA: saved 5 ATR lookbacks
#
# Processing UAA...
# ✔ UAA: saved 5 ATR lookbacks
#
# Processing UAL...
# ✔ UAL: saved 5 ATR lookbacks
#
# Processing UAWGQ...
# ✔ UAWGQ: saved 5 ATR lookbacks
#
# Processing UBER...
# ✔ UBER: saved 5 ATR lookbacks
#
# Processing UCC1...
# ✔ UCC1: saved 5 ATR lookbacks
#
# Processing UCL1...
# ✔ UCL1: saved 5 ATR lookbacks
#
# Processing UCM...
# ✔ UCM: saved 5 ATR lookbacks
#
# Processing UDR...
# ✔ UDR: saved 5 ATR lookbacks
#
# Processing UHS...
# ✔ UHS: saved 5 ATR lookbacks
#
# Processing UIS...
# ⚠ VALIDATION: UIS | W=14 | ATR_spike_detected | max atr14=32.4143, median=0.9650
# ⚠ VALIDATION: UIS | W=20 | ATR_spike_detected | max atr20=29.1300, median=0.9737
# ⚠ VALIDATION: UIS | W=28 | ATR_spike_detected | max atr28=25.6321, median=0.9689
# ⚠ VALIDATION: UIS | W=42 | ATR_spike_detected | max atr42=22.4524, median=0.9595
# ⚠ VALIDATION: UIS | W=63 | ATR_spike_detected | max atr63=20.5270, median=0.9797
# ✔ UIS: saved 5 ATR lookbacks
#
# Processing UK1...
# ✔ UK1: saved 5 ATR lookbacks
#
# Processing UL...
# ✔ UL: saved 5 ATR lookbacks
#
# Processing ULTA...
# ✔ ULTA: saved 5 ATR lookbacks
#
# Processing UNH...
# ⚠ VALIDATION: UNH | W=14 | ATR_spike_detected | max atr14=32.2234, median=1.0454
# ⚠ VALIDATION: UNH | W=20 | ATR_spike_detected | max atr20=25.7180, median=1.0431
# ⚠ VALIDATION: UNH | W=28 | ATR_spike_detected | max atr28=23.9618, median=1.0494
# ⚠ VALIDATION: UNH | W=42 | ATR_spike_detected | max atr42=21.0723, median=1.0341
# ✔ UNH: saved 5 ATR lookbacks
#
# Processing UNM...
# ✔ UNM: saved 5 ATR lookbacks
#
# Processing UNP...
# ✔ UNP: saved 5 ATR lookbacks
#
# Processing UPC1...
# ✔ UPC1: saved 5 ATR lookbacks
#
# Processing UPR...
# ✔ UPR: saved 5 ATR lookbacks
#
# Processing UPS...
# ✔ UPS: saved 5 ATR lookbacks
#
# Processing URBN...
# ✔ URBN: saved 5 ATR lookbacks
#
# Processing URI...
# ⚠ VALIDATION: URI | W=14 | ATR_spike_detected | max atr14=39.5659, median=1.5038
# ⚠ VALIDATION: URI | W=20 | ATR_spike_detected | max atr20=36.8907, median=1.4812
# ⚠ VALIDATION: URI | W=28 | ATR_spike_detected | max atr28=32.4147, median=1.4854
# ✔ URI: saved 5 ATR lookbacks
#
# Processing USB...
# ✔ USB: saved 5 ATR lookbacks
#
# Processing USB1...
# ✔ USB1: saved 5 ATR lookbacks
#
# Processing USG1...
# ✔ USG1: saved 5 ATR lookbacks
#
# Processing USS1...
# ✔ USS1: saved 5 ATR lookbacks
#
# Processing UST1...
# ✔ UST1: saved 5 ATR lookbacks
#
# Processing USW...
# ✔ USW: saved 5 ATR lookbacks
#
# Processing UVN...
# ✔ UVN: saved 5 ATR lookbacks
#
# Processing V...
# ✔ V: saved 5 ATR lookbacks
#
# Processing VALPQ...
# ✔ VALPQ: saved 5 ATR lookbacks
#
# Processing VAR...
# ✔ VAR: saved 5 ATR lookbacks
#
# Processing VFC...
# ✔ VFC: saved 5 ATR lookbacks
#
# Processing VIAB...
# ✔ VIAB: saved 5 ATR lookbacks
#
# Processing VIAV...
# ⚠ VALIDATION: VIAV | W=14 | ATR_spike_detected | max atr14=69.4482, median=0.3389
# ⚠ VALIDATION: VIAV | W=20 | ATR_spike_detected | max atr20=63.9277, median=0.3403
# ⚠ VALIDATION: VIAV | W=28 | ATR_spike_detected | max atr28=58.9174, median=0.3389
# ⚠ VALIDATION: VIAV | W=42 | ATR_spike_detected | max atr42=55.6503, median=0.3405
# ⚠ VALIDATION: VIAV | W=63 | ATR_spike_detected | max atr63=48.4505, median=0.3445
# ✔ VIAV: saved 5 ATR lookbacks
#
# Processing VICI...
# ✔ VICI: saved 5 ATR lookbacks
#
# Processing VLO...
# ✔ VLO: saved 5 ATR lookbacks
#
# Processing VLTO...
# ✔ VLTO: saved 5 ATR lookbacks
#
# Processing VMC...
# ✔ VMC: saved 5 ATR lookbacks
#
# Processing VNO...
# ✔ VNO: saved 5 ATR lookbacks
#
# Processing VNT...
# ✔ VNT: saved 5 ATR lookbacks
#
# Processing VO1...
# ✔ VO1: saved 5 ATR lookbacks
#
# Processing VRSK...
# ✔ VRSK: saved 5 ATR lookbacks
#
# Processing VRSN...
# ✔ VRSN: saved 5 ATR lookbacks
#
# Processing VRTS1...
# ✔ VRTS1: saved 5 ATR lookbacks
#
# Processing VRTX...
# ✔ VRTX: saved 5 ATR lookbacks
#
# Processing VST...
# ⚠ VALIDATION: VST | W=14 | ATR_spike_detected | max atr14=15.7613, median=0.5499
# ⚠ VALIDATION: VST | W=20 | ATR_spike_detected | max atr20=14.2286, median=0.5446
# ⚠ VALIDATION: VST | W=28 | ATR_spike_detected | max atr28=13.1293, median=0.5516
# ⚠ VALIDATION: VST | W=42 | ATR_spike_detected | max atr42=12.4099, median=0.5581
# ⚠ VALIDATION: VST | W=63 | ATR_spike_detected | max atr63=11.5015, median=0.5535
# ✔ VST: saved 5 ATR lookbacks
#
# Processing VSTNQ...
# ✔ VSTNQ: saved 5 ATR lookbacks
#
# Processing VTR...
# ✔ VTR: saved 5 ATR lookbacks
#
# Processing VTRS...
# ✔ VTRS: saved 5 ATR lookbacks
#
# Processing VTSS...
# ⚠ VALIDATION: VTSS | W=14 | ATR_spike_detected | max atr14=264.1071, median=1.3429
# ⚠ VALIDATION: VTSS | W=20 | ATR_spike_detected | max atr20=240.5625, median=1.3200
# ⚠ VALIDATION: VTSS | W=28 | ATR_spike_detected | max atr28=212.7679, median=1.2643
# ⚠ VALIDATION: VTSS | W=42 | ATR_spike_detected | max atr42=208.9881, median=1.2524
# ⚠ VALIDATION: VTSS | W=63 | ATR_spike_detected | max atr63=185.6944, median=1.4206
# ✔ VTSS: saved 5 ATR lookbacks
#
# Processing VYX...
# ✔ VYX: saved 5 ATR lookbacks
#
# Processing VZ...
# ✔ VZ: saved 5 ATR lookbacks
#
# Processing WAB...
# ✔ WAB: saved 5 ATR lookbacks
#
# Processing WAI1...
# ✔ WAI1: saved 5 ATR lookbacks
#
# Processing WAMUQ...
# ✔ WAMUQ: saved 5 ATR lookbacks
#
# Processing WAT...
# ✔ WAT: saved 5 ATR lookbacks
#
# Processing WB1...
# ✔ WB1: saved 5 ATR lookbacks
#
# Processing WB2...
# ✔ WB2: saved 5 ATR lookbacks
#
# Processing WBA...
# ✔ WBA: saved 5 ATR lookbacks
#
# Processing WBD...
# ✔ WBD: saved 5 ATR lookbacks
#
# Processing WCG...
# ✔ WCG: saved 5 ATR lookbacks
#
# Processing WCOEQ...
# ✔ WCOEQ: saved 5 ATR lookbacks
#
# Processing WDAY...
# ✔ WDAY: saved 5 ATR lookbacks
#
# Processing WDC...
# ✔ WDC: saved 5 ATR lookbacks
#
# Processing WEC...
# ⚠ VALIDATION: WEC | W=14 | ATR_spike_detected | max atr14=9.4878, median=0.3234
# ⚠ VALIDATION: WEC | W=20 | ATR_spike_detected | max atr20=8.1301, median=0.3208
# ⚠ VALIDATION: WEC | W=28 | ATR_spike_detected | max atr28=7.0799, median=0.3272
# ✔ WEC: saved 5 ATR lookbacks
#
# Processing WELL...
# ✔ WELL: saved 5 ATR lookbacks
#
# Processing WEN...
# ✔ WEN: saved 5 ATR lookbacks
#
# Processing WFC...
# ✔ WFC: saved 5 ATR lookbacks
#
# Processing WFC1...
# ✔ WFC1: saved 5 ATR lookbacks
#
# Processing WFM...
# ✔ WFM: saved 5 ATR lookbacks
#
# Processing WFTIQ...
# ✔ WFTIQ: saved 5 ATR lookbacks
#
# Processing WGL...
# ✔ WGL: saved 5 ATR lookbacks
#
# Processing WHR...
# ✔ WHR: saved 5 ATR lookbacks
#
# Processing WINMQ...
# ✔ WINMQ: saved 5 ATR lookbacks
#
# Processing WLA...
# ✔ WLA: saved 5 ATR lookbacks
#
# Processing WLL1...
# ✔ WLL1: saved 5 ATR lookbacks
#
# Processing WLP1...
# ✔ WLP1: saved 5 ATR lookbacks
#
# Processing WM...
# ✔ WM: saved 5 ATR lookbacks
#
# Processing WMB...
# ✔ WMB: saved 5 ATR lookbacks
#
# Processing WMT...
# ✔ WMT: saved 5 ATR lookbacks
#
# Processing WNDXQ...
# ✔ WNDXQ: saved 5 ATR lookbacks
#
# Processing WOR...
# ✔ WOR: saved 5 ATR lookbacks
#
# Processing WPX...
# ✔ WPX: saved 5 ATR lookbacks
#
# Processing WRB...
# ⚠ VALIDATION: WRB | W=14 | ATR_spike_detected | max atr14=2.8871, median=0.1437
# ✔ WRB: saved 5 ATR lookbacks
#
# Processing WRK...
# ✔ WRK: saved 5 ATR lookbacks
#
# Processing WSM...
# ⚠ VALIDATION: WSM | W=14 | ATR_spike_detected | max atr14=13.1301, median=0.4158
# ⚠ VALIDATION: WSM | W=20 | ATR_spike_detected | max atr20=11.8258, median=0.4152
# ⚠ VALIDATION: WSM | W=28 | ATR_spike_detected | max atr28=11.3008, median=0.4138
# ⚠ VALIDATION: WSM | W=42 | ATR_spike_detected | max atr42=10.2341, median=0.4087
# ⚠ VALIDATION: WSM | W=63 | ATR_spike_detected | max atr63=8.7930, median=0.4113
# ✔ WSM: saved 5 ATR lookbacks
#
# Processing WST...
# ⚠ VALIDATION: WST | W=14 | ATR_spike_detected | max atr14=18.4465, median=0.5811
# ⚠ VALIDATION: WST | W=20 | ATR_spike_detected | max atr20=16.1599, median=0.5765
# ⚠ VALIDATION: WST | W=28 | ATR_spike_detected | max atr28=15.0305, median=0.5747
# ⚠ VALIDATION: WST | W=42 | ATR_spike_detected | max atr42=14.8433, median=0.5748
# ⚠ VALIDATION: WST | W=63 | ATR_spike_detected | max atr63=14.3368, median=0.5756
# ✔ WST: saved 5 ATR lookbacks
#
# Processing WTW...
# ✔ WTW: saved 5 ATR lookbacks
#
# Processing WU...
# ✔ WU: saved 5 ATR lookbacks
#
# Processing WWY...
# ✔ WWY: saved 5 ATR lookbacks
#
# Processing WY...
# ✔ WY: saved 5 ATR lookbacks
#
# Processing WYE...
# ✔ WYE: saved 5 ATR lookbacks
#
# Processing WYNN...
# ✔ WYNN: saved 5 ATR lookbacks
#
# Processing X...
# ✔ X: saved 5 ATR lookbacks
#
# Processing XEC...
# ✔ XEC: saved 5 ATR lookbacks
#
# Processing XEL...
# ✔ XEL: saved 5 ATR lookbacks
#
# Processing XL1...
# ✔ XL1: saved 5 ATR lookbacks
#
# Processing XLNX...
# ✔ XLNX: saved 5 ATR lookbacks
#
# Processing XOM...
# ✔ XOM: saved 5 ATR lookbacks
#
# Processing XRAY...
# ✔ XRAY: saved 5 ATR lookbacks
#
# Processing XRX...
# ✔ XRX: saved 5 ATR lookbacks
#
# Processing XTO...
# ✔ XTO: saved 5 ATR lookbacks
#
# Processing XYL...
# ✔ XYL: saved 5 ATR lookbacks
#
# Processing XYZ...
# ✔ XYZ: saved 5 ATR lookbacks
#
# Processing YHOO...
# ✔ YHOO: saved 5 ATR lookbacks
#
# Processing YNR...
# ✔ YNR: saved 5 ATR lookbacks
#
# Processing YUM...
# ✔ YUM: saved 5 ATR lookbacks
#
# Processing ZBH...
# ✔ ZBH: saved 5 ATR lookbacks
#
# Processing ZBRA...
# ✔ ZBRA: saved 5 ATR lookbacks
#
# Processing ZION...
# ✔ ZION: saved 5 ATR lookbacks
#
# Processing ZTS...
# ✔ ZTS: saved 5 ATR lookbacks
#
#
# ====================================================
#  MULTI-ATR VALIDATION SUMMARY
# ====================================================
#     ticker  window               issue                            detail
# 0     AAPL      14  ATR_spike_detected  max atr14=13.8029, median=0.2692
# 1     AAPL      20  ATR_spike_detected  max atr20=11.3977, median=0.2763
# 2     AAPL      28  ATR_spike_detected   max atr28=9.9184, median=0.2817
# 3     AAPL      42  ATR_spike_detected   max atr42=8.9032, median=0.2811
# 4     AAPL      63  ATR_spike_detected   max atr63=7.8908, median=0.2798
# ..     ...     ...                 ...                               ...
# 423    WST      14  ATR_spike_detected  max atr14=18.4465, median=0.5811
# 424    WST      20  ATR_spike_detected  max atr20=16.1599, median=0.5765
# 425    WST      28  ATR_spike_detected  max atr28=15.0305, median=0.5747
# 426    WST      42  ATR_spike_detected  max atr42=14.8433, median=0.5748
# 427    WST      63  ATR_spike_detected  max atr63=14.3368, median=0.5756
#
# [428 rows x 4 columns]
#
# Validation logs saved to:
#   → ./system_verification/4-ATR20_adjusted_All_Prices\atr_multi_validation-20251231-083810.csv
#   → ./system_verification/4-ATR20_adjusted_All_Prices\atr_14D\atr_validation-20251231-083810.csv
#   → ./system_verification/4-ATR20_adjusted_All_Prices\atr_20D\atr_validation-20251231-083810.csv
#   → ./system_verification/4-ATR20_adjusted_All_Prices\atr_28D\atr_validation-20251231-083810.csv
#   → ./system_verification/4-ATR20_adjusted_All_Prices\atr_42D\atr_validation-20251231-083810.csv
#   → ./system_verification/4-ATR20_adjusted_All_Prices\atr_63D\atr_validation-20251231-083810.csv
# ====================================================
