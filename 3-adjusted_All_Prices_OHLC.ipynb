# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime

# ============================================================
# CONFIGURATION
# ============================================================

INPUT_DIR  = "./2-all_prices/sharadar_sep_full"
OUTPUT_DIR = "./3-adjusted_All_Prices_OHLC"
VER_DIR    = "./system_verification/3-adjusted_All_Prices_OHLC"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(VER_DIR, exist_ok=True)

REQUIRED = {"open", "high", "low", "close", "closeadj"}

print(f"\nScanning directory: {INPUT_DIR}")
files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".csv")])
print(f"Tickers found: {len(files)}\n")

# ============================================================
# VALIDATION STORAGE
# ============================================================

validation = []

def v(t, issue, detail=""):
    print(f"⚠ VALIDATION: {t} | {issue} | {detail}")
    validation.append({"ticker": t, "issue": issue, "detail": detail})


# ============================================================
# OPTIMIZED PRICE ADJUSTMENT
# ============================================================

def compute_adjusted(df, ticker):

    # vectorized & fast
    df["date"] = pd.to_datetime(df["date"], errors="coerce")
    df.sort_values("date", inplace=True)
    df.reset_index(drop=True, inplace=True)

    # ------------ VALIDATION (vectorized) -----------------

    # Missing columns
    cols = set(df.columns)
    if not REQUIRED.issubset(cols):
        missing = REQUIRED - cols
        v(ticker, "missing_columns", str(missing))
        raise ValueError(f"Missing columns: {missing}")

    # Nonpositive
    if (df["close"] <= 0).any():
        v(ticker, "nonpositive_close", (df["close"] <= 0).sum())

    if (df["closeadj"] <= 0).any():
        v(ticker, "invalid_closeadj", (df["closeadj"] <= 0).sum())

    # Missing dates or NaTs
    if df["date"].isna().any():
        v(ticker, "invalid_dates", df["date"].isna().sum())
        df.dropna(subset=["date"], inplace=True)

    # Large gaps
    gaps = df["date"].diff().dt.days.values
    max_gap = np.nanmax(gaps)
    if max_gap > 7:
        v(ticker, "large_date_gap", int(max_gap))

    # ------------ ADJUSTMENT (fully vectorized) -------------

    # adj_factor
    df["adj_factor"] = df["closeadj"].values / df["close"].values

    # detect split-like jumps > 25%
    jumps = np.abs(np.diff(df["adj_factor"].values) / df["adj_factor"].values[:-1])
    if (jumps > 0.25).any():
        v(ticker, "adj_factor_jump", f"max jump {jumps.max():.3f}")

    # adjusted prices (vectorized)
    adj_factor = df["adj_factor"].values
    df["open_adj"]  = df["open"].values  * adj_factor
    df["high_adj"]  = df["high"].values  * adj_factor
    df["low_adj"]   = df["low"].values   * adj_factor
    df["close_adj"] = df["closeadj"].values

    return df


# ============================================================
# MAIN LOOP
# ============================================================

for file in files:
    ticker = file.replace(".csv", "")
    in_path = os.path.join(INPUT_DIR, file)
    out_path = os.path.join(OUTPUT_DIR, f"{ticker}.parquet")

    print(f"Processing {ticker} …")

    try:
        df = pd.read_csv(in_path, engine="pyarrow")
        df2 = compute_adjusted(df, ticker)

        df2.to_parquet(out_path, index=False)
        print(f"✔ Saved → {out_path}\n")

    except Exception as e:
        v(ticker, "processing_error", str(e))
        print(f"❌ ERROR for {ticker}: {e}\n")


# ============================================================
# SAVE VALIDATION
# ============================================================

val_df = pd.DataFrame(validation)
val_path = os.path.join(
    VER_DIR,
    f"adjusted_price_validation-{datetime.now().strftime('%Y%m%d-%H%M%S')}.csv"
)
val_df.to_csv(val_path, index=False)

print("\n====================================================")
print(" VALIDATION SUMMARY")
print("====================================================")

if val_df.empty:
    print("No issues detected.")
else:
    print(val_df)

print("\nSaved validation →", val_path)
print("====================================================\n")
# Out:
# Scanning directory: ./2-all_prices/sharadar_sep_full
# Tickers found: 1167
#
# Processing A …
# ⚠ VALIDATION: A | adj_factor_jump | max jump 0.384
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\A.parquet
#
# Processing AAL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AAL.parquet
#
# Processing AAMRQ …
# ⚠ VALIDATION: AAMRQ | adj_factor_jump | max jump 0.982
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AAMRQ.parquet
#
# Processing AAP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AAP.parquet
#
# Processing AAPL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AAPL.parquet
#
# Processing ABBV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ABBV.parquet
#
# Processing ABI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ABI1.parquet
#
# Processing ABKFQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ABKFQ.parquet
#
# Processing ABMD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ABMD.parquet
#
# Processing ABNB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ABNB.parquet
#
# Processing ABS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ABS.parquet
#
# Processing ABT …
# ⚠ VALIDATION: ABT | adj_factor_jump | max jump 1.081
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ABT.parquet
#
# Processing ACAS …
# ⚠ VALIDATION: ACAS | adj_factor_jump | max jump 0.327
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ACAS.parquet
#
# Processing ACGL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ACGL.parquet
#
# Processing ACKHQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ACKHQ.parquet
#
# Processing ACN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ACN.parquet
#
# Processing ACS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ACS.parquet
#
# Processing ACV1 …
# ⚠ VALIDATION: ACV1 | adj_factor_jump | max jump 1.540
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ACV1.parquet
#
# Processing ADBE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ADBE.parquet
#
# Processing ADCT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ADCT1.parquet
#
# Processing ADI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ADI.parquet
#
# Processing ADM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ADM.parquet
#
# Processing ADP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ADP.parquet
#
# Processing ADSK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ADSK.parquet
#
# Processing ADT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ADT1.parquet
#
# Processing AEE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AEE.parquet
#
# Processing AEP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AEP.parquet
#
# Processing AES …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AES.parquet
#
# Processing AET …
# ⚠ VALIDATION: AET | adj_factor_jump | max jump 1.026
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AET.parquet
#
# Processing AFL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AFL.parquet
#
# Processing AFS.A …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AFS.A.parquet
#
# Processing AGC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AGC1.parquet
#
# Processing AGN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AGN.parquet
#
# Processing AGN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AGN1.parquet
#
# Processing AHM1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AHM1.parquet
#
# Processing AIG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AIG.parquet
#
# Processing AIT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AIT.parquet
#
# Processing AIV …
# ⚠ VALIDATION: AIV | adj_factor_jump | max jump 7.145
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AIV.parquet
#
# Processing AIZ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AIZ.parquet
#
# Processing AJG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AJG.parquet
#
# Processing AKAM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AKAM.parquet
#
# Processing AKS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AKS.parquet
#
# Processing AL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AL1.parquet
#
# Processing ALB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ALB.parquet
#
# Processing ALGN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ALGN.parquet
#
# Processing ALK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ALK.parquet
#
# Processing ALL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ALL.parquet
#
# Processing ALLE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ALLE.parquet
#
# Processing ALTR1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ALTR1.parquet
#
# Processing ALXN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ALXN.parquet
#
# Processing AM1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AM1.parquet
#
# Processing AMAT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMAT.parquet
#
# Processing AMCC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMCC.parquet
#
# Processing AMCR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMCR.parquet
#
# Processing AMD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMD.parquet
#
# Processing AME …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AME.parquet
#
# Processing AMG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMG.parquet
#
# Processing AMGN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMGN.parquet
#
# Processing AMP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMP.parquet
#
# Processing AMP1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMP1.parquet
#
# Processing AMT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMT.parquet
#
# Processing AMTM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMTM.parquet
#
# Processing AMZN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AMZN.parquet
#
# Processing AN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AN.parquet
#
# Processing AN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AN1.parquet
#
# Processing ANDV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ANDV.parquet
#
# Processing ANDW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ANDW.parquet
#
# Processing ANET …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ANET.parquet
#
# Processing ANF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ANF.parquet
#
# Processing ANRZQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ANRZQ.parquet
#
# Processing ANSS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ANSS.parquet
#
# Processing ANV1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ANV1.parquet
#
# Processing AON …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AON.parquet
#
# Processing AOS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AOS.parquet
#
# Processing APA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APA.parquet
#
# Processing APC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APC.parquet
#
# Processing APCC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APCC.parquet
#
# Processing APD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APD.parquet
#
# Processing APH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APH.parquet
#
# Processing APO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APO.parquet
#
# Processing APOL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APOL.parquet
#
# Processing APP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APP.parquet
#
# Processing APTV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\APTV.parquet
#
# Processing AR1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AR1.parquet
#
# Processing ARC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ARC1.parquet
#
# Processing ARE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ARE.parquet
#
# Processing ARES …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ARES.parquet
#
# Processing ARG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ARG.parquet
#
# Processing AS1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AS1.parquet
#
# Processing ASC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ASC1.parquet
#
# Processing ASH …
# ⚠ VALIDATION: ASH | adj_factor_jump | max jump 1.047
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ASH.parquet
#
# Processing ASN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ASN.parquet
#
# Processing ASND1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ASND1.parquet
#
# Processing ASO1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ASO1.parquet
#
# Processing AT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AT1.parquet
#
# Processing ATGE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ATGE.parquet
#
# Processing ATI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ATI.parquet
#
# Processing ATI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ATI1.parquet
#
# Processing ATO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ATO.parquet
#
# Processing ATVI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ATVI.parquet
#
# Processing AV1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AV1.parquet
#
# Processing AVB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AVB.parquet
#
# Processing AVGO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AVGO.parquet
#
# Processing AVP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AVP.parquet
#
# Processing AVY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AVY.parquet
#
# Processing AW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AW.parquet
#
# Processing AWE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AWE.parquet
#
# Processing AWK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AWK.parquet
#
# Processing AXON …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AXON.parquet
#
# Processing AXP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AXP.parquet
#
# Processing AYE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AYE.parquet
#
# Processing AYI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AYI.parquet
#
# Processing AZA.A …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AZA.A.parquet
#
# Processing AZO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\AZO.parquet
#
# Processing B …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\B.parquet
#
# Processing BA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BA.parquet
#
# Processing BAC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BAC.parquet
#
# Processing BAC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BAC1.parquet
#
# Processing BALL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BALL.parquet
#
# Processing BAX …
# ⚠ VALIDATION: BAX | adj_factor_jump | max jump 0.850
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BAX.parquet
#
# Processing BAY1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BAY1.parquet
#
# Processing BBBYQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BBBYQ.parquet
#
# Processing BBI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BBI1.parquet
#
# Processing BBWI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BBWI.parquet
#
# Processing BBY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BBY.parquet
#
# Processing BC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BC.parquet
#
# Processing BCR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BCR.parquet
#
# Processing BDK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BDK.parquet
#
# Processing BDX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BDX.parquet
#
# Processing BEAM2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BEAM2.parquet
#
# Processing BEN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BEN.parquet
#
# Processing BF.B …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BF.B.parquet
#
# Processing BFH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BFH.parquet
#
# Processing BFI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BFI1.parquet
#
# Processing BFO1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BFO1.parquet
#
# Processing BG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BG.parquet
#
# Processing BGEN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BGEN.parquet
#
# Processing BGGSQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BGGSQ.parquet
#
# Processing BHF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BHF.parquet
#
# Processing BHI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BHI.parquet
#
# Processing BHMSQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BHMSQ.parquet
#
# Processing BIGGQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BIGGQ.parquet
#
# Processing BIIB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BIIB.parquet
#
# Processing BIO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BIO.parquet
#
# Processing BJS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BJS.parquet
#
# Processing BK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BK.parquet
#
# Processing BKB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BKB.parquet
#
# Processing BKNG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BKNG.parquet
#
# Processing BKR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BKR.parquet
#
# Processing BLDR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BLDR.parquet
#
# Processing BLK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BLK.parquet
#
# Processing BLS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BLS.parquet
#
# Processing BMC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BMC.parquet
#
# Processing BMET …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BMET.parquet
#
# Processing BMGCA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BMGCA.parquet
#
# Processing BMS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BMS.parquet
#
# Processing BMY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BMY.parquet
#
# Processing BNI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BNI.parquet
#
# Processing BNL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BNL1.parquet
#
# Processing BOL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BOL.parquet
#
# Processing BR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BR.parquet
#
# Processing BR1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BR1.parquet
#
# Processing BRCM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BRCM.parquet
#
# Processing BRK.B …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BRK.B.parquet
#
# Processing BRL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BRL.parquet
#
# Processing BRO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BRO.parquet
#
# Processing BSC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BSC1.parquet
#
# Processing BSX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BSX.parquet
#
# Processing BT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BT1.parquet
#
# Processing BTUUQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BTUUQ.parquet
#
# Processing BUD1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BUD1.parquet
#
# Processing BVSN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BVSN.parquet
#
# Processing BWA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BWA.parquet
#
# Processing BX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BX.parquet
#
# Processing BXLT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BXLT.parquet
#
# Processing BXP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\BXP.parquet
#
# Processing C …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\C.parquet
#
# Processing C1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\C1.parquet
#
# Processing CA1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CA1.parquet
#
# Processing CAG …
# ⚠ VALIDATION: CAG | adj_factor_jump | max jump 0.289
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CAG.parquet
#
# Processing CAH …
# ⚠ VALIDATION: CAH | adj_factor_jump | max jump 0.388
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CAH.parquet
#
# Processing CAL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CAL.parquet
#
# Processing CAM2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CAM2.parquet
#
# Processing CAR …
# ⚠ VALIDATION: CAR | adj_factor_jump | max jump 5.333
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CAR.parquet
#
# Processing CARR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CARR.parquet
#
# Processing CAT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CAT.parquet
#
# Processing CB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CB.parquet
#
# Processing CB1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CB1.parquet
#
# Processing CBE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CBE.parquet
#
# Processing CBH1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CBH1.parquet
#
# Processing CBOE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CBOE.parquet
#
# Processing CBRE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CBRE.parquet
#
# Processing CBS1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CBS1.parquet
#
# Processing CBSS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CBSS.parquet
#
# Processing CCE1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CCE1.parquet
#
# Processing CCI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CCI.parquet
#
# Processing CCI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CCI1.parquet
#
# Processing CCK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CCK.parquet
#
# Processing CCL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CCL.parquet
#
# Processing CCTYQ …
# ⚠ VALIDATION: CCTYQ | adj_factor_jump | max jump 0.487
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CCTYQ.parquet
#
# Processing CCU1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CCU1.parquet
#
# Processing CDNS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CDNS.parquet
#
# Processing CDW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CDW.parquet
#
# Processing CE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CE.parquet
#
# Processing CE1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CE1.parquet
#
# Processing CEG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CEG.parquet
#
# Processing CEG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CEG1.parquet
#
# Processing CELG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CELG.parquet
#
# Processing CEM1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CEM1.parquet
#
# Processing CEN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CEN1.parquet
#
# Processing CEPH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CEPH.parquet
#
# Processing CERN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CERN.parquet
#
# Processing CF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CF.parquet
#
# Processing CF1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CF1.parquet
#
# Processing CFC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CFC.parquet
#
# Processing CFG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CFG.parquet
#
# Processing CFL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CFL1.parquet
#
# Processing CFN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CFN.parquet
#
# Processing CG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CG1.parquet
#
# Processing CGP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CGP.parquet
#
# Processing CHA1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CHA1.parquet
#
# Processing CHD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CHD.parquet
#
# Processing CHIR1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CHIR1.parquet
#
# Processing CHKAQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CHKAQ.parquet
#
# Processing CHRS1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CHRS1.parquet
#
# Processing CHRW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CHRW.parquet
#
# Processing CHTR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CHTR.parquet
#
# Processing CI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CI.parquet
#
# Processing CIEN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CIEN.parquet
#
# Processing CIN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CIN.parquet
#
# Processing CINF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CINF.parquet
#
# Processing CIT.A …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CIT.A.parquet
#
# Processing CITGQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CITGQ.parquet
#
# Processing CL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CL.parquet
#
# Processing CLF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CLF.parquet
#
# Processing CLX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CLX.parquet
#
# Processing CMA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMA.parquet
#
# Processing CMCSA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMCSA.parquet
#
# Processing CMCSK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMCSK.parquet
#
# Processing CME …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CME.parquet
#
# Processing CMG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMG.parquet
#
# Processing CMI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMI.parquet
#
# Processing CMS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMS.parquet
#
# Processing CMVT …
# ⚠ VALIDATION: CMVT | adj_factor_jump | max jump 0.853
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMVT.parquet
#
# Processing CMX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CMX.parquet
#
# Processing CNC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CNC.parquet
#
# Processing CNCEQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CNCEQ.parquet
#
# Processing CNG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CNG.parquet
#
# Processing CNP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CNP.parquet
#
# Processing CNW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CNW.parquet
#
# Processing CNX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CNX.parquet
#
# Processing CNXT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CNXT1.parquet
#
# Processing COC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COC.parquet
#
# Processing COF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COF.parquet
#
# Processing COIN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COIN.parquet
#
# Processing COL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COL.parquet
#
# Processing COMS1 …
# ⚠ VALIDATION: COMS1 | adj_factor_jump | max jump 3.923
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COMS1.parquet
#
# Processing COO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COO.parquet
#
# Processing COP …
# ⚠ VALIDATION: COP | adj_factor_jump | max jump 0.301
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COP.parquet
#
# Processing COR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COR.parquet
#
# Processing COST …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COST.parquet
#
# Processing COT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COT1.parquet
#
# Processing COTY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COTY.parquet
#
# Processing COV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\COV.parquet
#
# Processing CPAY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPAY.parquet
#
# Processing CPB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPB.parquet
#
# Processing CPGX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPGX.parquet
#
# Processing CPNLQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPNLQ.parquet
#
# Processing CPPRQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPPRQ.parquet
#
# Processing CPQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPQ.parquet
#
# Processing CPRI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPRI.parquet
#
# Processing CPRT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPRT.parquet
#
# Processing CPT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPT.parquet
#
# Processing CPWR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CPWR.parquet
#
# Processing CRH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CRH.parquet
#
# Processing CRL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CRL.parquet
#
# Processing CRM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CRM.parquet
#
# Processing CRWD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CRWD.parquet
#
# Processing CSC …
# ⚠ VALIDATION: CSC | adj_factor_jump | max jump 1.323
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CSC.parquet
#
# Processing CSCO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CSCO.parquet
#
# Processing CSE1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CSE1.parquet
#
# Processing CSGP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CSGP.parquet
#
# Processing CSR1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CSR1.parquet
#
# Processing CSRA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CSRA.parquet
#
# Processing CSX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CSX.parquet
#
# Processing CTAS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTAS.parquet
#
# Processing CTB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTB.parquet
#
# Processing CTLT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTLT.parquet
#
# Processing CTRA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTRA.parquet
#
# Processing CTSH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTSH.parquet
#
# Processing CTVA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTVA.parquet
#
# Processing CTX1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTX1.parquet
#
# Processing CTXS …
# ⚠ VALIDATION: CTXS | adj_factor_jump | max jump 0.250
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CTXS.parquet
#
# Processing CVC …
# ⚠ VALIDATION: CVC | adj_factor_jump | max jump 0.521
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CVC.parquet
#
# Processing CVG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CVG.parquet
#
# Processing CVGYQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CVGYQ.parquet
#
# Processing CVH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CVH.parquet
#
# Processing CVNA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CVNA.parquet
#
# Processing CVS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CVS.parquet
#
# Processing CVX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CVX.parquet
#
# Processing CXO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CXO.parquet
#
# Processing CXT …
# ⚠ VALIDATION: CXT | adj_factor_jump | max jump 1.829
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CXT.parquet
#
# Processing CYM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CYM.parquet
#
# Processing CZR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\CZR.parquet
#
# Processing D …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\D.parquet
#
# Processing DAL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DAL.parquet
#
# Processing DALRQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DALRQ.parquet
#
# Processing DASH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DASH.parquet
#
# Processing DAY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DAY.parquet
#
# Processing DCNAQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DCNAQ.parquet
#
# Processing DD …
# ⚠ VALIDATION: DD | adj_factor_jump | max jump 1.369
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DD.parquet
#
# Processing DD1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DD1.parquet
#
# Processing DDOG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DDOG.parquet
#
# Processing DDS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DDS.parquet
#
# Processing DE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DE.parquet
#
# Processing DEC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DEC1.parquet
#
# Processing DECK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DECK.parquet
#
# Processing DELL …
# ⚠ VALIDATION: DELL | adj_factor_jump | max jump 1.080
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DELL.parquet
#
# Processing DELL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DELL1.parquet
#
# Processing DFODQ …
# ⚠ VALIDATION: DFODQ | adj_factor_jump | max jump 1.164
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DFODQ.parquet
#
# Processing DFS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DFS.parquet
#
# Processing DG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DG.parquet
#
# Processing DG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DG1.parquet
#
# Processing DGN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DGN.parquet
#
# Processing DGX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DGX.parquet
#
# Processing DHI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DHI.parquet
#
# Processing DHR …
# ⚠ VALIDATION: DHR | adj_factor_jump | max jump 0.319
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DHR.parquet
#
# Processing DI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DI1.parquet
#
# Processing DIGI2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DIGI2.parquet
#
# Processing DINO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DINO.parquet
#
# Processing DIS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DIS.parquet
#
# Processing DISCK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DISCK.parquet
#
# Processing DISH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DISH.parquet
#
# Processing DJ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DJ.parquet
#
# Processing DLR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DLR.parquet
#
# Processing DLTR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DLTR.parquet
#
# Processing DLX …
# ⚠ VALIDATION: DLX | adj_factor_jump | max jump 0.298
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DLX.parquet
#
# Processing DNB1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DNB1.parquet
#
# Processing DNB2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DNB2.parquet
#
# Processing DNB3 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DNB3.parquet
#
# Processing DNRCQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DNRCQ.parquet
#
# Processing DOC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DOC.parquet
#
# Processing DOFSQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DOFSQ.parquet
#
# Processing DOV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DOV.parquet
#
# Processing DOW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DOW.parquet
#
# Processing DPHIQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DPHIQ.parquet
#
# Processing DPZ …
# ⚠ VALIDATION: DPZ | adj_factor_jump | max jump 0.688
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DPZ.parquet
#
# Processing DRE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DRE.parquet
#
# Processing DRI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DRI.parquet
#
# Processing DTE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DTE.parquet
#
# Processing DTV1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DTV1.parquet
#
# Processing DUK …
# ⚠ VALIDATION: DUK | adj_factor_jump | max jump 0.725
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DUK.parquet
#
# Processing DVA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DVA.parquet
#
# Processing DVN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DVN.parquet
#
# Processing DXC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DXC.parquet
#
# Processing DXCM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DXCM.parquet
#
# Processing DYNIQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\DYNIQ.parquet
#
# Processing EA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EA.parquet
#
# Processing EBAY …
# ⚠ VALIDATION: EBAY | adj_factor_jump | max jump 1.344
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EBAY.parquet
#
# Processing EC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EC1.parquet
#
# Processing ECH1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ECH1.parquet
#
# Processing ECL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ECL.parquet
#
# Processing ECO1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ECO1.parquet
#
# Processing ED …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ED.parquet
#
# Processing EDS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EDS.parquet
#
# Processing EFU1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EFU1.parquet
#
# Processing EFX …
# ⚠ VALIDATION: EFX | adj_factor_jump | max jump 0.698
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EFX.parquet
#
# Processing EG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EG.parquet
#
# Processing EHC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EHC.parquet
#
# Processing EIX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EIX.parquet
#
# Processing EKDKQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EKDKQ.parquet
#
# Processing EL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EL.parquet
#
# Processing ELV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ELV.parquet
#
# Processing EMC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EMC1.parquet
#
# Processing EME …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EME.parquet
#
# Processing EMN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EMN.parquet
#
# Processing EMR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EMR.parquet
#
# Processing ENDPQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ENDPQ.parquet
#
# Processing ENPH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ENPH.parquet
#
# Processing ENRNQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ENRNQ.parquet
#
# Processing EOG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EOG.parquet
#
# Processing EOP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EOP.parquet
#
# Processing EP1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EP1.parquet
#
# Processing EPAM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EPAM.parquet
#
# Processing EQ1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EQ1.parquet
#
# Processing EQIX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EQIX.parquet
#
# Processing EQR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EQR.parquet
#
# Processing EQT …
# ⚠ VALIDATION: EQT | adj_factor_jump | max jump 0.841
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EQT.parquet
#
# Processing ERIE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ERIE.parquet
#
# Processing ES …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ES.parquet
#
# Processing ESRX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ESRX.parquet
#
# Processing ESS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ESS.parquet
#
# Processing ETFC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ETFC.parquet
#
# Processing ETN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ETN.parquet
#
# Processing ETR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ETR.parquet
#
# Processing ETS1 …
# ⚠ VALIDATION: ETS1 | adj_factor_jump | max jump 0.577
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ETS1.parquet
#
# Processing ETSY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ETSY.parquet
#
# Processing EVHC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EVHC.parquet
#
# Processing EVRG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EVRG.parquet
#
# Processing EW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EW.parquet
#
# Processing EXC …
# ⚠ VALIDATION: EXC | adj_factor_jump | max jump 0.389
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EXC.parquet
#
# Processing EXE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EXE.parquet
#
# Processing EXPD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EXPD.parquet
#
# Processing EXPE …
# ⚠ VALIDATION: EXPE | adj_factor_jump | max jump 0.986
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EXPE.parquet
#
# Processing EXR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\EXR.parquet
#
# Processing F …
# ⚠ VALIDATION: F | adj_factor_jump | max jump 0.684
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\F.parquet
#
# Processing FANG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FANG.parquet
#
# Processing FAST …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FAST.parquet
#
# Processing FBF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FBF.parquet
#
# Processing FBIN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FBIN.parquet
#
# Processing FCN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FCN1.parquet
#
# Processing FCX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FCX.parquet
#
# Processing FDC1 …
# ⚠ VALIDATION: FDC1 | adj_factor_jump | max jump 0.818
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FDC1.parquet
#
# Processing FDO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FDO.parquet
#
# Processing FDS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FDS.parquet
#
# Processing FDX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FDX.parquet
#
# Processing FE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FE.parquet
#
# Processing FFIV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FFIV.parquet
#
# Processing FG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FG1.parquet
#
# Processing FHI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FHI.parquet
#
# Processing FHN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FHN.parquet
#
# Processing FICO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FICO.parquet
#
# Processing FIS …
# ⚠ VALIDATION: FIS | adj_factor_jump | max jump 0.819
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FIS.parquet
#
# Processing FISV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FISV.parquet
#
# Processing FITB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FITB.parquet
#
# Processing FIX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FIX.parquet
#
# Processing FJ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FJ.parquet
#
# Processing FL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FL.parquet
#
# Processing FLIR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FLIR.parquet
#
# Processing FLMIQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FLMIQ.parquet
#
# Processing FLR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FLR.parquet
#
# Processing FLS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FLS.parquet
#
# Processing FLTWQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FLTWQ.parquet
#
# Processing FMC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FMC.parquet
#
# Processing FMCC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FMCC.parquet
#
# Processing FMY1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FMY1.parquet
#
# Processing FNMA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FNMA.parquet
#
# Processing FOSL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FOSL.parquet
#
# Processing FOX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FOX.parquet
#
# Processing FOXA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FOXA.parquet
#
# Processing FPC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FPC.parquet
#
# Processing FRCB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FRCB.parquet
#
# Processing FRO1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FRO1.parquet
#
# Processing FRT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FRT.parquet
#
# Processing FRX1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FRX1.parquet
#
# Processing FSH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FSH.parquet
#
# Processing FSL.B …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FSL.B.parquet
#
# Processing FSLR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FSLR.parquet
#
# Processing FTI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FTI.parquet
#
# Processing FTI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FTI1.parquet
#
# Processing FTL.A …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FTL.A.parquet
#
# Processing FTNT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FTNT.parquet
#
# Processing FTRCQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FTRCQ.parquet
#
# Processing FTV …
# ⚠ VALIDATION: FTV | adj_factor_jump | max jump 0.339
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FTV.parquet
#
# Processing FWLT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\FWLT.parquet
#
# Processing G1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\G1.parquet
#
# Processing GAP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GAP.parquet
#
# Processing GAPTQ …
# ⚠ VALIDATION: GAPTQ | adj_factor_jump | max jump 0.261
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GAPTQ.parquet
#
# Processing GAS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GAS.parquet
#
# Processing GAS1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GAS1.parquet
#
# Processing GD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GD.parquet
#
# Processing GDDY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GDDY.parquet
#
# Processing GDT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GDT.parquet
#
# Processing GDW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GDW.parquet
#
# Processing GE …
# ⚠ VALIDATION: GE | adj_factor_jump | max jump 0.273
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GE.parquet
#
# Processing GEHC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GEHC.parquet
#
# Processing GEN …
# ⚠ VALIDATION: GEN | adj_factor_jump | max jump 0.700
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GEN.parquet
#
# Processing GEN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GEN1.parquet
#
# Processing GENZ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GENZ.parquet
#
# Processing GEV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GEV.parquet
#
# Processing GFS.A …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GFS.A.parquet
#
# Processing GGP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GGP.parquet
#
# Processing GHC …
# ⚠ VALIDATION: GHC | adj_factor_jump | max jump 0.613
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GHC.parquet
#
# Processing GIC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GIC1.parquet
#
# Processing GILD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GILD.parquet
#
# Processing GIS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GIS.parquet
#
# Processing GL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GL.parquet
#
# Processing GLK1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GLK1.parquet
#
# Processing GLW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GLW.parquet
#
# Processing GM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GM.parquet
#
# Processing GMCR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GMCR.parquet
#
# Processing GME …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GME.parquet
#
# Processing GNRC …
# ⚠ VALIDATION: GNRC | adj_factor_jump | max jump 0.289
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GNRC.parquet
#
# Processing GNT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GNT1.parquet
#
# Processing GNW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GNW.parquet
#
# Processing GOOG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GOOG.parquet
#
# Processing GOOGL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GOOGL.parquet
#
# Processing GOSHA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GOSHA.parquet
#
# Processing GP1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GP1.parquet
#
# Processing GPC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GPC.parquet
#
# Processing GPN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GPN.parquet
#
# Processing GPU …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GPU.parquet
#
# Processing GR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GR.parquet
#
# Processing GRA …
# ⚠ VALIDATION: GRA | adj_factor_jump | max jump 3.254
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GRA.parquet
#
# Processing GRMN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GRMN.parquet
#
# Processing GRN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GRN1.parquet
#
# Processing GS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GS.parquet
#
# Processing GSX1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GSX1.parquet
#
# Processing GT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GT.parquet
#
# Processing GTE1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GTE1.parquet
#
# Processing GTW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GTW.parquet
#
# Processing GWOW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GWOW.parquet
#
# Processing GWW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GWW.parquet
#
# Processing GX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\GX.parquet
#
# Processing H1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\H1.parquet
#
# Processing H2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\H2.parquet
#
# Processing HAL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HAL.parquet
#
# Processing HAR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HAR.parquet
#
# Processing HAS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HAS.parquet
#
# Processing HBAN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HBAN.parquet
#
# Processing HBI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HBI.parquet
#
# Processing HBOC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HBOC.parquet
#
# Processing HCA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HCA.parquet
#
# Processing HCA1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HCA1.parquet
#
# Processing HCBK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HCBK.parquet
#
# Processing HCR1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HCR1.parquet
#
# Processing HD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HD.parquet
#
# Processing HES …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HES.parquet
#
# Processing HET …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HET.parquet
#
# Processing HI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HI1.parquet
#
# Processing HIG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HIG.parquet
#
# Processing HII …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HII.parquet
#
# Processing HLT …
# ⚠ VALIDATION: HLT | adj_factor_jump | max jump 0.422
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HLT.parquet
#
# Processing HLT1 …
# ⚠ VALIDATION: HLT1 | adj_factor_jump | max jump 0.479
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HLT1.parquet
#
# Processing HM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HM.parquet
#
# Processing HMA1 …
# ⚠ VALIDATION: HMA1 | adj_factor_jump | max jump 0.972
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HMA1.parquet
#
# Processing HNZ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HNZ.parquet
#
# Processing HOG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HOG.parquet
#
# Processing HOLX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HOLX.parquet
#
# Processing HON …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HON.parquet
#
# Processing HON1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HON1.parquet
#
# Processing HOOD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HOOD.parquet
#
# Processing HOT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HOT.parquet
#
# Processing HP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HP.parquet
#
# Processing HPC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HPC.parquet
#
# Processing HPE …
# ⚠ VALIDATION: HPE | adj_factor_jump | max jump 0.330
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HPE.parquet
#
# Processing HPQ …
# ⚠ VALIDATION: HPQ | adj_factor_jump | max jump 1.202
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HPQ.parquet
#
# Processing HRB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HRB.parquet
#
# Processing HRL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HRL.parquet
#
# Processing HRZIQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HRZIQ.parquet
#
# Processing HSH …
# ⚠ VALIDATION: HSH | adj_factor_jump | max jump 2.208
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HSH.parquet
#
# Processing HSIC …
# ⚠ VALIDATION: HSIC | adj_factor_jump | max jump 0.285
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HSIC.parquet
#
# Processing HSP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HSP.parquet
#
# Processing HST …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HST.parquet
#
# Processing HSY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HSY.parquet
#
# Processing HUBB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HUBB.parquet
#
# Processing HUM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HUM.parquet
#
# Processing HWM …
# ⚠ VALIDATION: HWM | adj_factor_jump | max jump 0.331
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\HWM.parquet
#
# Processing IBKR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IBKR.parquet
#
# Processing IBM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IBM.parquet
#
# Processing ICE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ICE.parquet
#
# Processing IDXX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IDXX.parquet
#
# Processing IEX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IEX.parquet
#
# Processing IFF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IFF.parquet
#
# Processing IGT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IGT1.parquet
#
# Processing IKN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IKN.parquet
#
# Processing ILMN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ILMN.parquet
#
# Processing IMNX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IMNX.parquet
#
# Processing INCLF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\INCLF.parquet
#
# Processing INCY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\INCY.parquet
#
# Processing INFO1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\INFO1.parquet
#
# Processing INTC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\INTC.parquet
#
# Processing INTU …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\INTU.parquet
#
# Processing INVH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\INVH.parquet
#
# Processing IP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IP.parquet
#
# Processing IPG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IPG.parquet
#
# Processing IPGP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IPGP.parquet
#
# Processing IQV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IQV.parquet
#
# Processing IR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IR.parquet
#
# Processing IRM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IRM.parquet
#
# Processing ISRG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ISRG.parquet
#
# Processing IT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IT.parquet
#
# Processing ITT …
# ⚠ VALIDATION: ITT | adj_factor_jump | max jump 4.047
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ITT.parquet
#
# Processing ITT1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ITT1.parquet
#
# Processing ITW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ITW.parquet
#
# Processing IVZ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\IVZ.parquet
#
# Processing J …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\J.parquet
#
# Processing JAVA1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JAVA1.parquet
#
# Processing JBHT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JBHT.parquet
#
# Processing JBL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JBL.parquet
#
# Processing JCI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JCI.parquet
#
# Processing JEF …
# ⚠ VALIDATION: JEF | adj_factor_jump | max jump 0.578
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JEF.parquet
#
# Processing JH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JH.parquet
#
# Processing JHF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JHF.parquet
#
# Processing JKHY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JKHY.parquet
#
# Processing JM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JM.parquet
#
# Processing JNJ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JNJ.parquet
#
# Processing JNPR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JNPR.parquet
#
# Processing JNS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JNS.parquet
#
# Processing JNY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JNY.parquet
#
# Processing JOS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JOS.parquet
#
# Processing JOY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JOY.parquet
#
# Processing JP1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JP1.parquet
#
# Processing JPM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JPM.parquet
#
# Processing JPM1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JPM1.parquet
#
# Processing JWN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\JWN.parquet
#
# Processing K …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\K.parquet
#
# Processing KATE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KATE.parquet
#
# Processing KBH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KBH.parquet
#
# Processing KDP …
# ⚠ VALIDATION: KDP | adj_factor_jump | max jump 4.676
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KDP.parquet
#
# Processing KEY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KEY.parquet
#
# Processing KEYS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KEYS.parquet
#
# Processing KG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KG1.parquet
#
# Processing KHC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KHC.parquet
#
# Processing KIM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KIM.parquet
#
# Processing KKR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KKR.parquet
#
# Processing KLAC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KLAC.parquet
#
# Processing KM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KM.parquet
#
# Processing KMB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KMB.parquet
#
# Processing KMG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KMG1.parquet
#
# Processing KMI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KMI.parquet
#
# Processing KMI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KMI1.parquet
#
# Processing KMX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KMX.parquet
#
# Processing KO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KO.parquet
#
# Processing KR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KR.parquet
#
# Processing KRB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KRB.parquet
#
# Processing KRFT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KRFT.parquet
#
# Processing KRI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KRI.parquet
#
# Processing KSE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KSE.parquet
#
# Processing KSS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KSS.parquet
#
# Processing KSU …
# ⚠ VALIDATION: KSU | adj_factor_jump | max jump 28.962
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KSU.parquet
#
# Processing KVUE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KVUE.parquet
#
# Processing KWP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\KWP.parquet
#
# Processing L …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\L.parquet
#
# Processing LDG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LDG.parquet
#
# Processing LDOS …
# ⚠ VALIDATION: LDOS | adj_factor_jump | max jump 0.469
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LDOS.parquet
#
# Processing LDWIF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LDWIF.parquet
#
# Processing LEG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LEG.parquet
#
# Processing LEHMQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LEHMQ.parquet
#
# Processing LEN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LEN.parquet
#
# Processing LH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LH.parquet
#
# Processing LHX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LHX.parquet
#
# Processing LIFE2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LIFE2.parquet
#
# Processing LII …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LII.parquet
#
# Processing LIN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LIN.parquet
#
# Processing LKQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LKQ.parquet
#
# Processing LLL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LLL1.parquet
#
# Processing LLTC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LLTC.parquet
#
# Processing LLY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LLY.parquet
#
# Processing LM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LM.parquet
#
# Processing LMT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LMT.parquet
#
# Processing LNC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LNC.parquet
#
# Processing LNT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\LNT.parquet
#
# Processing LO …
# ...
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SRE.parquet
#
# Processing SSP …
# ⚠ VALIDATION: SSP | adj_factor_jump | max jump 12.007
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SSP.parquet
#
# Processing STE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STE.parquet
#
# Processing STI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STI1.parquet
#
# Processing STJ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STJ.parquet
#
# Processing STLD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STLD.parquet
#
# Processing STO1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STO1.parquet
#
# Processing STR1 …
# ⚠ VALIDATION: STR1 | adj_factor_jump | max jump 1.986
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STR1.parquet
#
# Processing STT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STT.parquet
#
# Processing STX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STX.parquet
#
# Processing STZ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\STZ.parquet
#
# Processing SUB1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SUB1.parquet
#
# Processing SUN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SUN1.parquet
#
# Processing SUNEQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SUNEQ.parquet
#
# Processing SVU …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SVU.parquet
#
# Processing SW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SW.parquet
#
# Processing SWK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SWK.parquet
#
# Processing SWKS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SWKS.parquet
#
# Processing SWN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SWN.parquet
#
# Processing SWY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SWY.parquet
#
# Processing SXCL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SXCL.parquet
#
# Processing SYF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SYF.parquet
#
# Processing SYK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SYK.parquet
#
# Processing SYY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\SYY.parquet
#
# Processing T …
# ⚠ VALIDATION: T | adj_factor_jump | max jump 0.301
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\T.parquet
#
# Processing T1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\T1.parquet
#
# Processing TA2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TA2.parquet
#
# Processing TAP.B …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TAP.B.parquet
#
# Processing TAP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TAP.parquet
#
# Processing TCOMA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TCOMA.parquet
#
# Processing TDC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TDC.parquet
#
# Processing TDG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TDG.parquet
#
# Processing TDY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TDY.parquet
#
# Processing TE1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TE1.parquet
#
# Processing TECH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TECH.parquet
#
# Processing TEG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TEG.parquet
#
# Processing TEK1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TEK1.parquet
#
# Processing TEL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TEL.parquet
#
# Processing TEN1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TEN1.parquet
#
# Processing TER …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TER.parquet
#
# Processing TEX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TEX.parquet
#
# Processing TFC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TFC.parquet
#
# Processing TFCF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TFCF.parquet
#
# Processing TFCFA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TFCFA.parquet
#
# Processing TFX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TFX.parquet
#
# Processing TGNA …
# ⚠ VALIDATION: TGNA | adj_factor_jump | max jump 0.569
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TGNA.parquet
#
# Processing TGT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TGT.parquet
#
# Processing THC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\THC.parquet
#
# Processing TIE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TIE.parquet
#
# Processing TIF …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TIF.parquet
#
# Processing TIN …
# ⚠ VALIDATION: TIN | adj_factor_jump | max jump 0.593
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TIN.parquet
#
# Processing TJX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TJX.parquet
#
# Processing TKO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TKO.parquet
#
# Processing TKR …
# ⚠ VALIDATION: TKR | adj_factor_jump | max jump 0.400
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TKR.parquet
#
# Processing TLAB …
# ⚠ VALIDATION: TLAB | adj_factor_jump | max jump 0.389
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TLAB.parquet
#
# Processing TMC.A …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TMC.A.parquet
#
# Processing TMO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TMO.parquet
#
# Processing TMUS …
# ⚠ VALIDATION: TMUS | adj_factor_jump | max jump 0.490
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TMUS.parquet
#
# Processing TNB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TNB.parquet
#
# Processing TNL …
# ⚠ VALIDATION: TNL | adj_factor_jump | max jump 1.223
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TNL.parquet
#
# Processing TOS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TOS.parquet
#
# Processing TOY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TOY.parquet
#
# Processing TPL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TPL.parquet
#
# Processing TPR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TPR.parquet
#
# Processing TRB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TRB.parquet
#
# Processing TRGP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TRGP.parquet
#
# Processing TRIP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TRIP.parquet
#
# Processing TRMB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TRMB.parquet
#
# Processing TROW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TROW.parquet
#
# Processing TRV …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TRV.parquet
#
# Processing TRW1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TRW1.parquet
#
# Processing TSCO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TSCO.parquet
#
# Processing TSG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TSG1.parquet
#
# Processing TSLA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TSLA.parquet
#
# Processing TSN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TSN.parquet
#
# Processing TSS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TSS.parquet
#
# Processing TT …
# ⚠ VALIDATION: TT | adj_factor_jump | max jump 0.297
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TT.parquet
#
# Processing TT2 …
# ⚠ VALIDATION: TT2 | adj_factor_jump | max jump 0.421
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TT2.parquet
#
# Processing TTD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TTD.parquet
#
# Processing TTWO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TTWO.parquet
#
# Processing TUPBQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TUPBQ.parquet
#
# Processing TWC …
# ⚠ VALIDATION: TWC | adj_factor_jump | max jump 1.513
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TWC.parquet
#
# Processing TWTR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TWTR.parquet
#
# Processing TWX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TWX.parquet
#
# Processing TWX1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TWX1.parquet
#
# Processing TX1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TX1.parquet
#
# Processing TXN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TXN.parquet
#
# Processing TXT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TXT.parquet
#
# Processing TXU …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TXU.parquet
#
# Processing TYC …
# ⚠ VALIDATION: TYC | adj_factor_jump | max jump 1.659
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TYC.parquet
#
# Processing TYL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\TYL.parquet
#
# Processing UA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UA.parquet
#
# Processing UAA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UAA.parquet
#
# Processing UAL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UAL.parquet
#
# Processing UAWGQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UAWGQ.parquet
#
# Processing UBER …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UBER.parquet
#
# Processing UCC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UCC1.parquet
#
# Processing UCL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UCL1.parquet
#
# Processing UCM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UCM.parquet
#
# Processing UDR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UDR.parquet
#
# Processing UHS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UHS.parquet
#
# Processing UIS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UIS.parquet
#
# Processing UK1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UK1.parquet
#
# Processing UL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UL.parquet
#
# Processing ULTA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ULTA.parquet
#
# Processing UNH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UNH.parquet
#
# Processing UNM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UNM.parquet
#
# Processing UNP …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UNP.parquet
#
# Processing UPC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UPC1.parquet
#
# Processing UPR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UPR.parquet
#
# Processing UPS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UPS.parquet
#
# Processing URBN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\URBN.parquet
#
# Processing URI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\URI.parquet
#
# Processing USB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\USB.parquet
#
# Processing USB1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\USB1.parquet
#
# Processing USG1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\USG1.parquet
#
# Processing USS1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\USS1.parquet
#
# Processing UST1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UST1.parquet
#
# Processing USW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\USW.parquet
#
# Processing UVN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\UVN.parquet
#
# Processing V …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\V.parquet
#
# Processing VALPQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VALPQ.parquet
#
# Processing VAR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VAR.parquet
#
# Processing VFC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VFC.parquet
#
# Processing VIAB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VIAB.parquet
#
# Processing VIAV …
# ⚠ VALIDATION: VIAV | adj_factor_jump | max jump 0.752
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VIAV.parquet
#
# Processing VICI …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VICI.parquet
#
# Processing VLO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VLO.parquet
#
# Processing VLTO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VLTO.parquet
#
# Processing VMC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VMC.parquet
#
# Processing VNO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VNO.parquet
#
# Processing VNT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VNT.parquet
#
# Processing VO1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VO1.parquet
#
# Processing VRSK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VRSK.parquet
#
# Processing VRSN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VRSN.parquet
#
# Processing VRTS1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VRTS1.parquet
#
# Processing VRTX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VRTX.parquet
#
# Processing VST …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VST.parquet
#
# Processing VSTNQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VSTNQ.parquet
#
# Processing VTR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VTR.parquet
#
# Processing VTRS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VTRS.parquet
#
# Processing VTSS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VTSS.parquet
#
# Processing VYX …
# ⚠ VALIDATION: VYX | adj_factor_jump | max jump 1.090
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VYX.parquet
#
# Processing VZ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\VZ.parquet
#
# Processing WAB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WAB.parquet
#
# Processing WAI1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WAI1.parquet
#
# Processing WAMUQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WAMUQ.parquet
#
# Processing WAT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WAT.parquet
#
# Processing WB1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WB1.parquet
#
# Processing WB2 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WB2.parquet
#
# Processing WBA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WBA.parquet
#
# Processing WBD …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WBD.parquet
#
# Processing WCG …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WCG.parquet
#
# Processing WCOEQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WCOEQ.parquet
#
# Processing WDAY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WDAY.parquet
#
# Processing WDC …
# ⚠ VALIDATION: WDC | adj_factor_jump | max jump 0.342
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WDC.parquet
#
# Processing WEC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WEC.parquet
#
# Processing WELL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WELL.parquet
#
# Processing WEN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WEN.parquet
#
# Processing WFC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WFC.parquet
#
# Processing WFC1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WFC1.parquet
#
# Processing WFM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WFM.parquet
#
# Processing WFTIQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WFTIQ.parquet
#
# Processing WGL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WGL.parquet
#
# Processing WHR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WHR.parquet
#
# Processing WINMQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WINMQ.parquet
#
# Processing WLA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WLA.parquet
#
# Processing WLL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WLL1.parquet
#
# Processing WLP1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WLP1.parquet
#
# Processing WM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WM.parquet
#
# Processing WMB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WMB.parquet
#
# Processing WMT …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WMT.parquet
#
# Processing WNDXQ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WNDXQ.parquet
#
# Processing WOR …
# ⚠ VALIDATION: WOR | adj_factor_jump | max jump 0.604
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WOR.parquet
#
# Processing WPX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WPX.parquet
#
# Processing WRB …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WRB.parquet
#
# Processing WRK …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WRK.parquet
#
# Processing WSM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WSM.parquet
#
# Processing WST …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WST.parquet
#
# Processing WTW …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WTW.parquet
#
# Processing WU …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WU.parquet
#
# Processing WWY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WWY.parquet
#
# Processing WY …
# ⚠ VALIDATION: WY | adj_factor_jump | max jump 1.661
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WY.parquet
#
# Processing WYE …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WYE.parquet
#
# Processing WYNN …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\WYNN.parquet
#
# Processing X …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\X.parquet
#
# Processing XEC …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XEC.parquet
#
# Processing XEL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XEL.parquet
#
# Processing XL1 …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XL1.parquet
#
# Processing XLNX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XLNX.parquet
#
# Processing XOM …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XOM.parquet
#
# Processing XRAY …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XRAY.parquet
#
# Processing XRX …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XRX.parquet
#
# Processing XTO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XTO.parquet
#
# Processing XYL …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XYL.parquet
#
# Processing XYZ …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\XYZ.parquet
#
# Processing YHOO …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\YHOO.parquet
#
# Processing YNR …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\YNR.parquet
#
# Processing YUM …
# ⚠ VALIDATION: YUM | adj_factor_jump | max jump 0.399
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\YUM.parquet
#
# Processing ZBH …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ZBH.parquet
#
# Processing ZBRA …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ZBRA.parquet
#
# Processing ZION …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ZION.parquet
#
# Processing ZTS …
# ✔ Saved → ./3-adjusted_All_Prices_OHLC\ZTS.parquet
#
#
# ====================================================
#  VALIDATION SUMMARY
# ====================================================
#     ticker            issue          detail
# 0        A  adj_factor_jump  max jump 0.384
# 1    AAMRQ  adj_factor_jump  max jump 0.982
# 2      ABT  adj_factor_jump  max jump 1.081
# 3     ACAS  adj_factor_jump  max jump 0.327
# 4     ACV1  adj_factor_jump  max jump 1.540
# ..     ...              ...             ...
# 99     VYX  adj_factor_jump  max jump 1.090
# 100    WDC  adj_factor_jump  max jump 0.342
# 101    WOR  adj_factor_jump  max jump 0.604
# 102     WY  adj_factor_jump  max jump 1.661
# 103    YUM  adj_factor_jump  max jump 0.399
#
# [104 rows x 3 columns]
#
# Saved validation → ./system_verification/3-adjusted_All_Prices_OHLC\adjusted_price_validation-20251231-083623.csv
# ====================================================

# %%
import pandas as pd
aapl_df = pd.read_parquet(os.path.join(OUTPUT_DIR, "apa.parquet"))
print(aapl_df.head())
print(f"\nShape: {aapl_df.shape}")
print(f"Columns: {list(aapl_df.columns)}")
# Out:
#   ticker       date    open    high     low   close     volume  closeadj  \
# 0    APA 1997-12-31  17.125  17.625  17.095  17.530  1603000.0    11.927
# 1    APA 1998-01-02  17.595  17.595  17.030  17.030   621000.0    11.587
# 2    APA 1998-01-05  17.280  17.280  16.530  16.565  1675000.0    11.271
# 3    APA 1998-01-06  16.315  16.500  16.125  16.250  2998000.0    11.056
# 4    APA 1998-01-07  16.440  16.625  15.940  16.095  1714000.0    10.951
#
#    closeunadj lastupdated  adj_factor   open_adj   high_adj    low_adj  \
# 0       35.06  2025-10-23    0.680376  11.651448  11.991636  11.631036
# 1       34.06  2025-10-23    0.680388  11.971419  11.971419  11.587000
# 2       33.13  2025-10-23    0.680411  11.757494  11.757494  11.247186
# 3       32.50  2025-10-23    0.680369  11.100224  11.226092  10.970954
# 4       32.19  2025-10-23    0.680398  11.185737  11.311611  10.845538
#
#    close_adj
# 0     11.927
# 1     11.587
# 2     11.271
# 3     11.056
# 4     10.951
#
# Shape: (7043, 15)
# Columns: ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'closeadj', 'closeunadj', 'lastupdated', 'adj_factor', 'open_adj', 'high_adj', 'low_adj', 'close_adj']

# %%
# Filter apa data for the specified date range and export to CSV
start_date = "2020-01-01"
end_date = "2020-06-03"

aapl_df = pd.read_parquet(os.path.join(OUTPUT_DIR, "apa.parquet"))
aapl_df["date"] = pd.to_datetime(aapl_df["date"])

# Filter by date range
filtered_df = aapl_df[(aapl_df["date"] >= start_date) & (aapl_df["date"] <= end_date)]

# Export to CSV
csv_output_path = os.path.join(OUTPUT_DIR, "apa_2020-01-01_to_2020-06-03.csv")
filtered_df.to_csv(csv_output_path, index=False)

print(f"✔ Exported {len(filtered_df)} rows to {csv_output_path}")
print(f"\nDate range: {filtered_df['date'].min()} to {filtered_df['date'].max()}")
print(f"\nFirst few rows:")
print(filtered_df.head())
# Out:
# ✔ Exported 106 rows to ./3-adjusted_All_Prices_OHLC\apa_2020-01-01_to_2020-06-03.csv
#
# Date range: 2020-01-02 00:00:00 to 2020-06-03 00:00:00
#
# First few rows:
#      ticker       date   open   high     low  close      volume  closeadj  \
# 5536    APA 2020-01-02  25.70  25.93  25.130  25.36   3395000.0    21.887
# 5537    APA 2020-01-03  25.71  26.14  25.530  25.69   5941000.0    22.172
# 5538    APA 2020-01-06  25.94  25.98  25.165  25.64   4470000.0    22.129
# 5539    APA 2020-01-07  29.93  32.58  29.500  32.51  37027000.0    28.058
# 5540    APA 2020-01-08  32.51  33.21  32.040  32.73  13506000.0    28.248
#
#       closeunadj lastupdated  adj_factor   open_adj   high_adj    low_adj  \
# 5536       25.36  2025-10-23    0.863052  22.180438  22.378940  21.688498
# 5537       25.69  2025-10-23    0.863060  22.189261  22.560377  22.033910
# 5538       25.64  2025-10-23    0.863066  22.387920  22.422442  21.719044
# 5539       32.51  2025-10-23    0.863058  25.831312  28.118414  25.460197
# 5540       32.73  2025-10-23    0.863061  28.058126  28.662269  27.652488
#
#       close_adj
# 5536     21.887
# 5537     22.172
# 5538     22.129
# 5539     28.058
# 5540     28.248

# %%
from pathlib import Path
import pandas as pd

# --- settings ---
BASE_DIR = Path("./3-adjusted_All_Prices_OHLC")   # <-- must be Path, not str
TICKER = "NVDA"
start_date = pd.Timestamp("2003-05-01")
end_date   = pd.Timestamp("2003-09-03")

parquet_path = BASE_DIR / f"{TICKER}.parquet"
print("Reading parquet:", parquet_path)

if not parquet_path.exists():
    print("❌ File not found:", parquet_path)
    print("\nHere are similar files in the folder (first 50):")
    files = sorted(BASE_DIR.glob("*.parquet"))
    for f in files[:50]:
        print("  ", f.name)
    raise FileNotFoundError(parquet_path)

df = pd.read_parquet(parquet_path)

# --- find date column robustly ---
date_col = None
for c in ["date", "Date", "datetime", "timestamp"]:
    if c in df.columns:
        date_col = c
        break
if date_col is None:
    raise KeyError(f"No date-like column found. Columns are: {list(df.columns)}")

df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
df = df.dropna(subset=[date_col])

print("Columns:", list(df.columns))
print("File date range:", df[date_col].min(), "to", df[date_col].max())

# Filter by date range
filtered = df[df[date_col].between(start_date, end_date, inclusive="both")].copy()

csv_output_path = BASE_DIR / f"{TICKER}_{start_date.date()}_to_{end_date.date()}.csv"
filtered.to_csv(csv_output_path, index=False)

print(f"✔ Exported {len(filtered):,} rows to {csv_output_path}")

if len(filtered) > 0:
    print("Filtered date range:", filtered[date_col].min(), "to", filtered[date_col].max())
    print(filtered.head())
else:
    print("⚠️ 0 rows after filtering. (Either no data in that range, or date column isn’t what we think.)")
# Out:
# Reading parquet: 3-adjusted_All_Prices_OHLC\NVDA.parquet
# Columns: ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'closeadj', 'closeunadj', 'lastupdated', 'adj_factor', 'open_adj', 'high_adj', 'low_adj', 'close_adj']
# File date range: 1999-01-22 00:00:00 to 2025-12-30 00:00:00
# ✔ Exported 87 rows to 3-adjusted_All_Prices_OHLC\NVDA_2003-05-01_to_2003-09-03.csv
# Filtered date range: 2003-05-01 00:00:00 to 2003-09-03 00:00:00
#      ticker       date   open   high    low  close        volume  closeadj  \
# 1073   NVDA 2003-05-01  0.119  0.121  0.118  0.120  7.333680e+08     0.110
# 1074   NVDA 2003-05-02  0.122  0.133  0.121  0.133  1.691088e+09     0.122
# 1075   NVDA 2003-05-05  0.134  0.142  0.131  0.136  1.576164e+09     0.124
# 1076   NVDA 2003-05-06  0.135  0.139  0.133  0.136  1.143864e+09     0.125
# 1077   NVDA 2003-05-07  0.134  0.137  0.131  0.134  8.973720e+08     0.123
#
#       closeunadj lastupdated  adj_factor  open_adj  high_adj   low_adj  \
# 1073       14.42  2025-12-04    0.916667  0.109083  0.110917  0.108167
# 1074       15.90  2025-12-04    0.917293  0.111910  0.122000  0.110992
# 1075       16.29  2025-12-04    0.911765  0.122176  0.129471  0.119441
# 1076       16.31  2025-12-04    0.919118  0.124081  0.127757  0.122243
# 1077       16.05  2025-12-04    0.917910  0.123000  0.125754  0.120246
#
#       close_adj
# 1073      0.110
# 1074      0.122
# 1075      0.124
# 1076      0.125
# 1077      0.123
