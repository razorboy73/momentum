# %%
"""
===============================================================================
DOWNLOAD FULL SHARADAR/SEP PRICE HISTORY FOR ALL S&P 500 TICKERS regardless of membership status
===============================================================================
Adds DIAGNOSTICS:
 - Less than 100 days of price data after Jan 1, 1998
 - No price data at all
 - Last price date older than 30 days
 - Very early termination (possible delisting)
 - Very late start (recent IPO)
 - Large gaps in trading history (>10 days)
 

Downloads full SHARADAR/SEP price history for every ticker that has ever appeared in the S&P 500,
saving per-ticker CSVs in ./2-all_prices/sharadar_sep_full. Loads the membership list from the
daily matrix, fetches data in chunks with API key configured via NASDAQ_DATA_LINK_API_KEY, and
prints diagnostics for missing data, short histories after 1998, stale prices (>30 days), very
late starts, very early terminations, and large gaps (>10 days) between trading days.

===============================================================================
"""

import os
import pandas as pd
import numpy as np
import nasdaqdatalink
import time
from datetime import datetime, timedelta

# ---------------------------------------------------------
# API KEY (replace if needed)
# ---------------------------------------------------------
nasdaqdatalink_key = os.getenv("NASDAQ_DATA_LINK_API_KEY")
nasdaqdatalink.ApiConfig.api_key = nasdaqdatalink_key


# ============================================================
# 1. CONFIG
# ============================================================
MEMBERSHIP_FILE = "./1-sp500_membership_daily_matrix/sp500_membership_full.parquet"

OUTPUT_DIR = "./2-all_prices/sharadar_sep_full"
os.makedirs(OUTPUT_DIR, exist_ok=True)

CHUNK_SIZE = 40   # safe for API limits

START_DATE = pd.Timestamp("1998-01-01")
TODAY = pd.Timestamp.today().normalize()

# ============================================================
# 2. LOAD MEMBERSHIP
# ============================================================
print("Loading membership matrix…")
membership = pd.read_parquet(MEMBERSHIP_FILE)
all_tickers = sorted(membership.index.tolist())

print(f"✔ Loaded {len(all_tickers)} unique historical S&P 500 tickers")
print(f"Membership covers: {membership.columns.min()} → {membership.columns.max()}")


# ============================================================
# 3. DOWNLOAD SHARADAR/SEP DATA
# ============================================================
print("\nDownloading SHARADAR/SEP…")
all_parts = []

for i in range(0, len(all_tickers), CHUNK_SIZE):
    chunk = all_tickers[i:i+CHUNK_SIZE]
    print(f"→ Chunk {i//CHUNK_SIZE + 1}: {len(chunk)} tickers…")

    df = nasdaqdatalink.get_table(
        "SHARADAR/SEP",
        ticker=chunk,
        paginate=True
    )

    all_parts.append(df)

    time.sleep(1.2)   # rate limit safety

sep = pd.concat(all_parts, ignore_index=True)
sep["date"] = pd.to_datetime(sep["date"])

print(f"\n✔ Downloaded {len(sep):,} rows")
print(f"✔ Unique tickers received: {sep['ticker'].nunique()}")


# ============================================================
# 4. DIAGNOSTIC PRINT UTIL
# ============================================================
def print_flag(ticker, message):
    print(f"⚠ {ticker}: {message}")


# ============================================================
# 5. SAVE FILES + RUN DIAGNOSTICS
# ============================================================
print("\nSaving ticker-level CSV files + running diagnostics…\n")

tickers = sep["ticker"].unique()

for tk in tickers:

    df_tk = sep[sep["ticker"] == tk].sort_values("date")

    # Save file
    out_file = os.path.join(OUTPUT_DIR, f"{tk}.csv")
    df_tk.to_csv(out_file, index=False)

    print(f"Saved: {out_file}")

    # ========================================================
    # DIAGNOSTICS START HERE
    # ========================================================

    if df_tk.empty:
        print_flag(tk, "NO PRICE DATA RECEIVED")
        continue

    df98 = df_tk[df_tk["date"] >= START_DATE]
    n_days = len(df98)

    # 1. <100 days of price data after 1998
    if n_days < 100:
        last_day = df98["date"].max() if n_days > 0 else None
        print_flag(
            tk,
            f"LESS THAN 100 DAYS of price data after 1998 — {n_days} days (last date = {last_day})"
        )

    # 2. Data starts very late (possible recent IPO)
    first_price = df_tk["date"].min()
    if first_price.year > 2015:
        print_flag(tk, f"Recent IPO — first price date is {first_price.date()}")

    # 3. Data ends very early (possible delisting)
    last_price = df_tk["date"].max()
    if last_price < TODAY - pd.Timedelta(days=30):
        print_flag(
            tk,
            f"Data ends at {last_price.date()} — older than 30 days (likely delisted or missing data)"
        )

    # 4. Suspiciously short full history (e.g., <5 years total)
    full_days = len(df_tk)
    if full_days < 250 * 5:
        print_flag(
            tk,
            f"Short full history (<5 years) — only {full_days} trading days total."
        )

    # 5. Detect large gaps (>10 days) between trading days
    dates = df_tk["date"].sort_values()
    gaps = dates.diff().dt.days
    if (gaps > 10).any():
        max_gap = gaps.max()
        print_flag(tk, f"LARGE GAP in data — max gap = {int(max_gap)} days")


print("\n===============================================================================")
print(" DONE — Full SHARADAR/SEP OHLCV + TOTAL-RETURN CLOSE (closeadj) saved per ticker")
print(" Diagnostics printed to terminal.")
print(" Location:", OUTPUT_DIR)
print("===============================================================================")
# Out:
# Loading membership matrix…
# ✔ Loaded 1187 unique historical S&P 500 tickers
# Membership covers: 1957-03-04 00:00:00 → 2025-12-05 00:00:00
#
# Downloading SHARADAR/SEP…
# → Chunk 1: 40 tickers…
# → Chunk 2: 40 tickers…
# → Chunk 3: 40 tickers…
# → Chunk 4: 40 tickers…
# → Chunk 5: 40 tickers…
# → Chunk 6: 40 tickers…
# → Chunk 7: 40 tickers…
# → Chunk 8: 40 tickers…
# → Chunk 9: 40 tickers…
# → Chunk 10: 40 tickers…
# → Chunk 11: 40 tickers…
# → Chunk 12: 40 tickers…
# → Chunk 13: 40 tickers…
# → Chunk 14: 40 tickers…
# → Chunk 15: 40 tickers…
# → Chunk 16: 40 tickers…
# → Chunk 17: 40 tickers…
# → Chunk 18: 40 tickers…
# → Chunk 19: 40 tickers…
# → Chunk 20: 40 tickers…
# → Chunk 21: 40 tickers…
# → Chunk 22: 40 tickers…
# → Chunk 23: 40 tickers…
# → Chunk 24: 40 tickers…
# → Chunk 25: 40 tickers…
# → Chunk 26: 40 tickers…
# → Chunk 27: 40 tickers…
# → Chunk 28: 40 tickers…
# → Chunk 29: 40 tickers…
# → Chunk 30: 27 tickers…
#
# ✔ Downloaded 5,336,685 rows
# ✔ Unique tickers received: 1162
#
# Saving ticker-level CSV files + running diagnostics…
#
# Saved: ./2-all_prices/sharadar_sep_full\AIZ.csv
# Saved: ./2-all_prices/sharadar_sep_full\AIV.csv
# Saved: ./2-all_prices/sharadar_sep_full\AIT.csv
# Saved: ./2-all_prices/sharadar_sep_full\AIG.csv
# Saved: ./2-all_prices/sharadar_sep_full\AHM1.csv
# ⚠ AHM1: Data ends at 1998-10-01 — older than 30 days (likely delisted or missing data)
# ⚠ AHM1: Short full history (<5 years) — only 190 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AGN1.csv
# ⚠ AGN1: Data ends at 2015-03-16 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AGN.csv
# ⚠ AGN: Data ends at 2020-05-08 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AGC1.csv
# ⚠ AGC1: Data ends at 2001-08-28 — older than 30 days (likely delisted or missing data)
# ⚠ AGC1: Short full history (<5 years) — only 923 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AFS.A.csv
# ⚠ AFS.A: Data ends at 2000-11-30 — older than 30 days (likely delisted or missing data)
# ⚠ AFS.A: Short full history (<5 years) — only 737 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AFL.csv
# Saved: ./2-all_prices/sharadar_sep_full\AET.csv
# ⚠ AET: Data ends at 2018-11-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AES.csv
# Saved: ./2-all_prices/sharadar_sep_full\AEP.csv
# Saved: ./2-all_prices/sharadar_sep_full\AEE.csv
# Saved: ./2-all_prices/sharadar_sep_full\ADT1.csv
# ⚠ ADT1: Data ends at 2016-04-29 — older than 30 days (likely delisted or missing data)
# ⚠ ADT1: Short full history (<5 years) — only 910 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\ADSK.csv
# Saved: ./2-all_prices/sharadar_sep_full\ADP.csv
# Saved: ./2-all_prices/sharadar_sep_full\ADM.csv
# Saved: ./2-all_prices/sharadar_sep_full\ADI.csv
# Saved: ./2-all_prices/sharadar_sep_full\ADCT1.csv
# ⚠ ADCT1: Data ends at 2010-12-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ADBE.csv
# Saved: ./2-all_prices/sharadar_sep_full\ACV1.csv
# ⚠ ACV1: Data ends at 2011-05-10 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ACS.csv
# ⚠ ACS: Data ends at 2010-02-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ACN.csv
# Saved: ./2-all_prices/sharadar_sep_full\ACKHQ.csv
# ⚠ ACKHQ: Data ends at 2007-12-12 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ACGL.csv
# Saved: ./2-all_prices/sharadar_sep_full\ACAS.csv
# ⚠ ACAS: Data ends at 2017-01-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ABT.csv
# Saved: ./2-all_prices/sharadar_sep_full\ABS.csv
# ⚠ ABS: Data ends at 2006-06-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ABNB.csv
# ⚠ ABNB: Recent IPO — first price date is 2020-12-10
# Saved: ./2-all_prices/sharadar_sep_full\ABMD.csv
# ⚠ ABMD: Data ends at 2022-12-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ABKFQ.csv
# ⚠ ABKFQ: Data ends at 2010-11-16 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ABI1.csv
# ⚠ ABI1: Data ends at 2008-11-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ABBV.csv
# Saved: ./2-all_prices/sharadar_sep_full\AAPL.csv
# Saved: ./2-all_prices/sharadar_sep_full\AAP.csv
# Saved: ./2-all_prices/sharadar_sep_full\AAMRQ.csv
# ⚠ AAMRQ: Data ends at 2013-12-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AAL.csv
# Saved: ./2-all_prices/sharadar_sep_full\A.csv
# Saved: ./2-all_prices/sharadar_sep_full\APH.csv
# Saved: ./2-all_prices/sharadar_sep_full\APD.csv
# Saved: ./2-all_prices/sharadar_sep_full\APCC.csv
# ⚠ APCC: Data ends at 2007-02-14 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\APC.csv
# ⚠ APC: Data ends at 2019-08-08 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\APA.csv
# Saved: ./2-all_prices/sharadar_sep_full\AOS.csv
# Saved: ./2-all_prices/sharadar_sep_full\AON.csv
# Saved: ./2-all_prices/sharadar_sep_full\ANV1.csv
# ⚠ ANV1: Data ends at 1999-04-09 — older than 30 days (likely delisted or missing data)
# ⚠ ANV1: Short full history (<5 years) — only 320 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\ANSS.csv
# ⚠ ANSS: Data ends at 2025-07-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ANRZQ.csv
# ⚠ ANRZQ: Data ends at 2016-07-26 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ANF.csv
# Saved: ./2-all_prices/sharadar_sep_full\ANET.csv
# Saved: ./2-all_prices/sharadar_sep_full\ANDW.csv
# ⚠ ANDW: Data ends at 2007-12-27 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ANDV.csv
# ⚠ ANDV: Data ends at 2018-09-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AN1.csv
# ⚠ AN1: Data ends at 1998-12-31 — older than 30 days (likely delisted or missing data)
# ⚠ AN1: Short full history (<5 years) — only 253 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AN.csv
# Saved: ./2-all_prices/sharadar_sep_full\AMZN.csv
# Saved: ./2-all_prices/sharadar_sep_full\AMTM.csv
# ⚠ AMTM: Recent IPO — first price date is 2024-09-30
# ⚠ AMTM: Short full history (<5 years) — only 298 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AMT.csv
# Saved: ./2-all_prices/sharadar_sep_full\AMP1.csv
# ⚠ AMP1: Data ends at 1999-04-01 — older than 30 days (likely delisted or missing data)
# ⚠ AMP1: Short full history (<5 years) — only 315 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AMP.csv
# Saved: ./2-all_prices/sharadar_sep_full\AMGN.csv
# Saved: ./2-all_prices/sharadar_sep_full\AMG.csv
# Saved: ./2-all_prices/sharadar_sep_full\AME.csv
# Saved: ./2-all_prices/sharadar_sep_full\AMD.csv
# Saved: ./2-all_prices/sharadar_sep_full\AMCR.csv
# ⚠ AMCR: Recent IPO — first price date is 2019-06-11
# Saved: ./2-all_prices/sharadar_sep_full\AMCC.csv
# ⚠ AMCC: Data ends at 2017-01-26 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AMAT.csv
# Saved: ./2-all_prices/sharadar_sep_full\AM1.csv
# ⚠ AM1: Data ends at 2013-08-08 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ALXN.csv
# ⚠ ALXN: Data ends at 2021-07-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ALTR1.csv
# ⚠ ALTR1: Data ends at 2015-12-24 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ALLE.csv
# Saved: ./2-all_prices/sharadar_sep_full\ALL.csv
# Saved: ./2-all_prices/sharadar_sep_full\ALK.csv
# Saved: ./2-all_prices/sharadar_sep_full\ALGN.csv
# Saved: ./2-all_prices/sharadar_sep_full\ALB.csv
# Saved: ./2-all_prices/sharadar_sep_full\AL1.csv
# ⚠ AL1: Data ends at 2007-11-13 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AKS.csv
# ⚠ AKS: Data ends at 2020-03-12 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AKAM.csv
# Saved: ./2-all_prices/sharadar_sep_full\AJG.csv
# Saved: ./2-all_prices/sharadar_sep_full\BAX.csv
# Saved: ./2-all_prices/sharadar_sep_full\BALL.csv
# Saved: ./2-all_prices/sharadar_sep_full\BAC1.csv
# ⚠ BAC1: Data ends at 1998-09-30 — older than 30 days (likely delisted or missing data)
# ⚠ BAC1: Short full history (<5 years) — only 189 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BAC.csv
# Saved: ./2-all_prices/sharadar_sep_full\BA.csv
# Saved: ./2-all_prices/sharadar_sep_full\B.csv
# Saved: ./2-all_prices/sharadar_sep_full\AZO.csv
# Saved: ./2-all_prices/sharadar_sep_full\AZA.A.csv
# ⚠ AZA.A: Data ends at 2001-06-22 — older than 30 days (likely delisted or missing data)
# ⚠ AZA.A: Short full history (<5 years) — only 877 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AYI.csv
# Saved: ./2-all_prices/sharadar_sep_full\AYE.csv
# ⚠ AYE: Data ends at 2011-02-25 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AXP.csv
# Saved: ./2-all_prices/sharadar_sep_full\AXON.csv
# Saved: ./2-all_prices/sharadar_sep_full\AWK.csv
# Saved: ./2-all_prices/sharadar_sep_full\AWE.csv
# ⚠ AWE: Data ends at 2004-10-26 — older than 30 days (likely delisted or missing data)
# ⚠ AWE: Short full history (<5 years) — only 1130 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AW.csv
# ⚠ AW: Data ends at 2008-12-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AVY.csv
# Saved: ./2-all_prices/sharadar_sep_full\AVP.csv
# ⚠ AVP: Data ends at 2020-01-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\AVGO.csv
# Saved: ./2-all_prices/sharadar_sep_full\AVB.csv
# Saved: ./2-all_prices/sharadar_sep_full\AV1.csv
# ⚠ AV1: Data ends at 2007-10-25 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ATVI.csv
# ⚠ ATVI: Data ends at 2023-10-12 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ATO.csv
# Saved: ./2-all_prices/sharadar_sep_full\ATI1.csv
# ⚠ ATI1: Data ends at 1999-06-29 — older than 30 days (likely delisted or missing data)
# ⚠ ATI1: Short full history (<5 years) — only 376 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\ATI.csv
# Saved: ./2-all_prices/sharadar_sep_full\ATGE.csv
# Saved: ./2-all_prices/sharadar_sep_full\AT1.csv
# ⚠ AT1: Data ends at 2007-11-15 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ASO1.csv
# ⚠ ASO1: Data ends at 2006-11-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ASND1.csv
# ⚠ ASND1: Data ends at 1999-06-24 — older than 30 days (likely delisted or missing data)
# ⚠ ASND1: Short full history (<5 years) — only 373 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\ASN.csv
# ⚠ ASN: Data ends at 2007-10-04 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ASH.csv
# Saved: ./2-all_prices/sharadar_sep_full\ASC1.csv
# ⚠ ASC1: Data ends at 1999-06-23 — older than 30 days (likely delisted or missing data)
# ⚠ ASC1: Short full history (<5 years) — only 372 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AS1.csv
# ⚠ AS1: Data ends at 1999-09-30 — older than 30 days (likely delisted or missing data)
# ⚠ AS1: Short full history (<5 years) — only 441 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\ARG.csv
# ⚠ ARG: Data ends at 2016-05-20 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ARE.csv
# Saved: ./2-all_prices/sharadar_sep_full\ARC1.csv
# ⚠ ARC1: Data ends at 2000-04-17 — older than 30 days (likely delisted or missing data)
# ⚠ ARC1: Short full history (<5 years) — only 579 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\AR1.csv
# ⚠ AR1: Data ends at 1999-11-17 — older than 30 days (likely delisted or missing data)
# ⚠ AR1: Short full history (<5 years) — only 475 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\APTV.csv
# Saved: ./2-all_prices/sharadar_sep_full\APP.csv
# ⚠ APP: Recent IPO — first price date is 2021-04-15
# ⚠ APP: Short full history (<5 years) — only 1168 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\APOL.csv
# ⚠ APOL: Data ends at 2017-02-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\APO.csv
# Saved: ./2-all_prices/sharadar_sep_full\BOL.csv
# ⚠ BOL: Data ends at 2007-10-26 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BNL1.csv
# ⚠ BNL1: Data ends at 1998-06-30 — older than 30 days (likely delisted or missing data)
# ⚠ BNL1: Short full history (<5 years) — only 125 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BNI.csv
# ⚠ BNI: Data ends at 2010-02-12 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BMY.csv
# Saved: ./2-all_prices/sharadar_sep_full\BMS.csv
# ⚠ BMS: Data ends at 2019-06-10 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BMGCA.csv
# ⚠ BMGCA: Data ends at 2001-01-10 — older than 30 days (likely delisted or missing data)
# ⚠ BMGCA: Short full history (<5 years) — only 764 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BMET.csv
# ⚠ BMET: Data ends at 2007-09-25 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BMC.csv
# ⚠ BMC: Data ends at 2013-09-10 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BLS.csv
# ⚠ BLS: Data ends at 2006-12-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BLK.csv
# Saved: ./2-all_prices/sharadar_sep_full\BLDR.csv
# Saved: ./2-all_prices/sharadar_sep_full\BKR.csv
# ⚠ BKR: Recent IPO — first price date is 2017-07-05
# Saved: ./2-all_prices/sharadar_sep_full\BKNG.csv
# Saved: ./2-all_prices/sharadar_sep_full\BKB.csv
# ⚠ BKB: Data ends at 1999-09-30 — older than 30 days (likely delisted or missing data)
# ⚠ BKB: Short full history (<5 years) — only 441 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BK.csv
# Saved: ./2-all_prices/sharadar_sep_full\BJS.csv
# ⚠ BJS: Data ends at 2010-04-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BIO.csv
# Saved: ./2-all_prices/sharadar_sep_full\BIIB.csv
# Saved: ./2-all_prices/sharadar_sep_full\BIGGQ.csv
# ⚠ BIGGQ: Data ends at 2024-09-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BHMSQ.csv
# ⚠ BHMSQ: Data ends at 2004-01-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BHI.csv
# ⚠ BHI: Data ends at 2017-07-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BHF.csv
# ⚠ BHF: Recent IPO — first price date is 2017-07-17
# Saved: ./2-all_prices/sharadar_sep_full\BGGSQ.csv
# ⚠ BGGSQ: Data ends at 2021-01-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BGEN.csv
# ⚠ BGEN: Data ends at 2003-11-12 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BG.csv
# Saved: ./2-all_prices/sharadar_sep_full\BFO1.csv
# ⚠ BFO1: Data ends at 2000-10-04 — older than 30 days (likely delisted or missing data)
# ⚠ BFO1: Short full history (<5 years) — only 697 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BFI1.csv
# ⚠ BFI1: Data ends at 1999-07-30 — older than 30 days (likely delisted or missing data)
# ⚠ BFI1: Short full history (<5 years) — only 398 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BFH.csv
# Saved: ./2-all_prices/sharadar_sep_full\BF.B.csv
# Saved: ./2-all_prices/sharadar_sep_full\BEN.csv
# Saved: ./2-all_prices/sharadar_sep_full\BEAM2.csv
# ⚠ BEAM2: Data ends at 2014-04-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BDX.csv
# Saved: ./2-all_prices/sharadar_sep_full\BDK.csv
# ⚠ BDK: Data ends at 2010-03-12 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BCR.csv
# ⚠ BCR: Data ends at 2017-12-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BC.csv
# Saved: ./2-all_prices/sharadar_sep_full\BBY.csv
# Saved: ./2-all_prices/sharadar_sep_full\BBWI.csv
# Saved: ./2-all_prices/sharadar_sep_full\BBI1.csv
# ⚠ BBI1: LESS THAN 100 DAYS of price data after 1998 — 6 days (last date = 1998-01-09 00:00:00)
# ⚠ BBI1: Data ends at 1998-01-09 — older than 30 days (likely delisted or missing data)
# ⚠ BBI1: Short full history (<5 years) — only 7 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BBBYQ.csv
# ⚠ BBBYQ: Data ends at 2023-05-02 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BAY1.csv
# ⚠ BAY1: Data ends at 1998-08-28 — older than 30 days (likely delisted or missing data)
# ⚠ BAY1: Short full history (<5 years) — only 167 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CCI1.csv
# ⚠ CCI1: Data ends at 1998-10-07 — older than 30 days (likely delisted or missing data)
# ⚠ CCI1: Short full history (<5 years) — only 194 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CCI.csv
# Saved: ./2-all_prices/sharadar_sep_full\CCE1.csv
# ⚠ CCE1: Data ends at 2016-05-27 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CBSS.csv
# ⚠ CBSS: Data ends at 2007-09-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CBS1.csv
# ⚠ CBS1: Data ends at 2000-05-03 — older than 30 days (likely delisted or missing data)
# ⚠ CBS1: Short full history (<5 years) — only 590 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CBRE.csv
# Saved: ./2-all_prices/sharadar_sep_full\CBOE.csv
# Saved: ./2-all_prices/sharadar_sep_full\CBH1.csv
# ⚠ CBH1: Data ends at 2008-03-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CBE.csv
# ⚠ CBE: Data ends at 2012-11-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CB1.csv
# ⚠ CB1: Data ends at 2016-01-14 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CB.csv
# Saved: ./2-all_prices/sharadar_sep_full\CAT.csv
# Saved: ./2-all_prices/sharadar_sep_full\CARR.csv
# ⚠ CARR: Recent IPO — first price date is 2020-03-19
# Saved: ./2-all_prices/sharadar_sep_full\CAR.csv
# Saved: ./2-all_prices/sharadar_sep_full\CAM2.csv
# ⚠ CAM2: Data ends at 2016-04-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CAL.csv
# Saved: ./2-all_prices/sharadar_sep_full\CAH.csv
# Saved: ./2-all_prices/sharadar_sep_full\CAG.csv
# Saved: ./2-all_prices/sharadar_sep_full\CA1.csv
# ⚠ CA1: Data ends at 2018-11-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\C1.csv
# ⚠ C1: Data ends at 1998-11-12 — older than 30 days (likely delisted or missing data)
# ⚠ C1: Short full history (<5 years) — only 220 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\C.csv
# Saved: ./2-all_prices/sharadar_sep_full\BXP.csv
# Saved: ./2-all_prices/sharadar_sep_full\BXLT.csv
# ⚠ BXLT: Data ends at 2016-06-02 — older than 30 days (likely delisted or missing data)
# ⚠ BXLT: Short full history (<5 years) — only 233 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BX.csv
# Saved: ./2-all_prices/sharadar_sep_full\BWA.csv
# Saved: ./2-all_prices/sharadar_sep_full\BVSN.csv
# ⚠ BVSN: Data ends at 2020-05-18 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BUD1.csv
# ⚠ BUD1: Data ends at 2008-11-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BTUUQ.csv
# ⚠ BTUUQ: Data ends at 2017-04-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BT1.csv
# ⚠ BT1: Data ends at 1999-06-03 — older than 30 days (likely delisted or missing data)
# ⚠ BT1: Short full history (<5 years) — only 358 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\BSX.csv
# Saved: ./2-all_prices/sharadar_sep_full\BSC1.csv
# ⚠ BSC1: Data ends at 2008-05-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BRO.csv
# Saved: ./2-all_prices/sharadar_sep_full\BRL.csv
# ⚠ BRL: Data ends at 2008-12-22 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BRK.B.csv
# Saved: ./2-all_prices/sharadar_sep_full\BRCM.csv
# ⚠ BRCM: Data ends at 2016-01-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BR1.csv
# ⚠ BR1: Data ends at 2006-03-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\BR.csv
# Saved: ./2-all_prices/sharadar_sep_full\CLF.csv
# Saved: ./2-all_prices/sharadar_sep_full\CL.csv
# Saved: ./2-all_prices/sharadar_sep_full\CITGQ.csv
# ⚠ CITGQ: Data ends at 2009-12-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CIT.A.csv
# ⚠ CIT.A: Data ends at 2001-06-01 — older than 30 days (likely delisted or missing data)
# ⚠ CIT.A: Short full history (<5 years) — only 862 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CINF.csv
# Saved: ./2-all_prices/sharadar_sep_full\CIN.csv
# ⚠ CIN: Data ends at 2006-03-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CIEN.csv
# Saved: ./2-all_prices/sharadar_sep_full\CI.csv
# Saved: ./2-all_prices/sharadar_sep_full\CHTR.csv
# Saved: ./2-all_prices/sharadar_sep_full\CHRW.csv
# Saved: ./2-all_prices/sharadar_sep_full\CHRS1.csv
# ⚠ CHRS1: Data ends at 2012-06-14 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CHKAQ.csv
# ⚠ CHKAQ: Data ends at 2021-02-10 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CHIR1.csv
# ⚠ CHIR1: Data ends at 2006-04-19 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CHD.csv
# Saved: ./2-all_prices/sharadar_sep_full\CHA1.csv
# ⚠ CHA1: Data ends at 2000-06-20 — older than 30 days (likely delisted or missing data)
# ⚠ CHA1: Short full history (<5 years) — only 623 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CGP.csv
# ⚠ CGP: Data ends at 2001-01-29 — older than 30 days (likely delisted or missing data)
# ⚠ CGP: Short full history (<5 years) — only 776 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CG1.csv
# ⚠ CG1: Data ends at 2000-11-01 — older than 30 days (likely delisted or missing data)
# ⚠ CG1: Short full history (<5 years) — only 717 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CFN.csv
# ⚠ CFN: Data ends at 2015-03-16 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CFL1.csv
# ⚠ CFL1: LESS THAN 100 DAYS of price data after 1998 — 79 days (last date = 1998-04-27 00:00:00)
# ⚠ CFL1: Data ends at 1998-04-27 — older than 30 days (likely delisted or missing data)
# ⚠ CFL1: Short full history (<5 years) — only 80 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CFG.csv
# Saved: ./2-all_prices/sharadar_sep_full\CFC.csv
# ⚠ CFC: Data ends at 2008-06-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CF1.csv
# ⚠ CF1: Data ends at 2004-08-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CF.csv
# Saved: ./2-all_prices/sharadar_sep_full\CERN.csv
# ⚠ CERN: Data ends at 2022-06-07 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CEPH.csv
# ⚠ CEPH: Data ends at 2011-10-13 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CEN1.csv
# ⚠ CEN1: Data ends at 2007-11-07 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CEM1.csv
# ⚠ CEM1: Data ends at 2002-11-06 — older than 30 days (likely delisted or missing data)
# ⚠ CEM1: Short full history (<5 years) — only 1220 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CELG.csv
# ⚠ CELG: Data ends at 2019-11-20 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CEG1.csv
# ⚠ CEG1: Data ends at 2012-03-12 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CEG.csv
# ⚠ CEG: Recent IPO — first price date is 2022-02-02
# ⚠ CEG: Short full history (<5 years) — only 965 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CE1.csv
# ⚠ CE1: Data ends at 2004-02-26 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CE.csv
# Saved: ./2-all_prices/sharadar_sep_full\CDW.csv
# Saved: ./2-all_prices/sharadar_sep_full\CDNS.csv
# Saved: ./2-all_prices/sharadar_sep_full\CCU1.csv
# ⚠ CCU1: Data ends at 2008-07-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CCTYQ.csv
# ⚠ CCTYQ: Data ends at 2009-01-20 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CCL.csv
# Saved: ./2-all_prices/sharadar_sep_full\CCK.csv
# Saved: ./2-all_prices/sharadar_sep_full\CPWR.csv
# ⚠ CPWR: Data ends at 2014-12-15 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CPT.csv
# Saved: ./2-all_prices/sharadar_sep_full\CPRT.csv
# Saved: ./2-all_prices/sharadar_sep_full\CPRI.csv
# Saved: ./2-all_prices/sharadar_sep_full\CPQ.csv
# ⚠ CPQ: Data ends at 2002-05-03 — older than 30 days (likely delisted or missing data)
# ⚠ CPQ: Short full history (<5 years) — only 1090 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CPPRQ.csv
# ⚠ CPPRQ: Data ends at 2021-02-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CPNLQ.csv
# ⚠ CPNLQ: Data ends at 2008-02-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CPGX.csv
# ⚠ CPGX: Data ends at 2016-06-30 — older than 30 days (likely delisted or missing data)
# ⚠ CPGX: Short full history (<5 years) — only 252 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CPB.csv
# Saved: ./2-all_prices/sharadar_sep_full\CPAY.csv
# Saved: ./2-all_prices/sharadar_sep_full\COV.csv
# ⚠ COV: Data ends at 2015-01-26 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\COTY.csv
# Saved: ./2-all_prices/sharadar_sep_full\COT1.csv
# ⚠ COT1: Data ends at 1999-07-12 — older than 30 days (likely delisted or missing data)
# ⚠ COT1: Short full history (<5 years) — only 384 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\COST.csv
# Saved: ./2-all_prices/sharadar_sep_full\COR.csv
# Saved: ./2-all_prices/sharadar_sep_full\COP.csv
# Saved: ./2-all_prices/sharadar_sep_full\COO.csv
# Saved: ./2-all_prices/sharadar_sep_full\COMS1.csv
# ⚠ COMS1: Data ends at 2010-04-08 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\COL.csv
# ⚠ COL: Data ends at 2018-11-26 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\COIN.csv
# ⚠ COIN: Recent IPO — first price date is 2021-04-14
# ⚠ COIN: Short full history (<5 years) — only 1169 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\COF.csv
# Saved: ./2-all_prices/sharadar_sep_full\COC.csv
# ⚠ COC: Data ends at 2002-08-30 — older than 30 days (likely delisted or missing data)
# ⚠ COC: Short full history (<5 years) — only 789 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CNXT1.csv
# ⚠ CNXT1: Data ends at 2011-04-18 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CNX.csv
# Saved: ./2-all_prices/sharadar_sep_full\CNW.csv
# ⚠ CNW: Data ends at 2015-10-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CNP.csv
# Saved: ./2-all_prices/sharadar_sep_full\CNG.csv
# ⚠ CNG: Data ends at 2000-01-28 — older than 30 days (likely delisted or missing data)
# ⚠ CNG: Short full history (<5 years) — only 524 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CNCEQ.csv
# ⚠ CNCEQ: Data ends at 2002-08-08 — older than 30 days (likely delisted or missing data)
# ⚠ CNCEQ: Short full history (<5 years) — only 1157 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CNC.csv
# Saved: ./2-all_prices/sharadar_sep_full\CMX.csv
# ⚠ CMX: Data ends at 2007-03-22 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CMVT.csv
# ⚠ CMVT: Data ends at 2013-02-04 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CMS.csv
# Saved: ./2-all_prices/sharadar_sep_full\CMI.csv
# Saved: ./2-all_prices/sharadar_sep_full\CMG.csv
# Saved: ./2-all_prices/sharadar_sep_full\CME.csv
# Saved: ./2-all_prices/sharadar_sep_full\CMCSK.csv
# ⚠ CMCSK: Data ends at 2015-12-11 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CMCSA.csv
# Saved: ./2-all_prices/sharadar_sep_full\CMA.csv
# Saved: ./2-all_prices/sharadar_sep_full\CLX.csv
# Saved: ./2-all_prices/sharadar_sep_full\DE.csv
# Saved: ./2-all_prices/sharadar_sep_full\DDS.csv
# Saved: ./2-all_prices/sharadar_sep_full\DDOG.csv
# ⚠ DDOG: Recent IPO — first price date is 2019-09-19
# Saved: ./2-all_prices/sharadar_sep_full\DD1.csv
# ⚠ DD1: Data ends at 2017-08-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DD.csv
# Saved: ./2-all_prices/sharadar_sep_full\DCNAQ.csv
# ⚠ DCNAQ: Data ends at 2008-01-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DAY.csv
# ⚠ DAY: Recent IPO — first price date is 2018-04-26
# Saved: ./2-all_prices/sharadar_sep_full\DASH.csv
# ⚠ DASH: Recent IPO — first price date is 2020-12-09
# Saved: ./2-all_prices/sharadar_sep_full\DALRQ.csv
# ⚠ DALRQ: Data ends at 2007-04-27 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DAL.csv
# Saved: ./2-all_prices/sharadar_sep_full\D.csv
# Saved: ./2-all_prices/sharadar_sep_full\CZR.csv
# Saved: ./2-all_prices/sharadar_sep_full\CYM.csv
# ⚠ CYM: Data ends at 1999-12-02 — older than 30 days (likely delisted or missing data)
# ⚠ CYM: Short full history (<5 years) — only 485 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CXT.csv
# Saved: ./2-all_prices/sharadar_sep_full\CXO.csv
# ⚠ CXO: Data ends at 2021-01-15 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CVX.csv
# Saved: ./2-all_prices/sharadar_sep_full\CVS.csv
# Saved: ./2-all_prices/sharadar_sep_full\CVH.csv
# ⚠ CVH: Data ends at 2013-05-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CVGYQ.csv
# ⚠ CVGYQ: Data ends at 2002-03-28 — older than 30 days (likely delisted or missing data)
# ⚠ CVGYQ: Short full history (<5 years) — only 1065 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CVG.csv
# ⚠ CVG: Data ends at 2018-10-04 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CVC.csv
# ⚠ CVC: Data ends at 2016-06-20 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CTXS.csv
# ⚠ CTXS: Data ends at 2022-09-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CTX1.csv
# ⚠ CTX1: Data ends at 2009-08-18 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CTVA.csv
# ⚠ CTVA: Recent IPO — first price date is 2019-06-03
# Saved: ./2-all_prices/sharadar_sep_full\CTSH.csv
# Saved: ./2-all_prices/sharadar_sep_full\CTRA.csv
# Saved: ./2-all_prices/sharadar_sep_full\CTLT.csv
# ⚠ CTLT: Data ends at 2024-12-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CTB.csv
# ⚠ CTB: Data ends at 2021-06-04 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CTAS.csv
# Saved: ./2-all_prices/sharadar_sep_full\CSX.csv
# Saved: ./2-all_prices/sharadar_sep_full\CSRA.csv
# ⚠ CSRA: Data ends at 2018-04-03 — older than 30 days (likely delisted or missing data)
# ⚠ CSRA: Short full history (<5 years) — only 589 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CSR1.csv
# ⚠ CSR1: Data ends at 2000-06-15 — older than 30 days (likely delisted or missing data)
# ⚠ CSR1: Short full history (<5 years) — only 620 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CSGP.csv
# Saved: ./2-all_prices/sharadar_sep_full\CSE1.csv
# ⚠ CSE1: Data ends at 1999-11-12 — older than 30 days (likely delisted or missing data)
# ⚠ CSE1: Short full history (<5 years) — only 472 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\CSCO.csv
# Saved: ./2-all_prices/sharadar_sep_full\CSC.csv
# ⚠ CSC: Data ends at 2017-03-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\CRWD.csv
# ⚠ CRWD: Recent IPO — first price date is 2019-06-12
# Saved: ./2-all_prices/sharadar_sep_full\CRM.csv
# Saved: ./2-all_prices/sharadar_sep_full\CRL.csv
# Saved: ./2-all_prices/sharadar_sep_full\DXC.csv
# ⚠ DXC: Recent IPO — first price date is 2017-04-03
# Saved: ./2-all_prices/sharadar_sep_full\DVN.csv
# Saved: ./2-all_prices/sharadar_sep_full\DVA.csv
# Saved: ./2-all_prices/sharadar_sep_full\DUK.csv
# Saved: ./2-all_prices/sharadar_sep_full\DTV1.csv
# ⚠ DTV1: Data ends at 2015-07-24 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DTE.csv
# Saved: ./2-all_prices/sharadar_sep_full\DRI.csv
# Saved: ./2-all_prices/sharadar_sep_full\DRE.csv
# ⚠ DRE: Data ends at 2022-09-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DPZ.csv
# Saved: ./2-all_prices/sharadar_sep_full\DPHIQ.csv
# ⚠ DPHIQ: Data ends at 2009-10-07 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DOW.csv
# ⚠ DOW: Recent IPO — first price date is 2019-04-02
# Saved: ./2-all_prices/sharadar_sep_full\DOV.csv
# Saved: ./2-all_prices/sharadar_sep_full\DOFSQ.csv
# ⚠ DOFSQ: Data ends at 2021-04-23 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DOC.csv
# Saved: ./2-all_prices/sharadar_sep_full\DNRCQ.csv
# ⚠ DNRCQ: Data ends at 2020-09-18 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DNB3.csv
# ⚠ DNB3: Data ends at 2019-02-07 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DNB2.csv
# ⚠ DNB2: Data ends at 1998-06-30 — older than 30 days (likely delisted or missing data)
# ⚠ DNB2: Short full history (<5 years) — only 125 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\DNB1.csv
# ⚠ DNB1: Data ends at 2000-10-02 — older than 30 days (likely delisted or missing data)
# ⚠ DNB1: Short full history (<5 years) — only 570 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\DLX.csv
# Saved: ./2-all_prices/sharadar_sep_full\DLTR.csv
# Saved: ./2-all_prices/sharadar_sep_full\DLR.csv
# Saved: ./2-all_prices/sharadar_sep_full\DJ.csv
# ⚠ DJ: Data ends at 2007-12-13 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DISH.csv
# ⚠ DISH: Data ends at 2023-12-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DISCK.csv
# ⚠ DISCK: Data ends at 2022-04-08 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DIS.csv
# Saved: ./2-all_prices/sharadar_sep_full\DINO.csv
# Saved: ./2-all_prices/sharadar_sep_full\DIGI2.csv
# ⚠ DIGI2: Data ends at 1998-09-04 — older than 30 days (likely delisted or missing data)
# ⚠ DIGI2: Short full history (<5 years) — only 172 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\DI1.csv
# ⚠ DI1: Data ends at 1998-09-29 — older than 30 days (likely delisted or missing data)
# ⚠ DI1: Short full history (<5 years) — only 188 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\DHR.csv
# Saved: ./2-all_prices/sharadar_sep_full\DHI.csv
# Saved: ./2-all_prices/sharadar_sep_full\DGX.csv
# Saved: ./2-all_prices/sharadar_sep_full\DGN.csv
# ⚠ DGN: Data ends at 1999-10-12 — older than 30 days (likely delisted or missing data)
# ⚠ DGN: Short full history (<5 years) — only 449 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\DG1.csv
# ⚠ DG1: Data ends at 2007-07-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DG.csv
# Saved: ./2-all_prices/sharadar_sep_full\DFS.csv
# ⚠ DFS: Data ends at 2025-05-16 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DFODQ.csv
# ⚠ DFODQ: Data ends at 2021-06-02 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DELL1.csv
# ⚠ DELL1: Data ends at 2013-10-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DELL.csv
# ⚠ DELL: Recent IPO — first price date is 2016-09-07
# Saved: ./2-all_prices/sharadar_sep_full\DECK.csv
# Saved: ./2-all_prices/sharadar_sep_full\DEC1.csv
# ⚠ DEC1: Data ends at 1998-06-11 — older than 30 days (likely delisted or missing data)
# ⚠ DEC1: Short full history (<5 years) — only 112 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\ETFC.csv
# ⚠ ETFC: Data ends at 2020-10-02 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ESS.csv
# Saved: ./2-all_prices/sharadar_sep_full\ESRX.csv
# ⚠ ESRX: Data ends at 2018-12-20 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ES.csv
# Saved: ./2-all_prices/sharadar_sep_full\ERIE.csv
# Saved: ./2-all_prices/sharadar_sep_full\EQT.csv
# Saved: ./2-all_prices/sharadar_sep_full\EQR.csv
# Saved: ./2-all_prices/sharadar_sep_full\EQIX.csv
# Saved: ./2-all_prices/sharadar_sep_full\EQ1.csv
# ⚠ EQ1: Data ends at 2009-06-30 — older than 30 days (likely delisted or missing data)
# ⚠ EQ1: Short full history (<5 years) — only 794 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\EPAM.csv
# Saved: ./2-all_prices/sharadar_sep_full\EP1.csv
# ⚠ EP1: Data ends at 2012-05-24 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\EOP.csv
# ⚠ EOP: Data ends at 2007-02-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\EOG.csv
# Saved: ./2-all_prices/sharadar_sep_full\ENRNQ.csv
# ⚠ ENRNQ: Data ends at 2004-11-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ENPH.csv
# Saved: ./2-all_prices/sharadar_sep_full\ENDPQ.csv
# ⚠ ENDPQ: Data ends at 2022-08-25 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\EMR.csv
# Saved: ./2-all_prices/sharadar_sep_full\EMN.csv
# Saved: ./2-all_prices/sharadar_sep_full\EME.csv
# Saved: ./2-all_prices/sharadar_sep_full\EMC1.csv
# ⚠ EMC1: Data ends at 2016-09-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ELV.csv
# Saved: ./2-all_prices/sharadar_sep_full\EL.csv
# Saved: ./2-all_prices/sharadar_sep_full\EKDKQ.csv
# ⚠ EKDKQ: Data ends at 2013-09-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\EIX.csv
# Saved: ./2-all_prices/sharadar_sep_full\EHC.csv
# Saved: ./2-all_prices/sharadar_sep_full\EG.csv
# Saved: ./2-all_prices/sharadar_sep_full\EFX.csv
# Saved: ./2-all_prices/sharadar_sep_full\EFU1.csv
# ⚠ EFU1: Data ends at 2000-11-08 — older than 30 days (likely delisted or missing data)
# ⚠ EFU1: Short full history (<5 years) — only 722 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\EDS.csv
# ⚠ EDS: Data ends at 2008-08-25 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ED.csv
# Saved: ./2-all_prices/sharadar_sep_full\ECO1.csv
# ⚠ ECO1: Data ends at 2003-01-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ECL.csv
# Saved: ./2-all_prices/sharadar_sep_full\ECH1.csv
# ⚠ ECH1: Data ends at 1998-07-09 — older than 30 days (likely delisted or missing data)
# ⚠ ECH1: Short full history (<5 years) — only 131 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\EC1.csv
# ⚠ EC1: Data ends at 2006-06-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\EBAY.csv
# Saved: ./2-all_prices/sharadar_sep_full\EA.csv
# Saved: ./2-all_prices/sharadar_sep_full\DYNIQ.csv
# ⚠ DYNIQ: Data ends at 2012-10-02 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\DXCM.csv
# Saved: ./2-all_prices/sharadar_sep_full\FLS.csv
# Saved: ./2-all_prices/sharadar_sep_full\FLR.csv
# Saved: ./2-all_prices/sharadar_sep_full\FLMIQ.csv
# ⚠ FLMIQ: Data ends at 2003-11-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FLIR.csv
# ⚠ FLIR: Data ends at 2021-05-14 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FL.csv
# ⚠ FL: Data ends at 2025-09-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FJ.csv
# ⚠ FJ: Data ends at 2000-11-24 — older than 30 days (likely delisted or missing data)
# ⚠ FJ: Short full history (<5 years) — only 733 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\FITB.csv
# Saved: ./2-all_prices/sharadar_sep_full\FISV.csv
# Saved: ./2-all_prices/sharadar_sep_full\FIS.csv
# Saved: ./2-all_prices/sharadar_sep_full\FICO.csv
# Saved: ./2-all_prices/sharadar_sep_full\FHN.csv
# Saved: ./2-all_prices/sharadar_sep_full\FHI.csv
# Saved: ./2-all_prices/sharadar_sep_full\FG1.csv
# ⚠ FG1: LESS THAN 100 DAYS of price data after 1998 — 78 days (last date = 1998-04-24 00:00:00)
# ⚠ FG1: Data ends at 1998-04-24 — older than 30 days (likely delisted or missing data)
# ⚠ FG1: Short full history (<5 years) — only 79 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\FFIV.csv
# Saved: ./2-all_prices/sharadar_sep_full\FE.csv
# Saved: ./2-all_prices/sharadar_sep_full\FDX.csv
# Saved: ./2-all_prices/sharadar_sep_full\FDS.csv
# Saved: ./2-all_prices/sharadar_sep_full\FDO.csv
# ⚠ FDO: Data ends at 2015-07-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FDC1.csv
# ⚠ FDC1: Data ends at 2007-09-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FCX.csv
# Saved: ./2-all_prices/sharadar_sep_full\FCN1.csv
# ⚠ FCN1: Data ends at 1998-10-01 — older than 30 days (likely delisted or missing data)
# ⚠ FCN1: Short full history (<5 years) — only 190 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\FBIN.csv
# Saved: ./2-all_prices/sharadar_sep_full\FBF.csv
# ⚠ FBF: Data ends at 2004-03-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FAST.csv
# Saved: ./2-all_prices/sharadar_sep_full\FANG.csv
# Saved: ./2-all_prices/sharadar_sep_full\F.csv
# Saved: ./2-all_prices/sharadar_sep_full\EXR.csv
# Saved: ./2-all_prices/sharadar_sep_full\EXPE.csv
# Saved: ./2-all_prices/sharadar_sep_full\EXPD.csv
# Saved: ./2-all_prices/sharadar_sep_full\EXE.csv
# ⚠ EXE: Recent IPO — first price date is 2021-02-10
# ⚠ EXE: Short full history (<5 years) — only 1212 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\EXC.csv
# Saved: ./2-all_prices/sharadar_sep_full\EW.csv
# Saved: ./2-all_prices/sharadar_sep_full\EVRG.csv
# ⚠ EVRG: Recent IPO — first price date is 2018-04-25
# Saved: ./2-all_prices/sharadar_sep_full\EVHC.csv
# ⚠ EVHC: Data ends at 2018-10-10 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ETSY.csv
# Saved: ./2-all_prices/sharadar_sep_full\ETS1.csv
# ⚠ ETS1: Data ends at 2006-02-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\ETR.csv
# Saved: ./2-all_prices/sharadar_sep_full\ETN.csv
# Saved: ./2-all_prices/sharadar_sep_full\GGP.csv
# ⚠ GGP: Data ends at 2018-08-27 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GFS.A.csv
# ⚠ GFS.A: Data ends at 1998-10-30 — older than 30 days (likely delisted or missing data)
# ⚠ GFS.A: Short full history (<5 years) — only 211 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\GEV.csv
# ⚠ GEV: Recent IPO — first price date is 2024-04-02
# ⚠ GEV: Short full history (<5 years) — only 423 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\GENZ.csv
# ⚠ GENZ: Data ends at 2011-04-08 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GEN1.csv
# ⚠ GEN1: Data ends at 2012-12-14 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GEN.csv
# Saved: ./2-all_prices/sharadar_sep_full\GEHC.csv
# ⚠ GEHC: Recent IPO — first price date is 2023-01-04
# ⚠ GEHC: Short full history (<5 years) — only 734 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\GE.csv
# Saved: ./2-all_prices/sharadar_sep_full\GDW.csv
# ⚠ GDW: Data ends at 2006-09-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GDT.csv
# ⚠ GDT: Data ends at 2006-04-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GDDY.csv
# Saved: ./2-all_prices/sharadar_sep_full\GD.csv
# Saved: ./2-all_prices/sharadar_sep_full\GAS1.csv
# ⚠ GAS1: Data ends at 2011-12-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GAS.csv
# ⚠ GAS: Data ends at 2016-06-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GAPTQ.csv
# ⚠ GAPTQ: Data ends at 2012-03-13 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\GAP.csv
# Saved: ./2-all_prices/sharadar_sep_full\G1.csv
# ⚠ G1: Data ends at 2005-09-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FWLT.csv
# ⚠ FWLT: Data ends at 2014-12-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FTV.csv
# ⚠ FTV: Recent IPO — first price date is 2016-07-05
# Saved: ./2-all_prices/sharadar_sep_full\FTRCQ.csv
# ⚠ FTRCQ: Data ends at 2021-04-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FTNT.csv
# Saved: ./2-all_prices/sharadar_sep_full\FTL.A.csv
# ⚠ FTL.A: Data ends at 2000-04-20 — older than 30 days (likely delisted or missing data)
# ⚠ FTL.A: Short full history (<5 years) — only 582 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\FTI1.csv
# ⚠ FTI1: Data ends at 2017-01-13 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FTI.csv
# ⚠ FTI: Recent IPO — first price date is 2017-01-17
# Saved: ./2-all_prices/sharadar_sep_full\FSLR.csv
# Saved: ./2-all_prices/sharadar_sep_full\FSL.B.csv
# ⚠ FSL.B: Data ends at 2006-12-01 — older than 30 days (likely delisted or missing data)
# ⚠ FSL.B: Short full history (<5 years) — only 511 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\FSH.csv
# ⚠ FSH: Data ends at 2006-11-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FRX1.csv
# ⚠ FRX1: Data ends at 2014-06-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FRT.csv
# Saved: ./2-all_prices/sharadar_sep_full\FRO1.csv
# ⚠ FRO1: Data ends at 1999-09-28 — older than 30 days (likely delisted or missing data)
# ⚠ FRO1: Short full history (<5 years) — only 439 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\FRCB.csv
# ⚠ FRCB: Data ends at 2023-05-03 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\FPC.csv
# ...
# Saved: ./2-all_prices/sharadar_sep_full\TE1.csv
# ⚠ TE1: Data ends at 2016-06-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TDY.csv
# Saved: ./2-all_prices/sharadar_sep_full\TDG.csv
# Saved: ./2-all_prices/sharadar_sep_full\TDC.csv
# Saved: ./2-all_prices/sharadar_sep_full\TCOMA.csv
# ⚠ TCOMA: Data ends at 1999-03-09 — older than 30 days (likely delisted or missing data)
# ⚠ TCOMA: Short full history (<5 years) — only 298 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\TAP.B.csv
# ⚠ TAP.B: Data ends at 2004-04-01 — older than 30 days (likely delisted or missing data)
# ⚠ TAP.B: Short full history (<5 years) — only 408 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\TAP.csv
# Saved: ./2-all_prices/sharadar_sep_full\TA2.csv
# ⚠ TA2: Data ends at 1999-07-21 — older than 30 days (likely delisted or missing data)
# ⚠ TA2: Short full history (<5 years) — only 391 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\T1.csv
# ⚠ T1: Data ends at 2005-11-18 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\T.csv
# Saved: ./2-all_prices/sharadar_sep_full\SYY.csv
# Saved: ./2-all_prices/sharadar_sep_full\SYK.csv
# Saved: ./2-all_prices/sharadar_sep_full\SYF.csv
# Saved: ./2-all_prices/sharadar_sep_full\SXCL.csv
# ⚠ SXCL: Data ends at 2017-02-09 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\SWY.csv
# ⚠ SWY: Data ends at 2015-01-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\UCL1.csv
# ⚠ UCL1: Data ends at 2005-08-10 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\UCC1.csv
# ⚠ UCC1: Data ends at 1999-04-30 — older than 30 days (likely delisted or missing data)
# ⚠ UCC1: Short full history (<5 years) — only 335 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\UBER.csv
# ⚠ UBER: Recent IPO — first price date is 2019-05-10
# Saved: ./2-all_prices/sharadar_sep_full\UAWGQ.csv
# ⚠ UAWGQ: Data ends at 2003-03-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\UAL.csv
# Saved: ./2-all_prices/sharadar_sep_full\UAA.csv
# Saved: ./2-all_prices/sharadar_sep_full\UA.csv
# ⚠ UA: Recent IPO — first price date is 2016-04-08
# Saved: ./2-all_prices/sharadar_sep_full\TYL.csv
# Saved: ./2-all_prices/sharadar_sep_full\TYC.csv
# ⚠ TYC: Data ends at 2016-09-02 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TXU.csv
# ⚠ TXU: Data ends at 2007-10-10 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TXT.csv
# Saved: ./2-all_prices/sharadar_sep_full\TXN.csv
# Saved: ./2-all_prices/sharadar_sep_full\TX1.csv
# ⚠ TX1: Data ends at 2001-10-09 — older than 30 days (likely delisted or missing data)
# ⚠ TX1: Short full history (<5 years) — only 948 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\TWX1.csv
# ⚠ TWX1: Data ends at 2001-01-11 — older than 30 days (likely delisted or missing data)
# ⚠ TWX1: Short full history (<5 years) — only 765 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\TWX.csv
# ⚠ TWX: Data ends at 2018-06-15 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TWTR.csv
# ⚠ TWTR: Data ends at 2022-10-27 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TWC.csv
# ⚠ TWC: Data ends at 2016-05-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TUPBQ.csv
# ⚠ TUPBQ: Data ends at 2024-09-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TTWO.csv
# Saved: ./2-all_prices/sharadar_sep_full\TTD.csv
# ⚠ TTD: Recent IPO — first price date is 2016-09-21
# Saved: ./2-all_prices/sharadar_sep_full\TT2.csv
# ⚠ TT2: Data ends at 2008-06-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TT.csv
# Saved: ./2-all_prices/sharadar_sep_full\TSS.csv
# ⚠ TSS: Data ends at 2019-09-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TSN.csv
# Saved: ./2-all_prices/sharadar_sep_full\TSLA.csv
# Saved: ./2-all_prices/sharadar_sep_full\TSG1.csv
# ⚠ TSG1: Data ends at 2007-03-29 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TSCO.csv
# Saved: ./2-all_prices/sharadar_sep_full\TRW1.csv
# ⚠ TRW1: Data ends at 2002-12-11 — older than 30 days (likely delisted or missing data)
# ⚠ TRW1: Short full history (<5 years) — only 1244 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\TRV.csv
# Saved: ./2-all_prices/sharadar_sep_full\TROW.csv
# Saved: ./2-all_prices/sharadar_sep_full\TRMB.csv
# Saved: ./2-all_prices/sharadar_sep_full\TRIP.csv
# Saved: ./2-all_prices/sharadar_sep_full\TRGP.csv
# Saved: ./2-all_prices/sharadar_sep_full\TRB.csv
# ⚠ TRB: Data ends at 2007-12-20 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TPR.csv
# Saved: ./2-all_prices/sharadar_sep_full\TPL.csv
# Saved: ./2-all_prices/sharadar_sep_full\TOY.csv
# ⚠ TOY: Data ends at 2005-07-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\TOS.csv
# ⚠ TOS: Data ends at 2001-09-10 — older than 30 days (likely delisted or missing data)
# ⚠ TOS: Short full history (<5 years) — only 931 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\TNL.csv
# Saved: ./2-all_prices/sharadar_sep_full\TNB.csv
# ⚠ TNB: Data ends at 2012-05-16 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\VRTX.csv
# Saved: ./2-all_prices/sharadar_sep_full\VRTS1.csv
# ⚠ VRTS1: Data ends at 2005-07-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\VRSN.csv
# Saved: ./2-all_prices/sharadar_sep_full\VRSK.csv
# Saved: ./2-all_prices/sharadar_sep_full\VO1.csv
# ⚠ VO1: Data ends at 2000-12-08 — older than 30 days (likely delisted or missing data)
# ⚠ VO1: Short full history (<5 years) — only 743 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\VNT.csv
# ⚠ VNT: Recent IPO — first price date is 2020-09-24
# Saved: ./2-all_prices/sharadar_sep_full\VNO.csv
# Saved: ./2-all_prices/sharadar_sep_full\VMC.csv
# Saved: ./2-all_prices/sharadar_sep_full\VLTO.csv
# ⚠ VLTO: Recent IPO — first price date is 2023-10-02
# ⚠ VLTO: Short full history (<5 years) — only 548 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\VLO.csv
# Saved: ./2-all_prices/sharadar_sep_full\VICI.csv
# ⚠ VICI: Recent IPO — first price date is 2018-01-04
# Saved: ./2-all_prices/sharadar_sep_full\VIAV.csv
# Saved: ./2-all_prices/sharadar_sep_full\VIAB.csv
# ⚠ VIAB: Data ends at 2019-12-04 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\VFC.csv
# Saved: ./2-all_prices/sharadar_sep_full\VAR.csv
# ⚠ VAR: Data ends at 2021-04-14 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\VALPQ.csv
# ⚠ VALPQ: Data ends at 2021-04-27 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\V.csv
# Saved: ./2-all_prices/sharadar_sep_full\UVN.csv
# ⚠ UVN: Data ends at 2007-03-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\USW.csv
# ⚠ USW: Data ends at 2000-06-30 — older than 30 days (likely delisted or missing data)
# ⚠ USW: Short full history (<5 years) — only 631 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\UST1.csv
# ⚠ UST1: Data ends at 2009-01-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\USS1.csv
# ⚠ USS1: Data ends at 1998-10-01 — older than 30 days (likely delisted or missing data)
# ⚠ USS1: Short full history (<5 years) — only 190 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\USG1.csv
# ⚠ USG1: Data ends at 2019-04-23 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\USB1.csv
# ⚠ USB1: Data ends at 2001-02-23 — older than 30 days (likely delisted or missing data)
# ⚠ USB1: Short full history (<5 years) — only 794 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\USB.csv
# Saved: ./2-all_prices/sharadar_sep_full\URI.csv
# Saved: ./2-all_prices/sharadar_sep_full\URBN.csv
# Saved: ./2-all_prices/sharadar_sep_full\UPS.csv
# Saved: ./2-all_prices/sharadar_sep_full\UPR.csv
# ⚠ UPR: Data ends at 2000-07-14 — older than 30 days (likely delisted or missing data)
# ⚠ UPR: Short full history (<5 years) — only 640 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\UPC1.csv
# ⚠ UPC1: Data ends at 2004-06-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\UNP.csv
# Saved: ./2-all_prices/sharadar_sep_full\UNM.csv
# Saved: ./2-all_prices/sharadar_sep_full\UNH.csv
# Saved: ./2-all_prices/sharadar_sep_full\ULTA.csv
# Saved: ./2-all_prices/sharadar_sep_full\UL.csv
# Saved: ./2-all_prices/sharadar_sep_full\UK1.csv
# ⚠ UK1: Data ends at 2001-02-06 — older than 30 days (likely delisted or missing data)
# ⚠ UK1: Short full history (<5 years) — only 782 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\UIS.csv
# Saved: ./2-all_prices/sharadar_sep_full\UHS.csv
# Saved: ./2-all_prices/sharadar_sep_full\UDR.csv
# Saved: ./2-all_prices/sharadar_sep_full\UCM.csv
# ⚠ UCM: Data ends at 2000-10-20 — older than 30 days (likely delisted or missing data)
# ⚠ UCM: Short full history (<5 years) — only 709 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\WRK.csv
# ⚠ WRK: Data ends at 2024-07-05 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WRB.csv
# Saved: ./2-all_prices/sharadar_sep_full\WPX.csv
# ⚠ WPX: Data ends at 2021-01-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WOR.csv
# Saved: ./2-all_prices/sharadar_sep_full\WNDXQ.csv
# ⚠ WNDXQ: Data ends at 2006-11-21 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WMT.csv
# Saved: ./2-all_prices/sharadar_sep_full\WMB.csv
# Saved: ./2-all_prices/sharadar_sep_full\WM.csv
# Saved: ./2-all_prices/sharadar_sep_full\WLP1.csv
# ⚠ WLP1: Data ends at 2004-12-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WLL1.csv
# ⚠ WLL1: Data ends at 2002-03-14 — older than 30 days (likely delisted or missing data)
# ⚠ WLL1: Short full history (<5 years) — only 1055 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\WLA.csv
# ⚠ WLA: Data ends at 2000-06-19 — older than 30 days (likely delisted or missing data)
# ⚠ WLA: Short full history (<5 years) — only 622 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\WINMQ.csv
# ⚠ WINMQ: Data ends at 2020-09-22 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WHR.csv
# Saved: ./2-all_prices/sharadar_sep_full\WGL.csv
# ⚠ WGL: Data ends at 2018-07-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WFTIQ.csv
# ⚠ WFTIQ: Data ends at 2019-12-13 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WFM.csv
# ⚠ WFM: Data ends at 2017-08-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WFC1.csv
# ⚠ WFC1: Data ends at 1998-11-02 — older than 30 days (likely delisted or missing data)
# ⚠ WFC1: Short full history (<5 years) — only 212 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\WFC.csv
# Saved: ./2-all_prices/sharadar_sep_full\WEN.csv
# Saved: ./2-all_prices/sharadar_sep_full\WELL.csv
# Saved: ./2-all_prices/sharadar_sep_full\WEC.csv
# Saved: ./2-all_prices/sharadar_sep_full\WDC.csv
# Saved: ./2-all_prices/sharadar_sep_full\WDAY.csv
# Saved: ./2-all_prices/sharadar_sep_full\WCOEQ.csv
# ⚠ WCOEQ: Data ends at 2004-04-19 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WCG.csv
# ⚠ WCG: Data ends at 2020-01-23 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WBD.csv
# Saved: ./2-all_prices/sharadar_sep_full\WBA.csv
# ⚠ WBA: Data ends at 2025-08-28 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WB2.csv
# ⚠ WB2: Data ends at 2001-08-31 — older than 30 days (likely delisted or missing data)
# ⚠ WB2: Short full history (<5 years) — only 926 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\WB1.csv
# ⚠ WB1: Data ends at 2008-12-31 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WAT.csv
# Saved: ./2-all_prices/sharadar_sep_full\WAMUQ.csv
# ⚠ WAMUQ: Data ends at 2012-03-20 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WAI1.csv
# ⚠ WAI1: Data ends at 1998-08-10 — older than 30 days (likely delisted or missing data)
# ⚠ WAI1: Short full history (<5 years) — only 153 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\WAB.csv
# Saved: ./2-all_prices/sharadar_sep_full\VZ.csv
# Saved: ./2-all_prices/sharadar_sep_full\VYX.csv
# Saved: ./2-all_prices/sharadar_sep_full\VTSS.csv
# ⚠ VTSS: Data ends at 2015-04-27 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\VTRS.csv
# Saved: ./2-all_prices/sharadar_sep_full\VTR.csv
# Saved: ./2-all_prices/sharadar_sep_full\VSTNQ.csv
# ⚠ VSTNQ: Data ends at 2010-10-01 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\VST.csv
# ⚠ VST: Recent IPO — first price date is 2016-10-05
# Saved: ./2-all_prices/sharadar_sep_full\ZTS.csv
# Saved: ./2-all_prices/sharadar_sep_full\ZION.csv
# Saved: ./2-all_prices/sharadar_sep_full\ZBRA.csv
# Saved: ./2-all_prices/sharadar_sep_full\ZBH.csv
# Saved: ./2-all_prices/sharadar_sep_full\YUM.csv
# Saved: ./2-all_prices/sharadar_sep_full\YNR.csv
# ⚠ YNR: Data ends at 2000-10-03 — older than 30 days (likely delisted or missing data)
# ⚠ YNR: Short full history (<5 years) — only 606 trading days total.
# Saved: ./2-all_prices/sharadar_sep_full\YHOO.csv
# ⚠ YHOO: Data ends at 2017-06-16 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\XYZ.csv
# Saved: ./2-all_prices/sharadar_sep_full\XYL.csv
# Saved: ./2-all_prices/sharadar_sep_full\XTO.csv
# ⚠ XTO: Data ends at 2010-06-25 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\XRX.csv
# Saved: ./2-all_prices/sharadar_sep_full\XRAY.csv
# Saved: ./2-all_prices/sharadar_sep_full\XOM.csv
# Saved: ./2-all_prices/sharadar_sep_full\XLNX.csv
# ⚠ XLNX: Data ends at 2022-02-11 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\XL1.csv
# ⚠ XL1: Data ends at 2018-09-11 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\XEL.csv
# Saved: ./2-all_prices/sharadar_sep_full\XEC.csv
# ⚠ XEC: Data ends at 2021-09-30 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\X.csv
# ⚠ X: Data ends at 2025-06-17 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WYNN.csv
# Saved: ./2-all_prices/sharadar_sep_full\WYE.csv
# ⚠ WYE: Data ends at 2009-10-15 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WY.csv
# Saved: ./2-all_prices/sharadar_sep_full\WWY.csv
# ⚠ WWY: Data ends at 2008-10-06 — older than 30 days (likely delisted or missing data)
# Saved: ./2-all_prices/sharadar_sep_full\WU.csv
# Saved: ./2-all_prices/sharadar_sep_full\WTW.csv
# Saved: ./2-all_prices/sharadar_sep_full\WST.csv
# Saved: ./2-all_prices/sharadar_sep_full\WSM.csv
#
# ===============================================================================
#  DONE — Full SHARADAR/SEP OHLCV + TOTAL-RETURN CLOSE (closeadj) saved per ticker
#  Diagnostics printed to terminal.
#  Location: ./2-all_prices/sharadar_sep_full
# ===============================================================================

# %%
import pandas as pd
df = pd.read_parquet("./sp500_prices/sp500_price_matrix_raw.parquet")
df
# Out:
# date    1997-12-31  1998-01-02  1998-01-05  1998-01-06  1998-01-07  \
# ticker
# A              NaN         NaN         NaN         NaN         NaN
# AAL            NaN         NaN         NaN         NaN         NaN
# AAMRQ       64.250      63.812      64.312      64.719      66.375
# AAP            NaN         NaN         NaN         NaN         NaN
# AAPL         0.117       0.145       0.142       0.169       0.156
# ...            ...         ...         ...         ...         ...
# YUM          7.265       7.282       7.062       6.765       6.750
# ZBH            NaN         NaN         NaN         NaN         NaN
# ZBRA        13.222      13.222      13.084      13.111      13.027
# ZION        45.380      45.500      46.380      45.630      44.880
# ZTS            NaN         NaN         NaN         NaN         NaN
#
# date    1998-01-08  1998-01-09  1998-01-12  1998-01-13  1998-01-14  ...  \
# ticker                                                              ...
# A              NaN         NaN         NaN         NaN         NaN  ...
# AAL            NaN         NaN         NaN         NaN         NaN  ...
# AAMRQ       65.438      62.500      64.781      64.812      64.625  ...
# AAP            NaN         NaN         NaN         NaN         NaN  ...
# AAPL         0.163       0.163       0.163       0.174       0.176  ...
# ...            ...         ...         ...         ...         ...  ...
# YUM          6.485       6.500       6.532       6.532       6.532  ...
# ZBH            NaN         NaN         NaN         NaN         NaN  ...
# ZBRA        13.000      11.836      11.804      12.280      11.613  ...
# ZION        41.500      39.560      40.500      40.750      42.250  ...
# ZTS            NaN         NaN         NaN         NaN         NaN  ...
#
# date    2025-11-11  2025-11-12  2025-11-13  2025-11-14  2025-11-17  \
# ticker
# A           149.42      151.52      146.89      146.82      144.52
# AAL          12.99       13.41       13.07       12.76       12.34
# AAMRQ          NaN         NaN         NaN         NaN         NaN
# AAP          51.06       51.02       50.22       50.03       48.93
# AAPL        275.25      273.47      272.95      272.41      267.46
# ...            ...         ...         ...         ...         ...
# YUM         150.75      149.37      149.73      149.02      148.03
# ZBH          88.50       90.03       90.57       89.91       88.64
# ZBRA        255.17      255.69      241.57      240.56      232.71
# ZION         52.67       52.45       50.91       51.02       48.92
# ZTS         120.12      121.25      121.16      120.82      118.80
#
# date    2025-11-18  2025-11-19  2025-11-20  2025-11-21  2025-11-24
# ticker
# A           143.84      144.40      145.06      151.25      153.60
# AAL          12.36       12.33       12.24       12.87       13.10
# AAMRQ          NaN         NaN         NaN         NaN         NaN
# AAP          49.76       50.04       48.37       51.70       50.93
# AAPL        267.44      268.56      266.25      271.49      275.92
# ...            ...         ...         ...         ...         ...
# YUM         148.82      148.32      149.21      152.98      151.08
# ZBH          89.08       89.45       89.07       92.18       93.52
# ZBRA        230.90      230.93      228.40      240.95      242.45
# ZION         49.34       50.43       50.44       52.12       51.89
# ZTS         118.14      117.08      115.89      122.06      122.87
#
# [1162 rows x 7019 columns]
