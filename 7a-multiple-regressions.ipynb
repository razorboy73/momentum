# %%
#!/usr/bin/env python3
import os
import pandas as pd
import numpy as np
from datetime import datetime
from numba import njit, prange

"""
Purpose:
    Compute rolling log-price regressions (slope + R²) for multiple lookback windows
    and save outputs bucketed into subdirectories per lookback.

Outputs:
    OUTPUT_ROOT/lookback_XXD/{TICKER}.parquet
    VER_ROOT/lookback_XXD/regression_validation-<timestamp>.csv
"""

# ============================================================
# CONFIG
# ============================================================

INPUT_DIR   = "./3-adjusted_All_Prices_OHLC"

# Keep your existing output directories as the ROOT, and bucket by subfolders
OUTPUT_ROOT = "./7a-multiple_regressions_adjusted_all_prices"
VER_ROOT    = "./system_verification/7a-multiple_regressions_adjusted_all_prices"

os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(VER_ROOT, exist_ok=True)

# 4–5 lookback windows (trading days)
WINDOWS = [60, 90, 120, 180, 252]

TRADING_DAYS_PER_YEAR = 252  # for annualization
REQUIRED = {"date", "close_adj"}

print(f"\nLoading adjusted OHLC files from: {INPUT_DIR}")
files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".parquet")])
print(f"Found {len(files)} tickers.\n")

# ============================================================
# VALIDATION STORAGE
# ============================================================

validation_rows = []

def add_validation(ticker, window, issue, detail=""):
    row = {"ticker": ticker, "window": int(window), "issue": issue, "detail": detail}
    validation_rows.append(row)
    print(f"⚠ VALIDATION: {ticker} | W={window} | {issue} | {detail}")

# ============================================================
# NUMBA REGRESSION ENGINE (window-parameterized)
# ============================================================

@njit
def fast_regression_window(y, x, x_mean, var_x, W):
    """
    Computes slope + R² for one window of log prices.
    Regression: log(price) ~ beta0 + beta1 * time_index
    beta1 is in units of log-price per day (≈ avg daily log-return).
    """
    # reject invalid windows
    for v in y:
        if np.isnan(v) or np.isinf(v):
            return np.nan, np.nan

    y_mean = np.mean(y)

    # covariance
    cov_xy = 0.0
    for i in range(W):
        cov_xy += (x[i] - x_mean) * (y[i] - y_mean)
    cov_xy /= W

    beta1 = cov_xy / var_x
    beta0 = y_mean - beta1 * x_mean

    # compute R²
    ss_res = 0.0
    ss_tot = 0.0
    for i in range(W):
        y_hat = beta0 + beta1 * x[i]
        ss_res += (y[i] - y_hat) ** 2
        ss_tot += (y[i] - y_mean) ** 2

    r2 = 1.0 - ss_res / ss_tot if ss_tot > 0 else np.nan
    return beta1, r2

@njit(parallel=True)
def run_rolling_regressions(log_prices, W, x, x_mean, var_x):
    """
    log_prices: 1D array of log-adjusted prices for this ticker.

    Alignment:
    - slope at index t uses window ending at t (inclusive):
      log_prices[t-W+1 : t+1]
    - first valid index is W-1.
    """
    n = len(log_prices)
    slopes_daily = np.full(n, np.nan)
    r2_out = np.full(n, np.nan)

    for t in prange(W - 1, n):
        window = log_prices[t - W + 1 : t + 1]
        slope, r2 = fast_regression_window(window, x, x_mean, var_x, W)
        slopes_daily[t] = slope
        r2_out[t] = r2

    return slopes_daily, r2_out

# ============================================================
# MAIN LOGIC
# ============================================================

for file in files:
    ticker = file.replace(".parquet", "")
    in_path = os.path.join(INPUT_DIR, file)

    print(f"Processing {ticker}...")

    try:
        # -----------------------------
        # Load & validate (once)
        # -----------------------------
        df = pd.read_parquet(in_path)

        if not REQUIRED.issubset(df.columns):
            add_validation(ticker, -1, "missing_columns", str(REQUIRED - set(df.columns)))
            continue

        df["date"] = pd.to_datetime(df["date"])
        df = df.sort_values("date").reset_index(drop=True)

        if (df["close_adj"] <= 0).any():
            add_validation(
                ticker, -1, "nonpositive_close_adj",
                f"{(df['close_adj'] <= 0).sum()} rows"
            )

        # Prepare log prices once
        px = df["close_adj"].astype(float).values
        px = np.where(px > 0, px, np.nan)  # guard
        log_px = np.log(px)

        n = len(df)

        # -----------------------------
        # Compute each lookback window
        # -----------------------------
        for W in WINDOWS:
            out_dir = os.path.join(OUTPUT_ROOT, f"lookback_{W}D")
            ver_dir = os.path.join(VER_ROOT,  f"lookback_{W}D")
            os.makedirs(out_dir, exist_ok=True)
            os.makedirs(ver_dir, exist_ok=True)

            out_path = os.path.join(out_dir, f"{ticker}.parquet")

            if n < W:
                last_date = df["date"].max().date()
                add_validation(
                    ticker, W, "insufficient_history_for_regression",
                    f"{n} rows, last={last_date}"
                )
                continue

            # Precompute x-axis for this window (0..W-1)
            x = np.arange(W, dtype=np.float64)
            x_mean = x.mean()
            var_x = np.mean((x - x_mean) ** 2)

            slopes_daily, r2 = run_rolling_regressions(log_px, W, x, x_mean, var_x)

            # annualize slope: slope_daily is avg daily log-return
            slopes_annual = np.expm1(slopes_daily * TRADING_DAYS_PER_YEAR)

            df_out = df.copy()
            df_out["window"]       = int(W)
            df_out["slope_daily"]  = slopes_daily
            df_out["slope_annual"] = slopes_annual
            df_out["r2"]           = r2

            df_out.to_parquet(out_path, index=False)

        print(f"✔ {ticker}: done ({len(WINDOWS)} lookbacks)\n")

    except Exception as e:
        # window=-1 indicates "not window-specific"
        add_validation(ticker, -1, "processing_error", str(e))
        print(f"❌ ERROR for {ticker}: {e}\n")

# ============================================================
# SAVE VALIDATION REPORT (single combined file)
# ============================================================

validation_df = pd.DataFrame(validation_rows)

val_file = os.path.join(
    VER_ROOT,
    f"regression_multi_validation-{datetime.now().strftime('%Y%m%d-%H%M%S')}.csv"
)
validation_df.to_csv(val_file, index=False)

print("\n====================================================")
print(" MULTI-LOOKBACK REGRESSION VALIDATION SUMMARY")
print("====================================================")
if validation_df.empty:
    print("No validation issues detected.")
else:
    print(validation_df)
print("\nValidation log saved to:")
print(val_file)
print("====================================================\n")
# Out:
# Loading adjusted OHLC files from: ./3-adjusted_All_Prices_OHLC
# Found 1167 tickers.
#
# Processing A...
# ✔ A: done (5 lookbacks)
#
# Processing AAL...
# ✔ AAL: done (5 lookbacks)
#
# Processing AAMRQ...
# ✔ AAMRQ: done (5 lookbacks)
#
# Processing AAP...
# ✔ AAP: done (5 lookbacks)
#
# Processing AAPL...
# ✔ AAPL: done (5 lookbacks)
#
# Processing ABBV...
# ✔ ABBV: done (5 lookbacks)
#
# Processing ABI1...
# ✔ ABI1: done (5 lookbacks)
#
# Processing ABKFQ...
# ✔ ABKFQ: done (5 lookbacks)
#
# Processing ABMD...
# ✔ ABMD: done (5 lookbacks)
#
# Processing ABNB...
# ✔ ABNB: done (5 lookbacks)
#
# Processing ABS...
# ✔ ABS: done (5 lookbacks)
#
# Processing ABT...
# ✔ ABT: done (5 lookbacks)
#
# Processing ACAS...
# ✔ ACAS: done (5 lookbacks)
#
# Processing ACGL...
# ✔ ACGL: done (5 lookbacks)
#
# Processing ACKHQ...
# ✔ ACKHQ: done (5 lookbacks)
#
# Processing ACN...
# ✔ ACN: done (5 lookbacks)
#
# Processing ACS...
# ✔ ACS: done (5 lookbacks)
#
# Processing ACV1...
# ✔ ACV1: done (5 lookbacks)
#
# Processing ADBE...
# ✔ ADBE: done (5 lookbacks)
#
# Processing ADCT1...
# ✔ ADCT1: done (5 lookbacks)
#
# Processing ADI...
# ✔ ADI: done (5 lookbacks)
#
# Processing ADM...
# ✔ ADM: done (5 lookbacks)
#
# Processing ADP...
# ✔ ADP: done (5 lookbacks)
#
# Processing ADSK...
# ✔ ADSK: done (5 lookbacks)
#
# Processing ADT1...
# ✔ ADT1: done (5 lookbacks)
#
# Processing AEE...
# ✔ AEE: done (5 lookbacks)
#
# Processing AEP...
# ✔ AEP: done (5 lookbacks)
#
# Processing AES...
# ✔ AES: done (5 lookbacks)
#
# Processing AET...
# ✔ AET: done (5 lookbacks)
#
# Processing AFL...
# ✔ AFL: done (5 lookbacks)
#
# Processing AFS.A...
# ✔ AFS.A: done (5 lookbacks)
#
# Processing AGC1...
# ✔ AGC1: done (5 lookbacks)
#
# Processing AGN...
# ✔ AGN: done (5 lookbacks)
#
# Processing AGN1...
# ✔ AGN1: done (5 lookbacks)
#
# Processing AHM1...
# ⚠ VALIDATION: AHM1 | W=252 | insufficient_history_for_regression | 190 rows, last=1998-10-01
# ✔ AHM1: done (5 lookbacks)
#
# Processing AIG...
# ✔ AIG: done (5 lookbacks)
#
# Processing AIT...
# ✔ AIT: done (5 lookbacks)
#
# Processing AIV...
# ✔ AIV: done (5 lookbacks)
#
# Processing AIZ...
# ✔ AIZ: done (5 lookbacks)
#
# Processing AJG...
# ✔ AJG: done (5 lookbacks)
#
# Processing AKAM...
# ✔ AKAM: done (5 lookbacks)
#
# Processing AKS...
# ✔ AKS: done (5 lookbacks)
#
# Processing AL1...
# ✔ AL1: done (5 lookbacks)
#
# Processing ALB...
# ✔ ALB: done (5 lookbacks)
#
# Processing ALGN...
# ✔ ALGN: done (5 lookbacks)
#
# Processing ALK...
# ✔ ALK: done (5 lookbacks)
#
# Processing ALL...
# ✔ ALL: done (5 lookbacks)
#
# Processing ALLE...
# ✔ ALLE: done (5 lookbacks)
#
# Processing ALTR1...
# ✔ ALTR1: done (5 lookbacks)
#
# Processing ALXN...
# ✔ ALXN: done (5 lookbacks)
#
# Processing AM1...
# ✔ AM1: done (5 lookbacks)
#
# Processing AMAT...
# ✔ AMAT: done (5 lookbacks)
#
# Processing AMCC...
# ✔ AMCC: done (5 lookbacks)
#
# Processing AMCR...
# ✔ AMCR: done (5 lookbacks)
#
# Processing AMD...
# ✔ AMD: done (5 lookbacks)
#
# Processing AME...
# ✔ AME: done (5 lookbacks)
#
# Processing AMG...
# ✔ AMG: done (5 lookbacks)
#
# Processing AMGN...
# ✔ AMGN: done (5 lookbacks)
#
# Processing AMP...
# ✔ AMP: done (5 lookbacks)
#
# Processing AMP1...
# ✔ AMP1: done (5 lookbacks)
#
# Processing AMT...
# ✔ AMT: done (5 lookbacks)
#
# Processing AMTM...
# ✔ AMTM: done (5 lookbacks)
#
# Processing AMZN...
# ✔ AMZN: done (5 lookbacks)
#
# Processing AN...
# ✔ AN: done (5 lookbacks)
#
# Processing AN1...
# ✔ AN1: done (5 lookbacks)
#
# Processing ANDV...
# ✔ ANDV: done (5 lookbacks)
#
# Processing ANDW...
# ✔ ANDW: done (5 lookbacks)
#
# Processing ANET...
# ✔ ANET: done (5 lookbacks)
#
# Processing ANF...
# ✔ ANF: done (5 lookbacks)
#
# Processing ANRZQ...
# ✔ ANRZQ: done (5 lookbacks)
#
# Processing ANSS...
# ✔ ANSS: done (5 lookbacks)
#
# Processing ANV1...
# ✔ ANV1: done (5 lookbacks)
#
# Processing AON...
# ✔ AON: done (5 lookbacks)
#
# Processing AOS...
# ✔ AOS: done (5 lookbacks)
#
# Processing APA...
# ✔ APA: done (5 lookbacks)
#
# Processing APC...
# ✔ APC: done (5 lookbacks)
#
# Processing APCC...
# ✔ APCC: done (5 lookbacks)
#
# Processing APD...
# ✔ APD: done (5 lookbacks)
#
# Processing APH...
# ✔ APH: done (5 lookbacks)
#
# Processing APO...
# ✔ APO: done (5 lookbacks)
#
# Processing APOL...
# ✔ APOL: done (5 lookbacks)
#
# Processing APP...
# ✔ APP: done (5 lookbacks)
#
# Processing APTV...
# ✔ APTV: done (5 lookbacks)
#
# Processing AR1...
# ✔ AR1: done (5 lookbacks)
#
# Processing ARC1...
# ✔ ARC1: done (5 lookbacks)
#
# Processing ARE...
# ✔ ARE: done (5 lookbacks)
#
# Processing ARES...
# ✔ ARES: done (5 lookbacks)
#
# Processing ARG...
# ✔ ARG: done (5 lookbacks)
#
# Processing AS1...
# ✔ AS1: done (5 lookbacks)
#
# Processing ASC1...
# ✔ ASC1: done (5 lookbacks)
#
# Processing ASH...
# ✔ ASH: done (5 lookbacks)
#
# Processing ASN...
# ✔ ASN: done (5 lookbacks)
#
# Processing ASND1...
# ✔ ASND1: done (5 lookbacks)
#
# Processing ASO1...
# ✔ ASO1: done (5 lookbacks)
#
# Processing AT1...
# ✔ AT1: done (5 lookbacks)
#
# Processing ATGE...
# ✔ ATGE: done (5 lookbacks)
#
# Processing ATI...
# ✔ ATI: done (5 lookbacks)
#
# Processing ATI1...
# ✔ ATI1: done (5 lookbacks)
#
# Processing ATO...
# ✔ ATO: done (5 lookbacks)
#
# Processing ATVI...
# ✔ ATVI: done (5 lookbacks)
#
# Processing AV1...
# ✔ AV1: done (5 lookbacks)
#
# Processing AVB...
# ✔ AVB: done (5 lookbacks)
#
# Processing AVGO...
# ✔ AVGO: done (5 lookbacks)
#
# Processing AVP...
# ✔ AVP: done (5 lookbacks)
#
# Processing AVY...
# ✔ AVY: done (5 lookbacks)
#
# Processing AW...
# ✔ AW: done (5 lookbacks)
#
# Processing AWE...
# ✔ AWE: done (5 lookbacks)
#
# Processing AWK...
# ✔ AWK: done (5 lookbacks)
#
# Processing AXON...
# ✔ AXON: done (5 lookbacks)
#
# Processing AXP...
# ✔ AXP: done (5 lookbacks)
#
# Processing AYE...
# ✔ AYE: done (5 lookbacks)
#
# Processing AYI...
# ✔ AYI: done (5 lookbacks)
#
# Processing AZA.A...
# ✔ AZA.A: done (5 lookbacks)
#
# Processing AZO...
# ✔ AZO: done (5 lookbacks)
#
# Processing B...
# ✔ B: done (5 lookbacks)
#
# Processing BA...
# ✔ BA: done (5 lookbacks)
#
# Processing BAC...
# ✔ BAC: done (5 lookbacks)
#
# Processing BAC1...
# ⚠ VALIDATION: BAC1 | W=252 | insufficient_history_for_regression | 189 rows, last=1998-09-30
# ✔ BAC1: done (5 lookbacks)
#
# Processing BALL...
# ✔ BALL: done (5 lookbacks)
#
# Processing BAX...
# ✔ BAX: done (5 lookbacks)
#
# Processing BAY1...
# ⚠ VALIDATION: BAY1 | W=180 | insufficient_history_for_regression | 167 rows, last=1998-08-28
# ⚠ VALIDATION: BAY1 | W=252 | insufficient_history_for_regression | 167 rows, last=1998-08-28
# ✔ BAY1: done (5 lookbacks)
#
# Processing BBBYQ...
# ✔ BBBYQ: done (5 lookbacks)
#
# Processing BBI1...
# ⚠ VALIDATION: BBI1 | W=60 | insufficient_history_for_regression | 7 rows, last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=90 | insufficient_history_for_regression | 7 rows, last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=120 | insufficient_history_for_regression | 7 rows, last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=180 | insufficient_history_for_regression | 7 rows, last=1998-01-09
# ⚠ VALIDATION: BBI1 | W=252 | insufficient_history_for_regression | 7 rows, last=1998-01-09
# ✔ BBI1: done (5 lookbacks)
#
# Processing BBWI...
# ✔ BBWI: done (5 lookbacks)
#
# Processing BBY...
# ✔ BBY: done (5 lookbacks)
#
# Processing BC...
# ✔ BC: done (5 lookbacks)
#
# Processing BCR...
# ✔ BCR: done (5 lookbacks)
#
# Processing BDK...
# ✔ BDK: done (5 lookbacks)
#
# Processing BDX...
# ✔ BDX: done (5 lookbacks)
#
# Processing BEAM2...
# ✔ BEAM2: done (5 lookbacks)
#
# Processing BEN...
# ✔ BEN: done (5 lookbacks)
#
# Processing BF.B...
# ✔ BF.B: done (5 lookbacks)
#
# Processing BFH...
# ✔ BFH: done (5 lookbacks)
#
# Processing BFI1...
# ✔ BFI1: done (5 lookbacks)
#
# Processing BFO1...
# ✔ BFO1: done (5 lookbacks)
#
# Processing BG...
# ✔ BG: done (5 lookbacks)
#
# Processing BGEN...
# ✔ BGEN: done (5 lookbacks)
#
# Processing BGGSQ...
# ✔ BGGSQ: done (5 lookbacks)
#
# Processing BHF...
# ✔ BHF: done (5 lookbacks)
#
# Processing BHI...
# ✔ BHI: done (5 lookbacks)
#
# Processing BHMSQ...
# ✔ BHMSQ: done (5 lookbacks)
#
# Processing BIGGQ...
# ✔ BIGGQ: done (5 lookbacks)
#
# Processing BIIB...
# ✔ BIIB: done (5 lookbacks)
#
# Processing BIO...
# ✔ BIO: done (5 lookbacks)
#
# Processing BJS...
# ✔ BJS: done (5 lookbacks)
#
# Processing BK...
# ✔ BK: done (5 lookbacks)
#
# Processing BKB...
# ✔ BKB: done (5 lookbacks)
#
# Processing BKNG...
# ✔ BKNG: done (5 lookbacks)
#
# Processing BKR...
# ✔ BKR: done (5 lookbacks)
#
# Processing BLDR...
# ✔ BLDR: done (5 lookbacks)
#
# Processing BLK...
# ✔ BLK: done (5 lookbacks)
#
# Processing BLS...
# ✔ BLS: done (5 lookbacks)
#
# Processing BMC...
# ✔ BMC: done (5 lookbacks)
#
# Processing BMET...
# ✔ BMET: done (5 lookbacks)
#
# Processing BMGCA...
# ✔ BMGCA: done (5 lookbacks)
#
# Processing BMS...
# ✔ BMS: done (5 lookbacks)
#
# Processing BMY...
# ✔ BMY: done (5 lookbacks)
#
# Processing BNI...
# ✔ BNI: done (5 lookbacks)
#
# Processing BNL1...
# ⚠ VALIDATION: BNL1 | W=180 | insufficient_history_for_regression | 125 rows, last=1998-06-30
# ⚠ VALIDATION: BNL1 | W=252 | insufficient_history_for_regression | 125 rows, last=1998-06-30
# ✔ BNL1: done (5 lookbacks)
#
# Processing BOL...
# ✔ BOL: done (5 lookbacks)
#
# Processing BR...
# ✔ BR: done (5 lookbacks)
#
# Processing BR1...
# ✔ BR1: done (5 lookbacks)
#
# Processing BRCM...
# ✔ BRCM: done (5 lookbacks)
#
# Processing BRK.B...
# ✔ BRK.B: done (5 lookbacks)
#
# Processing BRL...
# ✔ BRL: done (5 lookbacks)
#
# Processing BRO...
# ✔ BRO: done (5 lookbacks)
#
# Processing BSC1...
# ✔ BSC1: done (5 lookbacks)
#
# Processing BSX...
# ✔ BSX: done (5 lookbacks)
#
# Processing BT1...
# ✔ BT1: done (5 lookbacks)
#
# Processing BTUUQ...
# ✔ BTUUQ: done (5 lookbacks)
#
# Processing BUD1...
# ✔ BUD1: done (5 lookbacks)
#
# Processing BVSN...
# ✔ BVSN: done (5 lookbacks)
#
# Processing BWA...
# ✔ BWA: done (5 lookbacks)
#
# Processing BX...
# ✔ BX: done (5 lookbacks)
#
# Processing BXLT...
# ⚠ VALIDATION: BXLT | W=252 | insufficient_history_for_regression | 233 rows, last=2016-06-02
# ✔ BXLT: done (5 lookbacks)
#
# Processing BXP...
# ✔ BXP: done (5 lookbacks)
#
# Processing C...
# ✔ C: done (5 lookbacks)
#
# Processing C1...
# ⚠ VALIDATION: C1 | W=252 | insufficient_history_for_regression | 220 rows, last=1998-11-12
# ✔ C1: done (5 lookbacks)
#
# Processing CA1...
# ✔ CA1: done (5 lookbacks)
#
# Processing CAG...
# ✔ CAG: done (5 lookbacks)
#
# Processing CAH...
# ✔ CAH: done (5 lookbacks)
#
# Processing CAL...
# ✔ CAL: done (5 lookbacks)
#
# Processing CAM2...
# ✔ CAM2: done (5 lookbacks)
#
# Processing CAR...
# ✔ CAR: done (5 lookbacks)
#
# Processing CARR...
# ✔ CARR: done (5 lookbacks)
#
# Processing CAT...
# ✔ CAT: done (5 lookbacks)
#
# Processing CB...
# ✔ CB: done (5 lookbacks)
#
# Processing CB1...
# ✔ CB1: done (5 lookbacks)
#
# Processing CBE...
# ✔ CBE: done (5 lookbacks)
#
# Processing CBH1...
# ✔ CBH1: done (5 lookbacks)
#
# Processing CBOE...
# ✔ CBOE: done (5 lookbacks)
#
# Processing CBRE...
# ✔ CBRE: done (5 lookbacks)
#
# Processing CBS1...
# ✔ CBS1: done (5 lookbacks)
#
# Processing CBSS...
# ✔ CBSS: done (5 lookbacks)
#
# Processing CCE1...
# ✔ CCE1: done (5 lookbacks)
#
# Processing CCI...
# ✔ CCI: done (5 lookbacks)
#
# Processing CCI1...
# ⚠ VALIDATION: CCI1 | W=252 | insufficient_history_for_regression | 194 rows, last=1998-10-07
# ✔ CCI1: done (5 lookbacks)
#
# Processing CCK...
# ✔ CCK: done (5 lookbacks)
#
# Processing CCL...
# ✔ CCL: done (5 lookbacks)
#
# Processing CCTYQ...
# ✔ CCTYQ: done (5 lookbacks)
#
# Processing CCU1...
# ✔ CCU1: done (5 lookbacks)
#
# Processing CDNS...
# ✔ CDNS: done (5 lookbacks)
#
# Processing CDW...
# ✔ CDW: done (5 lookbacks)
#
# Processing CE...
# ✔ CE: done (5 lookbacks)
#
# Processing CE1...
# ✔ CE1: done (5 lookbacks)
#
# Processing CEG...
# ✔ CEG: done (5 lookbacks)
#
# Processing CEG1...
# ✔ CEG1: done (5 lookbacks)
#
# Processing CELG...
# ✔ CELG: done (5 lookbacks)
#
# Processing CEM1...
# ✔ CEM1: done (5 lookbacks)
#
# Processing CEN1...
# ✔ CEN1: done (5 lookbacks)
#
# Processing CEPH...
# ✔ CEPH: done (5 lookbacks)
#
# Processing CERN...
# ✔ CERN: done (5 lookbacks)
#
# Processing CF...
# ✔ CF: done (5 lookbacks)
#
# Processing CF1...
# ✔ CF1: done (5 lookbacks)
#
# Processing CFC...
# ✔ CFC: done (5 lookbacks)
#
# Processing CFG...
# ✔ CFG: done (5 lookbacks)
#
# Processing CFL1...
# ⚠ VALIDATION: CFL1 | W=90 | insufficient_history_for_regression | 80 rows, last=1998-04-27
# ⚠ VALIDATION: CFL1 | W=120 | insufficient_history_for_regression | 80 rows, last=1998-04-27
# ⚠ VALIDATION: CFL1 | W=180 | insufficient_history_for_regression | 80 rows, last=1998-04-27
# ⚠ VALIDATION: CFL1 | W=252 | insufficient_history_for_regression | 80 rows, last=1998-04-27
# ✔ CFL1: done (5 lookbacks)
#
# Processing CFN...
# ✔ CFN: done (5 lookbacks)
#
# Processing CG1...
# ✔ CG1: done (5 lookbacks)
#
# Processing CGP...
# ✔ CGP: done (5 lookbacks)
#
# Processing CHA1...
# ✔ CHA1: done (5 lookbacks)
#
# Processing CHD...
# ✔ CHD: done (5 lookbacks)
#
# Processing CHIR1...
# ✔ CHIR1: done (5 lookbacks)
#
# Processing CHKAQ...
# ✔ CHKAQ: done (5 lookbacks)
#
# Processing CHRS1...
# ✔ CHRS1: done (5 lookbacks)
#
# Processing CHRW...
# ✔ CHRW: done (5 lookbacks)
#
# Processing CHTR...
# ✔ CHTR: done (5 lookbacks)
#
# Processing CI...
# ✔ CI: done (5 lookbacks)
#
# Processing CIEN...
# ✔ CIEN: done (5 lookbacks)
#
# Processing CIN...
# ✔ CIN: done (5 lookbacks)
#
# Processing CINF...
# ✔ CINF: done (5 lookbacks)
#
# Processing CIT.A...
# ✔ CIT.A: done (5 lookbacks)
#
# Processing CITGQ...
# ✔ CITGQ: done (5 lookbacks)
#
# Processing CL...
# ✔ CL: done (5 lookbacks)
#
# Processing CLF...
# ✔ CLF: done (5 lookbacks)
#
# Processing CLX...
# ✔ CLX: done (5 lookbacks)
#
# Processing CMA...
# ✔ CMA: done (5 lookbacks)
#
# Processing CMCSA...
# ✔ CMCSA: done (5 lookbacks)
#
# Processing CMCSK...
# ✔ CMCSK: done (5 lookbacks)
#
# Processing CME...
# ✔ CME: done (5 lookbacks)
#
# Processing CMG...
# ✔ CMG: done (5 lookbacks)
#
# Processing CMI...
# ✔ CMI: done (5 lookbacks)
#
# Processing CMS...
# ✔ CMS: done (5 lookbacks)
#
# Processing CMVT...
# ✔ CMVT: done (5 lookbacks)
#
# Processing CMX...
# ✔ CMX: done (5 lookbacks)
#
# Processing CNC...
# ✔ CNC: done (5 lookbacks)
#
# Processing CNCEQ...
# ✔ CNCEQ: done (5 lookbacks)
#
# Processing CNG...
# ✔ CNG: done (5 lookbacks)
#
# Processing CNP...
# ✔ CNP: done (5 lookbacks)
#
# Processing CNW...
# ✔ CNW: done (5 lookbacks)
#
# Processing CNX...
# ✔ CNX: done (5 lookbacks)
#
# Processing CNXT1...
# ✔ CNXT1: done (5 lookbacks)
#
# Processing COC...
# ✔ COC: done (5 lookbacks)
#
# Processing COF...
# ✔ COF: done (5 lookbacks)
#
# Processing COIN...
# ✔ COIN: done (5 lookbacks)
#
# Processing COL...
# ✔ COL: done (5 lookbacks)
#
# Processing COMS1...
# ✔ COMS1: done (5 lookbacks)
#
# Processing COO...
# ✔ COO: done (5 lookbacks)
#
# Processing COP...
# ✔ COP: done (5 lookbacks)
#
# Processing COR...
# ✔ COR: done (5 lookbacks)
#
# Processing COST...
# ✔ COST: done (5 lookbacks)
#
# Processing COT1...
# ✔ COT1: done (5 lookbacks)
#
# Processing COTY...
# ✔ COTY: done (5 lookbacks)
#
# Processing COV...
# ✔ COV: done (5 lookbacks)
#
# Processing CPAY...
# ✔ CPAY: done (5 lookbacks)
#
# Processing CPB...
# ✔ CPB: done (5 lookbacks)
#
# Processing CPGX...
# ✔ CPGX: done (5 lookbacks)
#
# Processing CPNLQ...
# ✔ CPNLQ: done (5 lookbacks)
#
# Processing CPPRQ...
# ✔ CPPRQ: done (5 lookbacks)
#
# Processing CPQ...
# ✔ CPQ: done (5 lookbacks)
#
# Processing CPRI...
# ✔ CPRI: done (5 lookbacks)
#
# Processing CPRT...
# ✔ CPRT: done (5 lookbacks)
#
# Processing CPT...
# ✔ CPT: done (5 lookbacks)
#
# Processing CPWR...
# ✔ CPWR: done (5 lookbacks)
#
# Processing CRH...
# ✔ CRH: done (5 lookbacks)
#
# Processing CRL...
# ✔ CRL: done (5 lookbacks)
#
# Processing CRM...
# ✔ CRM: done (5 lookbacks)
#
# Processing CRWD...
# ✔ CRWD: done (5 lookbacks)
#
# Processing CSC...
# ✔ CSC: done (5 lookbacks)
#
# Processing CSCO...
# ✔ CSCO: done (5 lookbacks)
#
# Processing CSE1...
# ✔ CSE1: done (5 lookbacks)
#
# Processing CSGP...
# ✔ CSGP: done (5 lookbacks)
#
# Processing CSR1...
# ✔ CSR1: done (5 lookbacks)
#
# Processing CSRA...
# ✔ CSRA: done (5 lookbacks)
#
# Processing CSX...
# ✔ CSX: done (5 lookbacks)
#
# Processing CTAS...
# ✔ CTAS: done (5 lookbacks)
#
# Processing CTB...
# ✔ CTB: done (5 lookbacks)
#
# Processing CTLT...
# ✔ CTLT: done (5 lookbacks)
#
# Processing CTRA...
# ✔ CTRA: done (5 lookbacks)
#
# Processing CTSH...
# ✔ CTSH: done (5 lookbacks)
#
# Processing CTVA...
# ✔ CTVA: done (5 lookbacks)
#
# Processing CTX1...
# ✔ CTX1: done (5 lookbacks)
#
# Processing CTXS...
# ✔ CTXS: done (5 lookbacks)
#
# Processing CVC...
# ✔ CVC: done (5 lookbacks)
#
# Processing CVG...
# ✔ CVG: done (5 lookbacks)
#
# Processing CVGYQ...
# ✔ CVGYQ: done (5 lookbacks)
#
# Processing CVH...
# ✔ CVH: done (5 lookbacks)
#
# Processing CVNA...
# ✔ CVNA: done (5 lookbacks)
#
# Processing CVS...
# ✔ CVS: done (5 lookbacks)
#
# Processing CVX...
# ✔ CVX: done (5 lookbacks)
#
# Processing CXO...
# ✔ CXO: done (5 lookbacks)
#
# Processing CXT...
# ✔ CXT: done (5 lookbacks)
#
# Processing CYM...
# ✔ CYM: done (5 lookbacks)
#
# Processing CZR...
# ✔ CZR: done (5 lookbacks)
#
# Processing D...
# ✔ D: done (5 lookbacks)
#
# Processing DAL...
# ✔ DAL: done (5 lookbacks)
#
# Processing DALRQ...
# ✔ DALRQ: done (5 lookbacks)
#
# Processing DASH...
# ✔ DASH: done (5 lookbacks)
#
# Processing DAY...
# ✔ DAY: done (5 lookbacks)
#
# Processing DCNAQ...
# ✔ DCNAQ: done (5 lookbacks)
#
# Processing DD...
# ✔ DD: done (5 lookbacks)
#
# Processing DD1...
# ✔ DD1: done (5 lookbacks)
#
# Processing DDOG...
# ✔ DDOG: done (5 lookbacks)
#
# Processing DDS...
# ✔ DDS: done (5 lookbacks)
#
# Processing DE...
# ✔ DE: done (5 lookbacks)
#
# Processing DEC1...
# ⚠ VALIDATION: DEC1 | W=120 | insufficient_history_for_regression | 112 rows, last=1998-06-11
# ⚠ VALIDATION: DEC1 | W=180 | insufficient_history_for_regression | 112 rows, last=1998-06-11
# ⚠ VALIDATION: DEC1 | W=252 | insufficient_history_for_regression | 112 rows, last=1998-06-11
# ✔ DEC1: done (5 lookbacks)
#
# Processing DECK...
# ✔ DECK: done (5 lookbacks)
#
# Processing DELL...
# ✔ DELL: done (5 lookbacks)
#
# Processing DELL1...
# ✔ DELL1: done (5 lookbacks)
#
# Processing DFODQ...
# ✔ DFODQ: done (5 lookbacks)
#
# Processing DFS...
# ✔ DFS: done (5 lookbacks)
#
# Processing DG...
# ✔ DG: done (5 lookbacks)
#
# Processing DG1...
# ✔ DG1: done (5 lookbacks)
#
# Processing DGN...
# ✔ DGN: done (5 lookbacks)
#
# Processing DGX...
# ✔ DGX: done (5 lookbacks)
#
# Processing DHI...
# ✔ DHI: done (5 lookbacks)
#
# Processing DHR...
# ✔ DHR: done (5 lookbacks)
#
# Processing DI1...
# ⚠ VALIDATION: DI1 | W=252 | insufficient_history_for_regression | 188 rows, last=1998-09-29
# ✔ DI1: done (5 lookbacks)
#
# Processing DIGI2...
# ⚠ VALIDATION: DIGI2 | W=180 | insufficient_history_for_regression | 172 rows, last=1998-09-04
# ⚠ VALIDATION: DIGI2 | W=252 | insufficient_history_for_regression | 172 rows, last=1998-09-04
# ✔ DIGI2: done (5 lookbacks)
#
# Processing DINO...
# ✔ DINO: done (5 lookbacks)
#
# Processing DIS...
# ✔ DIS: done (5 lookbacks)
#
# Processing DISCK...
# ✔ DISCK: done (5 lookbacks)
#
# Processing DISH...
# ✔ DISH: done (5 lookbacks)
#
# Processing DJ...
# ✔ DJ: done (5 lookbacks)
#
# Processing DLR...
# ✔ DLR: done (5 lookbacks)
#
# Processing DLTR...
# ✔ DLTR: done (5 lookbacks)
#
# Processing DLX...
# ✔ DLX: done (5 lookbacks)
#
# Processing DNB1...
# ✔ DNB1: done (5 lookbacks)
#
# Processing DNB2...
# ⚠ VALIDATION: DNB2 | W=180 | insufficient_history_for_regression | 125 rows, last=1998-06-30
# ⚠ VALIDATION: DNB2 | W=252 | insufficient_history_for_regression | 125 rows, last=1998-06-30
# ✔ DNB2: done (5 lookbacks)
#
# Processing DNB3...
# ✔ DNB3: done (5 lookbacks)
#
# Processing DNRCQ...
# ✔ DNRCQ: done (5 lookbacks)
#
# Processing DOC...
# ✔ DOC: done (5 lookbacks)
#
# Processing DOFSQ...
# ✔ DOFSQ: done (5 lookbacks)
#
# Processing DOV...
# ✔ DOV: done (5 lookbacks)
#
# Processing DOW...
# ✔ DOW: done (5 lookbacks)
#
# Processing DPHIQ...
# ✔ DPHIQ: done (5 lookbacks)
#
# Processing DPZ...
# ✔ DPZ: done (5 lookbacks)
#
# Processing DRE...
# ✔ DRE: done (5 lookbacks)
#
# Processing DRI...
# ✔ DRI: done (5 lookbacks)
#
# Processing DTE...
# ✔ DTE: done (5 lookbacks)
#
# Processing DTV1...
# ✔ DTV1: done (5 lookbacks)
#
# Processing DUK...
# ✔ DUK: done (5 lookbacks)
#
# Processing DVA...
# ✔ DVA: done (5 lookbacks)
#
# Processing DVN...
# ✔ DVN: done (5 lookbacks)
#
# Processing DXC...
# ✔ DXC: done (5 lookbacks)
#
# Processing DXCM...
# ✔ DXCM: done (5 lookbacks)
#
# Processing DYNIQ...
# ✔ DYNIQ: done (5 lookbacks)
#
# Processing EA...
# ✔ EA: done (5 lookbacks)
#
# Processing EBAY...
# ✔ EBAY: done (5 lookbacks)
#
# Processing EC1...
# ✔ EC1: done (5 lookbacks)
#
# Processing ECH1...
# ⚠ VALIDATION: ECH1 | W=180 | insufficient_history_for_regression | 131 rows, last=1998-07-09
# ⚠ VALIDATION: ECH1 | W=252 | insufficient_history_for_regression | 131 rows, last=1998-07-09
# ✔ ECH1: done (5 lookbacks)
#
# Processing ECL...
# ✔ ECL: done (5 lookbacks)
#
# Processing ECO1...
# ✔ ECO1: done (5 lookbacks)
#
# Processing ED...
# ✔ ED: done (5 lookbacks)
#
# Processing EDS...
# ✔ EDS: done (5 lookbacks)
#
# Processing EFU1...
# ✔ EFU1: done (5 lookbacks)
#
# Processing EFX...
# ✔ EFX: done (5 lookbacks)
#
# Processing EG...
# ✔ EG: done (5 lookbacks)
#
# Processing EHC...
# ✔ EHC: done (5 lookbacks)
#
# Processing EIX...
# ✔ EIX: done (5 lookbacks)
#
# Processing EKDKQ...
# ✔ EKDKQ: done (5 lookbacks)
#
# Processing EL...
# ✔ EL: done (5 lookbacks)
#
# Processing ELV...
# ✔ ELV: done (5 lookbacks)
#
# Processing EMC1...
# ✔ EMC1: done (5 lookbacks)
#
# Processing EME...
# ✔ EME: done (5 lookbacks)
#
# Processing EMN...
# ✔ EMN: done (5 lookbacks)
#
# Processing EMR...
# ✔ EMR: done (5 lookbacks)
#
# Processing ENDPQ...
# ✔ ENDPQ: done (5 lookbacks)
#
# Processing ENPH...
# ✔ ENPH: done (5 lookbacks)
#
# Processing ENRNQ...
# ✔ ENRNQ: done (5 lookbacks)
#
# Processing EOG...
# ✔ EOG: done (5 lookbacks)
#
# Processing EOP...
# ✔ EOP: done (5 lookbacks)
#
# Processing EP1...
# ✔ EP1: done (5 lookbacks)
#
# Processing EPAM...
# ✔ EPAM: done (5 lookbacks)
#
# Processing EQ1...
# ✔ EQ1: done (5 lookbacks)
#
# Processing EQIX...
# ✔ EQIX: done (5 lookbacks)
#
# Processing EQR...
# ✔ EQR: done (5 lookbacks)
#
# Processing EQT...
# ✔ EQT: done (5 lookbacks)
#
# Processing ERIE...
# ✔ ERIE: done (5 lookbacks)
#
# Processing ES...
# ✔ ES: done (5 lookbacks)
#
# Processing ESRX...
# ✔ ESRX: done (5 lookbacks)
#
# Processing ESS...
# ✔ ESS: done (5 lookbacks)
#
# Processing ETFC...
# ✔ ETFC: done (5 lookbacks)
#
# Processing ETN...
# ✔ ETN: done (5 lookbacks)
#
# Processing ETR...
# ✔ ETR: done (5 lookbacks)
#
# Processing ETS1...
# ✔ ETS1: done (5 lookbacks)
#
# Processing ETSY...
# ✔ ETSY: done (5 lookbacks)
#
# Processing EVHC...
# ✔ EVHC: done (5 lookbacks)
#
# Processing EVRG...
# ✔ EVRG: done (5 lookbacks)
#
# Processing EW...
# ✔ EW: done (5 lookbacks)
#
# Processing EXC...
# ✔ EXC: done (5 lookbacks)
#
# Processing EXE...
# ✔ EXE: done (5 lookbacks)
#
# Processing EXPD...
# ✔ EXPD: done (5 lookbacks)
#
# Processing EXPE...
# ✔ EXPE: done (5 lookbacks)
#
# Processing EXR...
# ✔ EXR: done (5 lookbacks)
#
# Processing F...
# ✔ F: done (5 lookbacks)
#
# Processing FANG...
# ✔ FANG: done (5 lookbacks)
#
# Processing FAST...
# ✔ FAST: done (5 lookbacks)
#
# Processing FBF...
# ✔ FBF: done (5 lookbacks)
#
# Processing FBIN...
# ✔ FBIN: done (5 lookbacks)
#
# Processing FCN1...
# ⚠ VALIDATION: FCN1 | W=252 | insufficient_history_for_regression | 190 rows, last=1998-10-01
# ✔ FCN1: done (5 lookbacks)
#
# Processing FCX...
# ✔ FCX: done (5 lookbacks)
#
# Processing FDC1...
# ✔ FDC1: done (5 lookbacks)
#
# Processing FDO...
# ✔ FDO: done (5 lookbacks)
#
# Processing FDS...
# ✔ FDS: done (5 lookbacks)
#
# Processing FDX...
# ✔ FDX: done (5 lookbacks)
#
# Processing FE...
# ✔ FE: done (5 lookbacks)
#
# Processing FFIV...
# ✔ FFIV: done (5 lookbacks)
#
# Processing FG1...
# ⚠ VALIDATION: FG1 | W=90 | insufficient_history_for_regression | 79 rows, last=1998-04-24
# ⚠ VALIDATION: FG1 | W=120 | insufficient_history_for_regression | 79 rows, last=1998-04-24
# ⚠ VALIDATION: FG1 | W=180 | insufficient_history_for_regression | 79 rows, last=1998-04-24
# ⚠ VALIDATION: FG1 | W=252 | insufficient_history_for_regression | 79 rows, last=1998-04-24
# ✔ FG1: done (5 lookbacks)
#
# Processing FHI...
# ✔ FHI: done (5 lookbacks)
#
# Processing FHN...
# ✔ FHN: done (5 lookbacks)
#
# Processing FICO...
# ✔ FICO: done (5 lookbacks)
#
# Processing FIS...
# ✔ FIS: done (5 lookbacks)
#
# Processing FISV...
# ✔ FISV: done (5 lookbacks)
#
# Processing FITB...
# ✔ FITB: done (5 lookbacks)
#
# Processing FIX...
# ✔ FIX: done (5 lookbacks)
#
# Processing FJ...
# ✔ FJ: done (5 lookbacks)
#
# Processing FL...
# ✔ FL: done (5 lookbacks)
#
# Processing FLIR...
# ✔ FLIR: done (5 lookbacks)
#
# Processing FLMIQ...
# ✔ FLMIQ: done (5 lookbacks)
#
# Processing FLR...
# ✔ FLR: done (5 lookbacks)
#
# Processing FLS...
# ✔ FLS: done (5 lookbacks)
#
# Processing FLTWQ...
# ✔ FLTWQ: done (5 lookbacks)
#
# Processing FMC...
# ✔ FMC: done (5 lookbacks)
#
# Processing FMCC...
# ✔ FMCC: done (5 lookbacks)
#
# Processing FMY1...
# ✔ FMY1: done (5 lookbacks)
#
# Processing FNMA...
# ✔ FNMA: done (5 lookbacks)
#
# Processing FOSL...
# ✔ FOSL: done (5 lookbacks)
#
# Processing FOX...
# ✔ FOX: done (5 lookbacks)
#
# Processing FOXA...
# ✔ FOXA: done (5 lookbacks)
#
# Processing FPC...
# ✔ FPC: done (5 lookbacks)
#
# Processing FRCB...
# ✔ FRCB: done (5 lookbacks)
#
# Processing FRO1...
# ✔ FRO1: done (5 lookbacks)
#
# Processing FRT...
# ✔ FRT: done (5 lookbacks)
#
# Processing FRX1...
# ✔ FRX1: done (5 lookbacks)
#
# Processing FSH...
# ✔ FSH: done (5 lookbacks)
#
# Processing FSL.B...
# ✔ FSL.B: done (5 lookbacks)
#
# Processing FSLR...
# ✔ FSLR: done (5 lookbacks)
#
# Processing FTI...
# ✔ FTI: done (5 lookbacks)
#
# Processing FTI1...
# ✔ FTI1: done (5 lookbacks)
#
# Processing FTL.A...
# ✔ FTL.A: done (5 lookbacks)
#
# Processing FTNT...
# ✔ FTNT: done (5 lookbacks)
#
# Processing FTRCQ...
# ✔ FTRCQ: done (5 lookbacks)
#
# Processing FTV...
# ✔ FTV: done (5 lookbacks)
#
# Processing FWLT...
# ✔ FWLT: done (5 lookbacks)
#
# Processing G1...
# ✔ G1: done (5 lookbacks)
#
# Processing GAP...
# ✔ GAP: done (5 lookbacks)
#
# Processing GAPTQ...
# ✔ GAPTQ: done (5 lookbacks)
#
# Processing GAS...
# ✔ GAS: done (5 lookbacks)
#
# Processing GAS1...
# ✔ GAS1: done (5 lookbacks)
#
# Processing GD...
# ✔ GD: done (5 lookbacks)
#
# Processing GDDY...
# ✔ GDDY: done (5 lookbacks)
#
# Processing GDT...
# ✔ GDT: done (5 lookbacks)
#
# Processing GDW...
# ✔ GDW: done (5 lookbacks)
#
# Processing GE...
# ✔ GE: done (5 lookbacks)
#
# Processing GEHC...
# ✔ GEHC: done (5 lookbacks)
#
# Processing GEN...
# ✔ GEN: done (5 lookbacks)
#
# Processing GEN1...
# ✔ GEN1: done (5 lookbacks)
#
# Processing GENZ...
# ✔ GENZ: done (5 lookbacks)
#
# Processing GEV...
# ✔ GEV: done (5 lookbacks)
#
# Processing GFS.A...
# ⚠ VALIDATION: GFS.A | W=252 | insufficient_history_for_regression | 211 rows, last=1998-10-30
# ✔ GFS.A: done (5 lookbacks)
#
# Processing GGP...
# ✔ GGP: done (5 lookbacks)
#
# Processing GHC...
# ✔ GHC: done (5 lookbacks)
#
# Processing GIC1...
# ✔ GIC1: done (5 lookbacks)
#
# Processing GILD...
# ✔ GILD: done (5 lookbacks)
#
# Processing GIS...
# ✔ GIS: done (5 lookbacks)
#
# Processing GL...
# ✔ GL: done (5 lookbacks)
#
# Processing GLK1...
# ✔ GLK1: done (5 lookbacks)
#
# Processing GLW...
# ✔ GLW: done (5 lookbacks)
#
# Processing GM...
# ✔ GM: done (5 lookbacks)
#
# Processing GMCR...
# ✔ GMCR: done (5 lookbacks)
#
# Processing GME...
# ✔ GME: done (5 lookbacks)
#
# Processing GNRC...
# ✔ GNRC: done (5 lookbacks)
#
# Processing GNT1...
# ⚠ VALIDATION: GNT1 | W=180 | insufficient_history_for_regression | 125 rows, last=1998-06-30
# ⚠ VALIDATION: GNT1 | W=252 | insufficient_history_for_regression | 125 rows, last=1998-06-30
# ✔ GNT1: done (5 lookbacks)
#
# Processing GNW...
# ✔ GNW: done (5 lookbacks)
#
# Processing GOOG...
# ✔ GOOG: done (5 lookbacks)
#
# Processing GOOGL...
# ✔ GOOGL: done (5 lookbacks)
#
# Processing GOSHA...
# ✔ GOSHA: done (5 lookbacks)
#
# Processing GP1...
# ✔ GP1: done (5 lookbacks)
#
# Processing GPC...
# ✔ GPC: done (5 lookbacks)
#
# Processing GPN...
# ✔ GPN: done (5 lookbacks)
#
# Processing GPU...
# ✔ GPU: done (5 lookbacks)
#
# Processing GR...
# ✔ GR: done (5 lookbacks)
#
# Processing GRA...
# ✔ GRA: done (5 lookbacks)
#
# Processing GRMN...
# ✔ GRMN: done (5 lookbacks)
#
# Processing GRN1...
# ⚠ VALIDATION: GRN1 | W=252 | insufficient_history_for_regression | 246 rows, last=1998-12-21
# ✔ GRN1: done (5 lookbacks)
#
# Processing GS...
# ✔ GS: done (5 lookbacks)
#
# Processing GSX1...
# ⚠ VALIDATION: GSX1 | W=252 | insufficient_history_for_regression | 193 rows, last=1998-10-06
# ✔ GSX1: done (5 lookbacks)
#
# Processing GT...
# ✔ GT: done (5 lookbacks)
#
# Processing GTE1...
# ✔ GTE1: done (5 lookbacks)
#
# Processing GTW...
# ✔ GTW: done (5 lookbacks)
#
# Processing GWOW...
# ✔ GWOW: done (5 lookbacks)
#
# Processing GWW...
# ✔ GWW: done (5 lookbacks)
#
# Processing GX...
# ✔ GX: done (5 lookbacks)
#
# Processing H1...
# ⚠ VALIDATION: H1 | W=252 | insufficient_history_for_regression | 181 rows, last=2007-04-09
# ✔ H1: done (5 lookbacks)
#
# Processing H2...
# ✔ H2: done (5 lookbacks)
#
# Processing HAL...
# ✔ HAL: done (5 lookbacks)
#
# Processing HAR...
# ✔ HAR: done (5 lookbacks)
#
# Processing HAS...
# ✔ HAS: done (5 lookbacks)
#
# Processing HBAN...
# ✔ HBAN: done (5 lookbacks)
#
# Processing HBI...
# ✔ HBI: done (5 lookbacks)
#
# Processing HBOC...
# ✔ HBOC: done (5 lookbacks)
#
# Processing HCA...
# ✔ HCA: done (5 lookbacks)
#
# Processing HCA1...
# ✔ HCA1: done (5 lookbacks)
#
# Processing HCBK...
# ✔ HCBK: done (5 lookbacks)
#
# Processing HCR1...
# ✔ HCR1: done (5 lookbacks)
#
# Processing HD...
# ✔ HD: done (5 lookbacks)
#
# Processing HES...
# ✔ HES: done (5 lookbacks)
#
# Processing HET...
# ✔ HET: done (5 lookbacks)
#
# Processing HI1...
# ✔ HI1: done (5 lookbacks)
#
# Processing HIG...
# ✔ HIG: done (5 lookbacks)
#
# Processing HII...
# ✔ HII: done (5 lookbacks)
#
# Processing HLT...
# ✔ HLT: done (5 lookbacks)
#
# Processing HLT1...
# ✔ HLT1: done (5 lookbacks)
#
# Processing HM...
# ✔ HM: done (5 lookbacks)
#
# Processing HMA1...
# ✔ HMA1: done (5 lookbacks)
#
# Processing HNZ...
# ✔ HNZ: done (5 lookbacks)
#
# Processing HOG...
# ✔ HOG: done (5 lookbacks)
#
# Processing HOLX...
# ✔ HOLX: done (5 lookbacks)
#
# Processing HON...
# ✔ HON: done (5 lookbacks)
#
# Processing HON1...
# ✔ HON1: done (5 lookbacks)
#
# Processing HOOD...
# ✔ HOOD: done (5 lookbacks)
#
# Processing HOT...
# ✔ HOT: done (5 lookbacks)
#
# Processing HP...
# ✔ HP: done (5 lookbacks)
#
# Processing HPC...
# ✔ HPC: done (5 lookbacks)
#
# Processing HPE...
# ✔ HPE: done (5 lookbacks)
#
# Processing HPQ...
# ✔ HPQ: done (5 lookbacks)
#
# Processing HRB...
# ✔ HRB: done (5 lookbacks)
#
# Processing HRL...
# ✔ HRL: done (5 lookbacks)
#
# Processing HRZIQ...
# ✔ HRZIQ: done (5 lookbacks)
#
# Processing HSH...
# ✔ HSH: done (5 lookbacks)
#
# Processing HSIC...
# ✔ HSIC: done (5 lookbacks)
#
# Processing HSP...
# ✔ HSP: done (5 lookbacks)
#
# Processing HST...
# ✔ HST: done (5 lookbacks)
#
# Processing HSY...
# ✔ HSY: done (5 lookbacks)
#
# Processing HUBB...
# ✔ HUBB: done (5 lookbacks)
#
# Processing HUM...
# ✔ HUM: done (5 lookbacks)
#
# Processing HWM...
# ✔ HWM: done (5 lookbacks)
#
# Processing IBKR...
# ✔ IBKR: done (5 lookbacks)
#
# Processing IBM...
# ✔ IBM: done (5 lookbacks)
#
# Processing ICE...
# ✔ ICE: done (5 lookbacks)
#
# Processing IDXX...
# ✔ IDXX: done (5 lookbacks)
#
# Processing IEX...
# ✔ IEX: done (5 lookbacks)
#
# Processing IFF...
# ✔ IFF: done (5 lookbacks)
#
# Processing IGT1...
# ✔ IGT1: done (5 lookbacks)
#
# Processing IKN...
# ✔ IKN: done (5 lookbacks)
#
# Processing ILMN...
# ✔ ILMN: done (5 lookbacks)
#
# Processing IMNX...
# ✔ IMNX: done (5 lookbacks)
#
# Processing INCLF...
# ✔ INCLF: done (5 lookbacks)
#
# Processing INCY...
# ✔ INCY: done (5 lookbacks)
#
# Processing INFO1...
# ✔ INFO1: done (5 lookbacks)
#
# Processing INTC...
# ✔ INTC: done (5 lookbacks)
#
# Processing INTU...
# ✔ INTU: done (5 lookbacks)
#
# Processing INVH...
# ✔ INVH: done (5 lookbacks)
#
# Processing IP...
# ✔ IP: done (5 lookbacks)
#
# Processing IPG...
# ✔ IPG: done (5 lookbacks)
#
# Processing IPGP...
# ✔ IPGP: done (5 lookbacks)
#
# Processing IQV...
# ✔ IQV: done (5 lookbacks)
#
# Processing IR...
# ✔ IR: done (5 lookbacks)
#
# Processing IRM...
# ✔ IRM: done (5 lookbacks)
#
# Processing ISRG...
# ✔ ISRG: done (5 lookbacks)
#
# Processing IT...
# ✔ IT: done (5 lookbacks)
#
# Processing ITT...
# ✔ ITT: done (5 lookbacks)
#
# Processing ITT1...
# ⚠ VALIDATION: ITT1 | W=60 | insufficient_history_for_regression | 36 rows, last=1998-02-23
# ⚠ VALIDATION: ITT1 | W=90 | insufficient_history_for_regression | 36 rows, last=1998-02-23
# ⚠ VALIDATION: ITT1 | W=120 | insufficient_history_for_regression | 36 rows, last=1998-02-23
# ⚠ VALIDATION: ITT1 | W=180 | insufficient_history_for_regression | 36 rows, last=1998-02-23
# ⚠ VALIDATION: ITT1 | W=252 | insufficient_history_for_regression | 36 rows, last=1998-02-23
# ✔ ITT1: done (5 lookbacks)
#
# Processing ITW...
# ✔ ITW: done (5 lookbacks)
#
# Processing IVZ...
# ✔ IVZ: done (5 lookbacks)
#
# Processing J...
# ✔ J: done (5 lookbacks)
#
# Processing JAVA1...
# ✔ JAVA1: done (5 lookbacks)
#
# Processing JBHT...
# ✔ JBHT: done (5 lookbacks)
#
# Processing JBL...
# ✔ JBL: done (5 lookbacks)
#
# Processing JCI...
# ✔ JCI: done (5 lookbacks)
#
# Processing JEF...
# ✔ JEF: done (5 lookbacks)
#
# Processing JH...
# ✔ JH: done (5 lookbacks)
#
# Processing JHF...
# ✔ JHF: done (5 lookbacks)
#
# Processing JKHY...
# ✔ JKHY: done (5 lookbacks)
#
# Processing JM...
# ✔ JM: done (5 lookbacks)
#
# Processing JNJ...
# ✔ JNJ: done (5 lookbacks)
#
# Processing JNPR...
# ✔ JNPR: done (5 lookbacks)
#
# Processing JNS...
# ✔ JNS: done (5 lookbacks)
#
# Processing JNY...
# ✔ JNY: done (5 lookbacks)
#
# Processing JOS...
# ✔ JOS: done (5 lookbacks)
#
# Processing JOY...
# ✔ JOY: done (5 lookbacks)
#
# Processing JP1...
# ✔ JP1: done (5 lookbacks)
#
# Processing JPM...
# ✔ JPM: done (5 lookbacks)
#
# Processing JPM1...
# ✔ JPM1: done (5 lookbacks)
#
# Processing JWN...
# ✔ JWN: done (5 lookbacks)
#
# Processing K...
# ✔ K: done (5 lookbacks)
#
# Processing KATE...
# ✔ KATE: done (5 lookbacks)
#
# Processing KBH...
# ✔ KBH: done (5 lookbacks)
#
# Processing KDP...
# ✔ KDP: done (5 lookbacks)
#
# Processing KEY...
# ✔ KEY: done (5 lookbacks)
#
# Processing KEYS...
# ✔ KEYS: done (5 lookbacks)
#
# Processing KG1...
# ✔ KG1: done (5 lookbacks)
#
# Processing KHC...
# ✔ KHC: done (5 lookbacks)
#
# Processing KIM...
# ✔ KIM: done (5 lookbacks)
#
# Processing KKR...
# ✔ KKR: done (5 lookbacks)
#
# Processing KLAC...
# ✔ KLAC: done (5 lookbacks)
#
# Processing KM...
# ✔ KM: done (5 lookbacks)
#
# Processing KMB...
# ✔ KMB: done (5 lookbacks)
#
# Processing KMG1...
# ✔ KMG1: done (5 lookbacks)
#
# Processing KMI...
# ✔ KMI: done (5 lookbacks)
#
# Processing KMI1...
# ✔ KMI1: done (5 lookbacks)
#
# Processing KMX...
# ✔ KMX: done (5 lookbacks)
#
# Processing KO...
# ✔ KO: done (5 lookbacks)
#
# Processing KR...
# ✔ KR: done (5 lookbacks)
#
# Processing KRB...
# ✔ KRB: done (5 lookbacks)
#
# Processing KRFT...
# ✔ KRFT: done (5 lookbacks)
#
# Processing KRI...
# ✔ KRI: done (5 lookbacks)
#
# Processing KSE...
# ✔ KSE: done (5 lookbacks)
#
# Processing KSS...
# ✔ KSS: done (5 lookbacks)
#
# Processing KSU...
# ✔ KSU: done (5 lookbacks)
#
# Processing KVUE...
# ✔ KVUE: done (5 lookbacks)
#
# Processing KWP...
# ✔ KWP: done (5 lookbacks)
#
# Processing L...
# ✔ L: done (5 lookbacks)
#
# Processing LDG...
# ✔ LDG: done (5 lookbacks)
#
# Processing LDOS...
# ✔ LDOS: done (5 lookbacks)
#
# Processing LDWIF...
# ✔ LDWIF: done (5 lookbacks)
#
# Processing LEG...
# ✔ LEG: done (5 lookbacks)
#
# Processing LEHMQ...
# ✔ LEHMQ: done (5 lookbacks)
#
# Processing LEN...
# ✔ LEN: done (5 lookbacks)
#
# Processing LH...
# ✔ LH: done (5 lookbacks)
#
# Processing LHX...
# ✔ LHX: done (5 lookbacks)
#
# Processing LIFE2...
# ✔ LIFE2: done (5 lookbacks)
#
# Processing LII...
# ✔ LII: done (5 lookbacks)
#
# Processing LIN...
# ✔ LIN: done (5 lookbacks)
#
# Processing LKQ...
# ✔ LKQ: done (5 lookbacks)
#
# Processing LLL1...
# ✔ LLL1: done (5 lookbacks)
#
# Processing LLTC...
# ✔ LLTC: done (5 lookbacks)
#
# Processing LLY...
# ✔ LLY: done (5 lookbacks)
#
# Processing LM...
# ✔ LM: done (5 lookbacks)
#
# Processing LMT...
# ✔ LMT: done (5 lookbacks)
#
# Processing LNC...
# ✔ LNC: done (5 lookbacks)
#
# Processing LNT...
# ✔ LNT: done (5 lookbacks)
#
# Processing LO...
# ✔ LO: done (5 lookbacks)
#
# Processing LOW...
# ✔ LOW: done (5 lookbacks)
#
# Processing LPX...
# ✔ LPX: done (5 lookbacks)
#
# Processing LRCX...
# ✔ LRCX: done (5 lookbacks)
#
# Processing LSI1...
# ✔ LSI1: done (5 lookbacks)
#
# Processing LU1...
# ✔ LU1: done (5 lookbacks)
#
# Processing LULU...
# ✔ LULU: done (5 lookbacks)
#
# Processing LUMN...
# ✔ LUMN: done (5 lookbacks)
#
# Processing LUV...
# ✔ LUV: done (5 lookbacks)
#
# Processing LVLT...
# ✔ LVLT: done (5 lookbacks)
#
# Processing LVS...
# ✔ LVS: done (5 lookbacks)
#
# Processing LW...
# ✔ LW: done (5 lookbacks)
#
# Processing LXK...
# ✔ LXK: done (5 lookbacks)
#
# Processing LYB...
# ✔ LYB: done (5 lookbacks)
#
# Processing LYV...
# ✔ LYV: done (5 lookbacks)
#
# Processing M...
# ✔ M: done (5 lookbacks)
#
# Processing MA...
# ✔ MA: done (5 lookbacks)
#
# Processing MAA...
# ✔ MAA: done (5 lookbacks)
#
# Processing MAC...
# ✔ MAC: done (5 lookbacks)
#
# Processing MAR...
# ✔ MAR: done (5 lookbacks)
#
# Processing MAS...
# ✔ MAS: done (5 lookbacks)
#
# Processing MAT...
# ✔ MAT: done (5 lookbacks)
#
# Processing MAY1...
# ✔ MAY1: done (5 lookbacks)
#
# Processing MBI...
# ✔ MBI: done (5 lookbacks)
#
# Processing MCD...
# ✔ MCD: done (5 lookbacks)
#
# Processing MCHP...
# ✔ MCHP: done (5 lookbacks)
#
# Processing MCIC...
# ⚠ VALIDATION: MCIC | W=180 | insufficient_history_for_regression | 177 rows, last=1998-09-14
# ⚠ VALIDATION: MCIC | W=252 | insufficient_history_for_regression | 177 rows, last=1998-09-14
# ✔ MCIC: done (5 lookbacks)
#
# Processing MCK...
# ✔ MCK: done (5 lookbacks)
#
# Processing MCO...
# ✔ MCO: done (5 lookbacks)
#
# Processing MDLZ...
# ✔ MDLZ: done (5 lookbacks)
#
# Processing MDP...
# ✔ MDP: done (5 lookbacks)
#
# Processing MDRIQ...
# ✔ MDRIQ: done (5 lookbacks)
#
# Processing MDT...
# ✔ MDT: done (5 lookbacks)
#
# Processing MEA1...
# ✔ MEA1: done (5 lookbacks)
#
# Processing MEDI1...
# ✔ MEDI1: done (5 lookbacks)
#
# Processing MEE...
# ✔ MEE: done (5 lookbacks)
#
# Processing MEL...
# ✔ MEL: done (5 lookbacks)
#
# Processing MER...
# ✔ MER: done (5 lookbacks)
#
# Processing MERQ...
# ✔ MERQ: done (5 lookbacks)
#
# Processing MET...
# ✔ MET: done (5 lookbacks)
#
# Processing META...
# ✔ META: done (5 lookbacks)
#
# Processing MFE...
# ✔ MFE: done (5 lookbacks)
#
# Processing MGM...
# ✔ MGM: done (5 lookbacks)
#
# Processing MHK...
# ✔ MHK: done (5 lookbacks)
#
# Processing MHS...
# ✔ MHS: done (5 lookbacks)
#
# Processing MI2...
# ✔ MI2: done (5 lookbacks)
#
# Processing MII1...
# ✔ MII1: done (5 lookbacks)
#
# Processing MIL1...
# ✔ MIL1: done (5 lookbacks)
#
# Processing MIR1...
# ✔ MIR1: done (5 lookbacks)
#
# Processing MJN...
# ✔ MJN: done (5 lookbacks)
#
# Processing MKC...
# ✔ MKC: done (5 lookbacks)
#
# Processing MKG...
# ✔ MKG: done (5 lookbacks)
#
# Processing MKTX...
# ✔ MKTX: done (5 lookbacks)
#
# Processing MLM...
# ✔ MLM: done (5 lookbacks)
#
# Processing MMC...
# ✔ MMC: done (5 lookbacks)
#
# Processing MMI1...
# ✔ MMI1: done (5 lookbacks)
#
# Processing MMM...
# ✔ MMM: done (5 lookbacks)
#
# Processing MNKKQ...
# ✔ MNKKQ: done (5 lookbacks)
#
# Processing MNR1...
# ⚠ VALIDATION: MNR1 | W=252 | insufficient_history_for_regression | 186 rows, last=1998-09-25
# ✔ MNR1: done (5 lookbacks)
#
# Processing MNST...
# ✔ MNST: done (5 lookbacks)
#
# Processing MO...
# ✔ MO: done (5 lookbacks)
#
# Processing MOB1...
# ✔ MOB1: done (5 lookbacks)
#
# Processing MOH...
# ✔ MOH: done (5 lookbacks)
#
# Processing MOLX...
# ✔ MOLX: done (5 lookbacks)
#
# Processing MON2...
# ✔ MON2: done (5 lookbacks)
#
# Processing MOS...
# ✔ MOS: done (5 lookbacks)
#
# Processing MPC...
# ✔ MPC: done (5 lookbacks)
#
# Processing MPWR...
# ✔ MPWR: done (5 lookbacks)
#
# Processing MRK...
# ✔ MRK: done (5 lookbacks)
#
# Processing MRNA...
# ✔ MRNA: done (5 lookbacks)
#
# Processing MRO...
# ✔ MRO: done (5 lookbacks)
#
# Processing MS...
# ✔ MS: done (5 lookbacks)
#
# Processing MSCI...
# ✔ MSCI: done (5 lookbacks)
#
# Processing MSFT...
# ✔ MSFT: done (5 lookbacks)
#
# Processing MSI...
# ✔ MSI: done (5 lookbacks)
#
# Processing MST1...
# ⚠ VALIDATION: MST1 | W=180 | insufficient_history_for_regression | 159 rows, last=1998-08-18
# ⚠ VALIDATION: MST1 | W=252 | insufficient_history_for_regression | 159 rows, last=1998-08-18
# ✔ MST1: done (5 lookbacks)
#
# Processing MTB...
# ✔ MTB: done (5 lookbacks)
#
# Processing MTCH...
# ✔ MTCH: done (5 lookbacks)
#
# Processing MTD...
# ✔ MTD: done (5 lookbacks)
#
# Processing MTG...
# ✔ MTG: done (5 lookbacks)
#
# Processing MTL1...
# ✔ MTL1: done (5 lookbacks)
#
# Processing MTLQQ...
# ✔ MTLQQ: done (5 lookbacks)
#
# Processing MTW...
# ✔ MTW: done (5 lookbacks)
#
# Processing MU...
# ✔ MU: done (5 lookbacks)
#
# Processing MUR...
# ✔ MUR: done (5 lookbacks)
#
# Processing MWI...
# ✔ MWI: done (5 lookbacks)
#
# Processing MWV...
# ✔ MWV: done (5 lookbacks)
#
# Processing MWW...
# ✔ MWW: done (5 lookbacks)
#
# Processing MXIM...
# ✔ MXIM: done (5 lookbacks)
#
# Processing MYG1...
# ✔ MYG1: done (5 lookbacks)
#
# Processing MZIAQ...
# ✔ MZIAQ: done (5 lookbacks)
#
# Processing NAV...
# ✔ NAV: done (5 lookbacks)
#
# Processing NAVI...
# ✔ NAVI: done (5 lookbacks)
#
# Processing NBL...
# ✔ NBL: done (5 lookbacks)
#
# Processing NBR...
# ✔ NBR: done (5 lookbacks)
#
# Processing NC...
# ✔ NC: done (5 lookbacks)
#
# Processing NCC...
# ✔ NCC: done (5 lookbacks)
#
# Processing NCE...
# ✔ NCE: done (5 lookbacks)
#
# Processing NCLH...
# ✔ NCLH: done (5 lookbacks)
#
# Processing NDAQ...
# ✔ NDAQ: done (5 lookbacks)
#
# Processing NDSN...
# ✔ NDSN: done (5 lookbacks)
#
# Processing NEBLQ...
# ✔ NEBLQ: done (5 lookbacks)
#
# Processing NEE...
# ✔ NEE: done (5 lookbacks)
#
# Processing NEM...
# ✔ NEM: done (5 lookbacks)
#
# Processing NFB...
# ✔ NFB: done (5 lookbacks)
#
# Processing NFLX...
# ✔ NFLX: done (5 lookbacks)
#
# Processing NFX...
# ✔ NFX: done (5 lookbacks)
#
# Processing NGH...
# ✔ NGH: done (5 lookbacks)
#
# Processing NI...
# ✔ NI: done (5 lookbacks)
#
# Processing NKE...
# ✔ NKE: done (5 lookbacks)
#
# Processing NKTR...
# ✔ NKTR: done (5 lookbacks)
#
# Processing NLC1...
# ✔ NLC1: done (5 lookbacks)
#
# Processing NLSN...
# ✔ NLSN: done (5 lookbacks)
#
# Processing NMK1...
# ✔ NMK1: done (5 lookbacks)
#
# Processing NOC...
# ✔ NOC: done (5 lookbacks)
#
# Processing NOV...
# ✔ NOV: done (5 lookbacks)
#
# Processing NOVL...
# ✔ NOVL: done (5 lookbacks)
#
# Processing NOW...
# ✔ NOW: done (5 lookbacks)
#
# Processing NRG...
# ✔ NRG: done (5 lookbacks)
#
# Processing NRTLQ...
# ✔ NRTLQ: done (5 lookbacks)
#
# Processing NSC...
# ✔ NSC: done (5 lookbacks)
#
# Processing NSI1...
# ✔ NSI1: done (5 lookbacks)
#
# Processing NSM1...
# ✔ NSM1: done (5 lookbacks)
#
# Processing NTAP...
# ✔ NTAP: done (5 lookbacks)
#
# Processing NTRS...
# ✔ NTRS: done (5 lookbacks)
#
# Processing NUE...
# ✔ NUE: done (5 lookbacks)
#
# Processing NVDA...
# ✔ NVDA: done (5 lookbacks)
#
# Processing NVLS1...
# ✔ NVLS1: done (5 lookbacks)
#
# Processing NVR...
# ✔ NVR: done (5 lookbacks)
#
# Processing NWL...
# ✔ NWL: done (5 lookbacks)
#
# Processing NWS...
# ✔ NWS: done (5 lookbacks)
#
# Processing NWSA...
# ✔ NWSA: done (5 lookbacks)
#
# Processing NXPI...
# ✔ NXPI: done (5 lookbacks)
#
# Processing NXTL...
# ✔ NXTL: done (5 lookbacks)
#
# Processing NYT...
# ✔ NYT: done (5 lookbacks)
#
# Processing NYX1...
# ✔ NYX1: done (5 lookbacks)
#
# Processing O...
# ✔ O: done (5 lookbacks)
#
# Processing OAT...
# ✔ OAT: done (5 lookbacks)
#
# Processing ODFL...
# ✔ ODFL: done (5 lookbacks)
#
# Processing ODP...
# ✔ ODP: done (5 lookbacks)
#
# Processing OGN...
# ✔ OGN: done (5 lookbacks)
#
# Processing OI...
# ✔ OI: done (5 lookbacks)
#
# Processing OK...
# ✔ OK: done (5 lookbacks)
#
# Processing OKE...
# ✔ OKE: done (5 lookbacks)
#
# Processing OMC...
# ✔ OMC: done (5 lookbacks)
#
# Processing OMX...
# ✔ OMX: done (5 lookbacks)
#
# Processing ON...
# ✔ ON: done (5 lookbacks)
#
# Processing ONE1...
# ✔ ONE1: done (5 lookbacks)
#
# Processing ORCL...
# ✔ ORCL: done (5 lookbacks)
#
# Processing ORLY...
# ✔ ORLY: done (5 lookbacks)
#
# Processing ORX...
# ✔ ORX: done (5 lookbacks)
#
# Processing OTIS...
# ✔ OTIS: done (5 lookbacks)
#
# Processing OWENQ...
# ✔ OWENQ: done (5 lookbacks)
#
# Processing OXY...
# ✔ OXY: done (5 lookbacks)
#
# Processing PALM...
# ✔ PALM: done (5 lookbacks)
#
# Processing PANW...
# ✔ PANW: done (5 lookbacks)
#
# Processing PAS...
# ✔ PAS: done (5 lookbacks)
#
# Processing PAYC...
# ✔ PAYC: done (5 lookbacks)
#
# Processing PAYX...
# ✔ PAYX: done (5 lookbacks)
#
# Processing PBCT...
# ✔ PBCT: done (5 lookbacks)
#
# Processing PBG...
# ✔ PBG: done (5 lookbacks)
#
# Processing PBI...
# ✔ PBI: done (5 lookbacks)
#
# Processing PBY1...
# ✔ PBY1: done (5 lookbacks)
#
# Processing PCAR...
# ✔ PCAR: done (5 lookbacks)
#
# Processing PCG...
# ✔ PCG: done (5 lookbacks)
#
# Processing PCH...
# ✔ PCH: done (5 lookbacks)
#
# Processing PCL1...
# ✔ PCL1: done (5 lookbacks)
#
# Processing PCP...
# ✔ PCP: done (5 lookbacks)
#
# Processing PCS1...
# ✔ PCS1: done (5 lookbacks)
#
# Processing PD1...
# ✔ PD1: done (5 lookbacks)
#
# Processing PDCO...
# ✔ PDCO: done (5 lookbacks)
#
# Processing PDG...
# ✔ PDG: done (5 lookbacks)
#
# Processing PEG...
# ✔ PEG: done (5 lookbacks)
#
# Processing PENN...
# ✔ PENN: done (5 lookbacks)
#
# Processing PEP...
# ✔ PEP: done (5 lookbacks)
#
# Processing PET1...
# ⚠ VALIDATION: PET1 | W=180 | insufficient_history_for_regression | 123 rows, last=1998-06-26
# ⚠ VALIDATION: PET1 | W=252 | insufficient_history_for_regression | 123 rows, last=1998-06-26
# ✔ PET1: done (5 lookbacks)
#
# Processing PETM...
# ✔ PETM: done (5 lookbacks)
#
# Processing PFE...
# ✔ PFE: done (5 lookbacks)
#
# Processing PFG...
# ✔ PFG: done (5 lookbacks)
#
# Processing PG...
# ✔ PG: done (5 lookbacks)
#
# Processing PGL...
# ✔ PGL: done (5 lookbacks)
#
# Processing PGN1...
# ✔ PGN1: done (5 lookbacks)
#
# Processing PGR...
# ✔ PGR: done (5 lookbacks)
#
# Processing PH...
# ✔ PH: done (5 lookbacks)
#
# Processing PHA...
# ✔ PHA: done (5 lookbacks)
#
# Processing PHB1...
# ✔ PHB1: done (5 lookbacks)
#
# Processing PHM...
# ✔ PHM: done (5 lookbacks)
#
# Processing PKG...
# ✔ PKG: done (5 lookbacks)
#
# Processing PLD...
# ✔ PLD: done (5 lookbacks)
#
# Processing PLL1...
# ✔ PLL1: done (5 lookbacks)
#
# Processing PLTR...
# ✔ PLTR: done (5 lookbacks)
#
# Processing PM...
# ✔ PM: done (5 lookbacks)
#
# Processing PMCS...
# ✔ PMCS: done (5 lookbacks)
#
# Processing PMI1...
# ✔ PMI1: done (5 lookbacks)
#
# Processing PNC...
# ✔ PNC: done (5 lookbacks)
#
# Processing PNR...
# ✔ PNR: done (5 lookbacks)
#
# Processing PNU1...
# ✔ PNU1: done (5 lookbacks)
#
# Processing PNW...
# ✔ PNW: done (5 lookbacks)
#
# Processing PODD...
# ✔ PODD: done (5 lookbacks)
#
# Processing POM1...
# ✔ POM1: done (5 lookbacks)
#
# Processing POOL...
# ✔ POOL: done (5 lookbacks)
#
# Processing PPG...
# ✔ PPG: done (5 lookbacks)
#
# Processing PPL...
# ✔ PPL: done (5 lookbacks)
#
# Processing PPW...
# ✔ PPW: done (5 lookbacks)
#
# Processing PRDCQ...
# ✔ PRDCQ: done (5 lookbacks)
#
# Processing PRGO...
# ✔ PRGO: done (5 lookbacks)
#
# Processing PRU...
# ✔ PRU: done (5 lookbacks)
#
# Processing PSA...
# ✔ PSA: done (5 lookbacks)
#
# Processing PSFT...
# ✔ PSFT: done (5 lookbacks)
#
# Processing PSKY...
# ✔ PSKY: done (5 lookbacks)
#
# Processing PSX...
# ✔ PSX: done (5 lookbacks)
#
# Processing PTC...
# ✔ PTC: done (5 lookbacks)
#
# Processing PTV...
# ✔ PTV: done (5 lookbacks)
#
# Processing PVH...
# ✔ PVH: done (5 lookbacks)
#
# Processing PVN...
# ✔ PVN: done (5 lookbacks)
#
# Processing PVT1...
# ✔ PVT1: done (5 lookbacks)
#
# Processing PWER1...
# ✔ PWER1: done (5 lookbacks)
#
# Processing PWJ1...
# ✔ PWJ1: done (5 lookbacks)
#
# Processing PWR...
# ✔ PWR: done (5 lookbacks)
#
# Processing PX1...
# ✔ PX1: done (5 lookbacks)
#
# Processing PXD...
# ✔ PXD: done (5 lookbacks)
#
# Processing PYPL...
# ✔ PYPL: done (5 lookbacks)
#
# Processing PZE1...
# ✔ PZE1: done (5 lookbacks)
#
# Processing Q...
# ⚠ VALIDATION: Q | W=60 | insufficient_history_for_regression | 40 rows, last=2025-12-30
# ⚠ VALIDATION: Q | W=90 | insufficient_history_for_regression | 40 rows, last=2025-12-30
# ⚠ VALIDATION: Q | W=120 | insufficient_history_for_regression | 40 rows, last=2025-12-30
# ⚠ VALIDATION: Q | W=180 | insufficient_history_for_regression | 40 rows, last=2025-12-30
# ⚠ VALIDATION: Q | W=252 | insufficient_history_for_regression | 40 rows, last=2025-12-30
# ✔ Q: done (5 lookbacks)
#
# Processing Q1...
# ✔ Q1: done (5 lookbacks)
#
# Processing QCOM...
# ✔ QCOM: done (5 lookbacks)
#
# Processing QEP...
# ✔ QEP: done (5 lookbacks)
#
# Processing QLGC...
# ✔ QLGC: done (5 lookbacks)
#
# Processing QRVO...
# ✔ QRVO: done (5 lookbacks)
#
# Processing QTRN...
# ✔ QTRN: done (5 lookbacks)
#
# Processing R...
# ✔ R: done (5 lookbacks)
#
# Processing RADCQ...
# ✔ RADCQ: done (5 lookbacks)
#
# Processing RAI...
# ✔ RAI: done (5 lookbacks)
#
# Processing RAL1...
# ✔ RAL1: done (5 lookbacks)
#
# Processing RATL...
# ✔ RATL: done (5 lookbacks)
#
# Processing RBD...
# ✔ RBD: done (5 lookbacks)
#
# Processing RBK...
# ✔ RBK: done (5 lookbacks)
#
# Processing RCL...
# ✔ RCL: done (5 lookbacks)
#
# Processing RDC...
# ✔ RDC: done (5 lookbacks)
#
# Processing REG...
# ✔ REG: done (5 lookbacks)
#
# Processing REGN...
# ✔ REGN: done (5 lookbacks)
#
# Processing RF...
# ✔ RF: done (5 lookbacks)
#
# Processing RHI...
# ✔ RHI: done (5 lookbacks)
#
# Processing RHT...
# ✔ RHT: done (5 lookbacks)
#
# Processing RIG...
# ✔ RIG: done (5 lookbacks)
#
# Processing RJF...
# ✔ RJF: done (5 lookbacks)
#
# Processing RL...
# ✔ RL: done (5 lookbacks)
#
# Processing RLM1...
# ✔ RLM1: done (5 lookbacks)
#
# Processing RMD...
# ✔ RMD: done (5 lookbacks)
#
# Processing RML...
# ✔ RML: done (5 lookbacks)
#
# Processing RNB...
# ✔ RNB: done (5 lookbacks)
#
# Processing ROH...
# ✔ ROH: done (5 lookbacks)
#
# Processing ROK...
# ✔ ROK: done (5 lookbacks)
#
# Processing ROL...
# ✔ ROL: done (5 lookbacks)
#
# Processing ROP...
# ✔ ROP: done (5 lookbacks)
#
# Processing ROST...
# ✔ ROST: done (5 lookbacks)
#
# Processing RRC...
# ✔ RRC: done (5 lookbacks)
#
# Processing RRD...
# ✔ RRD: done (5 lookbacks)
#
# Processing RSG...
# ✔ RSG: done (5 lookbacks)
#
# Processing RSHCQ...
# ✔ RSHCQ: done (5 lookbacks)
#
# Processing RTN...
# ✔ RTN: done (5 lookbacks)
#
# Processing RTX...
# ✔ RTX: done (5 lookbacks)
#
# Processing RVTY...
# ✔ RVTY: done (5 lookbacks)
#
# Processing RX...
# ✔ RX: done (5 lookbacks)
#
# Processing RYAN1...
# ✔ RYAN1: done (5 lookbacks)
#
# Processing RYC...
# ✔ RYC: done (5 lookbacks)
#
# Processing RYI1...
# ✔ RYI1: done (5 lookbacks)
#
# Processing S1...
# ✔ S1: done (5 lookbacks)
#
# Processing S2...
# ✔ S2: done (5 lookbacks)
#
# Processing SAF2...
# ✔ SAF2: done (5 lookbacks)
#
# Processing SAI1...
# ✔ SAI1: done (5 lookbacks)
#
# Processing SANM...
# ✔ SANM: done (5 lookbacks)
#
# Processing SAPE...
# ✔ SAPE: done (5 lookbacks)
#
# Processing SBAC...
# ✔ SBAC: done (5 lookbacks)
#
# Processing SBL...
# ✔ SBL: done (5 lookbacks)
#
# Processing SBNY...
# ✔ SBNY: done (5 lookbacks)
#
# Processing SBUX...
# ✔ SBUX: done (5 lookbacks)
#
# Processing SCG...
# ✔ SCG: done (5 lookbacks)
#
# Processing SCHW...
# ✔ SCHW: done (5 lookbacks)
#
# Processing SCI...
# ✔ SCI: done (5 lookbacks)
#
# Processing SDS1...
# ✔ SDS1: done (5 lookbacks)
#
# Processing SE1...
# ✔ SE1: done (5 lookbacks)
#
# Processing SEBL...
# ✔ SEBL: done (5 lookbacks)
#
# Processing SEDG...
# ✔ SEDG: done (5 lookbacks)
#
# Processing SEE...
# ✔ SEE: done (5 lookbacks)
#
# Processing SEG1...
# ✔ SEG1: done (5 lookbacks)
#
# Processing SFA...
# ✔ SFA: done (5 lookbacks)
#
# Processing SGID...
# ✔ SGID: done (5 lookbacks)
#
# Processing SGP...
# ✔ SGP: done (5 lookbacks)
#
# Processing SHEL...
# ✔ SHEL: done (5 lookbacks)
#
# Processing SHLDQ...
# ✔ SHLDQ: done (5 lookbacks)
#
# Processing SHW...
# ✔ SHW: done (5 lookbacks)
#
# Processing SIAL...
# ✔ SIAL: done (5 lookbacks)
#
# Processing SIG...
# ✔ SIG: done (5 lookbacks)
#
# Processing SII1...
# ✔ SII1: done (5 lookbacks)
#
# Processing SITC...
# ✔ SITC: done (5 lookbacks)
#
# Processing SIVBQ...
# ✔ SIVBQ: done (5 lookbacks)
#
# Processing SJM...
# ✔ SJM: done (5 lookbacks)
#
# Processing SK1...
# ⚠ VALIDATION: SK1 | W=120 | insufficient_history_for_regression | 97 rows, last=1998-05-20
# ⚠ VALIDATION: SK1 | W=180 | insufficient_history_for_regression | 97 rows, last=1998-05-20
# ⚠ VALIDATION: SK1 | W=252 | insufficient_history_for_regression | 97 rows, last=1998-05-20
# ✔ SK1: done (5 lookbacks)
#
# Processing SLB...
# ✔ SLB: done (5 lookbacks)
#
# Processing SLG...
# ✔ SLG: done (5 lookbacks)
#
# Processing SLM...
# ✔ SLM: done (5 lookbacks)
#
# Processing SLR...
# ✔ SLR: done (5 lookbacks)
#
# Processing SMCI...
# ✔ SMCI: done (5 lookbacks)
#
# Processing SMI1...
# ✔ SMI1: done (5 lookbacks)
#
# Processing SMS1...
# ✔ SMS1: done (5 lookbacks)
#
# Processing SNA...
# ✔ SNA: done (5 lookbacks)
#
# Processing SNDK...
# ⚠ VALIDATION: SNDK | W=252 | insufficient_history_for_regression | 215 rows, last=2025-12-30
# ✔ SNDK: done (5 lookbacks)
#
# Processing SNDK1...
# ✔ SNDK1: done (5 lookbacks)
#
# Processing SNI...
# ✔ SNI: done (5 lookbacks)
#
# Processing SNPS...
# ✔ SNPS: done (5 lookbacks)
#
# Processing SNV...
# ✔ SNV: done (5 lookbacks)
#
# Processing SO...
# ✔ SO: done (5 lookbacks)
#
# Processing SOLS...
# ⚠ VALIDATION: SOLS | W=60 | insufficient_history_for_regression | 42 rows, last=2025-12-30
# ⚠ VALIDATION: SOLS | W=90 | insufficient_history_for_regression | 42 rows, last=2025-12-30
# ⚠ VALIDATION: SOLS | W=120 | insufficient_history_for_regression | 42 rows, last=2025-12-30
# ⚠ VALIDATION: SOLS | W=180 | insufficient_history_for_regression | 42 rows, last=2025-12-30
# ⚠ VALIDATION: SOLS | W=252 | insufficient_history_for_regression | 42 rows, last=2025-12-30
# ✔ SOLS: done (5 lookbacks)
#
# Processing SOLV...
# ✔ SOLV: done (5 lookbacks)
#
# Processing SOTR...
# ✔ SOTR: done (5 lookbacks)
#
# Processing SOV...
# ✔ SOV: done (5 lookbacks)
#
# Processing SPG...
# ✔ SPG: done (5 lookbacks)
#
# Processing SPGI...
# ✔ SPGI: done (5 lookbacks)
#
# Processing SPLS...
# ✔ SPLS: done (5 lookbacks)
#
# Processing SRCL...
# ✔ SRCL: done (5 lookbacks)
#
# Processing SRE...
# ✔ SRE: done (5 lookbacks)
#
# Processing SSP...
# ✔ SSP: done (5 lookbacks)
#
# Processing STE...
# ✔ STE: done (5 lookbacks)
#
# Processing STI1...
# ✔ STI1: done (5 lookbacks)
#
# Processing STJ...
# ✔ STJ: done (5 lookbacks)
#
# Processing STLD...
# ✔ STLD: done (5 lookbacks)
#
# Processing STO1...
# ⚠ VALIDATION: STO1 | W=252 | insufficient_history_for_regression | 223 rows, last=1998-11-17
# ✔ STO1: done (5 lookbacks)
#
# Processing STR1...
# ✔ STR1: done (5 lookbacks)
#
# Processing STT...
# ✔ STT: done (5 lookbacks)
#
# Processing STX...
# ✔ STX: done (5 lookbacks)
#
# Processing STZ...
# ✔ STZ: done (5 lookbacks)
#
# Processing SUB1...
# ✔ SUB1: done (5 lookbacks)
#
# Processing SUN1...
# ✔ SUN1: done (5 lookbacks)
#
# Processing SUNEQ...
# ✔ SUNEQ: done (5 lookbacks)
#
# Processing SVU...
# ✔ SVU: done (5 lookbacks)
#
# Processing SW...
# ✔ SW: done (5 lookbacks)
#
# Processing SWK...
# ✔ SWK: done (5 lookbacks)
#
# Processing SWKS...
# ✔ SWKS: done (5 lookbacks)
#
# Processing SWN...
# ✔ SWN: done (5 lookbacks)
#
# Processing SWY...
# ✔ SWY: done (5 lookbacks)
#
# Processing SXCL...
# ✔ SXCL: done (5 lookbacks)
#
# Processing SYF...
# ✔ SYF: done (5 lookbacks)
#
# Processing SYK...
# ✔ SYK: done (5 lookbacks)
#
# Processing SYY...
# ✔ SYY: done (5 lookbacks)
#
# Processing T...
# ✔ T: done (5 lookbacks)
#
# Processing T1...
# ✔ T1: done (5 lookbacks)
#
# Processing TA2...
# ✔ TA2: done (5 lookbacks)
#
# Processing TAP.B...
# ✔ TAP.B: done (5 lookbacks)
#
# Processing TAP...
# ✔ TAP: done (5 lookbacks)
#
# Processing TCOMA...
# ✔ TCOMA: done (5 lookbacks)
#
# Processing TDC...
# ✔ TDC: done (5 lookbacks)
#
# Processing TDG...
# ✔ TDG: done (5 lookbacks)
#
# Processing TDY...
# ✔ TDY: done (5 lookbacks)
#
# Processing TE1...
# ✔ TE1: done (5 lookbacks)
#
# Processing TECH...
# ✔ TECH: done (5 lookbacks)
#
# Processing TEG...
# ✔ TEG: done (5 lookbacks)
#
# Processing TEK1...
# ✔ TEK1: done (5 lookbacks)
#
# Processing TEL...
# ✔ TEL: done (5 lookbacks)
#
# Processing TEN1...
# ✔ TEN1: done (5 lookbacks)
#
# Processing TER...
# ✔ TER: done (5 lookbacks)
#
# Processing TEX...
# ✔ TEX: done (5 lookbacks)
#
# Processing TFC...
# ✔ TFC: done (5 lookbacks)
#
# Processing TFCF...
# ✔ TFCF: done (5 lookbacks)
#
# Processing TFCFA...
# ✔ TFCFA: done (5 lookbacks)
#
# Processing TFX...
# ✔ TFX: done (5 lookbacks)
#
# Processing TGNA...
# ✔ TGNA: done (5 lookbacks)
#
# Processing TGT...
# ✔ TGT: done (5 lookbacks)
#
# Processing THC...
# ✔ THC: done (5 lookbacks)
#
# Processing TIE...
# ✔ TIE: done (5 lookbacks)
#
# Processing TIF...
# ✔ TIF: done (5 lookbacks)
#
# Processing TIN...
# ✔ TIN: done (5 lookbacks)
#
# Processing TJX...
# ✔ TJX: done (5 lookbacks)
#
# Processing TKO...
# ✔ TKO: done (5 lookbacks)
#
# Processing TKR...
# ✔ TKR: done (5 lookbacks)
#
# Processing TLAB...
# ✔ TLAB: done (5 lookbacks)
#
# Processing TMC.A...
# ✔ TMC.A: done (5 lookbacks)
#
# Processing TMO...
# ✔ TMO: done (5 lookbacks)
#
# Processing TMUS...
# ✔ TMUS: done (5 lookbacks)
#
# Processing TNB...
# ✔ TNB: done (5 lookbacks)
#
# Processing TNL...
# ✔ TNL: done (5 lookbacks)
#
# Processing TOS...
# ✔ TOS: done (5 lookbacks)
#
# Processing TOY...
# ✔ TOY: done (5 lookbacks)
#
# Processing TPL...
# ✔ TPL: done (5 lookbacks)
#
# Processing TPR...
# ✔ TPR: done (5 lookbacks)
#
# Processing TRB...
# ✔ TRB: done (5 lookbacks)
#
# Processing TRGP...
# ✔ TRGP: done (5 lookbacks)
#
# Processing TRIP...
# ✔ TRIP: done (5 lookbacks)
#
# Processing TRMB...
# ✔ TRMB: done (5 lookbacks)
#
# Processing TROW...
# ✔ TROW: done (5 lookbacks)
#
# Processing TRV...
# ✔ TRV: done (5 lookbacks)
#
# Processing TRW1...
# ✔ TRW1: done (5 lookbacks)
#
# Processing TSCO...
# ✔ TSCO: done (5 lookbacks)
#
# Processing TSG1...
# ✔ TSG1: done (5 lookbacks)
#
# Processing TSLA...
# ✔ TSLA: done (5 lookbacks)
#
# Processing TSN...
# ✔ TSN: done (5 lookbacks)
#
# Processing TSS...
# ✔ TSS: done (5 lookbacks)
#
# Processing TT...
# ✔ TT: done (5 lookbacks)
#
# Processing TT2...
# ✔ TT2: done (5 lookbacks)
#
# Processing TTD...
# ✔ TTD: done (5 lookbacks)
#
# Processing TTWO...
# ✔ TTWO: done (5 lookbacks)
#
# Processing TUPBQ...
# ✔ TUPBQ: done (5 lookbacks)
#
# Processing TWC...
# ✔ TWC: done (5 lookbacks)
#
# Processing TWTR...
# ✔ TWTR: done (5 lookbacks)
#
# Processing TWX...
# ✔ TWX: done (5 lookbacks)
#
# Processing TWX1...
# ✔ TWX1: done (5 lookbacks)
#
# Processing TX1...
# ✔ TX1: done (5 lookbacks)
#
# Processing TXN...
# ✔ TXN: done (5 lookbacks)
#
# Processing TXT...
# ✔ TXT: done (5 lookbacks)
#
# Processing TXU...
# ✔ TXU: done (5 lookbacks)
#
# Processing TYC...
# ✔ TYC: done (5 lookbacks)
#
# Processing TYL...
# ✔ TYL: done (5 lookbacks)
#
# Processing UA...
# ✔ UA: done (5 lookbacks)
#
# Processing UAA...
# ✔ UAA: done (5 lookbacks)
#
# Processing UAL...
# ✔ UAL: done (5 lookbacks)
#
# Processing UAWGQ...
# ✔ UAWGQ: done (5 lookbacks)
#
# Processing UBER...
# ✔ UBER: done (5 lookbacks)
#
# Processing UCC1...
# ✔ UCC1: done (5 lookbacks)
#
# Processing UCL1...
# ✔ UCL1: done (5 lookbacks)
#
# Processing UCM...
# ✔ UCM: done (5 lookbacks)
#
# Processing UDR...
# ✔ UDR: done (5 lookbacks)
#
# Processing UHS...
# ✔ UHS: done (5 lookbacks)
#
# Processing UIS...
# ✔ UIS: done (5 lookbacks)
#
# Processing UK1...
# ✔ UK1: done (5 lookbacks)
#
# Processing UL...
# ✔ UL: done (5 lookbacks)
#
# Processing ULTA...
# ✔ ULTA: done (5 lookbacks)
#
# Processing UNH...
# ✔ UNH: done (5 lookbacks)
#
# Processing UNM...
# ✔ UNM: done (5 lookbacks)
#
# Processing UNP...
# ✔ UNP: done (5 lookbacks)
#
# Processing UPC1...
# ✔ UPC1: done (5 lookbacks)
#
# Processing UPR...
# ✔ UPR: done (5 lookbacks)
#
# Processing UPS...
# ✔ UPS: done (5 lookbacks)
#
# Processing URBN...
# ✔ URBN: done (5 lookbacks)
#
# Processing URI...
# ✔ URI: done (5 lookbacks)
#
# Processing USB...
# ✔ USB: done (5 lookbacks)
#
# Processing USB1...
# ✔ USB1: done (5 lookbacks)
#
# Processing USG1...
# ✔ USG1: done (5 lookbacks)
#
# Processing USS1...
# ⚠ VALIDATION: USS1 | W=252 | insufficient_history_for_regression | 190 rows, last=1998-10-01
# ✔ USS1: done (5 lookbacks)
#
# Processing UST1...
# ✔ UST1: done (5 lookbacks)
#
# Processing USW...
# ✔ USW: done (5 lookbacks)
#
# Processing UVN...
# ✔ UVN: done (5 lookbacks)
#
# Processing V...
# ✔ V: done (5 lookbacks)
#
# Processing VALPQ...
# ✔ VALPQ: done (5 lookbacks)
#
# Processing VAR...
# ✔ VAR: done (5 lookbacks)
#
# Processing VFC...
# ✔ VFC: done (5 lookbacks)
#
# Processing VIAB...
# ✔ VIAB: done (5 lookbacks)
#
# Processing VIAV...
# ✔ VIAV: done (5 lookbacks)
#
# Processing VICI...
# ✔ VICI: done (5 lookbacks)
#
# Processing VLO...
# ✔ VLO: done (5 lookbacks)
#
# Processing VLTO...
# ✔ VLTO: done (5 lookbacks)
#
# Processing VMC...
# ✔ VMC: done (5 lookbacks)
#
# Processing VNO...
# ✔ VNO: done (5 lookbacks)
#
# Processing VNT...
# ✔ VNT: done (5 lookbacks)
#
# Processing VO1...
# ✔ VO1: done (5 lookbacks)
#
# Processing VRSK...
# ✔ VRSK: done (5 lookbacks)
#
# Processing VRSN...
# ✔ VRSN: done (5 lookbacks)
#
# Processing VRTS1...
# ✔ VRTS1: done (5 lookbacks)
#
# Processing VRTX...
# ✔ VRTX: done (5 lookbacks)
#
# Processing VST...
# ✔ VST: done (5 lookbacks)
#
# Processing VSTNQ...
# ✔ VSTNQ: done (5 lookbacks)
#
# Processing VTR...
# ✔ VTR: done (5 lookbacks)
#
# Processing VTRS...
# ✔ VTRS: done (5 lookbacks)
#
# Processing VTSS...
# ✔ VTSS: done (5 lookbacks)
#
# Processing VYX...
# ✔ VYX: done (5 lookbacks)
#
# Processing VZ...
# ✔ VZ: done (5 lookbacks)
#
# Processing WAB...
# ✔ WAB: done (5 lookbacks)
#
# Processing WAI1...
# ⚠ VALIDATION: WAI1 | W=180 | insufficient_history_for_regression | 153 rows, last=1998-08-10
# ⚠ VALIDATION: WAI1 | W=252 | insufficient_history_for_regression | 153 rows, last=1998-08-10
# ✔ WAI1: done (5 lookbacks)
#
# Processing WAMUQ...
# ✔ WAMUQ: done (5 lookbacks)
#
# Processing WAT...
# ✔ WAT: done (5 lookbacks)
#
# Processing WB1...
# ✔ WB1: done (5 lookbacks)
#
# Processing WB2...
# ✔ WB2: done (5 lookbacks)
#
# Processing WBA...
# ✔ WBA: done (5 lookbacks)
#
# Processing WBD...
# ✔ WBD: done (5 lookbacks)
#
# Processing WCG...
# ✔ WCG: done (5 lookbacks)
#
# Processing WCOEQ...
# ✔ WCOEQ: done (5 lookbacks)
#
# Processing WDAY...
# ✔ WDAY: done (5 lookbacks)
#
# Processing WDC...
# ✔ WDC: done (5 lookbacks)
#
# Processing WEC...
# ✔ WEC: done (5 lookbacks)
#
# Processing WELL...
# ✔ WELL: done (5 lookbacks)
#
# Processing WEN...
# ✔ WEN: done (5 lookbacks)
#
# Processing WFC...
# ✔ WFC: done (5 lookbacks)
#
# Processing WFC1...
# ⚠ VALIDATION: WFC1 | W=252 | insufficient_history_for_regression | 212 rows, last=1998-11-02
# ✔ WFC1: done (5 lookbacks)
#
# Processing WFM...
# ✔ WFM: done (5 lookbacks)
#
# Processing WFTIQ...
# ✔ WFTIQ: done (5 lookbacks)
#
# Processing WGL...
# ✔ WGL: done (5 lookbacks)
#
# Processing WHR...
# ✔ WHR: done (5 lookbacks)
#
# Processing WINMQ...
# ✔ WINMQ: done (5 lookbacks)
#
# Processing WLA...
# ✔ WLA: done (5 lookbacks)
#
# Processing WLL1...
# ✔ WLL1: done (5 lookbacks)
#
# Processing WLP1...
# ✔ WLP1: done (5 lookbacks)
#
# Processing WM...
# ✔ WM: done (5 lookbacks)
#
# Processing WMB...
# ✔ WMB: done (5 lookbacks)
#
# Processing WMT...
# ✔ WMT: done (5 lookbacks)
#
# Processing WNDXQ...
# ✔ WNDXQ: done (5 lookbacks)
#
# Processing WOR...
# ✔ WOR: done (5 lookbacks)
#
# Processing WPX...
# ✔ WPX: done (5 lookbacks)
#
# Processing WRB...
# ✔ WRB: done (5 lookbacks)
#
# Processing WRK...
# ✔ WRK: done (5 lookbacks)
#
# Processing WSM...
# ✔ WSM: done (5 lookbacks)
#
# Processing WST...
# ✔ WST: done (5 lookbacks)
#
# Processing WTW...
# ✔ WTW: done (5 lookbacks)
#
# Processing WU...
# ✔ WU: done (5 lookbacks)
#
# Processing WWY...
# ✔ WWY: done (5 lookbacks)
#
# Processing WY...
# ✔ WY: done (5 lookbacks)
#
# Processing WYE...
# ✔ WYE: done (5 lookbacks)
#
# Processing WYNN...
# ✔ WYNN: done (5 lookbacks)
#
# Processing X...
# ✔ X: done (5 lookbacks)
#
# Processing XEC...
# ✔ XEC: done (5 lookbacks)
#
# Processing XEL...
# ✔ XEL: done (5 lookbacks)
#
# Processing XL1...
# ✔ XL1: done (5 lookbacks)
#
# Processing XLNX...
# ✔ XLNX: done (5 lookbacks)
#
# Processing XOM...
# ✔ XOM: done (5 lookbacks)
#
# Processing XRAY...
# ✔ XRAY: done (5 lookbacks)
#
# Processing XRX...
# ✔ XRX: done (5 lookbacks)
#
# Processing XTO...
# ✔ XTO: done (5 lookbacks)
#
# Processing XYL...
# ✔ XYL: done (5 lookbacks)
#
# Processing XYZ...
# ✔ XYZ: done (5 lookbacks)
#
# Processing YHOO...
# ✔ YHOO: done (5 lookbacks)
#
# Processing YNR...
# ✔ YNR: done (5 lookbacks)
#
# Processing YUM...
# ✔ YUM: done (5 lookbacks)
#
# Processing ZBH...
# ✔ ZBH: done (5 lookbacks)
#
# Processing ZBRA...
# ✔ ZBRA: done (5 lookbacks)
#
# Processing ZION...
# ✔ ZION: done (5 lookbacks)
#
# Processing ZTS...
# ✔ ZTS: done (5 lookbacks)
#
#
# ====================================================
#  MULTI-LOOKBACK REGRESSION VALIDATION SUMMARY
# ====================================================
#    ticker  window                                issue  \
# 0    AHM1     252  insufficient_history_for_regression
# 1    BAC1     252  insufficient_history_for_regression
# 2    BAY1     180  insufficient_history_for_regression
# 3    BAY1     252  insufficient_history_for_regression
# 4    BBI1      60  insufficient_history_for_regression
# ..    ...     ...                                  ...
# 65   STO1     252  insufficient_history_for_regression
# 66   USS1     252  insufficient_history_for_regression
# 67   WAI1     180  insufficient_history_for_regression
# 68   WAI1     252  insufficient_history_for_regression
# 69   WFC1     252  insufficient_history_for_regression
#
#                        detail
# 0   190 rows, last=1998-10-01
# 1   189 rows, last=1998-09-30
# 2   167 rows, last=1998-08-28
# 3   167 rows, last=1998-08-28
# 4     7 rows, last=1998-01-09
# ..                        ...
# 65  223 rows, last=1998-11-17
# 66  190 rows, last=1998-10-01
# 67  153 rows, last=1998-08-10
# 68  153 rows, last=1998-08-10
# 69  212 rows, last=1998-11-02
#
# [70 rows x 4 columns]
#
# Validation log saved to:
# ./system_verification/7a-multiple_regressions_adjusted_all_prices\regression_multi_validation-20251231-084305.csv
# ====================================================
