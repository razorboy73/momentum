# %%
"""
Runs 90-day rolling log-price regressions on adjusted OHLC parquet files, using Numba to compute
daily and annualized slopes plus R² for each window. Validates required columns and positive closes,
skips tickers with insufficient history, saves per-ticker regression outputs to
./7-90Day_exp_regression_adjusted_all_prices, and logs validation issues to a timestamped CSV in
./system_verification/7-90Day_exp_regression_adjusted_all_prices.
"""



import os
import pandas as pd
import numpy as np
from datetime import datetime
from numba import njit, prange

# ============================================================
# CONFIG
# ============================================================

INPUT_DIR  = "./3-adjusted_All_Prices_OHLC"
OUTPUT_DIR = "./7-90Day_exp_regression_adjusted_all_prices"
VER_DIR    = "./system_verification/7-90Day_exp_regression_adjusted_all_prices"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(VER_DIR, exist_ok=True)

WINDOW = 90                    # 90 trading days
TRADING_DAYS_PER_YEAR = 252    # For annualization

print(f"\nLoading adjusted OHLC files from: {INPUT_DIR}")
files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".parquet")])
print(f"Found {len(files)} tickers.\n")

REQUIRED = {"date", "close_adj"}

# ============================================================
# VALIDATION STORAGE
# ============================================================

validation_rows = []

def add_validation(ticker, issue, detail=""):
    row = {"ticker": ticker, "issue": issue, "detail": detail}
    validation_rows.append(row)
    print(f"⚠ VALIDATION: {ticker} | {issue} | {detail}")

# ============================================================
# Numba Regression Engine
# ============================================================

# x axis (0..WINDOW-1)
x = np.arange(WINDOW, dtype=np.float64)
x_mean = x.mean()
var_x = np.mean((x - x_mean) ** 2)

@njit
def fast_regression_window(y):
    """
    Computes slope + R² for one window of log prices.
    y must be length = WINDOW.

    Regression: log(price) ~ beta0 + beta1 * time_index
    beta1 is in units of log-price per day (≈ avg daily log-return).
    """
    # reject invalid windows
    for v in y:
        if np.isnan(v) or np.isinf(v):
            return np.nan, np.nan

    y_mean = np.mean(y)

    # covariance
    cov_xy = 0.0
    for i in range(WINDOW):
        cov_xy += (x[i] - x_mean) * (y[i] - y_mean)
    cov_xy /= WINDOW

    beta1 = cov_xy / var_x
    beta0 = y_mean - beta1 * x_mean

    # compute R²
    ss_res = 0.0
    ss_tot = 0.0
    for i in range(WINDOW):
        y_hat = beta0 + beta1 * x[i]
        ss_res += (y[i] - y_hat) ** 2
        ss_tot += (y[i] - y_mean) ** 2

    # If ss_tot == 0 (flat series), R² is undefined; return NaN
    r2 = 1.0 - ss_res / ss_tot if ss_tot > 0 else np.nan

    return beta1, r2

@njit(parallel=True)
def run_rolling_regressions(log_prices):
    """
    log_prices: 1D array of log-adjusted prices for this ticker.

    IMPORTANT ALIGNMENT:
    - slope at index t uses window ending at t (inclusive):
      log_prices[t-WINDOW+1 : t+1]
    - first valid index is WINDOW-1.
    """
    n = len(log_prices)
    slopes_daily = np.full(n, np.nan)
    r2_out = np.full(n, np.nan)

    for t in prange(WINDOW - 1, n):
        window = log_prices[t - WINDOW + 1 : t + 1]  # includes t
        slope, r2 = fast_regression_window(window)
        slopes_daily[t] = slope
        r2_out[t] = r2

    return slopes_daily, r2_out

# ============================================================
# MAIN LOGIC
# ============================================================

for file in files:
    ticker = file.replace(".parquet", "")
    in_path = os.path.join(INPUT_DIR, file)
    out_path = os.path.join(OUTPUT_DIR, f"{ticker}.parquet")

    print(f"Processing {ticker}...")

    try:
        # -----------------------------
        # Load & validate
        # -----------------------------
        df = pd.read_parquet(in_path)

        if not REQUIRED.issubset(df.columns):
            add_validation(ticker, "missing_columns", str(REQUIRED - set(df.columns)))
            continue

        df["date"] = pd.to_datetime(df["date"])
        df = df.sort_values("date").reset_index(drop=True)

        if (df["close_adj"] <= 0).any():
            add_validation(
                ticker,
                "nonpositive_close_adj",
                f"{(df['close_adj'] <= 0).sum()} rows"
            )

        if len(df) < WINDOW:
            last_date = df["date"].max().date()
            add_validation(
                ticker,
                "insufficient_history_for_regression",
                f"{len(df)} rows, last={last_date}"
            )
            continue

        # -----------------------------
        # Prepare data: log prices
        # -----------------------------
        px = df["close_adj"].astype(float).values
        # Guard against <=0 -> log invalid
        px = np.where(px > 0, px, np.nan)
        log_px = np.log(px)

        # -----------------------------
        # Run Numba rolling regressions
        # -----------------------------
        slopes_daily, r2 = run_rolling_regressions(log_px)

        # annualize slope: slope_daily is avg daily log-return
        slopes_annual = np.expm1(slopes_daily * TRADING_DAYS_PER_YEAR)

        # -----------------------------
        # Write output file
        # -----------------------------
        df_out = df.copy()
        df_out["slope_daily"]  = slopes_daily
        df_out["slope_annual"] = slopes_annual
        df_out["r2"]           = r2

        df_out.to_parquet(out_path, index=False)
        print(f"✔ {ticker}: saved regression → {out_path}\n")

    except Exception as e:
        add_validation(ticker, "processing_error", str(e))
        print(f"❌ ERROR for {ticker}: {e}\n")

# ============================================================
# SAVE VALIDATION REPORT
# ============================================================

validation_df = pd.DataFrame(validation_rows)

val_file = os.path.join(
    VER_DIR,
    f"regression90_validation-{datetime.now().strftime('%Y%m%d-%H%M%S')}.csv"
)

validation_df.to_csv(val_file, index=False)

print("\n====================================================")
print(" 90-DAY REGRESSION VALIDATION SUMMARY")
print("====================================================")

if validation_df.empty:
    print("No validation issues detected.")
else:
    print(validation_df)

print("\nValidation log saved to:")
print(val_file)
print("====================================================\n")
# Out:
# Loading adjusted OHLC files from: ./3-adjusted_All_Prices_OHLC
# Found 1167 tickers.
#
# Processing A...
# ✔ A: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\A.parquet
#
# Processing AAL...
# ✔ AAL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AAL.parquet
#
# Processing AAMRQ...
# ✔ AAMRQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AAMRQ.parquet
#
# Processing AAP...
# ✔ AAP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AAP.parquet
#
# Processing AAPL...
# ✔ AAPL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AAPL.parquet
#
# Processing ABBV...
# ✔ ABBV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ABBV.parquet
#
# Processing ABI1...
# ✔ ABI1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ABI1.parquet
#
# Processing ABKFQ...
# ✔ ABKFQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ABKFQ.parquet
#
# Processing ABMD...
# ✔ ABMD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ABMD.parquet
#
# Processing ABNB...
# ✔ ABNB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ABNB.parquet
#
# Processing ABS...
# ✔ ABS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ABS.parquet
#
# Processing ABT...
# ✔ ABT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ABT.parquet
#
# Processing ACAS...
# ✔ ACAS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ACAS.parquet
#
# Processing ACGL...
# ✔ ACGL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ACGL.parquet
#
# Processing ACKHQ...
# ✔ ACKHQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ACKHQ.parquet
#
# Processing ACN...
# ✔ ACN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ACN.parquet
#
# Processing ACS...
# ✔ ACS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ACS.parquet
#
# Processing ACV1...
# ✔ ACV1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ACV1.parquet
#
# Processing ADBE...
# ✔ ADBE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ADBE.parquet
#
# Processing ADCT1...
# ✔ ADCT1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ADCT1.parquet
#
# Processing ADI...
# ✔ ADI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ADI.parquet
#
# Processing ADM...
# ✔ ADM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ADM.parquet
#
# Processing ADP...
# ✔ ADP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ADP.parquet
#
# Processing ADSK...
# ✔ ADSK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ADSK.parquet
#
# Processing ADT1...
# ✔ ADT1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ADT1.parquet
#
# Processing AEE...
# ✔ AEE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AEE.parquet
#
# Processing AEP...
# ✔ AEP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AEP.parquet
#
# Processing AES...
# ✔ AES: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AES.parquet
#
# Processing AET...
# ✔ AET: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AET.parquet
#
# Processing AFL...
# ✔ AFL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AFL.parquet
#
# Processing AFS.A...
# ✔ AFS.A: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AFS.A.parquet
#
# Processing AGC1...
# ✔ AGC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AGC1.parquet
#
# Processing AGN...
# ✔ AGN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AGN.parquet
#
# Processing AGN1...
# ✔ AGN1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AGN1.parquet
#
# Processing AHM1...
# ✔ AHM1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AHM1.parquet
#
# Processing AIG...
# ✔ AIG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AIG.parquet
#
# Processing AIT...
# ✔ AIT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AIT.parquet
#
# Processing AIV...
# ✔ AIV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AIV.parquet
#
# Processing AIZ...
# ✔ AIZ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AIZ.parquet
#
# Processing AJG...
# ✔ AJG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AJG.parquet
#
# Processing AKAM...
# ✔ AKAM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AKAM.parquet
#
# Processing AKS...
# ✔ AKS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AKS.parquet
#
# Processing AL1...
# ✔ AL1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AL1.parquet
#
# Processing ALB...
# ✔ ALB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ALB.parquet
#
# Processing ALGN...
# ✔ ALGN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ALGN.parquet
#
# Processing ALK...
# ✔ ALK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ALK.parquet
#
# Processing ALL...
# ✔ ALL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ALL.parquet
#
# Processing ALLE...
# ✔ ALLE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ALLE.parquet
#
# Processing ALTR1...
# ✔ ALTR1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ALTR1.parquet
#
# Processing ALXN...
# ✔ ALXN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ALXN.parquet
#
# Processing AM1...
# ✔ AM1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AM1.parquet
#
# Processing AMAT...
# ✔ AMAT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMAT.parquet
#
# Processing AMCC...
# ✔ AMCC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMCC.parquet
#
# Processing AMCR...
# ✔ AMCR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMCR.parquet
#
# Processing AMD...
# ✔ AMD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMD.parquet
#
# Processing AME...
# ✔ AME: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AME.parquet
#
# Processing AMG...
# ✔ AMG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMG.parquet
#
# Processing AMGN...
# ✔ AMGN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMGN.parquet
#
# Processing AMP...
# ✔ AMP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMP.parquet
#
# Processing AMP1...
# ✔ AMP1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMP1.parquet
#
# Processing AMT...
# ✔ AMT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMT.parquet
#
# Processing AMTM...
# ✔ AMTM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMTM.parquet
#
# Processing AMZN...
# ✔ AMZN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AMZN.parquet
#
# Processing AN...
# ✔ AN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AN.parquet
#
# Processing AN1...
# ✔ AN1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AN1.parquet
#
# Processing ANDV...
# ✔ ANDV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ANDV.parquet
#
# Processing ANDW...
# ✔ ANDW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ANDW.parquet
#
# Processing ANET...
# ✔ ANET: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ANET.parquet
#
# Processing ANF...
# ✔ ANF: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ANF.parquet
#
# Processing ANRZQ...
# ✔ ANRZQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ANRZQ.parquet
#
# Processing ANSS...
# ✔ ANSS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ANSS.parquet
#
# Processing ANV1...
# ✔ ANV1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ANV1.parquet
#
# Processing AON...
# ✔ AON: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AON.parquet
#
# Processing AOS...
# ✔ AOS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AOS.parquet
#
# Processing APA...
# ✔ APA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APA.parquet
#
# Processing APC...
# ✔ APC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APC.parquet
#
# Processing APCC...
# ✔ APCC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APCC.parquet
#
# Processing APD...
# ✔ APD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APD.parquet
#
# Processing APH...
# ✔ APH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APH.parquet
#
# Processing APO...
# ✔ APO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APO.parquet
#
# Processing APOL...
# ✔ APOL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APOL.parquet
#
# Processing APP...
# ✔ APP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APP.parquet
#
# Processing APTV...
# ✔ APTV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\APTV.parquet
#
# Processing AR1...
# ✔ AR1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AR1.parquet
#
# Processing ARC1...
# ✔ ARC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ARC1.parquet
#
# Processing ARE...
# ✔ ARE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ARE.parquet
#
# Processing ARES...
# ✔ ARES: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ARES.parquet
#
# Processing ARG...
# ✔ ARG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ARG.parquet
#
# Processing AS1...
# ✔ AS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AS1.parquet
#
# Processing ASC1...
# ✔ ASC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ASC1.parquet
#
# Processing ASH...
# ✔ ASH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ASH.parquet
#
# Processing ASN...
# ✔ ASN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ASN.parquet
#
# Processing ASND1...
# ✔ ASND1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ASND1.parquet
#
# Processing ASO1...
# ✔ ASO1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ASO1.parquet
#
# Processing AT1...
# ✔ AT1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AT1.parquet
#
# Processing ATGE...
# ✔ ATGE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ATGE.parquet
#
# Processing ATI...
# ✔ ATI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ATI.parquet
#
# Processing ATI1...
# ✔ ATI1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ATI1.parquet
#
# Processing ATO...
# ✔ ATO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ATO.parquet
#
# Processing ATVI...
# ✔ ATVI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ATVI.parquet
#
# Processing AV1...
# ✔ AV1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AV1.parquet
#
# Processing AVB...
# ✔ AVB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AVB.parquet
#
# Processing AVGO...
# ✔ AVGO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AVGO.parquet
#
# Processing AVP...
# ✔ AVP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AVP.parquet
#
# Processing AVY...
# ✔ AVY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AVY.parquet
#
# Processing AW...
# ✔ AW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AW.parquet
#
# Processing AWE...
# ✔ AWE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AWE.parquet
#
# Processing AWK...
# ✔ AWK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AWK.parquet
#
# Processing AXON...
# ✔ AXON: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AXON.parquet
#
# Processing AXP...
# ✔ AXP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AXP.parquet
#
# Processing AYE...
# ✔ AYE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AYE.parquet
#
# Processing AYI...
# ✔ AYI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AYI.parquet
#
# Processing AZA.A...
# ✔ AZA.A: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AZA.A.parquet
#
# Processing AZO...
# ✔ AZO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\AZO.parquet
#
# Processing B...
# ✔ B: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\B.parquet
#
# Processing BA...
# ✔ BA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BA.parquet
#
# Processing BAC...
# ✔ BAC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BAC.parquet
#
# Processing BAC1...
# ✔ BAC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BAC1.parquet
#
# Processing BALL...
# ✔ BALL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BALL.parquet
#
# Processing BAX...
# ✔ BAX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BAX.parquet
#
# Processing BAY1...
# ✔ BAY1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BAY1.parquet
#
# Processing BBBYQ...
# ✔ BBBYQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BBBYQ.parquet
#
# Processing BBI1...
# ⚠ VALIDATION: BBI1 | insufficient_history_for_regression | 7 rows, last=1998-01-09
# Processing BBWI...
# ✔ BBWI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BBWI.parquet
#
# Processing BBY...
# ✔ BBY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BBY.parquet
#
# Processing BC...
# ✔ BC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BC.parquet
#
# Processing BCR...
# ✔ BCR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BCR.parquet
#
# Processing BDK...
# ✔ BDK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BDK.parquet
#
# Processing BDX...
# ✔ BDX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BDX.parquet
#
# Processing BEAM2...
# ✔ BEAM2: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BEAM2.parquet
#
# Processing BEN...
# ✔ BEN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BEN.parquet
#
# Processing BF.B...
# ✔ BF.B: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BF.B.parquet
#
# Processing BFH...
# ✔ BFH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BFH.parquet
#
# Processing BFI1...
# ✔ BFI1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BFI1.parquet
#
# Processing BFO1...
# ✔ BFO1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BFO1.parquet
#
# Processing BG...
# ✔ BG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BG.parquet
#
# Processing BGEN...
# ✔ BGEN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BGEN.parquet
#
# Processing BGGSQ...
# ✔ BGGSQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BGGSQ.parquet
#
# Processing BHF...
# ✔ BHF: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BHF.parquet
#
# Processing BHI...
# ✔ BHI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BHI.parquet
#
# Processing BHMSQ...
# ✔ BHMSQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BHMSQ.parquet
#
# Processing BIGGQ...
# ✔ BIGGQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BIGGQ.parquet
#
# Processing BIIB...
# ✔ BIIB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BIIB.parquet
#
# Processing BIO...
# ✔ BIO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BIO.parquet
#
# Processing BJS...
# ✔ BJS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BJS.parquet
#
# Processing BK...
# ✔ BK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BK.parquet
#
# Processing BKB...
# ✔ BKB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BKB.parquet
#
# Processing BKNG...
# ✔ BKNG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BKNG.parquet
#
# Processing BKR...
# ✔ BKR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BKR.parquet
#
# Processing BLDR...
# ✔ BLDR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BLDR.parquet
#
# Processing BLK...
# ✔ BLK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BLK.parquet
#
# Processing BLS...
# ✔ BLS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BLS.parquet
#
# Processing BMC...
# ✔ BMC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BMC.parquet
#
# Processing BMET...
# ✔ BMET: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BMET.parquet
#
# Processing BMGCA...
# ✔ BMGCA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BMGCA.parquet
#
# Processing BMS...
# ✔ BMS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BMS.parquet
#
# Processing BMY...
# ✔ BMY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BMY.parquet
#
# Processing BNI...
# ✔ BNI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BNI.parquet
#
# Processing BNL1...
# ✔ BNL1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BNL1.parquet
#
# Processing BOL...
# ✔ BOL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BOL.parquet
#
# Processing BR...
# ✔ BR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BR.parquet
#
# Processing BR1...
# ✔ BR1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BR1.parquet
#
# Processing BRCM...
# ✔ BRCM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BRCM.parquet
#
# Processing BRK.B...
# ✔ BRK.B: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BRK.B.parquet
#
# Processing BRL...
# ✔ BRL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BRL.parquet
#
# Processing BRO...
# ✔ BRO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BRO.parquet
#
# Processing BSC1...
# ✔ BSC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BSC1.parquet
#
# Processing BSX...
# ✔ BSX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BSX.parquet
#
# Processing BT1...
# ✔ BT1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BT1.parquet
#
# Processing BTUUQ...
# ✔ BTUUQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BTUUQ.parquet
#
# Processing BUD1...
# ✔ BUD1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BUD1.parquet
#
# Processing BVSN...
# ✔ BVSN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BVSN.parquet
#
# Processing BWA...
# ✔ BWA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BWA.parquet
#
# Processing BX...
# ✔ BX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BX.parquet
#
# Processing BXLT...
# ✔ BXLT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BXLT.parquet
#
# Processing BXP...
# ✔ BXP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\BXP.parquet
#
# Processing C...
# ✔ C: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\C.parquet
#
# Processing C1...
# ✔ C1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\C1.parquet
#
# Processing CA1...
# ✔ CA1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CA1.parquet
#
# Processing CAG...
# ✔ CAG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CAG.parquet
#
# Processing CAH...
# ✔ CAH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CAH.parquet
#
# Processing CAL...
# ✔ CAL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CAL.parquet
#
# Processing CAM2...
# ✔ CAM2: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CAM2.parquet
#
# Processing CAR...
# ✔ CAR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CAR.parquet
#
# Processing CARR...
# ✔ CARR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CARR.parquet
#
# Processing CAT...
# ✔ CAT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CAT.parquet
#
# Processing CB...
# ✔ CB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CB.parquet
#
# Processing CB1...
# ✔ CB1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CB1.parquet
#
# Processing CBE...
# ✔ CBE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CBE.parquet
#
# Processing CBH1...
# ✔ CBH1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CBH1.parquet
#
# Processing CBOE...
# ✔ CBOE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CBOE.parquet
#
# Processing CBRE...
# ✔ CBRE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CBRE.parquet
#
# Processing CBS1...
# ✔ CBS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CBS1.parquet
#
# Processing CBSS...
# ✔ CBSS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CBSS.parquet
#
# Processing CCE1...
# ✔ CCE1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CCE1.parquet
#
# Processing CCI...
# ✔ CCI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CCI.parquet
#
# Processing CCI1...
# ✔ CCI1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CCI1.parquet
#
# Processing CCK...
# ✔ CCK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CCK.parquet
#
# Processing CCL...
# ✔ CCL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CCL.parquet
#
# Processing CCTYQ...
# ✔ CCTYQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CCTYQ.parquet
#
# Processing CCU1...
# ✔ CCU1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CCU1.parquet
#
# Processing CDNS...
# ✔ CDNS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CDNS.parquet
#
# Processing CDW...
# ✔ CDW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CDW.parquet
#
# Processing CE...
# ✔ CE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CE.parquet
#
# Processing CE1...
# ✔ CE1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CE1.parquet
#
# Processing CEG...
# ✔ CEG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CEG.parquet
#
# Processing CEG1...
# ✔ CEG1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CEG1.parquet
#
# Processing CELG...
# ✔ CELG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CELG.parquet
#
# Processing CEM1...
# ✔ CEM1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CEM1.parquet
#
# Processing CEN1...
# ✔ CEN1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CEN1.parquet
#
# Processing CEPH...
# ✔ CEPH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CEPH.parquet
#
# Processing CERN...
# ✔ CERN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CERN.parquet
#
# Processing CF...
# ✔ CF: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CF.parquet
#
# Processing CF1...
# ✔ CF1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CF1.parquet
#
# Processing CFC...
# ✔ CFC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CFC.parquet
#
# Processing CFG...
# ✔ CFG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CFG.parquet
#
# Processing CFL1...
# ⚠ VALIDATION: CFL1 | insufficient_history_for_regression | 80 rows, last=1998-04-27
# Processing CFN...
# ✔ CFN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CFN.parquet
#
# Processing CG1...
# ✔ CG1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CG1.parquet
#
# Processing CGP...
# ✔ CGP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CGP.parquet
#
# Processing CHA1...
# ✔ CHA1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CHA1.parquet
#
# Processing CHD...
# ✔ CHD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CHD.parquet
#
# Processing CHIR1...
# ✔ CHIR1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CHIR1.parquet
#
# Processing CHKAQ...
# ✔ CHKAQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CHKAQ.parquet
#
# Processing CHRS1...
# ✔ CHRS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CHRS1.parquet
#
# Processing CHRW...
# ✔ CHRW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CHRW.parquet
#
# Processing CHTR...
# ✔ CHTR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CHTR.parquet
#
# Processing CI...
# ✔ CI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CI.parquet
#
# Processing CIEN...
# ✔ CIEN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CIEN.parquet
#
# Processing CIN...
# ✔ CIN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CIN.parquet
#
# Processing CINF...
# ✔ CINF: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CINF.parquet
#
# Processing CIT.A...
# ✔ CIT.A: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CIT.A.parquet
#
# Processing CITGQ...
# ✔ CITGQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CITGQ.parquet
#
# Processing CL...
# ✔ CL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CL.parquet
#
# Processing CLF...
# ✔ CLF: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CLF.parquet
#
# Processing CLX...
# ✔ CLX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CLX.parquet
#
# Processing CMA...
# ✔ CMA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMA.parquet
#
# Processing CMCSA...
# ✔ CMCSA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMCSA.parquet
#
# Processing CMCSK...
# ✔ CMCSK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMCSK.parquet
#
# Processing CME...
# ✔ CME: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CME.parquet
#
# Processing CMG...
# ✔ CMG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMG.parquet
#
# Processing CMI...
# ✔ CMI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMI.parquet
#
# Processing CMS...
# ✔ CMS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMS.parquet
#
# Processing CMVT...
# ✔ CMVT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMVT.parquet
#
# Processing CMX...
# ✔ CMX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CMX.parquet
#
# Processing CNC...
# ✔ CNC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CNC.parquet
#
# Processing CNCEQ...
# ✔ CNCEQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CNCEQ.parquet
#
# Processing CNG...
# ✔ CNG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CNG.parquet
#
# Processing CNP...
# ✔ CNP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CNP.parquet
#
# Processing CNW...
# ✔ CNW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CNW.parquet
#
# Processing CNX...
# ✔ CNX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CNX.parquet
#
# Processing CNXT1...
# ✔ CNXT1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CNXT1.parquet
#
# Processing COC...
# ✔ COC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COC.parquet
#
# Processing COF...
# ✔ COF: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COF.parquet
#
# Processing COIN...
# ✔ COIN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COIN.parquet
#
# Processing COL...
# ✔ COL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COL.parquet
#
# Processing COMS1...
# ✔ COMS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COMS1.parquet
#
# Processing COO...
# ✔ COO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COO.parquet
#
# Processing COP...
# ✔ COP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COP.parquet
#
# Processing COR...
# ✔ COR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COR.parquet
#
# Processing COST...
# ✔ COST: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COST.parquet
#
# Processing COT1...
# ✔ COT1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COT1.parquet
#
# Processing COTY...
# ✔ COTY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COTY.parquet
#
# Processing COV...
# ✔ COV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\COV.parquet
#
# Processing CPAY...
# ✔ CPAY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPAY.parquet
#
# Processing CPB...
# ✔ CPB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPB.parquet
#
# Processing CPGX...
# ✔ CPGX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPGX.parquet
#
# Processing CPNLQ...
# ✔ CPNLQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPNLQ.parquet
#
# Processing CPPRQ...
# ✔ CPPRQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPPRQ.parquet
#
# Processing CPQ...
# ✔ CPQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPQ.parquet
#
# Processing CPRI...
# ✔ CPRI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPRI.parquet
#
# Processing CPRT...
# ✔ CPRT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPRT.parquet
#
# Processing CPT...
# ✔ CPT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPT.parquet
#
# Processing CPWR...
# ✔ CPWR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CPWR.parquet
#
# Processing CRH...
# ✔ CRH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CRH.parquet
#
# Processing CRL...
# ✔ CRL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CRL.parquet
#
# Processing CRM...
# ✔ CRM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CRM.parquet
#
# Processing CRWD...
# ✔ CRWD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CRWD.parquet
#
# Processing CSC...
# ✔ CSC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CSC.parquet
#
# Processing CSCO...
# ✔ CSCO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CSCO.parquet
#
# Processing CSE1...
# ✔ CSE1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CSE1.parquet
#
# Processing CSGP...
# ✔ CSGP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CSGP.parquet
#
# Processing CSR1...
# ✔ CSR1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CSR1.parquet
#
# Processing CSRA...
# ✔ CSRA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CSRA.parquet
#
# Processing CSX...
# ✔ CSX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CSX.parquet
#
# Processing CTAS...
# ✔ CTAS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTAS.parquet
#
# Processing CTB...
# ✔ CTB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTB.parquet
#
# Processing CTLT...
# ✔ CTLT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTLT.parquet
#
# Processing CTRA...
# ✔ CTRA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTRA.parquet
#
# Processing CTSH...
# ✔ CTSH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTSH.parquet
#
# Processing CTVA...
# ✔ CTVA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTVA.parquet
#
# Processing CTX1...
# ✔ CTX1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTX1.parquet
#
# Processing CTXS...
# ✔ CTXS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CTXS.parquet
#
# Processing CVC...
# ✔ CVC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CVC.parquet
#
# Processing CVG...
# ✔ CVG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CVG.parquet
#
# Processing CVGYQ...
# ✔ CVGYQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CVGYQ.parquet
#
# Processing CVH...
# ✔ CVH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CVH.parquet
#
# Processing CVNA...
# ✔ CVNA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CVNA.parquet
#
# Processing CVS...
# ✔ CVS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CVS.parquet
#
# Processing CVX...
# ✔ CVX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CVX.parquet
#
# Processing CXO...
# ✔ CXO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CXO.parquet
#
# Processing CXT...
# ✔ CXT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CXT.parquet
#
# Processing CYM...
# ✔ CYM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CYM.parquet
#
# Processing CZR...
# ✔ CZR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\CZR.parquet
#
# Processing D...
# ✔ D: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\D.parquet
#
# Processing DAL...
# ✔ DAL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DAL.parquet
#
# Processing DALRQ...
# ✔ DALRQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DALRQ.parquet
#
# Processing DASH...
# ✔ DASH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DASH.parquet
#
# Processing DAY...
# ✔ DAY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DAY.parquet
#
# Processing DCNAQ...
# ✔ DCNAQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DCNAQ.parquet
#
# Processing DD...
# ✔ DD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DD.parquet
#
# Processing DD1...
# ✔ DD1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DD1.parquet
#
# Processing DDOG...
# ✔ DDOG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DDOG.parquet
#
# Processing DDS...
# ✔ DDS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DDS.parquet
#
# Processing DE...
# ✔ DE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DE.parquet
#
# Processing DEC1...
# ✔ DEC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DEC1.parquet
#
# Processing DECK...
# ✔ DECK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DECK.parquet
#
# Processing DELL...
# ✔ DELL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DELL.parquet
#
# Processing DELL1...
# ✔ DELL1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DELL1.parquet
#
# Processing DFODQ...
# ✔ DFODQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DFODQ.parquet
#
# Processing DFS...
# ✔ DFS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DFS.parquet
#
# Processing DG...
# ✔ DG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DG.parquet
#
# Processing DG1...
# ✔ DG1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DG1.parquet
#
# Processing DGN...
# ✔ DGN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DGN.parquet
#
# Processing DGX...
# ✔ DGX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DGX.parquet
#
# Processing DHI...
# ✔ DHI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DHI.parquet
#
# Processing DHR...
# ✔ DHR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DHR.parquet
#
# Processing DI1...
# ✔ DI1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DI1.parquet
#
# Processing DIGI2...
# ✔ DIGI2: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DIGI2.parquet
#
# Processing DINO...
# ✔ DINO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DINO.parquet
#
# Processing DIS...
# ✔ DIS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DIS.parquet
#
# Processing DISCK...
# ✔ DISCK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DISCK.parquet
#
# Processing DISH...
# ✔ DISH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DISH.parquet
#
# Processing DJ...
# ✔ DJ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DJ.parquet
#
# Processing DLR...
# ✔ DLR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DLR.parquet
#
# Processing DLTR...
# ✔ DLTR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DLTR.parquet
#
# Processing DLX...
# ✔ DLX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DLX.parquet
#
# Processing DNB1...
# ✔ DNB1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DNB1.parquet
#
# Processing DNB2...
# ✔ DNB2: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DNB2.parquet
#
# Processing DNB3...
# ✔ DNB3: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DNB3.parquet
#
# Processing DNRCQ...
# ✔ DNRCQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DNRCQ.parquet
#
# Processing DOC...
# ✔ DOC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DOC.parquet
#
# Processing DOFSQ...
# ✔ DOFSQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DOFSQ.parquet
#
# Processing DOV...
# ✔ DOV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DOV.parquet
#
# Processing DOW...
# ✔ DOW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DOW.parquet
#
# Processing DPHIQ...
# ✔ DPHIQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DPHIQ.parquet
#
# Processing DPZ...
# ✔ DPZ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DPZ.parquet
#
# Processing DRE...
# ✔ DRE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DRE.parquet
#
# Processing DRI...
# ✔ DRI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DRI.parquet
#
# Processing DTE...
# ✔ DTE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DTE.parquet
#
# Processing DTV1...
# ✔ DTV1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DTV1.parquet
#
# Processing DUK...
# ✔ DUK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DUK.parquet
#
# Processing DVA...
# ✔ DVA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DVA.parquet
#
# Processing DVN...
# ✔ DVN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DVN.parquet
#
# Processing DXC...
# ✔ DXC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DXC.parquet
#
# Processing DXCM...
# ✔ DXCM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DXCM.parquet
#
# Processing DYNIQ...
# ✔ DYNIQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\DYNIQ.parquet
#
# Processing EA...
# ✔ EA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EA.parquet
#
# Processing EBAY...
# ✔ EBAY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EBAY.parquet
#
# Processing EC1...
# ✔ EC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EC1.parquet
#
# Processing ECH1...
# ✔ ECH1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ECH1.parquet
#
# Processing ECL...
# ✔ ECL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ECL.parquet
#
# Processing ECO1...
# ✔ ECO1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ECO1.parquet
#
# Processing ED...
# ✔ ED: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ED.parquet
#
# Processing EDS...
# ✔ EDS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EDS.parquet
#
# Processing EFU1...
# ✔ EFU1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EFU1.parquet
#
# Processing EFX...
# ✔ EFX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EFX.parquet
#
# Processing EG...
# ✔ EG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EG.parquet
#
# Processing EHC...
# ✔ EHC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EHC.parquet
#
# Processing EIX...
# ✔ EIX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EIX.parquet
#
# Processing EKDKQ...
# ✔ EKDKQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EKDKQ.parquet
#
# Processing EL...
# ✔ EL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EL.parquet
#
# Processing ELV...
# ✔ ELV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ELV.parquet
#
# Processing EMC1...
# ✔ EMC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EMC1.parquet
#
# Processing EME...
# ✔ EME: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EME.parquet
#
# Processing EMN...
# ✔ EMN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EMN.parquet
#
# Processing EMR...
# ✔ EMR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EMR.parquet
#
# Processing ENDPQ...
# ✔ ENDPQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ENDPQ.parquet
#
# Processing ENPH...
# ✔ ENPH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ENPH.parquet
#
# Processing ENRNQ...
# ✔ ENRNQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ENRNQ.parquet
#
# Processing EOG...
# ✔ EOG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EOG.parquet
#
# Processing EOP...
# ✔ EOP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EOP.parquet
#
# Processing EP1...
# ✔ EP1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EP1.parquet
#
# Processing EPAM...
# ✔ EPAM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EPAM.parquet
#
# Processing EQ1...
# ✔ EQ1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EQ1.parquet
#
# Processing EQIX...
# ✔ EQIX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EQIX.parquet
#
# Processing EQR...
# ✔ EQR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EQR.parquet
#
# Processing EQT...
# ✔ EQT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EQT.parquet
#
# Processing ERIE...
# ✔ ERIE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ERIE.parquet
#
# Processing ES...
# ✔ ES: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ES.parquet
#
# Processing ESRX...
# ✔ ESRX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ESRX.parquet
#
# Processing ESS...
# ✔ ESS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ESS.parquet
#
# Processing ETFC...
# ✔ ETFC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ETFC.parquet
#
# Processing ETN...
# ✔ ETN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ETN.parquet
#
# Processing ETR...
# ✔ ETR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ETR.parquet
#
# Processing ETS1...
# ✔ ETS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ETS1.parquet
#
# Processing ETSY...
# ✔ ETSY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ETSY.parquet
#
# Processing EVHC...
# ✔ EVHC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EVHC.parquet
#
# Processing EVRG...
# ✔ EVRG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EVRG.parquet
#
# Processing EW...
# ✔ EW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EW.parquet
#
# Processing EXC...
# ✔ EXC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EXC.parquet
#
# Processing EXE...
# ✔ EXE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EXE.parquet
#
# Processing EXPD...
# ✔ EXPD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EXPD.parquet
#
# Processing EXPE...
# ✔ EXPE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EXPE.parquet
#
# Processing EXR...
# ✔ EXR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\EXR.parquet
#
# Processing F...
# ✔ F: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\F.parquet
#
# Processing FANG...
# ✔ FANG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FANG.parquet
#
# Processing FAST...
# ✔ FAST: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FAST.parquet
#
# Processing FBF...
# ✔ FBF: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FBF.parquet
#
# Processing FBIN...
# ✔ FBIN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FBIN.parquet
#
# Processing FCN1...
# ✔ FCN1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FCN1.parquet
#
# Processing FCX...
# ✔ FCX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FCX.parquet
#
# Processing FDC1...
# ✔ FDC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FDC1.parquet
#
# Processing FDO...
# ✔ FDO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FDO.parquet
#
# Processing FDS...
# ✔ FDS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FDS.parquet
#
# Processing FDX...
# ✔ FDX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FDX.parquet
#
# Processing FE...
# ✔ FE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FE.parquet
#
# Processing FFIV...
# ✔ FFIV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FFIV.parquet
#
# Processing FG1...
# ⚠ VALIDATION: FG1 | insufficient_history_for_regression | 79 rows, last=1998-04-24
# Processing FHI...
# ✔ FHI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FHI.parquet
#
# Processing FHN...
# ✔ FHN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FHN.parquet
#
# Processing FICO...
# ✔ FICO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FICO.parquet
#
# Processing FIS...
# ✔ FIS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FIS.parquet
#
# Processing FISV...
# ✔ FISV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FISV.parquet
#
# Processing FITB...
# ✔ FITB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FITB.parquet
#
# Processing FIX...
# ✔ FIX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FIX.parquet
#
# Processing FJ...
# ✔ FJ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FJ.parquet
#
# Processing FL...
# ✔ FL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FL.parquet
#
# Processing FLIR...
# ✔ FLIR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FLIR.parquet
#
# Processing FLMIQ...
# ✔ FLMIQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FLMIQ.parquet
#
# Processing FLR...
# ✔ FLR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FLR.parquet
#
# Processing FLS...
# ✔ FLS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FLS.parquet
#
# Processing FLTWQ...
# ✔ FLTWQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FLTWQ.parquet
#
# Processing FMC...
# ✔ FMC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FMC.parquet
#
# Processing FMCC...
# ✔ FMCC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FMCC.parquet
#
# Processing FMY1...
# ✔ FMY1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FMY1.parquet
#
# Processing FNMA...
# ✔ FNMA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FNMA.parquet
#
# Processing FOSL...
# ✔ FOSL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FOSL.parquet
#
# Processing FOX...
# ✔ FOX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FOX.parquet
#
# Processing FOXA...
# ✔ FOXA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FOXA.parquet
#
# Processing FPC...
# ✔ FPC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FPC.parquet
#
# Processing FRCB...
# ✔ FRCB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FRCB.parquet
#
# Processing FRO1...
# ✔ FRO1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FRO1.parquet
#
# Processing FRT...
# ✔ FRT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FRT.parquet
#
# Processing FRX1...
# ✔ FRX1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FRX1.parquet
#
# Processing FSH...
# ✔ FSH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FSH.parquet
#
# Processing FSL.B...
# ✔ FSL.B: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FSL.B.parquet
#
# Processing FSLR...
# ✔ FSLR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FSLR.parquet
#
# Processing FTI...
# ✔ FTI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FTI.parquet
#
# Processing FTI1...
# ✔ FTI1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FTI1.parquet
#
# Processing FTL.A...
# ✔ FTL.A: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FTL.A.parquet
#
# Processing FTNT...
# ✔ FTNT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FTNT.parquet
#
# Processing FTRCQ...
# ✔ FTRCQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FTRCQ.parquet
#
# Processing FTV...
# ✔ FTV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FTV.parquet
#
# Processing FWLT...
# ✔ FWLT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\FWLT.parquet
#
# Processing G1...
# ✔ G1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\G1.parquet
#
# Processing GAP...
# ✔ GAP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\GAP.parquet
#
# Processing GAPTQ...
# ✔ GAPTQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\GAPTQ.parquet
#
# Processing GAS...
# ✔ GAS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\GAS.parquet
#
# Processing GAS1...
# ✔ GAS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\GAS1.parquet
#
# Processing GD...
# ✔ GD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\GD.parquet
#
# Processing GDDY...
# ✔ GDDY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\GDDY.parquet
#
# Processing GDT...
# ✔ GDT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\GDT.parquet
#
# Processing GDW...
# ...
#
# Processing TMO...
# ✔ TMO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TMO.parquet
#
# Processing TMUS...
# ✔ TMUS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TMUS.parquet
#
# Processing TNB...
# ✔ TNB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TNB.parquet
#
# Processing TNL...
# ✔ TNL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TNL.parquet
#
# Processing TOS...
# ✔ TOS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TOS.parquet
#
# Processing TOY...
# ✔ TOY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TOY.parquet
#
# Processing TPL...
# ✔ TPL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TPL.parquet
#
# Processing TPR...
# ✔ TPR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TPR.parquet
#
# Processing TRB...
# ✔ TRB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TRB.parquet
#
# Processing TRGP...
# ✔ TRGP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TRGP.parquet
#
# Processing TRIP...
# ✔ TRIP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TRIP.parquet
#
# Processing TRMB...
# ✔ TRMB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TRMB.parquet
#
# Processing TROW...
# ✔ TROW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TROW.parquet
#
# Processing TRV...
# ✔ TRV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TRV.parquet
#
# Processing TRW1...
# ✔ TRW1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TRW1.parquet
#
# Processing TSCO...
# ✔ TSCO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TSCO.parquet
#
# Processing TSG1...
# ✔ TSG1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TSG1.parquet
#
# Processing TSLA...
# ✔ TSLA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TSLA.parquet
#
# Processing TSN...
# ✔ TSN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TSN.parquet
#
# Processing TSS...
# ✔ TSS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TSS.parquet
#
# Processing TT...
# ✔ TT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TT.parquet
#
# Processing TT2...
# ✔ TT2: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TT2.parquet
#
# Processing TTD...
# ✔ TTD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TTD.parquet
#
# Processing TTWO...
# ✔ TTWO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TTWO.parquet
#
# Processing TUPBQ...
# ✔ TUPBQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TUPBQ.parquet
#
# Processing TWC...
# ✔ TWC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TWC.parquet
#
# Processing TWTR...
# ✔ TWTR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TWTR.parquet
#
# Processing TWX...
# ✔ TWX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TWX.parquet
#
# Processing TWX1...
# ✔ TWX1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TWX1.parquet
#
# Processing TX1...
# ✔ TX1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TX1.parquet
#
# Processing TXN...
# ✔ TXN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TXN.parquet
#
# Processing TXT...
# ✔ TXT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TXT.parquet
#
# Processing TXU...
# ✔ TXU: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TXU.parquet
#
# Processing TYC...
# ✔ TYC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TYC.parquet
#
# Processing TYL...
# ✔ TYL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\TYL.parquet
#
# Processing UA...
# ✔ UA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UA.parquet
#
# Processing UAA...
# ✔ UAA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UAA.parquet
#
# Processing UAL...
# ✔ UAL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UAL.parquet
#
# Processing UAWGQ...
# ✔ UAWGQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UAWGQ.parquet
#
# Processing UBER...
# ✔ UBER: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UBER.parquet
#
# Processing UCC1...
# ✔ UCC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UCC1.parquet
#
# Processing UCL1...
# ✔ UCL1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UCL1.parquet
#
# Processing UCM...
# ✔ UCM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UCM.parquet
#
# Processing UDR...
# ✔ UDR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UDR.parquet
#
# Processing UHS...
# ✔ UHS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UHS.parquet
#
# Processing UIS...
# ✔ UIS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UIS.parquet
#
# Processing UK1...
# ✔ UK1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UK1.parquet
#
# Processing UL...
# ✔ UL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UL.parquet
#
# Processing ULTA...
# ✔ ULTA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ULTA.parquet
#
# Processing UNH...
# ✔ UNH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UNH.parquet
#
# Processing UNM...
# ✔ UNM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UNM.parquet
#
# Processing UNP...
# ✔ UNP: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UNP.parquet
#
# Processing UPC1...
# ✔ UPC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UPC1.parquet
#
# Processing UPR...
# ✔ UPR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UPR.parquet
#
# Processing UPS...
# ✔ UPS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UPS.parquet
#
# Processing URBN...
# ✔ URBN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\URBN.parquet
#
# Processing URI...
# ✔ URI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\URI.parquet
#
# Processing USB...
# ✔ USB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\USB.parquet
#
# Processing USB1...
# ✔ USB1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\USB1.parquet
#
# Processing USG1...
# ✔ USG1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\USG1.parquet
#
# Processing USS1...
# ✔ USS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\USS1.parquet
#
# Processing UST1...
# ✔ UST1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UST1.parquet
#
# Processing USW...
# ✔ USW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\USW.parquet
#
# Processing UVN...
# ✔ UVN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\UVN.parquet
#
# Processing V...
# ✔ V: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\V.parquet
#
# Processing VALPQ...
# ✔ VALPQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VALPQ.parquet
#
# Processing VAR...
# ✔ VAR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VAR.parquet
#
# Processing VFC...
# ✔ VFC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VFC.parquet
#
# Processing VIAB...
# ✔ VIAB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VIAB.parquet
#
# Processing VIAV...
# ✔ VIAV: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VIAV.parquet
#
# Processing VICI...
# ✔ VICI: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VICI.parquet
#
# Processing VLO...
# ✔ VLO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VLO.parquet
#
# Processing VLTO...
# ✔ VLTO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VLTO.parquet
#
# Processing VMC...
# ✔ VMC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VMC.parquet
#
# Processing VNO...
# ✔ VNO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VNO.parquet
#
# Processing VNT...
# ✔ VNT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VNT.parquet
#
# Processing VO1...
# ✔ VO1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VO1.parquet
#
# Processing VRSK...
# ✔ VRSK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VRSK.parquet
#
# Processing VRSN...
# ✔ VRSN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VRSN.parquet
#
# Processing VRTS1...
# ✔ VRTS1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VRTS1.parquet
#
# Processing VRTX...
# ✔ VRTX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VRTX.parquet
#
# Processing VST...
# ✔ VST: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VST.parquet
#
# Processing VSTNQ...
# ✔ VSTNQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VSTNQ.parquet
#
# Processing VTR...
# ✔ VTR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VTR.parquet
#
# Processing VTRS...
# ✔ VTRS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VTRS.parquet
#
# Processing VTSS...
# ✔ VTSS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VTSS.parquet
#
# Processing VYX...
# ✔ VYX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VYX.parquet
#
# Processing VZ...
# ✔ VZ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\VZ.parquet
#
# Processing WAB...
# ✔ WAB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WAB.parquet
#
# Processing WAI1...
# ✔ WAI1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WAI1.parquet
#
# Processing WAMUQ...
# ✔ WAMUQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WAMUQ.parquet
#
# Processing WAT...
# ✔ WAT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WAT.parquet
#
# Processing WB1...
# ✔ WB1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WB1.parquet
#
# Processing WB2...
# ✔ WB2: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WB2.parquet
#
# Processing WBA...
# ✔ WBA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WBA.parquet
#
# Processing WBD...
# ✔ WBD: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WBD.parquet
#
# Processing WCG...
# ✔ WCG: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WCG.parquet
#
# Processing WCOEQ...
# ✔ WCOEQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WCOEQ.parquet
#
# Processing WDAY...
# ✔ WDAY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WDAY.parquet
#
# Processing WDC...
# ✔ WDC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WDC.parquet
#
# Processing WEC...
# ✔ WEC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WEC.parquet
#
# Processing WELL...
# ✔ WELL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WELL.parquet
#
# Processing WEN...
# ✔ WEN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WEN.parquet
#
# Processing WFC...
# ✔ WFC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WFC.parquet
#
# Processing WFC1...
# ✔ WFC1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WFC1.parquet
#
# Processing WFM...
# ✔ WFM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WFM.parquet
#
# Processing WFTIQ...
# ✔ WFTIQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WFTIQ.parquet
#
# Processing WGL...
# ✔ WGL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WGL.parquet
#
# Processing WHR...
# ✔ WHR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WHR.parquet
#
# Processing WINMQ...
# ✔ WINMQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WINMQ.parquet
#
# Processing WLA...
# ✔ WLA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WLA.parquet
#
# Processing WLL1...
# ✔ WLL1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WLL1.parquet
#
# Processing WLP1...
# ✔ WLP1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WLP1.parquet
#
# Processing WM...
# ✔ WM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WM.parquet
#
# Processing WMB...
# ✔ WMB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WMB.parquet
#
# Processing WMT...
# ✔ WMT: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WMT.parquet
#
# Processing WNDXQ...
# ✔ WNDXQ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WNDXQ.parquet
#
# Processing WOR...
# ✔ WOR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WOR.parquet
#
# Processing WPX...
# ✔ WPX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WPX.parquet
#
# Processing WRB...
# ✔ WRB: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WRB.parquet
#
# Processing WRK...
# ✔ WRK: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WRK.parquet
#
# Processing WSM...
# ✔ WSM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WSM.parquet
#
# Processing WST...
# ✔ WST: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WST.parquet
#
# Processing WTW...
# ✔ WTW: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WTW.parquet
#
# Processing WU...
# ✔ WU: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WU.parquet
#
# Processing WWY...
# ✔ WWY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WWY.parquet
#
# Processing WY...
# ✔ WY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WY.parquet
#
# Processing WYE...
# ✔ WYE: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WYE.parquet
#
# Processing WYNN...
# ✔ WYNN: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\WYNN.parquet
#
# Processing X...
# ✔ X: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\X.parquet
#
# Processing XEC...
# ✔ XEC: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XEC.parquet
#
# Processing XEL...
# ✔ XEL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XEL.parquet
#
# Processing XL1...
# ✔ XL1: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XL1.parquet
#
# Processing XLNX...
# ✔ XLNX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XLNX.parquet
#
# Processing XOM...
# ✔ XOM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XOM.parquet
#
# Processing XRAY...
# ✔ XRAY: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XRAY.parquet
#
# Processing XRX...
# ✔ XRX: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XRX.parquet
#
# Processing XTO...
# ✔ XTO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XTO.parquet
#
# Processing XYL...
# ✔ XYL: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XYL.parquet
#
# Processing XYZ...
# ✔ XYZ: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\XYZ.parquet
#
# Processing YHOO...
# ✔ YHOO: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\YHOO.parquet
#
# Processing YNR...
# ✔ YNR: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\YNR.parquet
#
# Processing YUM...
# ✔ YUM: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\YUM.parquet
#
# Processing ZBH...
# ✔ ZBH: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ZBH.parquet
#
# Processing ZBRA...
# ✔ ZBRA: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ZBRA.parquet
#
# Processing ZION...
# ✔ ZION: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ZION.parquet
#
# Processing ZTS...
# ✔ ZTS: saved regression → ./7-90Day_exp_regression_adjusted_all_prices\ZTS.parquet
#
#
# ====================================================
#  90-DAY REGRESSION VALIDATION SUMMARY
# ====================================================
#   ticker                                issue                    detail
# 0   BBI1  insufficient_history_for_regression   7 rows, last=1998-01-09
# 1   CFL1  insufficient_history_for_regression  80 rows, last=1998-04-27
# 2    FG1  insufficient_history_for_regression  79 rows, last=1998-04-24
# 3   ITT1  insufficient_history_for_regression  36 rows, last=1998-02-23
# 4      Q  insufficient_history_for_regression  40 rows, last=2025-12-30
# 5   SOLS  insufficient_history_for_regression  42 rows, last=2025-12-30
#
# Validation log saved to:
# ./system_verification/7-90Day_exp_regression_adjusted_all_prices\regression90_validation-20251231-084045.csv
# ====================================================

# %%
df_abbv = pd.read_parquet("7-90Day_exp_regression_adjusted_all_prices/ABBV.parquet")

# Basic overview
print(f"Rows: {len(df_abbv)}, Columns: {len(df_abbv.columns)}")
print(f"\nColumn names: {list(df_abbv.columns)}")
print(f"\nData types:\n{df_abbv.dtypes}")
print(f"\nFirst few rows:\n{df_abbv.head(91)}")
print(f"\nLast few rows:\n{df_abbv.tail()}")
# Out:
# Rows: 3269, Columns: 18
#
# Column names: ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'closeadj', 'closeunadj', 'lastupdated', 'adj_factor', 'open_adj', 'high_adj', 'low_adj', 'close_adj', 'slope_daily', 'slope_annual', 'r2']
#
# Data types:
# ticker                  object
# date            datetime64[ns]
# open                   float64
# high                   float64
# low                    float64
# close                  float64
# volume                 float64
# closeadj               float64
# closeunadj             float64
# lastupdated     datetime64[ms]
# adj_factor             float64
# open_adj               float64
# high_adj               float64
# low_adj                float64
# close_adj              float64
# slope_daily            float64
# slope_annual           float64
# r2                     float64
# dtype: object
#
# First few rows:
#    ticker       date   open   high    low   close      volume  closeadj  \
# 0    ABBV 2013-01-02  34.92  35.40  34.10  35.120  13768000.0    20.865
# 1    ABBV 2013-01-03  35.00  35.00  34.16  34.830  16739000.0    20.692
# 2    ABBV 2013-01-04  34.62  34.89  34.25  34.391  21372000.0    20.431
# 3    ABBV 2013-01-07  34.15  35.45  34.15  34.460  17897000.0    20.473
# 4    ABBV 2013-01-08  34.29  34.64  33.36  33.710  17863000.0    20.027
# ..    ...        ...    ...    ...    ...     ...         ...       ...
# 86   ABBV 2013-05-07  44.50  45.00  44.42  44.910   3746000.0    27.246
# 87   ABBV 2013-05-08  45.01  45.05  43.39  43.490   6973000.0    26.385
# 88   ABBV 2013-05-09  43.34  44.45  43.25  44.240   5047000.0    26.840
# 89   ABBV 2013-05-10  44.21  45.01  44.20  45.010   4456000.0    27.307
# 90   ABBV 2013-05-13  44.79  44.79  44.17  44.540   3738000.0    27.022
#
#     closeunadj lastupdated  adj_factor   open_adj   high_adj    low_adj  \
# 0       35.120  2025-10-21    0.594106  20.746179  21.031350  20.259012
# 1       34.830  2025-10-21    0.594086  20.792995  20.792995  20.293963
# 2       34.391  2025-10-21    0.594080  20.567044  20.727446  20.347235
# 3       34.460  2025-10-21    0.594109  20.288826  21.061168  20.288826
# 4       33.710  2025-10-21    0.594097  20.371576  20.579510  19.819066
# ..         ...         ...         ...        ...        ...        ...
# 86      44.910  2025-10-21    0.606680  26.997261  27.300601  26.948727
# 87      43.490  2025-10-21    0.606691  27.307171  27.331438  26.324331
# 88      44.240  2025-10-21    0.606691  26.293978  26.967405  26.239376
# 89      45.010  2025-10-21    0.606687  26.821650  27.307000  26.815583
# 90      44.540  2025-10-21    0.606691  27.173673  27.173673  26.797524
#
#     close_adj  slope_daily  slope_annual        r2
# 0      20.865          NaN           NaN       NaN
# 1      20.692          NaN           NaN       NaN
# 2      20.431          NaN           NaN       NaN
# 3      20.473          NaN           NaN       NaN
# 4      20.027          NaN           NaN       NaN
# ..        ...          ...           ...       ...
# 86     27.246          NaN           NaN       NaN
# 87     26.385          NaN           NaN       NaN
# 88     26.840          NaN           NaN       NaN
# 89     27.307     0.003268      1.278319  0.881727
# 90     27.022     0.003282      1.286801  0.883521
#
# [91 rows x 18 columns]
#
# Last few rows:
#      ticker       date    open     high     low   close     volume  closeadj  \
# 3264   ABBV 2025-12-23  228.22  230.790  227.91  228.79  2117000.0    228.79
# 3265   ABBV 2025-12-24  229.46  230.800  228.98  229.89  1745000.0    229.89
# 3266   ABBV 2025-12-26  229.82  230.610  228.68  229.98  1594000.0    229.98
# 3267   ABBV 2025-12-29  230.15  232.020  229.74  230.84  3803000.0    230.84
# 3268   ABBV 2025-12-30  230.77  231.205  228.62  229.74  1790000.0    229.74
#
#       closeunadj lastupdated  adj_factor  open_adj  high_adj  low_adj  \
# 3264      228.79  2025-12-23         1.0    228.22   230.790   227.91
# 3265      229.89  2025-12-24         1.0    229.46   230.800   228.98
# 3266      229.98  2025-12-27         1.0    229.82   230.610   228.68
# 3267      230.84  2025-12-29         1.0    230.15   232.020   229.74
# 3268      229.74  2025-12-30         1.0    230.77   231.205   228.62
#
#       close_adj  slope_daily  slope_annual        r2
# 3264     228.79     0.000989      0.283190  0.422268
# 3265     229.89     0.000953      0.271544  0.408112
# 3266     229.98     0.000914      0.259060  0.393161
# 3267     230.84     0.000886      0.250316  0.381410
# 3268     229.74     0.000855      0.240384  0.367126

# %%
df_abbv.to_csv("ABBV_regression.csv", index=False)
print(f"✔ Exported df_abbv to ABBV_regression.csv")
# Out:
# ✔ Exported df_abbv to ABBV_regression.csv
