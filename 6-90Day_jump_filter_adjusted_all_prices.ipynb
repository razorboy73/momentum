# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime

# ============================================================
# CONFIG
# ============================================================

INPUT_DIR  = "./3-adjusted_All_Prices_OHLC"
OUTPUT_DIR = "./6-90Day_jump_filter_adjusted_all_prices"
VER_DIR    = "./system_verification/6-90Day_jump_filter_adjusted_all_prices"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(VER_DIR, exist_ok=True)

print(f"\nLoading adjusted OHLC files from: {INPUT_DIR}")
files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".parquet")])
print(f"Found {len(files)} tickers.\n")

REQUIRED = {"date", "close_adj"}


# ============================================================
# VALIDATION STORAGE
# ============================================================

validation_rows = []

def add_validation(ticker, issue, detail=""):
    row = {"ticker": ticker, "issue": issue, "detail": detail}
    validation_rows.append(row)
    print(f"⚠ VALIDATION: {ticker} | {issue} | {detail}")


# ============================================================
# FUNCTION: 90-DAY JUMP FILTER
# ============================================================

def compute_jump90(df, ticker):

    # -------------------------------
    # Required columns?
    # -------------------------------
    if not REQUIRED.issubset(df.columns):
        missing = REQUIRED - set(df.columns)
        add_validation(ticker, "missing_required_columns", str(missing))
        return None

    # -------------------------------
    # Date handling
    # -------------------------------
    df["date"] = pd.to_datetime(df["date"])

    if not df["date"].is_monotonic_increasing:
        add_validation(ticker, "non_monotonic_dates")
        df = df.sort_values("date").reset_index(drop=True)

    # -------------------------------
    # Check for invalid close prices
    # -------------------------------
    if (df["close_adj"] <= 0).any():
        n = int((df["close_adj"] <= 0).sum())
        add_validation(ticker, "nonpositive_close_adj", f"{n} rows")

    # -------------------------------
    # Daily percent change
    # -------------------------------
    df["pct_change"] = df["close_adj"].pct_change()
    df["abs_pct"] = df["pct_change"].abs()

    # -------------------------------
    # Detect daily spike (>50%)
    # -------------------------------
    if (df["abs_pct"] > 0.50).any():
        idx = df[df["abs_pct"] > 0.50].index[0]
        spike_date = df.loc[idx, "date"].date()
        spike_val = df.loc[idx, "abs_pct"]
        add_validation(
            ticker,
            "huge_daily_spike",
            f"{spike_val:.2f} on {spike_date}"
        )

    # -------------------------------
    # 90-Day Rolling Max
    # -------------------------------
    df["abs_rollmax_90"] = (
        df["abs_pct"]
        .rolling(window=90, min_periods=90)
        .max()
    )

    # -------------------------------
    # TRADING RULE:
    # must have full 90-day window or stock is NOT tradable
    # -------------------------------
    df["no_big_jump_90"] = (
        (df["abs_rollmax_90"].notna()) & 
        (df["abs_rollmax_90"] <= 0.15)
    )

    return df


# ============================================================
# MAIN LOOP
# ============================================================

for file in files:
    ticker = file.replace(".parquet", "")
    in_path = os.path.join(INPUT_DIR, file)
    out_path = os.path.join(OUTPUT_DIR, f"{ticker}.parquet")

    print(f"Processing {ticker}...")

    try:
        df = pd.read_parquet(in_path)
        df2 = compute_jump90(df, ticker)

        if df2 is not None:
            df2.to_parquet(out_path, index=False)
            print(f"✔ {ticker}: saved jump filter → {out_path}\n")
        else:
            print(f"❌ {ticker}: jump filter not computed.\n")

    except Exception as e:
        add_validation(ticker, "processing_error", str(e))
        print(f"❌ ERROR for {ticker}: {e}\n")


# ============================================================
# SAVE VALIDATION REPORT
# ============================================================

validation_df = pd.DataFrame(validation_rows)

val_file = os.path.join(
    VER_DIR,
    f"jump90_validation-{datetime.now().strftime('%Y%m%d-%H%M%S')}.csv"
)

validation_df.to_csv(val_file, index=False)

print("\n====================================================")
print(" 90-DAY JUMP FILTER VALIDATION SUMMARY")
print("====================================================")

if validation_df.empty:
    print("No validation issues detected.")
else:
    print(validation_df)

print("\nValidation log saved to:")
print(val_file)
print("====================================================\n")
# Out:
# Loading adjusted OHLC files from: ./3-adjusted_All_Prices_OHLC
# Found 1167 tickers.
#
# Processing A...
# ✔ A: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\A.parquet
#
# Processing AAL...
# ✔ AAL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AAL.parquet
#
# Processing AAMRQ...
# ⚠ VALIDATION: AAMRQ | huge_daily_spike | 0.84 on 2011-11-29
# ✔ AAMRQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AAMRQ.parquet
#
# Processing AAP...
# ⚠ VALIDATION: AAP | huge_daily_spike | 0.57 on 2025-05-22
# ✔ AAP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AAP.parquet
#
# Processing AAPL...
# ⚠ VALIDATION: AAPL | huge_daily_spike | 0.52 on 2000-09-29
# ✔ AAPL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AAPL.parquet
#
# Processing ABBV...
# ✔ ABBV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ABBV.parquet
#
# Processing ABI1...
# ✔ ABI1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ABI1.parquet
#
# Processing ABKFQ...
# ⚠ VALIDATION: ABKFQ | huge_daily_spike | 0.52 on 2008-01-17
# ✔ ABKFQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ABKFQ.parquet
#
# Processing ABMD...
# ✔ ABMD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ABMD.parquet
#
# Processing ABNB...
# ✔ ABNB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ABNB.parquet
#
# Processing ABS...
# ✔ ABS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ABS.parquet
#
# Processing ABT...
# ✔ ABT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ABT.parquet
#
# Processing ACAS...
# ✔ ACAS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ACAS.parquet
#
# Processing ACGL...
# ✔ ACGL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ACGL.parquet
#
# Processing ACKHQ...
# ⚠ VALIDATION: ACKHQ | huge_daily_spike | 0.63 on 2002-11-14
# ✔ ACKHQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ACKHQ.parquet
#
# Processing ACN...
# ✔ ACN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ACN.parquet
#
# Processing ACS...
# ✔ ACS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ACS.parquet
#
# Processing ACV1...
# ✔ ACV1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ACV1.parquet
#
# Processing ADBE...
# ✔ ADBE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ADBE.parquet
#
# Processing ADCT1...
# ✔ ADCT1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ADCT1.parquet
#
# Processing ADI...
# ✔ ADI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ADI.parquet
#
# Processing ADM...
# ✔ ADM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ADM.parquet
#
# Processing ADP...
# ✔ ADP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ADP.parquet
#
# Processing ADSK...
# ✔ ADSK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ADSK.parquet
#
# Processing ADT1...
# ✔ ADT1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ADT1.parquet
#
# Processing AEE...
# ✔ AEE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AEE.parquet
#
# Processing AEP...
# ✔ AEP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AEP.parquet
#
# Processing AES...
# ✔ AES: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AES.parquet
#
# Processing AET...
# ✔ AET: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AET.parquet
#
# Processing AFL...
# ✔ AFL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AFL.parquet
#
# Processing AFS.A...
# ✔ AFS.A: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AFS.A.parquet
#
# Processing AGC1...
# ✔ AGC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AGC1.parquet
#
# Processing AGN...
# ✔ AGN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AGN.parquet
#
# Processing AGN1...
# ✔ AGN1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AGN1.parquet
#
# Processing AHM1...
# ✔ AHM1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AHM1.parquet
#
# Processing AIG...
# ⚠ VALIDATION: AIG | huge_daily_spike | 0.61 on 2008-09-15
# ✔ AIG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AIG.parquet
#
# Processing AIT...
# ✔ AIT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AIT.parquet
#
# Processing AIV...
# ✔ AIV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AIV.parquet
#
# Processing AIZ...
# ✔ AIZ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AIZ.parquet
#
# Processing AJG...
# ✔ AJG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AJG.parquet
#
# Processing AKAM...
# ✔ AKAM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AKAM.parquet
#
# Processing AKS...
# ✔ AKS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AKS.parquet
#
# Processing AL1...
# ✔ AL1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AL1.parquet
#
# Processing ALB...
# ✔ ALB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ALB.parquet
#
# Processing ALGN...
# ✔ ALGN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ALGN.parquet
#
# Processing ALK...
# ✔ ALK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ALK.parquet
#
# Processing ALL...
# ✔ ALL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ALL.parquet
#
# Processing ALLE...
# ✔ ALLE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ALLE.parquet
#
# Processing ALTR1...
# ✔ ALTR1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ALTR1.parquet
#
# Processing ALXN...
# ✔ ALXN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ALXN.parquet
#
# Processing AM1...
# ⚠ VALIDATION: AM1 | huge_daily_spike | 0.51 on 2009-06-24
# ✔ AM1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AM1.parquet
#
# Processing AMAT...
# ✔ AMAT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMAT.parquet
#
# Processing AMCC...
# ✔ AMCC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMCC.parquet
#
# Processing AMCR...
# ✔ AMCR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMCR.parquet
#
# Processing AMD...
# ⚠ VALIDATION: AMD | huge_daily_spike | 0.52 on 2016-04-22
# ✔ AMD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMD.parquet
#
# Processing AME...
# ✔ AME: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AME.parquet
#
# Processing AMG...
# ✔ AMG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMG.parquet
#
# Processing AMGN...
# ✔ AMGN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMGN.parquet
#
# Processing AMP...
# ✔ AMP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMP.parquet
#
# Processing AMP1...
# ✔ AMP1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMP1.parquet
#
# Processing AMT...
# ✔ AMT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMT.parquet
#
# Processing AMTM...
# ✔ AMTM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMTM.parquet
#
# Processing AMZN...
# ✔ AMZN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AMZN.parquet
#
# Processing AN...
# ✔ AN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AN.parquet
#
# Processing AN1...
# ✔ AN1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AN1.parquet
#
# Processing ANDV...
# ✔ ANDV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ANDV.parquet
#
# Processing ANDW...
# ✔ ANDW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ANDW.parquet
#
# Processing ANET...
# ✔ ANET: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ANET.parquet
#
# Processing ANF...
# ✔ ANF: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ANF.parquet
#
# Processing ANRZQ...
# ⚠ VALIDATION: ANRZQ | huge_daily_spike | 0.58 on 2015-07-17
# ✔ ANRZQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ANRZQ.parquet
#
# Processing ANSS...
# ✔ ANSS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ANSS.parquet
#
# Processing ANV1...
# ⚠ VALIDATION: ANV1 | huge_daily_spike | 0.59 on 1999-02-01
# ✔ ANV1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ANV1.parquet
#
# Processing AON...
# ✔ AON: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AON.parquet
#
# Processing AOS...
# ✔ AOS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AOS.parquet
#
# Processing APA...
# ⚠ VALIDATION: APA | huge_daily_spike | 0.54 on 2020-03-09
# ✔ APA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APA.parquet
#
# Processing APC...
# ✔ APC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APC.parquet
#
# Processing APCC...
# ✔ APCC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APCC.parquet
#
# Processing APD...
# ✔ APD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APD.parquet
#
# Processing APH...
# ✔ APH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APH.parquet
#
# Processing APO...
# ✔ APO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APO.parquet
#
# Processing APOL...
# ✔ APOL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APOL.parquet
#
# Processing APP...
# ✔ APP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APP.parquet
#
# Processing APTV...
# ✔ APTV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\APTV.parquet
#
# Processing AR1...
# ✔ AR1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AR1.parquet
#
# Processing ARC1...
# ✔ ARC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ARC1.parquet
#
# Processing ARE...
# ✔ ARE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ARE.parquet
#
# Processing ARES...
# ✔ ARES: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ARES.parquet
#
# Processing ARG...
# ✔ ARG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ARG.parquet
#
# Processing AS1...
# ✔ AS1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AS1.parquet
#
# Processing ASC1...
# ✔ ASC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ASC1.parquet
#
# Processing ASH...
# ✔ ASH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ASH.parquet
#
# Processing ASN...
# ✔ ASN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ASN.parquet
#
# Processing ASND1...
# ✔ ASND1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ASND1.parquet
#
# Processing ASO1...
# ✔ ASO1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ASO1.parquet
#
# Processing AT1...
# ✔ AT1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AT1.parquet
#
# Processing ATGE...
# ✔ ATGE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ATGE.parquet
#
# Processing ATI...
# ✔ ATI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ATI.parquet
#
# Processing ATI1...
# ✔ ATI1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ATI1.parquet
#
# Processing ATO...
# ✔ ATO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ATO.parquet
#
# Processing ATVI...
# ✔ ATVI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ATVI.parquet
#
# Processing AV1...
# ✔ AV1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AV1.parquet
#
# Processing AVB...
# ✔ AVB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AVB.parquet
#
# Processing AVGO...
# ✔ AVGO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AVGO.parquet
#
# Processing AVP...
# ✔ AVP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AVP.parquet
#
# Processing AVY...
# ✔ AVY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AVY.parquet
#
# Processing AW...
# ✔ AW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AW.parquet
#
# Processing AWE...
# ✔ AWE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AWE.parquet
#
# Processing AWK...
# ✔ AWK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AWK.parquet
#
# Processing AXON...
# ✔ AXON: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AXON.parquet
#
# Processing AXP...
# ✔ AXP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AXP.parquet
#
# Processing AYE...
# ✔ AYE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AYE.parquet
#
# Processing AYI...
# ✔ AYI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AYI.parquet
#
# Processing AZA.A...
# ✔ AZA.A: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AZA.A.parquet
#
# Processing AZO...
# ✔ AZO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\AZO.parquet
#
# Processing B...
# ✔ B: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\B.parquet
#
# Processing BA...
# ✔ BA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BA.parquet
#
# Processing BAC...
# ✔ BAC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BAC.parquet
#
# Processing BAC1...
# ✔ BAC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BAC1.parquet
#
# Processing BALL...
# ✔ BALL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BALL.parquet
#
# Processing BAX...
# ✔ BAX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BAX.parquet
#
# Processing BAY1...
# ✔ BAY1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BAY1.parquet
#
# Processing BBBYQ...
# ⚠ VALIDATION: BBBYQ | huge_daily_spike | 0.62 on 2021-06-02
# ✔ BBBYQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BBBYQ.parquet
#
# Processing BBI1...
# ✔ BBI1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BBI1.parquet
#
# Processing BBWI...
# ✔ BBWI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BBWI.parquet
#
# Processing BBY...
# ✔ BBY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BBY.parquet
#
# Processing BC...
# ⚠ VALIDATION: BC | huge_daily_spike | 0.52 on 2008-12-02
# ✔ BC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BC.parquet
#
# Processing BCR...
# ✔ BCR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BCR.parquet
#
# Processing BDK...
# ✔ BDK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BDK.parquet
#
# Processing BDX...
# ✔ BDX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BDX.parquet
#
# Processing BEAM2...
# ✔ BEAM2: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BEAM2.parquet
#
# Processing BEN...
# ✔ BEN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BEN.parquet
#
# Processing BF.B...
# ✔ BF.B: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BF.B.parquet
#
# Processing BFH...
# ✔ BFH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BFH.parquet
#
# Processing BFI1...
# ✔ BFI1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BFI1.parquet
#
# Processing BFO1...
# ✔ BFO1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BFO1.parquet
#
# Processing BG...
# ✔ BG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BG.parquet
#
# Processing BGEN...
# ✔ BGEN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BGEN.parquet
#
# Processing BGGSQ...
# ⚠ VALIDATION: BGGSQ | huge_daily_spike | 0.75 on 2020-07-21
# ✔ BGGSQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BGGSQ.parquet
#
# Processing BHF...
# ✔ BHF: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BHF.parquet
#
# Processing BHI...
# ✔ BHI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BHI.parquet
#
# Processing BHMSQ...
# ⚠ VALIDATION: BHMSQ | huge_daily_spike | 0.82 on 2001-10-16
# ✔ BHMSQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BHMSQ.parquet
#
# Processing BIGGQ...
# ✔ BIGGQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BIGGQ.parquet
#
# Processing BIIB...
# ✔ BIIB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BIIB.parquet
#
# Processing BIO...
# ✔ BIO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BIO.parquet
#
# Processing BJS...
# ✔ BJS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BJS.parquet
#
# Processing BK...
# ✔ BK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BK.parquet
#
# Processing BKB...
# ✔ BKB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BKB.parquet
#
# Processing BKNG...
# ✔ BKNG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BKNG.parquet
#
# Processing BKR...
# ✔ BKR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BKR.parquet
#
# Processing BLDR...
# ⚠ VALIDATION: BLDR | huge_daily_spike | 0.68 on 2015-04-13
# ✔ BLDR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BLDR.parquet
#
# Processing BLK...
# ✔ BLK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BLK.parquet
#
# Processing BLS...
# ✔ BLS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BLS.parquet
#
# Processing BMC...
# ✔ BMC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BMC.parquet
#
# Processing BMET...
# ✔ BMET: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BMET.parquet
#
# Processing BMGCA...
# ⚠ VALIDATION: BMGCA | huge_daily_spike | 0.60 on 1999-09-27
# ✔ BMGCA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BMGCA.parquet
#
# Processing BMS...
# ✔ BMS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BMS.parquet
#
# Processing BMY...
# ✔ BMY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BMY.parquet
#
# Processing BNI...
# ✔ BNI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BNI.parquet
#
# Processing BNL1...
# ✔ BNL1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BNL1.parquet
#
# Processing BOL...
# ✔ BOL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BOL.parquet
#
# Processing BR...
# ✔ BR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BR.parquet
#
# Processing BR1...
# ✔ BR1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BR1.parquet
#
# Processing BRCM...
# ✔ BRCM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BRCM.parquet
#
# Processing BRK.B...
# ✔ BRK.B: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BRK.B.parquet
#
# Processing BRL...
# ⚠ VALIDATION: BRL | huge_daily_spike | 0.66 on 2000-08-09
# ✔ BRL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BRL.parquet
#
# Processing BRO...
# ✔ BRO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BRO.parquet
#
# Processing BSC1...
# ⚠ VALIDATION: BSC1 | huge_daily_spike | 0.84 on 2008-03-17
# ✔ BSC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BSC1.parquet
#
# Processing BSX...
# ✔ BSX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BSX.parquet
#
# Processing BT1...
# ✔ BT1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BT1.parquet
#
# Processing BTUUQ...
# ⚠ VALIDATION: BTUUQ | huge_daily_spike | 0.60 on 2016-04-14
# ✔ BTUUQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BTUUQ.parquet
#
# Processing BUD1...
# ✔ BUD1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BUD1.parquet
#
# Processing BVSN...
# ⚠ VALIDATION: BVSN | huge_daily_spike | 0.70 on 2005-11-21
# ✔ BVSN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BVSN.parquet
#
# Processing BWA...
# ✔ BWA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BWA.parquet
#
# Processing BX...
# ✔ BX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BX.parquet
#
# Processing BXLT...
# ✔ BXLT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BXLT.parquet
#
# Processing BXP...
# ✔ BXP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\BXP.parquet
#
# Processing C...
# ⚠ VALIDATION: C | huge_daily_spike | 0.58 on 2008-11-24
# ✔ C: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\C.parquet
#
# Processing C1...
# ✔ C1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\C1.parquet
#
# Processing CA1...
# ✔ CA1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CA1.parquet
#
# Processing CAG...
# ✔ CAG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CAG.parquet
#
# Processing CAH...
# ✔ CAH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CAH.parquet
#
# Processing CAL...
# ✔ CAL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CAL.parquet
#
# Processing CAM2...
# ✔ CAM2: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CAM2.parquet
#
# Processing CAR...
# ⚠ VALIDATION: CAR | huge_daily_spike | 0.98 on 2009-03-20
# ✔ CAR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CAR.parquet
#
# Processing CARR...
# ✔ CARR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CARR.parquet
#
# Processing CAT...
# ✔ CAT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CAT.parquet
#
# Processing CB...
# ✔ CB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CB.parquet
#
# Processing CB1...
# ✔ CB1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CB1.parquet
#
# Processing CBE...
# ✔ CBE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CBE.parquet
#
# Processing CBH1...
# ✔ CBH1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CBH1.parquet
#
# Processing CBOE...
# ✔ CBOE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CBOE.parquet
#
# Processing CBRE...
# ⚠ VALIDATION: CBRE | huge_daily_spike | 0.64 on 2009-03-25
# ✔ CBRE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CBRE.parquet
#
# Processing CBS1...
# ✔ CBS1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CBS1.parquet
#
# Processing CBSS...
# ✔ CBSS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CBSS.parquet
#
# Processing CCE1...
# ✔ CCE1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CCE1.parquet
#
# Processing CCI...
# ✔ CCI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CCI.parquet
#
# Processing CCI1...
# ✔ CCI1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CCI1.parquet
#
# Processing CCK...
# ✔ CCK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CCK.parquet
#
# Processing CCL...
# ✔ CCL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CCL.parquet
#
# Processing CCTYQ...
# ⚠ VALIDATION: CCTYQ | huge_daily_spike | 0.60 on 2008-11-10
# ✔ CCTYQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CCTYQ.parquet
#
# Processing CCU1...
# ✔ CCU1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CCU1.parquet
#
# Processing CDNS...
# ✔ CDNS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CDNS.parquet
#
# Processing CDW...
# ✔ CDW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CDW.parquet
#
# Processing CE...
# ✔ CE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CE.parquet
#
# Processing CE1...
# ✔ CE1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CE1.parquet
#
# Processing CEG...
# ✔ CEG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CEG.parquet
#
# Processing CEG1...
# ✔ CEG1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CEG1.parquet
#
# Processing CELG...
# ✔ CELG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CELG.parquet
#
# Processing CEM1...
# ✔ CEM1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CEM1.parquet
#
# Processing CEN1...
# ✔ CEN1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CEN1.parquet
#
# Processing CEPH...
# ✔ CEPH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CEPH.parquet
#
# Processing CERN...
# ✔ CERN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CERN.parquet
#
# Processing CF...
# ✔ CF: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CF.parquet
#
# Processing CF1...
# ✔ CF1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CF1.parquet
#
# Processing CFC...
# ⚠ VALIDATION: CFC | huge_daily_spike | 0.51 on 2008-01-10
# ✔ CFC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CFC.parquet
#
# Processing CFG...
# ✔ CFG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CFG.parquet
#
# Processing CFL1...
# ✔ CFL1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CFL1.parquet
#
# Processing CFN...
# ✔ CFN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CFN.parquet
#
# Processing CG1...
# ✔ CG1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CG1.parquet
#
# Processing CGP...
# ✔ CGP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CGP.parquet
#
# Processing CHA1...
# ✔ CHA1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CHA1.parquet
#
# Processing CHD...
# ✔ CHD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CHD.parquet
#
# Processing CHIR1...
# ✔ CHIR1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CHIR1.parquet
#
# Processing CHKAQ...
# ⚠ VALIDATION: CHKAQ | huge_daily_spike | 0.77 on 2020-06-05
# ✔ CHKAQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CHKAQ.parquet
#
# Processing CHRS1...
# ⚠ VALIDATION: CHRS1 | huge_daily_spike | 0.52 on 2008-12-19
# ✔ CHRS1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CHRS1.parquet
#
# Processing CHRW...
# ✔ CHRW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CHRW.parquet
#
# Processing CHTR...
# ✔ CHTR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CHTR.parquet
#
# Processing CI...
# ✔ CI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CI.parquet
#
# Processing CIEN...
# ✔ CIEN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CIEN.parquet
#
# Processing CIN...
# ✔ CIN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CIN.parquet
#
# Processing CINF...
# ✔ CINF: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CINF.parquet
#
# Processing CIT.A...
# ✔ CIT.A: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CIT.A.parquet
#
# Processing CITGQ...
# ⚠ VALIDATION: CITGQ | huge_daily_spike | 0.62 on 2008-10-17
# ✔ CITGQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CITGQ.parquet
#
# Processing CL...
# ✔ CL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CL.parquet
#
# Processing CLF...
# ✔ CLF: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CLF.parquet
#
# Processing CLX...
# ✔ CLX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CLX.parquet
#
# Processing CMA...
# ✔ CMA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMA.parquet
#
# Processing CMCSA...
# ✔ CMCSA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMCSA.parquet
#
# Processing CMCSK...
# ⚠ VALIDATION: CMCSK | huge_daily_spike | 0.50 on 2004-08-03
# ✔ CMCSK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMCSK.parquet
#
# Processing CME...
# ✔ CME: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CME.parquet
#
# Processing CMG...
# ✔ CMG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMG.parquet
#
# Processing CMI...
# ✔ CMI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMI.parquet
#
# Processing CMS...
# ✔ CMS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMS.parquet
#
# Processing CMVT...
# ✔ CMVT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMVT.parquet
#
# Processing CMX...
# ✔ CMX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CMX.parquet
#
# Processing CNC...
# ✔ CNC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CNC.parquet
#
# Processing CNCEQ...
# ✔ CNCEQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CNCEQ.parquet
#
# Processing CNG...
# ✔ CNG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CNG.parquet
#
# Processing CNP...
# ⚠ VALIDATION: CNP | huge_daily_spike | 0.63 on 2002-07-25
# ✔ CNP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CNP.parquet
#
# Processing CNW...
# ✔ CNW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CNW.parquet
#
# Processing CNX...
# ✔ CNX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CNX.parquet
#
# Processing CNXT1...
# ⚠ VALIDATION: CNXT1 | huge_daily_spike | 0.58 on 2002-10-10
# ✔ CNXT1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CNXT1.parquet
#
# Processing COC...
# ✔ COC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COC.parquet
#
# Processing COF...
# ✔ COF: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COF.parquet
#
# Processing COIN...
# ✔ COIN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COIN.parquet
#
# Processing COL...
# ✔ COL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COL.parquet
#
# Processing COMS1...
# ✔ COMS1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COMS1.parquet
#
# Processing COO...
# ✔ COO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COO.parquet
#
# Processing COP...
# ✔ COP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COP.parquet
#
# Processing COR...
# ✔ COR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COR.parquet
#
# Processing COST...
# ✔ COST: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COST.parquet
#
# Processing COT1...
# ✔ COT1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COT1.parquet
#
# Processing COTY...
# ✔ COTY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COTY.parquet
#
# Processing COV...
# ✔ COV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\COV.parquet
#
# Processing CPAY...
# ✔ CPAY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPAY.parquet
#
# Processing CPB...
# ✔ CPB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPB.parquet
#
# Processing CPGX...
# ✔ CPGX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPGX.parquet
#
# Processing CPNLQ...
# ⚠ VALIDATION: CPNLQ | huge_daily_spike | 0.57 on 2005-11-29
# ✔ CPNLQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPNLQ.parquet
#
# Processing CPPRQ...
# ⚠ VALIDATION: CPPRQ | huge_daily_spike | 0.73 on 2020-05-20
# ✔ CPPRQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPPRQ.parquet
#
# Processing CPQ...
# ✔ CPQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPQ.parquet
#
# Processing CPRI...
# ⚠ VALIDATION: CPRI | huge_daily_spike | 0.56 on 2023-08-10
# ✔ CPRI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPRI.parquet
#
# Processing CPRT...
# ✔ CPRT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPRT.parquet
#
# Processing CPT...
# ✔ CPT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPT.parquet
#
# Processing CPWR...
# ✔ CPWR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CPWR.parquet
#
# Processing CRH...
# ✔ CRH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CRH.parquet
#
# Processing CRL...
# ✔ CRL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CRL.parquet
#
# Processing CRM...
# ✔ CRM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CRM.parquet
#
# Processing CRWD...
# ✔ CRWD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CRWD.parquet
#
# Processing CSC...
# ✔ CSC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CSC.parquet
#
# Processing CSCO...
# ✔ CSCO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CSCO.parquet
#
# Processing CSE1...
# ✔ CSE1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CSE1.parquet
#
# Processing CSGP...
# ✔ CSGP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CSGP.parquet
#
# Processing CSR1...
# ✔ CSR1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CSR1.parquet
#
# Processing CSRA...
# ✔ CSRA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CSRA.parquet
#
# Processing CSX...
# ✔ CSX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CSX.parquet
#
# Processing CTAS...
# ✔ CTAS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTAS.parquet
#
# Processing CTB...
# ✔ CTB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTB.parquet
#
# Processing CTLT...
# ✔ CTLT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTLT.parquet
#
# Processing CTRA...
# ✔ CTRA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTRA.parquet
#
# Processing CTSH...
# ✔ CTSH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTSH.parquet
#
# Processing CTVA...
# ✔ CTVA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTVA.parquet
#
# Processing CTX1...
# ✔ CTX1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTX1.parquet
#
# Processing CTXS...
# ✔ CTXS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CTXS.parquet
#
# Processing CVC...
# ✔ CVC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CVC.parquet
#
# Processing CVG...
# ✔ CVG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CVG.parquet
#
# Processing CVGYQ...
# ⚠ VALIDATION: CVGYQ | huge_daily_spike | 0.60 on 2001-12-24
# ✔ CVGYQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CVGYQ.parquet
#
# Processing CVH...
# ⚠ VALIDATION: CVH | huge_daily_spike | 0.51 on 2008-10-22
# ✔ CVH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CVH.parquet
#
# Processing CVNA...
# ⚠ VALIDATION: CVNA | huge_daily_spike | 0.56 on 2023-06-08
# ✔ CVNA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CVNA.parquet
#
# Processing CVS...
# ✔ CVS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CVS.parquet
#
# Processing CVX...
# ✔ CVX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CVX.parquet
#
# Processing CXO...
# ✔ CXO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CXO.parquet
#
# Processing CXT...
# ✔ CXT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CXT.parquet
#
# Processing CYM...
# ✔ CYM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CYM.parquet
#
# Processing CZR...
# ✔ CZR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\CZR.parquet
#
# Processing D...
# ✔ D: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\D.parquet
#
# Processing DAL...
# ✔ DAL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DAL.parquet
#
# Processing DALRQ...
# ⚠ VALIDATION: DALRQ | huge_daily_spike | 0.59 on 2007-04-26
# ✔ DALRQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DALRQ.parquet
#
# Processing DASH...
# ✔ DASH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DASH.parquet
#
# Processing DAY...
# ✔ DAY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DAY.parquet
#
# Processing DCNAQ...
# ⚠ VALIDATION: DCNAQ | huge_daily_spike | 0.52 on 2006-02-24
# ✔ DCNAQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DCNAQ.parquet
#
# Processing DD...
# ✔ DD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DD.parquet
#
# Processing DD1...
# ✔ DD1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DD1.parquet
#
# Processing DDOG...
# ✔ DDOG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DDOG.parquet
#
# Processing DDS...
# ✔ DDS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DDS.parquet
#
# Processing DE...
# ✔ DE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DE.parquet
#
# Processing DEC1...
# ✔ DEC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DEC1.parquet
#
# Processing DECK...
# ⚠ VALIDATION: DECK | huge_daily_spike | 0.54 on 1998-10-13
# ✔ DECK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DECK.parquet
#
# Processing DELL...
# ✔ DELL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DELL.parquet
#
# Processing DELL1...
# ✔ DELL1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DELL1.parquet
#
# Processing DFODQ...
# ⚠ VALIDATION: DFODQ | huge_daily_spike | 0.88 on 2019-11-13
# ✔ DFODQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DFODQ.parquet
#
# Processing DFS...
# ✔ DFS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DFS.parquet
#
# Processing DG...
# ✔ DG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DG.parquet
#
# Processing DG1...
# ✔ DG1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DG1.parquet
#
# Processing DGN...
# ✔ DGN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DGN.parquet
#
# Processing DGX...
# ✔ DGX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DGX.parquet
#
# Processing DHI...
# ✔ DHI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DHI.parquet
#
# Processing DHR...
# ✔ DHR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DHR.parquet
#
# Processing DI1...
# ✔ DI1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DI1.parquet
#
# Processing DIGI2...
# ✔ DIGI2: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DIGI2.parquet
#
# Processing DINO...
# ✔ DINO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DINO.parquet
#
# Processing DIS...
# ✔ DIS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DIS.parquet
#
# Processing DISCK...
# ✔ DISCK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DISCK.parquet
#
# Processing DISH...
# ✔ DISH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DISH.parquet
#
# Processing DJ...
# ⚠ VALIDATION: DJ | huge_daily_spike | 0.55 on 2007-05-01
# ✔ DJ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DJ.parquet
#
# Processing DLR...
# ✔ DLR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DLR.parquet
#
# Processing DLTR...
# ✔ DLTR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DLTR.parquet
#
# Processing DLX...
# ✔ DLX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DLX.parquet
#
# Processing DNB1...
# ✔ DNB1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DNB1.parquet
#
# Processing DNB2...
# ✔ DNB2: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DNB2.parquet
#
# Processing DNB3...
# ✔ DNB3: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DNB3.parquet
#
# Processing DNRCQ...
# ⚠ VALIDATION: DNRCQ | huge_daily_spike | 0.53 on 2016-03-04
# ✔ DNRCQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DNRCQ.parquet
#
# Processing DOC...
# ✔ DOC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DOC.parquet
#
# Processing DOFSQ...
# ⚠ VALIDATION: DOFSQ | huge_daily_spike | 1.65 on 2020-03-13
# ✔ DOFSQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DOFSQ.parquet
#
# Processing DOV...
# ✔ DOV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DOV.parquet
#
# Processing DOW...
# ✔ DOW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DOW.parquet
#
# Processing DPHIQ...
# ⚠ VALIDATION: DPHIQ | huge_daily_spike | 0.71 on 2005-10-10
# ✔ DPHIQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DPHIQ.parquet
#
# Processing DPZ...
# ✔ DPZ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DPZ.parquet
#
# Processing DRE...
# ✔ DRE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DRE.parquet
#
# Processing DRI...
# ✔ DRI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DRI.parquet
#
# Processing DTE...
# ✔ DTE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DTE.parquet
#
# Processing DTV1...
# ✔ DTV1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DTV1.parquet
#
# Processing DUK...
# ✔ DUK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DUK.parquet
#
# Processing DVA...
# ⚠ VALIDATION: DVA | huge_daily_spike | 0.58 on 1999-02-18
# ✔ DVA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DVA.parquet
#
# Processing DVN...
# ✔ DVN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DVN.parquet
#
# Processing DXC...
# ✔ DXC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DXC.parquet
#
# Processing DXCM...
# ⚠ VALIDATION: DXCM | huge_daily_spike | 0.51 on 2008-12-04
# ✔ DXCM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DXCM.parquet
#
# Processing DYNIQ...
# ⚠ VALIDATION: DYNIQ | huge_daily_spike | 0.64 on 2002-07-23
# ✔ DYNIQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\DYNIQ.parquet
#
# Processing EA...
# ✔ EA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EA.parquet
#
# Processing EBAY...
# ✔ EBAY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EBAY.parquet
#
# Processing EC1...
# ✔ EC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EC1.parquet
#
# Processing ECH1...
# ✔ ECH1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ECH1.parquet
#
# Processing ECL...
# ✔ ECL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ECL.parquet
#
# Processing ECO1...
# ⚠ VALIDATION: ECO1 | huge_daily_spike | 0.70 on 1999-09-27
# ✔ ECO1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ECO1.parquet
#
# Processing ED...
# ✔ ED: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ED.parquet
#
# Processing EDS...
# ⚠ VALIDATION: EDS | huge_daily_spike | 0.53 on 2002-09-19
# ✔ EDS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EDS.parquet
#
# Processing EFU1...
# ✔ EFU1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EFU1.parquet
#
# Processing EFX...
# ✔ EFX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EFX.parquet
#
# Processing EG...
# ✔ EG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EG.parquet
#
# Processing EHC...
# ⚠ VALIDATION: EHC | huge_daily_spike | 0.97 on 2003-03-26
# ✔ EHC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EHC.parquet
#
# Processing EIX...
# ✔ EIX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EIX.parquet
#
# Processing EKDKQ...
# ⚠ VALIDATION: EKDKQ | huge_daily_spike | 0.54 on 2011-09-30
# ✔ EKDKQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EKDKQ.parquet
#
# Processing EL...
# ✔ EL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EL.parquet
#
# Processing ELV...
# ✔ ELV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ELV.parquet
#
# Processing EMC1...
# ✔ EMC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EMC1.parquet
#
# Processing EME...
# ✔ EME: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EME.parquet
#
# Processing EMN...
# ✔ EMN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EMN.parquet
#
# Processing EMR...
# ✔ EMR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EMR.parquet
#
# Processing ENDPQ...
# ⚠ VALIDATION: ENDPQ | huge_daily_spike | 0.85 on 2022-06-28
# ✔ ENDPQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ENDPQ.parquet
#
# Processing ENPH...
# ✔ ENPH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ENPH.parquet
#
# Processing ENRNQ...
# ⚠ VALIDATION: ENRNQ | huge_daily_spike | 0.85 on 2001-11-28
# ✔ ENRNQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ENRNQ.parquet
#
# Processing EOG...
# ✔ EOG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EOG.parquet
#
# Processing EOP...
# ✔ EOP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EOP.parquet
#
# Processing EP1...
# ✔ EP1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EP1.parquet
#
# Processing EPAM...
# ✔ EPAM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EPAM.parquet
#
# Processing EQ1...
# ✔ EQ1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EQ1.parquet
#
# Processing EQIX...
# ⚠ VALIDATION: EQIX | huge_daily_spike | 0.56 on 2001-04-09
# ✔ EQIX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EQIX.parquet
#
# Processing EQR...
# ✔ EQR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EQR.parquet
#
# Processing EQT...
# ✔ EQT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EQT.parquet
#
# Processing ERIE...
# ✔ ERIE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ERIE.parquet
#
# Processing ES...
# ✔ ES: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ES.parquet
#
# Processing ESRX...
# ✔ ESRX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ESRX.parquet
#
# Processing ESS...
# ✔ ESS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ESS.parquet
#
# Processing ETFC...
# ⚠ VALIDATION: ETFC | huge_daily_spike | 0.59 on 2007-11-12
# ✔ ETFC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ETFC.parquet
#
# Processing ETN...
# ✔ ETN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ETN.parquet
#
# Processing ETR...
# ✔ ETR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ETR.parquet
#
# Processing ETS1...
# ⚠ VALIDATION: ETS1 | huge_daily_spike | 0.61 on 2002-02-04
# ✔ ETS1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ETS1.parquet
#
# Processing ETSY...
# ✔ ETSY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ETSY.parquet
#
# Processing EVHC...
# ✔ EVHC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EVHC.parquet
#
# Processing EVRG...
# ✔ EVRG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EVRG.parquet
#
# Processing EW...
# ✔ EW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EW.parquet
#
# Processing EXC...
# ✔ EXC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EXC.parquet
#
# Processing EXE...
# ✔ EXE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EXE.parquet
#
# Processing EXPD...
# ✔ EXPD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EXPD.parquet
#
# Processing EXPE...
# ✔ EXPE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EXPE.parquet
#
# Processing EXR...
# ✔ EXR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\EXR.parquet
#
# Processing F...
# ✔ F: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\F.parquet
#
# Processing FANG...
# ✔ FANG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FANG.parquet
#
# Processing FAST...
# ✔ FAST: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FAST.parquet
#
# Processing FBF...
# ✔ FBF: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FBF.parquet
#
# Processing FBIN...
# ✔ FBIN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FBIN.parquet
#
# Processing FCN1...
# ✔ FCN1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FCN1.parquet
#
# Processing FCX...
# ✔ FCX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FCX.parquet
#
# Processing FDC1...
# ✔ FDC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FDC1.parquet
#
# Processing FDO...
# ✔ FDO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FDO.parquet
#
# Processing FDS...
# ✔ FDS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FDS.parquet
#
# Processing FDX...
# ✔ FDX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FDX.parquet
#
# Processing FE...
# ✔ FE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FE.parquet
#
# Processing FFIV...
# ✔ FFIV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FFIV.parquet
#
# Processing FG1...
# ✔ FG1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FG1.parquet
#
# Processing FHI...
# ✔ FHI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FHI.parquet
#
# Processing FHN...
# ✔ FHN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FHN.parquet
#
# Processing FICO...
# ✔ FICO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FICO.parquet
#
# Processing FIS...
# ✔ FIS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FIS.parquet
#
# Processing FISV...
# ✔ FISV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FISV.parquet
#
# Processing FITB...
# ⚠ VALIDATION: FITB | huge_daily_spike | 0.60 on 2009-02-06
# ✔ FITB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FITB.parquet
#
# Processing FIX...
# ✔ FIX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FIX.parquet
#
# Processing FJ...
# ✔ FJ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FJ.parquet
#
# Processing FL...
# ⚠ VALIDATION: FL | huge_daily_spike | 0.86 on 2025-05-15
# ✔ FL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FL.parquet
#
# Processing FLIR...
# ✔ FLIR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FLIR.parquet
#
# Processing FLMIQ...
# ⚠ VALIDATION: FLMIQ | huge_daily_spike | 1.08 on 2003-11-06
# ✔ FLMIQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FLMIQ.parquet
#
# Processing FLR...
# ⚠ VALIDATION: FLR | huge_daily_spike | 0.76 on 2020-03-19
# ✔ FLR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FLR.parquet
#
# Processing FLS...
# ✔ FLS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FLS.parquet
#
# Processing FLTWQ...
# ⚠ VALIDATION: FLTWQ | huge_daily_spike | 1.17 on 2008-12-02
# ✔ FLTWQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FLTWQ.parquet
#
# Processing FMC...
# ✔ FMC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FMC.parquet
#
# Processing FMCC...
# ⚠ VALIDATION: FMCC | huge_daily_spike | 0.83 on 2008-09-08
# ✔ FMCC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\FMCC.parquet
#
# Processing FMY1...
# ...
# ✔ TRGP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TRGP.parquet
#
# Processing TRIP...
# ✔ TRIP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TRIP.parquet
#
# Processing TRMB...
# ✔ TRMB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TRMB.parquet
#
# Processing TROW...
# ✔ TROW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TROW.parquet
#
# Processing TRV...
# ✔ TRV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TRV.parquet
#
# Processing TRW1...
# ✔ TRW1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TRW1.parquet
#
# Processing TSCO...
# ✔ TSCO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TSCO.parquet
#
# Processing TSG1...
# ✔ TSG1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TSG1.parquet
#
# Processing TSLA...
# ✔ TSLA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TSLA.parquet
#
# Processing TSN...
# ✔ TSN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TSN.parquet
#
# Processing TSS...
# ✔ TSS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TSS.parquet
#
# Processing TT...
# ✔ TT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TT.parquet
#
# Processing TT2...
# ✔ TT2: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TT2.parquet
#
# Processing TTD...
# ✔ TTD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TTD.parquet
#
# Processing TTWO...
# ⚠ VALIDATION: TTWO | huge_daily_spike | 0.55 on 2008-02-25
# ✔ TTWO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TTWO.parquet
#
# Processing TUPBQ...
# ⚠ VALIDATION: TUPBQ | huge_daily_spike | 0.54 on 2020-04-09
# ✔ TUPBQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TUPBQ.parquet
#
# Processing TWC...
# ✔ TWC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TWC.parquet
#
# Processing TWTR...
# ✔ TWTR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TWTR.parquet
#
# Processing TWX...
# ✔ TWX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TWX.parquet
#
# Processing TWX1...
# ✔ TWX1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TWX1.parquet
#
# Processing TX1...
# ✔ TX1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TX1.parquet
#
# Processing TXN...
# ✔ TXN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TXN.parquet
#
# Processing TXT...
# ✔ TXT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TXT.parquet
#
# Processing TXU...
# ✔ TXU: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TXU.parquet
#
# Processing TYC...
# ✔ TYC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TYC.parquet
#
# Processing TYL...
# ✔ TYL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\TYL.parquet
#
# Processing UA...
# ✔ UA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UA.parquet
#
# Processing UAA...
# ✔ UAA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UAA.parquet
#
# Processing UAL...
# ⚠ VALIDATION: UAL | huge_daily_spike | 0.69 on 2008-07-22
# ✔ UAL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UAL.parquet
#
# Processing UAWGQ...
# ⚠ VALIDATION: UAWGQ | huge_daily_spike | 0.89 on 2000-05-24
# ✔ UAWGQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UAWGQ.parquet
#
# Processing UBER...
# ✔ UBER: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UBER.parquet
#
# Processing UCC1...
# ✔ UCC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UCC1.parquet
#
# Processing UCL1...
# ✔ UCL1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UCL1.parquet
#
# Processing UCM...
# ✔ UCM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UCM.parquet
#
# Processing UDR...
# ✔ UDR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UDR.parquet
#
# Processing UHS...
# ✔ UHS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UHS.parquet
#
# Processing UIS...
# ⚠ VALIDATION: UIS | huge_daily_spike | 0.69 on 2009-04-16
# ✔ UIS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UIS.parquet
#
# Processing UK1...
# ✔ UK1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UK1.parquet
#
# Processing UL...
# ✔ UL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UL.parquet
#
# Processing ULTA...
# ✔ ULTA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ULTA.parquet
#
# Processing UNH...
# ✔ UNH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UNH.parquet
#
# Processing UNM...
# ✔ UNM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UNM.parquet
#
# Processing UNP...
# ✔ UNP: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UNP.parquet
#
# Processing UPC1...
# ✔ UPC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UPC1.parquet
#
# Processing UPR...
# ✔ UPR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UPR.parquet
#
# Processing UPS...
# ✔ UPS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UPS.parquet
#
# Processing URBN...
# ✔ URBN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\URBN.parquet
#
# Processing URI...
# ✔ URI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\URI.parquet
#
# Processing USB...
# ✔ USB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\USB.parquet
#
# Processing USB1...
# ✔ USB1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\USB1.parquet
#
# Processing USG1...
# ✔ USG1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\USG1.parquet
#
# Processing USS1...
# ✔ USS1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\USS1.parquet
#
# Processing UST1...
# ✔ UST1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UST1.parquet
#
# Processing USW...
# ✔ USW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\USW.parquet
#
# Processing UVN...
# ✔ UVN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\UVN.parquet
#
# Processing V...
# ✔ V: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\V.parquet
#
# Processing VALPQ...
# ⚠ VALIDATION: VALPQ | huge_daily_spike | 1.62 on 2020-06-05
# ✔ VALPQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VALPQ.parquet
#
# Processing VAR...
# ⚠ VALIDATION: VAR | huge_daily_spike | 0.53 on 1999-04-05
# ✔ VAR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VAR.parquet
#
# Processing VFC...
# ✔ VFC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VFC.parquet
#
# Processing VIAB...
# ✔ VIAB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VIAB.parquet
#
# Processing VIAV...
# ✔ VIAV: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VIAV.parquet
#
# Processing VICI...
# ✔ VICI: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VICI.parquet
#
# Processing VLO...
# ✔ VLO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VLO.parquet
#
# Processing VLTO...
# ✔ VLTO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VLTO.parquet
#
# Processing VMC...
# ✔ VMC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VMC.parquet
#
# Processing VNO...
# ✔ VNO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VNO.parquet
#
# Processing VNT...
# ✔ VNT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VNT.parquet
#
# Processing VO1...
# ✔ VO1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VO1.parquet
#
# Processing VRSK...
# ✔ VRSK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VRSK.parquet
#
# Processing VRSN...
# ✔ VRSN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VRSN.parquet
#
# Processing VRTS1...
# ✔ VRTS1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VRTS1.parquet
#
# Processing VRTX...
# ⚠ VALIDATION: VRTX | huge_daily_spike | 0.55 on 2012-05-07
# ✔ VRTX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VRTX.parquet
#
# Processing VST...
# ✔ VST: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VST.parquet
#
# Processing VSTNQ...
# ⚠ VALIDATION: VSTNQ | huge_daily_spike | 0.71 on 2009-03-05
# ✔ VSTNQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VSTNQ.parquet
#
# Processing VTR...
# ✔ VTR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VTR.parquet
#
# Processing VTRS...
# ✔ VTRS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VTRS.parquet
#
# Processing VTSS...
# ⚠ VALIDATION: VTSS | huge_daily_spike | 0.55 on 2008-12-19
# ✔ VTSS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VTSS.parquet
#
# Processing VYX...
# ✔ VYX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VYX.parquet
#
# Processing VZ...
# ✔ VZ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\VZ.parquet
#
# Processing WAB...
# ✔ WAB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WAB.parquet
#
# Processing WAI1...
# ✔ WAI1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WAI1.parquet
#
# Processing WAMUQ...
# ⚠ VALIDATION: WAMUQ | huge_daily_spike | 0.91 on 2008-09-26
# ✔ WAMUQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WAMUQ.parquet
#
# Processing WAT...
# ✔ WAT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WAT.parquet
#
# Processing WB1...
# ⚠ VALIDATION: WB1 | huge_daily_spike | 0.59 on 2008-09-18
# ✔ WB1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WB1.parquet
#
# Processing WB2...
# ✔ WB2: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WB2.parquet
#
# Processing WBA...
# ✔ WBA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WBA.parquet
#
# Processing WBD...
# ✔ WBD: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WBD.parquet
#
# Processing WCG...
# ⚠ VALIDATION: WCG | huge_daily_spike | 0.63 on 2007-10-25
# ✔ WCG: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WCG.parquet
#
# Processing WCOEQ...
# ⚠ VALIDATION: WCOEQ | huge_daily_spike | 0.93 on 2002-07-01
# ✔ WCOEQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WCOEQ.parquet
#
# Processing WDAY...
# ✔ WDAY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WDAY.parquet
#
# Processing WDC...
# ✔ WDC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WDC.parquet
#
# Processing WEC...
# ✔ WEC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WEC.parquet
#
# Processing WELL...
# ✔ WELL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WELL.parquet
#
# Processing WEN...
# ✔ WEN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WEN.parquet
#
# Processing WFC...
# ✔ WFC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WFC.parquet
#
# Processing WFC1...
# ✔ WFC1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WFC1.parquet
#
# Processing WFM...
# ✔ WFM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WFM.parquet
#
# Processing WFTIQ...
# ⚠ VALIDATION: WFTIQ | huge_daily_spike | 0.85 on 2019-05-14
# ✔ WFTIQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WFTIQ.parquet
#
# Processing WGL...
# ✔ WGL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WGL.parquet
#
# Processing WHR...
# ✔ WHR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WHR.parquet
#
# Processing WINMQ...
# ⚠ VALIDATION: WINMQ | huge_daily_spike | 0.61 on 2019-02-19
# ✔ WINMQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WINMQ.parquet
#
# Processing WLA...
# ✔ WLA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WLA.parquet
#
# Processing WLL1...
# ✔ WLL1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WLL1.parquet
#
# Processing WLP1...
# ✔ WLP1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WLP1.parquet
#
# Processing WM...
# ✔ WM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WM.parquet
#
# Processing WMB...
# ⚠ VALIDATION: WMB | huge_daily_spike | 0.61 on 2002-07-22
# ✔ WMB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WMB.parquet
#
# Processing WMT...
# ✔ WMT: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WMT.parquet
#
# Processing WNDXQ...
# ⚠ VALIDATION: WNDXQ | huge_daily_spike | 0.52 on 2005-02-23
# ✔ WNDXQ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WNDXQ.parquet
#
# Processing WOR...
# ✔ WOR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WOR.parquet
#
# Processing WPX...
# ✔ WPX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WPX.parquet
#
# Processing WRB...
# ✔ WRB: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WRB.parquet
#
# Processing WRK...
# ✔ WRK: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WRK.parquet
#
# Processing WSM...
# ✔ WSM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WSM.parquet
#
# Processing WST...
# ✔ WST: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WST.parquet
#
# Processing WTW...
# ✔ WTW: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WTW.parquet
#
# Processing WU...
# ✔ WU: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WU.parquet
#
# Processing WWY...
# ✔ WWY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WWY.parquet
#
# Processing WY...
# ✔ WY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WY.parquet
#
# Processing WYE...
# ✔ WYE: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WYE.parquet
#
# Processing WYNN...
# ✔ WYNN: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\WYNN.parquet
#
# Processing X...
# ✔ X: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\X.parquet
#
# Processing XEC...
# ✔ XEC: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XEC.parquet
#
# Processing XEL...
# ✔ XEL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XEL.parquet
#
# Processing XL1...
# ⚠ VALIDATION: XL1 | huge_daily_spike | 0.54 on 2008-10-09
# ✔ XL1: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XL1.parquet
#
# Processing XLNX...
# ✔ XLNX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XLNX.parquet
#
# Processing XOM...
# ✔ XOM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XOM.parquet
#
# Processing XRAY...
# ✔ XRAY: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XRAY.parquet
#
# Processing XRX...
# ✔ XRX: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XRX.parquet
#
# Processing XTO...
# ✔ XTO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XTO.parquet
#
# Processing XYL...
# ✔ XYL: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XYL.parquet
#
# Processing XYZ...
# ✔ XYZ: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\XYZ.parquet
#
# Processing YHOO...
# ✔ YHOO: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\YHOO.parquet
#
# Processing YNR...
# ✔ YNR: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\YNR.parquet
#
# Processing YUM...
# ✔ YUM: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\YUM.parquet
#
# Processing ZBH...
# ✔ ZBH: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ZBH.parquet
#
# Processing ZBRA...
# ✔ ZBRA: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ZBRA.parquet
#
# Processing ZION...
# ✔ ZION: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ZION.parquet
#
# Processing ZTS...
# ✔ ZTS: saved jump filter → ./6-90Day_jump_filter_adjusted_all_prices\ZTS.parquet
#
#
# ====================================================
#  90-DAY JUMP FILTER VALIDATION SUMMARY
# ====================================================
#     ticker             issue              detail
# 0    AAMRQ  huge_daily_spike  0.84 on 2011-11-29
# 1      AAP  huge_daily_spike  0.57 on 2025-05-22
# 2     AAPL  huge_daily_spike  0.52 on 2000-09-29
# 3    ABKFQ  huge_daily_spike  0.52 on 2008-01-17
# 4    ACKHQ  huge_daily_spike  0.63 on 2002-11-14
# ..     ...               ...                 ...
# 160  WFTIQ  huge_daily_spike  0.85 on 2019-05-14
# 161  WINMQ  huge_daily_spike  0.61 on 2019-02-19
# 162    WMB  huge_daily_spike  0.61 on 2002-07-22
# 163  WNDXQ  huge_daily_spike  0.52 on 2005-02-23
# 164    XL1  huge_daily_spike  0.54 on 2008-10-09
#
# [165 rows x 3 columns]
#
# Validation log saved to:
# ./system_verification/6-90Day_jump_filter_adjusted_all_prices\jump90_validation-20251231-084020.csv
# ====================================================

# %%
df_abbv = pd.read_parquet("6-90Day_jump_filter_adjusted_all_prices/ABBV.parquet")

# Basic overview
print(f"Rows: {len(df_abbv)}, Columns: {len(df_abbv.columns)}")
print(f"\nColumn names: {list(df_abbv.columns)}")
print(f"\nData types:\n{df_abbv.dtypes}")
print(f"\nFirst few rows:\n{df_abbv.head()}")
print(f"\nLast few rows:\n{df_abbv.tail()}")
print(f"\nBasic statistics:\n{df_abbv[['close_adj', 'pct_change', 'abs_rollmax_90']].describe()}")
print(f"\nDate range: {df_abbv['date'].min()} to {df_abbv['date'].max()}")
print(f"\nno_big_jump_90 value counts:\n{df_abbv['no_big_jump_90'].value_counts()}")
# Out:
# Rows: 3269, Columns: 19
#
# Column names: ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'closeadj', 'closeunadj', 'lastupdated', 'adj_factor', 'open_adj', 'high_adj', 'low_adj', 'close_adj', 'pct_change', 'abs_pct', 'abs_rollmax_90', 'no_big_jump_90']
#
# Data types:
# ticker                    object
# date              datetime64[ns]
# open                     float64
# high                     float64
# low                      float64
# close                    float64
# volume                   float64
# closeadj                 float64
# closeunadj               float64
# lastupdated       datetime64[ms]
# adj_factor               float64
# open_adj                 float64
# high_adj                 float64
# low_adj                  float64
# close_adj                float64
# pct_change               float64
# abs_pct                  float64
# abs_rollmax_90           float64
# no_big_jump_90              bool
# dtype: object
#
# First few rows:
#   ticker       date   open   high    low   close      volume  closeadj  \
# 0   ABBV 2013-01-02  34.92  35.40  34.10  35.120  13768000.0    20.865
# 1   ABBV 2013-01-03  35.00  35.00  34.16  34.830  16739000.0    20.692
# 2   ABBV 2013-01-04  34.62  34.89  34.25  34.391  21372000.0    20.431
# 3   ABBV 2013-01-07  34.15  35.45  34.15  34.460  17897000.0    20.473
# 4   ABBV 2013-01-08  34.29  34.64  33.36  33.710  17863000.0    20.027
#
#    closeunadj lastupdated  adj_factor   open_adj   high_adj    low_adj  \
# 0      35.120  2025-10-21    0.594106  20.746179  21.031350  20.259012
# 1      34.830  2025-10-21    0.594086  20.792995  20.792995  20.293963
# 2      34.391  2025-10-21    0.594080  20.567044  20.727446  20.347235
# 3      34.460  2025-10-21    0.594109  20.288826  21.061168  20.288826
# 4      33.710  2025-10-21    0.594097  20.371576  20.579510  19.819066
#
#    close_adj  pct_change   abs_pct  abs_rollmax_90  no_big_jump_90
# 0     20.865         NaN       NaN             NaN           False
# 1     20.692   -0.008291  0.008291             NaN           False
# 2     20.431   -0.012614  0.012614             NaN           False
# 3     20.473    0.002056  0.002056             NaN           False
# 4     20.027   -0.021785  0.021785             NaN           False
#
# Last few rows:
#      ticker       date    open     high     low   close     volume  closeadj  \
# 3264   ABBV 2025-12-23  228.22  230.790  227.91  228.79  2117000.0    228.79
# 3265   ABBV 2025-12-24  229.46  230.800  228.98  229.89  1745000.0    229.89
# 3266   ABBV 2025-12-26  229.82  230.610  228.68  229.98  1594000.0    229.98
# 3267   ABBV 2025-12-29  230.15  232.020  229.74  230.84  3803000.0    230.84
# 3268   ABBV 2025-12-30  230.77  231.205  228.62  229.74  1790000.0    229.74
#
#       closeunadj lastupdated  adj_factor  open_adj  high_adj  low_adj  \
# 3264      228.79  2025-12-23         1.0    228.22   230.790   227.91
# 3265      229.89  2025-12-24         1.0    229.46   230.800   228.98
# 3266      229.98  2025-12-27         1.0    229.82   230.610   228.68
# 3267      230.84  2025-12-29         1.0    230.15   232.020   229.74
# 3268      229.74  2025-12-30         1.0    230.77   231.205   228.62
#
#       close_adj  pct_change   abs_pct  abs_rollmax_90  no_big_jump_90
# 3264     228.79    0.003861  0.003861        0.055452            True
# 3265     229.89    0.004808  0.004808        0.055452            True
# 3266     229.98    0.000391  0.000391        0.055452            True
# 3267     230.84    0.003739  0.003739        0.055452            True
# 3268     229.74   -0.004765  0.004765        0.055452            True
#
# Basic statistics:
#          close_adj   pct_change  abs_rollmax_90
# count  3269.000000  3268.000000     3179.000000
# mean     86.848822     0.000873        0.065504
# std      53.997010     0.016579        0.032006
# min      20.027000    -0.162524        0.022146
# 25%      42.165000    -0.006956        0.045851
# 50%      68.414000     0.001251        0.059626
# 75%     130.872000     0.009148        0.072806
# max     242.621000     0.137672        0.162524
#
# Date range: 2013-01-02 00:00:00 to 2025-12-30 00:00:00
#
# no_big_jump_90 value counts:
# no_big_jump_90
# True     3089
# False     180
# Name: count, dtype: int64
